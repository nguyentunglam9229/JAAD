# %%
# !nvidia-smi
# Out:
# Thu Jan 21 17:41:43 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

# %% [markdown]
# # Data preparation

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/data')

# %%
# %run data_prepare_new.ipynb
# Out:
# Cloning into 'JAAD'...
# remote: Enumerating objects: 355, done.
# remote: Counting objects: 100% (355/355), done.
# remote: Compressing objects: 100% (322/322), done.
# remote: Total 5786 (delta 326), reused 39 (delta 33), pack-reused 5431
# Receiving objects: 100% (5786/5786), 39.50 MiB | 7.58 MiB/s, done.
# Resolving deltas: 100% (5145/5145), done.
# Downloading...
# From: https://drive.google.com/uc?id=1ZwVzmXYlvaD9ifqTU6TKfKQSGkLNauLQ
# To: /content/videos.rar
# 1.07GB [00:06, 168MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1d9hAOhpLO9Cm59szoG4F7agT05L_c5ky
# To: /content/jaad_database_resized.pkl
# 65.0MB [00:00, 207MB/s]
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from videos.rar
#
# Creating    JAAD/videos                                               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    JAAD/videos/video_0001                                    OK
# Creating    JAAD/videos/video_0002                                    OK
# Creating    JAAD/videos/video_0003                                    OK
# Creating    JAAD/videos/video_0004                                    OK
# Creating    JAAD/videos/video_0005                                    OK
# Creating    JAAD/videos/video_0006                                    OK
# Creating    JAAD/videos/video_0007                                    OK
# Creating    JAAD/videos/video_0008                                    OK
# Creating    JAAD/videos/video_0009                                    OK
# Creating    JAAD/videos/video_0010                                    OK
# Creating    JAAD/videos/video_0011                                    OK
# Creating    JAAD/videos/video_0012                                    OK
# Creating    JAAD/videos/video_0013                                    OK
# Creating    JAAD/videos/video_0014                                    OK
# Creating    JAAD/videos/video_0015                                    OK
# Creating    JAAD/videos/video_0016                                    OK
# Creating    JAAD/videos/video_0017                                    OK
# Creating    JAAD/videos/video_0018                                    OK
# Creating    JAAD/videos/video_0019                                    OK
# Creating    JAAD/videos/video_0020                                    OK
# Creating    JAAD/videos/video_0021                                    OK
# Creating    JAAD/videos/video_0022                                    OK
# Creating    JAAD/videos/video_0023                                    OK
# Creating    JAAD/videos/video_0024                                    OK
# Creating    JAAD/videos/video_0025                                    OK
# Creating    JAAD/videos/video_0026                                    OK
# Creating    JAAD/videos/video_0027                                    OK
# Creating    JAAD/videos/video_0028                                    OK
# Creating    JAAD/videos/video_0029                                    OK
# Creating    JAAD/videos/video_0030                                    OK
# Creating    JAAD/videos/video_0031                                    OK
# Creating    JAAD/videos/video_0032                                    OK
# Creating    JAAD/videos/video_0033                                    OK
# Creating    JAAD/videos/video_0034                                    OK
# Creating    JAAD/videos/video_0035                                    OK
# Creating    JAAD/videos/video_0036                                    OK
# Creating    JAAD/videos/video_0037                                    OK
# Creating    JAAD/videos/video_0038                                    OK
# Creating    JAAD/videos/video_0039                                    OK
# Creating    JAAD/videos/video_0040                                    OK
# Creating    JAAD/videos/video_0041                                    OK
# Creating    JAAD/videos/video_0042                                    OK
# Creating    JAAD/videos/video_0043                                    OK
# Creating    JAAD/videos/video_0044                                    OK
# Creating    JAAD/videos/video_0045                                    OK
# Creating    JAAD/videos/video_0046                                    OK
# Creating    JAAD/videos/video_0047                                    OK
# Creating    JAAD/videos/video_0048                                    OK
# Creating    JAAD/videos/video_0049                                    OK
# Creating    JAAD/videos/video_0050                                    OK
# Creating    JAAD/videos/video_0051                                    OK
# Creating    JAAD/videos/video_0052                                    OK
# Creating    JAAD/videos/video_0053                                    OK
# Creating    JAAD/videos/video_0054                                    OK
# Creating    JAAD/videos/video_0055                                    OK
# Creating    JAAD/videos/video_0056                                    OK
# Creating    JAAD/videos/video_0057                                    OK
# Creating    JAAD/videos/video_0058                                    OK
# Creating    JAAD/videos/video_0059                                    OK
# Creating    JAAD/videos/video_0060                                    OK
# Creating    JAAD/videos/video_0061                                    OK
# Creating    JAAD/videos/video_0062                                    OK
# Creating    JAAD/videos/video_0063                                    OK
# Creating    JAAD/videos/video_0064                                    OK
# Creating    JAAD/videos/video_0065                                    OK
# Creating    JAAD/videos/video_0066                                    OK
# Creating    JAAD/videos/video_0067                                    OK
# Creating    JAAD/videos/video_0068                                    OK
# Creating    JAAD/videos/video_0069                                    OK
# Creating    JAAD/videos/video_0070                                    OK
# Creating    JAAD/videos/video_0071                                    OK
# Creating    JAAD/videos/video_0072                                    OK
# Creating    JAAD/videos/video_0073                                    OK
# Creating    JAAD/videos/video_0074                                    OK
# Creating    JAAD/videos/video_0075                                    OK
# Creating    JAAD/videos/video_0076                                    OK
# Creating    JAAD/videos/video_0077                                    OK
# Creating    JAAD/videos/video_0078                                    OK
# Creating    JAAD/videos/video_0079                                    OK
# Creating    JAAD/videos/video_0080                                    OK
# Creating    JAAD/videos/video_0081                                    OK
# Creating    JAAD/videos/video_0082                                    OK
# Creating    JAAD/videos/video_0083                                    OK
# Creating    JAAD/videos/video_0084                                    OK
# Creating    JAAD/videos/video_0085                                    OK
# Creating    JAAD/videos/video_0086                                    OK
# Creating    JAAD/videos/video_0087                                    OK
# Creating    JAAD/videos/video_0088                                    OK
# Creating    JAAD/videos/video_0089                                    OK
# Creating    JAAD/videos/video_0090                                    OK
# Creating    JAAD/videos/video_0091                                    OK
# Creating    JAAD/videos/video_0092                                    OK
# Creating    JAAD/videos/video_0093                                    OK
# Creating    JAAD/videos/video_0094                                    OK
# Creating    JAAD/videos/video_0095                                    OK
# Creating    JAAD/videos/video_0096                                    OK
# Creating    JAAD/videos/video_0097                                    OK
# Creating    JAAD/videos/video_0098                                    OK
# Creating    JAAD/videos/video_0099                                    OK
# Creating    JAAD/videos/video_0100                                    OK
# Creating    JAAD/videos/video_0101                                    OK
# Creating    JAAD/videos/video_0102                                    OK
# Creating    JAAD/videos/video_0103                                    OK
# Creating    JAAD/videos/video_0104                                    OK
# Creating    JAAD/videos/video_0105                                    OK
# Creating    JAAD/videos/video_0106                                    OK
# Creating    JAAD/videos/video_0107                                    OK
# Creating    JAAD/videos/video_0108                                    OK
# Creating    JAAD/videos/video_0109                                    OK
# Creating    JAAD/videos/video_0110                                    OK
# Creating    JAAD/videos/video_0111                                    OK
# Creating    JAAD/videos/video_0112                                    OK
# Creating    JAAD/videos/video_0113                                    OK
# Creating    JAAD/videos/video_0114                                    OK
# Creating    JAAD/videos/video_0115                                    OK
# Creating    JAAD/videos/video_0116                                    OK
# Creating    JAAD/videos/video_0117                                    OK
# Creating    JAAD/videos/video_0118                                    OK
# Creating    JAAD/videos/video_0119                                    OK
# Creating    JAAD/videos/video_0120                                    OK
# Creating    JAAD/videos/video_0121                                    OK
# Creating    JAAD/videos/video_0122                                    OK
# Creating    JAAD/videos/video_0123                                    OK
# Creating    JAAD/videos/video_0124                                    OK
# Creating    JAAD/videos/video_0125                                    OK
# Creating    JAAD/videos/video_0126                                    OK
# Creating    JAAD/videos/video_0127                                    OK
# Creating    JAAD/videos/video_0128                                    OK
# Creating    JAAD/videos/video_0129                                    OK
# Creating    JAAD/videos/video_0130                                    OK
# Creating    JAAD/videos/video_0131                                    OK
# Creating    JAAD/videos/video_0132                                    OK
# Creating    JAAD/videos/video_0133                                    OK
# Creating    JAAD/videos/video_0134                                    OK
# Creating    JAAD/videos/video_0135                                    OK
# Creating    JAAD/videos/video_0136                                    OK
# Creating    JAAD/videos/video_0137                                    OK
# Creating    JAAD/videos/video_0138                                    OK
# Creating    JAAD/videos/video_0139                                    OK
# Creating    JAAD/videos/video_0140                                    OK
# Creating    JAAD/videos/video_0141                                    OK
# Creating    JAAD/videos/video_0142                                    OK
# Creating    JAAD/videos/video_0143                                    OK
# Creating    JAAD/videos/video_0144                                    OK
# Creating    JAAD/videos/video_0145                                    OK
# Creating    JAAD/videos/video_0146                                    OK
# Creating    JAAD/videos/video_0147                                    OK
# Creating    JAAD/videos/video_0148                                    OK
# Creating    JAAD/videos/video_0149                                    OK
# Creating    JAAD/videos/video_0150                                    OK
# Creating    JAAD/videos/video_0151                                    OK
# Creating    JAAD/videos/video_0152                                    OK
# Creating    JAAD/videos/video_0153                                    OK
# Creating    JAAD/videos/video_0154                                    OK
# Creating    JAAD/videos/video_0155                                    OK
# Creating    JAAD/videos/video_0156                                    OK
# Creating    JAAD/videos/video_0157                                    OK
# Creating    JAAD/videos/video_0158                                    OK
# Creating    JAAD/videos/video_0159                                    OK
# Creating    JAAD/videos/video_0160                                    OK
# Creating    JAAD/videos/video_0161                                    OK
# Creating    JAAD/videos/video_0162                                    OK
# Creating    JAAD/videos/video_0163                                    OK
# Creating    JAAD/videos/video_0164                                    OK
# Creating    JAAD/videos/video_0165                                    OK
# Creating    JAAD/videos/video_0166                                    OK
# Creating    JAAD/videos/video_0167                                    OK
# Creating    JAAD/videos/video_0168                                    OK
# Creating    JAAD/videos/video_0169                                    OK
# Creating    JAAD/videos/video_0170                                    OK
# Creating    JAAD/videos/video_0171                                    OK
# Creating    JAAD/videos/video_0172                                    OK
# Creating    JAAD/videos/video_0173                                    OK
# Creating    JAAD/videos/video_0174                                    OK
# Creating    JAAD/videos/video_0175                                    OK
# Creating    JAAD/videos/video_0176                                    OK
# Creating    JAAD/videos/video_0177                                    OK
# Creating    JAAD/videos/video_0178                                    OK
# Creating    JAAD/videos/video_0179                                    OK
# Creating    JAAD/videos/video_0180                                    OK
# Creating    JAAD/videos/video_0181                                    OK
# Creating    JAAD/videos/video_0182                                    OK
# Creating    JAAD/videos/video_0183                                    OK
# Creating    JAAD/videos/video_0184                                    OK
# Creating    JAAD/videos/video_0185                                    OK
# Creating    JAAD/videos/video_0186                                    OK
# Creating    JAAD/videos/video_0187                                    OK
# Creating    JAAD/videos/video_0188                                    OK
# Creating    JAAD/videos/video_0189                                    OK
# Creating    JAAD/videos/video_0190                                    OK
# Creating    JAAD/videos/video_0191                                    OK
# Creating    JAAD/videos/video_0192                                    OK
# Creating    JAAD/videos/video_0193                                    OK
# Creating    JAAD/videos/video_0194                                    OK
# Creating    JAAD/videos/video_0195                                    OK
# Creating    JAAD/videos/video_0196                                    OK
# Creating    JAAD/videos/video_0197                                    OK
# Creating    JAAD/videos/video_0198                                    OK
# Creating    JAAD/videos/video_0199                                    OK
# Creating    JAAD/videos/video_0200                                    OK
# Creating    JAAD/videos/video_0201                                    OK
# Creating    JAAD/videos/video_0202                                    OK
# Creating    JAAD/videos/video_0203                                    OK
# Creating    JAAD/videos/video_0204                                    OK
# Creating    JAAD/videos/video_0205                                    OK
# Creating    JAAD/videos/video_0206                                    OK
# Creating    JAAD/videos/video_0207                                    OK
# Creating    JAAD/videos/video_0208                                    OK
# Creating    JAAD/videos/video_0209                                    OK
# Creating    JAAD/videos/video_0210                                    OK
# Creating    JAAD/videos/video_0211                                    OK
# Creating    JAAD/videos/video_0212                                    OK
# Creating    JAAD/videos/video_0213                                    OK
# Creating    JAAD/videos/video_0214                                    OK
# Creating    JAAD/videos/video_0215                                    OK
# Creating    JAAD/videos/video_0216                                    OK
# Creating    JAAD/videos/video_0217                                    OK
# Creating    JAAD/videos/video_0218                                    OK
# Creating    JAAD/videos/video_0219                                    OK
# Creating    JAAD/videos/video_0220                                    OK
# Creating    JAAD/videos/video_0221                                    OK
# Creating    JAAD/videos/video_0222                                    OK
# Creating    JAAD/videos/video_0223                                    OK
# Creating    JAAD/videos/video_0224                                    OK
# Creating    JAAD/videos/video_0225                                    OK
# Creating    JAAD/videos/video_0226                                    OK
# Creating    JAAD/videos/video_0227                                    OK
# Creating    JAAD/videos/video_0228                                    OK
# Creating    JAAD/videos/video_0229                                    OK
# Creating    JAAD/videos/video_0230                                    OK
# Creating    JAAD/videos/video_0231                                    OK
# Creating    JAAD/videos/video_0232                                    OK
# Creating    JAAD/videos/video_0233                                    OK
# Creating    JAAD/videos/video_0234                                    OK
# Creating    JAAD/videos/video_0235                                    OK
# Creating    JAAD/videos/video_0236                                    OK
# Creating    JAAD/videos/video_0237                                    OK
# Creating    JAAD/videos/video_0238                                    OK
# Creating    JAAD/videos/video_0239                                    OK
# Creating    JAAD/videos/video_0240                                    OK
# Creating    JAAD/videos/video_0241                                    OK
# Creating    JAAD/videos/video_0242                                    OK
# Creating    JAAD/videos/video_0243                                    OK
# Creating    JAAD/videos/video_0244                                    OK
# Creating    JAAD/videos/video_0245                                    OK
# Creating    JAAD/videos/video_0246                                    OK
# Creating    JAAD/videos/video_0247                                    OK
# Creating    JAAD/videos/video_0248                                    OK
# Creating    JAAD/videos/video_0249                                    OK
# Creating    JAAD/videos/video_0250                                    OK
# Creating    JAAD/videos/video_0251                                    OK
# Creating    JAAD/videos/video_0252                                    OK
# Creating    JAAD/videos/video_0253                                    OK
# Creating    JAAD/videos/video_0254                                    OK
# Creating    JAAD/videos/video_0255                                    OK
# Creating    JAAD/videos/video_0256                                    OK
# Creating    JAAD/videos/video_0257                                    OK
# Creating    JAAD/videos/video_0258                                    OK
# Creating    JAAD/videos/video_0259                                    OK
# Creating    JAAD/videos/video_0260                                    OK
# Creating    JAAD/videos/video_0261                                    OK
# Creating    JAAD/videos/video_0262                                    OK
# Creating    JAAD/videos/video_0263                                    OK
# Creating    JAAD/videos/video_0264                                    OK
# Creating    JAAD/videos/video_0265                                    OK
# Creating    JAAD/videos/video_0266                                    OK
# Creating    JAAD/videos/video_0267                                    OK
# Creating    JAAD/videos/video_0268                                    OK
# Creating    JAAD/videos/video_0269                                    OK
# Creating    JAAD/videos/video_0270                                    OK
# Creating    JAAD/videos/video_0271                                    OK
# Creating    JAAD/videos/video_0272                                    OK
# Creating    JAAD/videos/video_0273                                    OK
# Creating    JAAD/videos/video_0274                                    OK
# Creating    JAAD/videos/video_0275                                    OK
# Creating    JAAD/videos/video_0276                                    OK
# Creating    JAAD/videos/video_0277                                    OK
# Creating    JAAD/videos/video_0278                                    OK
# Creating    JAAD/videos/video_0279                                    OK
# Creating    JAAD/videos/video_0280                                    OK
# Creating    JAAD/videos/video_0281                                    OK
# Creating    JAAD/videos/video_0282                                    OK
# Creating    JAAD/videos/video_0283                                    OK
# Creating    JAAD/videos/video_0284                                    OK
# Creating    JAAD/videos/video_0285                                    OK
# Creating    JAAD/videos/video_0286                                    OK
# Creating    JAAD/videos/video_0287                                    OK
# Creating    JAAD/videos/video_0288                                    OK
# Creating    JAAD/videos/video_0289                                    OK
# Creating    JAAD/videos/video_0290                                    OK
# Creating    JAAD/videos/video_0291                                    OK
# Creating    JAAD/videos/video_0292                                    OK
# Creating    JAAD/videos/video_0293                                    OK
# Creating    JAAD/videos/video_0294                                    OK
# Creating    JAAD/videos/video_0295                                    OK
# Creating    JAAD/videos/video_0296                                    OK
# Creating    JAAD/videos/video_0297                                    OK
# Creating    JAAD/videos/video_0298                                    OK
# Creating    JAAD/videos/video_0299                                    OK
# Creating    JAAD/videos/video_0300                                    OK
# Creating    JAAD/videos/video_0301                                    OK
# Creating    JAAD/videos/video_0302                                    OK
# Creating    JAAD/videos/video_0303                                    OK
# Creating    JAAD/videos/video_0304                                    OK
# Creating    JAAD/videos/video_0305                                    OK
# Creating    JAAD/videos/video_0306                                    OK
# Creating    JAAD/videos/video_0307                                    OK
# Creating    JAAD/videos/video_0308                                    OK
# Creating    JAAD/videos/video_0309                                    OK
# Creating    JAAD/videos/video_0310                                    OK
# Creating    JAAD/videos/video_0311                                    OK
# Creating    JAAD/videos/video_0312                                    OK
# Creating    JAAD/videos/video_0313                                    OK
# Creating    JAAD/videos/video_0314                                    OK
# Creating    JAAD/videos/video_0315                                    OK
# Creating    JAAD/videos/video_0316                                    OK
# Creating    JAAD/videos/video_0317                                    OK
# Creating    JAAD/videos/video_0318                                    OK
# Creating    JAAD/videos/video_0319                                    OK
# Creating    JAAD/videos/video_0320                                    OK
# Creating    JAAD/videos/video_0321                                    OK
# Creating    JAAD/videos/video_0322                                    OK
# Creating    JAAD/videos/video_0323                                    OK
# Creating    JAAD/videos/video_0324                                    OK
# Creating    JAAD/videos/video_0325                                    OK
# Creating    JAAD/videos/video_0326                                    OK
# Creating    JAAD/videos/video_0327                                    OK
# Creating    JAAD/videos/video_0328                                    OK
# Creating    JAAD/videos/video_0329                                    OK
# Creating    JAAD/videos/video_0330                                    OK
# Creating    JAAD/videos/video_0331                                    OK
# Creating    JAAD/videos/video_0332                                    OK
# Creating    JAAD/videos/video_0333                                    OK
# Creating    JAAD/videos/video_0334                                    OK
# Creating    JAAD/videos/video_0335                                    OK
# Creating    JAAD/videos/video_0336                                    OK
# Creating    JAAD/videos/video_0337                                    OK
# Creating    JAAD/videos/video_0338                                    OK
# Creating    JAAD/videos/video_0339                                    OK
# Creating    JAAD/videos/video_0340                                    OK
# Creating    JAAD/videos/video_0341                                    OK
# Creating    JAAD/videos/video_0342                                    OK
# Creating    JAAD/videos/video_0343                                    OK
# Creating    JAAD/videos/video_0344                                    OK
# Creating    JAAD/videos/video_0345                                    OK
# Creating    JAAD/videos/video_0346                                    OK
# All OK
# /content/JAAD
# video_0001
# video_0002
# video_0003
# video_0004
# video_0005
# video_0006
# video_0007
# video_0008
# video_0009
# video_0010
# video_0011
# video_0012
# video_0013
# video_0014
# video_0015
# video_0016
# video_0017
# video_0018
# video_0019
# video_0020
# video_0021
# video_0022
# video_0023
# video_0024
# video_0025
# video_0026
# video_0027
# video_0028
# video_0029
# video_0030
# video_0031
# video_0032
# video_0033
# video_0034
# video_0035
# video_0036
# video_0037
# video_0038
# video_0039
# video_0040
# video_0041
# video_0042
# video_0043
# video_0044
# video_0045
# video_0046
# video_0047
# video_0048
# video_0049
# video_0050
# video_0051
# video_0052
# video_0053
# video_0054
# video_0055
# video_0056
# video_0057
# video_0058
# video_0059
# video_0060
# video_0061
# video_0062
# video_0063
# video_0064
# video_0065
# video_0066
# video_0067
# video_0068
# video_0069
# video_0070
# video_0071
# video_0072
# video_0073
# video_0074
# video_0075
# video_0076
# video_0077
# video_0078
# video_0079
# video_0080
# video_0081
# video_0082
# video_0083
# video_0084
# video_0085
# video_0086
# video_0087
# video_0088
# video_0089
# video_0090
# video_0091
# video_0092
# video_0093
# video_0094
# video_0095
# video_0096
# video_0097
# video_0098
# video_0099
# video_0100
# video_0101
# video_0102
# video_0103
# video_0104
# video_0105
# video_0106
# video_0107
# video_0108
# video_0109
# video_0110
# video_0111
# video_0112
# video_0113
# video_0114
# video_0115
# video_0116
# video_0117
# video_0118
# video_0119
# video_0120
# video_0121
# video_0122
# video_0123
# video_0124
# video_0125
# video_0126
# video_0127
# video_0128
# video_0129
# video_0130
# video_0131
# video_0132
# video_0133
# video_0134
# video_0135
# video_0136
# video_0137
# video_0138
# video_0139
# video_0140
# video_0141
# video_0142
# video_0143
# video_0144
# video_0145
# video_0146
# video_0147
# video_0148
# video_0149
# video_0150
# video_0151
# video_0152
# video_0153
# video_0154
# video_0155
# video_0156
# video_0157
# video_0158
# video_0159
# video_0160
# video_0161
# video_0162
# video_0163
# video_0164
# video_0165
# video_0166
# video_0167
# video_0168
# video_0169
# video_0170
# video_0171
# video_0172
# video_0173
# video_0174
# video_0175
# video_0176
# video_0177
# video_0178
# video_0179
# video_0180
# video_0181
# video_0182
# video_0183
# video_0184
# video_0185
# video_0186
# video_0187
# video_0188
# video_0189
# video_0190
# video_0191
# video_0192
# video_0193
# video_0194
# video_0195
# video_0196
# video_0197
# video_0198
# video_0199
# video_0200
# video_0201
# video_0202
# video_0203
# video_0204
# video_0205
# video_0206
# video_0207
# video_0208
# video_0209
# video_0210
# video_0211
# video_0212
# video_0213
# video_0214
# video_0215
# video_0216
# video_0217
# video_0218
# video_0219
# video_0220
# video_0221
# video_0222
# video_0223
# video_0224
# video_0225
# video_0226
# video_0227
# video_0228
# video_0229
# video_0230
# video_0231
# video_0232
# video_0233
# video_0234
# video_0235
# video_0236
# video_0237
# video_0238
# video_0239
# video_0240
# video_0241
# video_0242
# video_0243
# video_0244
# video_0245
# video_0246
# video_0247
# video_0248
# video_0249
# video_0250
# video_0251
# video_0252
# video_0253
# video_0254
# video_0255
# video_0256
# video_0257
# video_0258
# video_0259
# video_0260
# video_0261
# video_0262
# video_0263
# video_0264
# video_0265
# video_0266
# video_0267
# video_0268
# video_0269
# video_0270
# video_0271
# video_0272
# video_0273
# video_0274
# video_0275
# video_0276
# video_0277
# video_0278
# video_0279
# video_0280
# video_0281
# video_0282
# video_0283
# video_0284
# video_0285
# video_0286
# video_0287
# video_0288
# video_0289
# video_0290
# video_0291
# video_0292
# video_0293
# video_0294
# video_0295
# video_0296
# video_0297
# video_0298
# video_0299
# video_0300
# video_0301
# video_0302
# video_0303
# video_0304
# video_0305
# video_0306
# video_0307
# video_0308
# video_0309
# video_0310
# video_0311
# video_0312
# video_0313
# video_0314
# video_0315
# video_0316
# video_0317
# video_0318
# video_0319
# video_0320
# video_0321
# video_0322
# video_0323
# video_0324
# video_0325
# video_0326
# video_0327
# video_0328
# video_0329
# video_0330
# video_0331
# video_0332
# video_0333
# video_0334
# video_0335
# video_0336
# video_0337
# video_0338
# video_0339
# video_0340
# video_0341
# video_0342
# video_0343
# video_0344
# video_0345
# video_0346
# video_0001
# /content/JAAD/rgb-images/video_0001
#
#
# video_0001
# /content/JAAD/rgb-images/video_0001
#
#
# video_0002
# /content/JAAD/rgb-images/video_0002
#
#
# video_0002
# /content/JAAD/rgb-images/video_0002
#
#
# video_0003
# /content/JAAD/rgb-images/video_0003
#
#
# video_0003
# /content/JAAD/rgb-images/video_0003
#
#
# video_0004
# /content/JAAD/rgb-images/video_0004
#
#
# video_0004
# /content/JAAD/rgb-images/video_0004
#
#
# video_0005
# /content/JAAD/rgb-images/video_0005
#
#
# video_0005
# /content/JAAD/rgb-images/video_0005
#
#
# video_0006
# /content/JAAD/rgb-images/video_0006
#
#
# video_0006
# /content/JAAD/rgb-images/video_0006
#
#
# video_0007
# /content/JAAD/rgb-images/video_0007
#
#
# video_0007
# /content/JAAD/rgb-images/video_0007
#
#
# video_0008
# /content/JAAD/rgb-images/video_0008
#
#
# video_0008
# /content/JAAD/rgb-images/video_0008
#
#
# video_0009
# /content/JAAD/rgb-images/video_0009
#
#
# video_0009
# /content/JAAD/rgb-images/video_0009
#
#
# video_0010
# /content/JAAD/rgb-images/video_0010
#
#
# video_0010
# /content/JAAD/rgb-images/video_0010
#
#
# video_0011
# /content/JAAD/rgb-images/video_0011
#
#
# video_0011
# /content/JAAD/rgb-images/video_0011
#
#
# video_0012
# /content/JAAD/rgb-images/video_0012
#
#
# video_0012
# /content/JAAD/rgb-images/video_0012
#
#
# video_0013
# /content/JAAD/rgb-images/video_0013
#
#
# video_0013
# /content/JAAD/rgb-images/video_0013
#
#
# video_0014
# /content/JAAD/rgb-images/video_0014
#
#
# video_0014
# /content/JAAD/rgb-images/video_0014
#
#
# video_0015
# /content/JAAD/rgb-images/video_0015
#
#
# video_0015
# /content/JAAD/rgb-images/video_0015
#
#
# video_0016
# /content/JAAD/rgb-images/video_0016
#
#
# video_0016
# /content/JAAD/rgb-images/video_0016
#
#
# video_0017
# /content/JAAD/rgb-images/video_0017
#
#
# video_0017
# /content/JAAD/rgb-images/video_0017
#
#
# video_0018
# /content/JAAD/rgb-images/video_0018
#
#
# video_0018
# /content/JAAD/rgb-images/video_0018
#
#
# video_0019
# /content/JAAD/rgb-images/video_0019
#
#
# video_0019
# /content/JAAD/rgb-images/video_0019
#
#
# video_0020
# /content/JAAD/rgb-images/video_0020
#
#
# video_0020
# /content/JAAD/rgb-images/video_0020
#
#
# video_0021
# /content/JAAD/rgb-images/video_0021
#
#
# video_0021
# /content/JAAD/rgb-images/video_0021
#
#
# video_0022
# /content/JAAD/rgb-images/video_0022
#
#
# video_0022
# /content/JAAD/rgb-images/video_0022
#
#
# video_0023
# /content/JAAD/rgb-images/video_0023
#
#
# video_0023
# /content/JAAD/rgb-images/video_0023
#
#
# video_0024
# /content/JAAD/rgb-images/video_0024
#
#
# video_0024
# /content/JAAD/rgb-images/video_0024
#
#
# video_0025
# /content/JAAD/rgb-images/video_0025
#
#
# video_0025
# /content/JAAD/rgb-images/video_0025
#
#
# video_0026
# /content/JAAD/rgb-images/video_0026
#
#
# video_0026
# /content/JAAD/rgb-images/video_0026
#
#
# video_0027
# /content/JAAD/rgb-images/video_0027
#
#
# video_0027
# /content/JAAD/rgb-images/video_0027
#
#
# video_0028
# /content/JAAD/rgb-images/video_0028
#
#
# video_0028
# /content/JAAD/rgb-images/video_0028
#
#
# video_0029
# /content/JAAD/rgb-images/video_0029
#
#
# video_0029
# /content/JAAD/rgb-images/video_0029
#
#
# video_0030
# /content/JAAD/rgb-images/video_0030
#
#
# video_0030
# /content/JAAD/rgb-images/video_0030
#
#
# video_0031
# /content/JAAD/rgb-images/video_0031
#
#
# video_0031
# /content/JAAD/rgb-images/video_0031
#
#
# video_0032
# /content/JAAD/rgb-images/video_0032
#
#
# video_0032
# /content/JAAD/rgb-images/video_0032
#
#
# video_0033
# /content/JAAD/rgb-images/video_0033
#
#
# video_0033
# /content/JAAD/rgb-images/video_0033
#
#
# video_0034
# /content/JAAD/rgb-images/video_0034
#
#
# video_0034
# /content/JAAD/rgb-images/video_0034
#
#
# video_0035
# /content/JAAD/rgb-images/video_0035
#
#
# video_0035
# /content/JAAD/rgb-images/video_0035
#
#
# video_0036
# /content/JAAD/rgb-images/video_0036
#
#
# video_0036
# /content/JAAD/rgb-images/video_0036
#
#
# video_0037
# /content/JAAD/rgb-images/video_0037
#
#
# video_0037
# /content/JAAD/rgb-images/video_0037
#
#
# video_0038
# /content/JAAD/rgb-images/video_0038
#
#
# video_0038
# /content/JAAD/rgb-images/video_0038
#
#
# video_0039
# /content/JAAD/rgb-images/video_0039
#
#
# video_0039
# /content/JAAD/rgb-images/video_0039
#
#
# video_0040
# /content/JAAD/rgb-images/video_0040
#
#
# video_0040
# /content/JAAD/rgb-images/video_0040
#
#
# video_0041
# /content/JAAD/rgb-images/video_0041
#
#
# video_0041
# /content/JAAD/rgb-images/video_0041
#
#
# video_0042
# /content/JAAD/rgb-images/video_0042
#
#
# video_0042
# /content/JAAD/rgb-images/video_0042
#
#
# video_0043
# /content/JAAD/rgb-images/video_0043
#
#
# video_0043
# /content/JAAD/rgb-images/video_0043
#
#
# video_0044
# /content/JAAD/rgb-images/video_0044
#
#
# video_0044
# /content/JAAD/rgb-images/video_0044
#
#
# video_0045
# /content/JAAD/rgb-images/video_0045
#
#
# video_0045
# /content/JAAD/rgb-images/video_0045
#
#
# video_0046
# /content/JAAD/rgb-images/video_0046
#
#
# video_0046
# /content/JAAD/rgb-images/video_0046
#
#
# video_0047
# /content/JAAD/rgb-images/video_0047
#
#
# video_0047
# /content/JAAD/rgb-images/video_0047
#
#
# video_0048
# /content/JAAD/rgb-images/video_0048
#
#
# video_0048
# /content/JAAD/rgb-images/video_0048
#
#
# video_0049
# /content/JAAD/rgb-images/video_0049
#
#
# video_0049
# /content/JAAD/rgb-images/video_0049
#
#
# video_0050
# /content/JAAD/rgb-images/video_0050
#
#
# video_0050
# /content/JAAD/rgb-images/video_0050
#
#
# video_0051
# /content/JAAD/rgb-images/video_0051
#
#
# video_0051
# /content/JAAD/rgb-images/video_0051
#
#
# video_0052
# /content/JAAD/rgb-images/video_0052
#
#
# video_0052
# /content/JAAD/rgb-images/video_0052
#
#
# video_0053
# /content/JAAD/rgb-images/video_0053
#
#
# video_0053
# /content/JAAD/rgb-images/video_0053
#
#
# video_0054
# /content/JAAD/rgb-images/video_0054
#
#
# video_0054
# /content/JAAD/rgb-images/video_0054
#
#
# video_0055
# /content/JAAD/rgb-images/video_0055
#
#
# video_0055
# /content/JAAD/rgb-images/video_0055
#
#
# video_0056
# /content/JAAD/rgb-images/video_0056
#
#
# video_0056
# /content/JAAD/rgb-images/video_0056
#
#
# video_0057
# /content/JAAD/rgb-images/video_0057
#
#
# video_0057
# /content/JAAD/rgb-images/video_0057
#
#
# video_0058
# /content/JAAD/rgb-images/video_0058
#
#
# video_0058
# /content/JAAD/rgb-images/video_0058
#
#
# video_0059
# /content/JAAD/rgb-images/video_0059
#
#
# video_0059
# /content/JAAD/rgb-images/video_0059
#
#
# video_0060
# /content/JAAD/rgb-images/video_0060
#
#
# video_0060
# /content/JAAD/rgb-images/video_0060
#
#
# video_0061
# /content/JAAD/rgb-images/video_0061
#
#
# video_0061
# /content/JAAD/rgb-images/video_0061
#
#
# video_0062
# /content/JAAD/rgb-images/video_0062
#
#
# video_0062
# /content/JAAD/rgb-images/video_0062
#
#
# video_0063
# /content/JAAD/rgb-images/video_0063
#
#
# video_0063
# /content/JAAD/rgb-images/video_0063
#
#
# video_0064
# /content/JAAD/rgb-images/video_0064
#
#
# video_0064
# /content/JAAD/rgb-images/video_0064
#
#
# video_0065
# /content/JAAD/rgb-images/video_0065
#
#
# video_0065
# /content/JAAD/rgb-images/video_0065
#
#
# video_0066
# /content/JAAD/rgb-images/video_0066
#
#
# video_0066
# /content/JAAD/rgb-images/video_0066
#
#
# video_0067
# /content/JAAD/rgb-images/video_0067
#
#
# video_0067
# /content/JAAD/rgb-images/video_0067
#
#
# video_0068
# /content/JAAD/rgb-images/video_0068
#
#
# video_0068
# /content/JAAD/rgb-images/video_0068
#
#
# video_0069
# /content/JAAD/rgb-images/video_0069
#
#
# video_0069
# /content/JAAD/rgb-images/video_0069
#
#
# video_0070
# /content/JAAD/rgb-images/video_0070
#
#
# video_0070
# /content/JAAD/rgb-images/video_0070
#
#
# video_0071
# /content/JAAD/rgb-images/video_0071
#
#
# video_0071
# /content/JAAD/rgb-images/video_0071
#
#
# video_0072
# /content/JAAD/rgb-images/video_0072
#
#
# video_0072
# /content/JAAD/rgb-images/video_0072
#
#
# video_0073
# /content/JAAD/rgb-images/video_0073
#
#
# video_0073
# /content/JAAD/rgb-images/video_0073
#
#
# video_0074
# /content/JAAD/rgb-images/video_0074
#
#
# video_0074
# /content/JAAD/rgb-images/video_0074
#
#
# video_0075
# /content/JAAD/rgb-images/video_0075
#
#
# video_0075
# /content/JAAD/rgb-images/video_0075
#
#
# video_0076
# /content/JAAD/rgb-images/video_0076
#
#
# video_0076
# /content/JAAD/rgb-images/video_0076
#
#
# video_0077
# /content/JAAD/rgb-images/video_0077
#
#
# video_0077
# /content/JAAD/rgb-images/video_0077
#
#
# video_0078
# /content/JAAD/rgb-images/video_0078
#
#
# video_0078
# /content/JAAD/rgb-images/video_0078
#
#
# video_0079
# /content/JAAD/rgb-images/video_0079
#
#
# video_0079
# /content/JAAD/rgb-images/video_0079
#
#
# video_0080
# /content/JAAD/rgb-images/video_0080
#
#
# video_0080
# /content/JAAD/rgb-images/video_0080
#
#
# video_0081
# /content/JAAD/rgb-images/video_0081
#
#
# video_0081
# /content/JAAD/rgb-images/video_0081
#
#
# video_0082
# /content/JAAD/rgb-images/video_0082
#
#
# video_0082
# /content/JAAD/rgb-images/video_0082
#
#
# video_0083
# /content/JAAD/rgb-images/video_0083
#
#
# video_0083
# /content/JAAD/rgb-images/video_0083
#
#
# video_0084
# /content/JAAD/rgb-images/video_0084
#
#
# video_0084
# /content/JAAD/rgb-images/video_0084
#
#
# video_0085
# /content/JAAD/rgb-images/video_0085
#
#
# video_0085
# /content/JAAD/rgb-images/video_0085
#
#
# video_0086
# /content/JAAD/rgb-images/video_0086
#
#
# video_0086
# /content/JAAD/rgb-images/video_0086
#
#
# video_0087
# /content/JAAD/rgb-images/video_0087
#
#
# video_0087
# /content/JAAD/rgb-images/video_0087
#
#
# video_0088
# /content/JAAD/rgb-images/video_0088
#
#
# video_0088
# /content/JAAD/rgb-images/video_0088
#
#
# video_0089
# /content/JAAD/rgb-images/video_0089
#
#
# video_0089
# /content/JAAD/rgb-images/video_0089
#
#
# video_0090
# /content/JAAD/rgb-images/video_0090
#
#
# video_0090
# /content/JAAD/rgb-images/video_0090
#
#
# video_0091
# /content/JAAD/rgb-images/video_0091
#
#
# video_0091
# /content/JAAD/rgb-images/video_0091
#
#
# video_0092
# /content/JAAD/rgb-images/video_0092
#
#
# video_0092
# /content/JAAD/rgb-images/video_0092
#
#
# video_0093
# /content/JAAD/rgb-images/video_0093
#
#
# video_0093
# /content/JAAD/rgb-images/video_0093
#
#
# video_0094
# /content/JAAD/rgb-images/video_0094
#
#
# video_0094
# /content/JAAD/rgb-images/video_0094
#
#
# video_0095
# /content/JAAD/rgb-images/video_0095
#
#
# video_0095
# /content/JAAD/rgb-images/video_0095
#
#
# video_0096
# /content/JAAD/rgb-images/video_0096
#
#
# video_0096
# /content/JAAD/rgb-images/video_0096
#
#
# video_0097
# /content/JAAD/rgb-images/video_0097
#
#
# video_0097
# /content/JAAD/rgb-images/video_0097
#
#
# video_0098
# /content/JAAD/rgb-images/video_0098
#
#
# video_0098
# /content/JAAD/rgb-images/video_0098
#
#
# video_0099
# /content/JAAD/rgb-images/video_0099
#
#
# video_0099
# /content/JAAD/rgb-images/video_0099
#
#
# video_0100
# /content/JAAD/rgb-images/video_0100
#
#
# video_0100
# /content/JAAD/rgb-images/video_0100
#
#
# video_0101
# /content/JAAD/rgb-images/video_0101
#
#
# video_0101
# /content/JAAD/rgb-images/video_0101
#
#
# video_0102
# /content/JAAD/rgb-images/video_0102
#
#
# video_0102
# /content/JAAD/rgb-images/video_0102
#
#
# video_0103
# /content/JAAD/rgb-images/video_0103
#
#
# video_0103
# /content/JAAD/rgb-images/video_0103
#
#
# video_0104
# /content/JAAD/rgb-images/video_0104
#
#
# video_0104
# /content/JAAD/rgb-images/video_0104
#
#
# video_0105
# /content/JAAD/rgb-images/video_0105
#
#
# video_0105
# /content/JAAD/rgb-images/video_0105
#
#
# video_0106
# /content/JAAD/rgb-images/video_0106
#
#
# video_0106
# /content/JAAD/rgb-images/video_0106
#
#
# video_0107
# /content/JAAD/rgb-images/video_0107
#
#
# video_0107
# /content/JAAD/rgb-images/video_0107
#
#
# video_0108
# /content/JAAD/rgb-images/video_0108
#
#
# video_0108
# /content/JAAD/rgb-images/video_0108
#
#
# video_0109
# /content/JAAD/rgb-images/video_0109
#
#
# video_0109
# /content/JAAD/rgb-images/video_0109
#
#
# video_0110
# /content/JAAD/rgb-images/video_0110
#
#
# video_0110
# /content/JAAD/rgb-images/video_0110
#
#
# video_0111
# /content/JAAD/rgb-images/video_0111
#
#
# video_0111
# /content/JAAD/rgb-images/video_0111
#
#
# video_0112
# /content/JAAD/rgb-images/video_0112
#
#
# video_0112
# /content/JAAD/rgb-images/video_0112
#
#
# video_0113
# /content/JAAD/rgb-images/video_0113
#
#
# video_0113
# /content/JAAD/rgb-images/video_0113
#
#
# video_0114
# /content/JAAD/rgb-images/video_0114
#
#
# video_0114
# /content/JAAD/rgb-images/video_0114
#
#
# video_0115
# /content/JAAD/rgb-images/video_0115
#
#
# video_0115
# /content/JAAD/rgb-images/video_0115
#
#
# video_0116
# /content/JAAD/rgb-images/video_0116
#
#
# video_0116
# /content/JAAD/rgb-images/video_0116
#
#
# video_0117
# /content/JAAD/rgb-images/video_0117
#
#
# video_0117
# /content/JAAD/rgb-images/video_0117
#
#
# video_0118
# /content/JAAD/rgb-images/video_0118
#
#
# video_0118
# /content/JAAD/rgb-images/video_0118
#
#
# video_0119
# /content/JAAD/rgb-images/video_0119
#
#
# video_0119
# /content/JAAD/rgb-images/video_0119
#
#
# video_0120
# /content/JAAD/rgb-images/video_0120
#
#
# video_0120
# /content/JAAD/rgb-images/video_0120
#
#
# video_0121
# /content/JAAD/rgb-images/video_0121
#
#
# video_0121
# /content/JAAD/rgb-images/video_0121
#
#
# video_0122
# /content/JAAD/rgb-images/video_0122
#
#
# video_0122
# /content/JAAD/rgb-images/video_0122
#
#
# video_0123
# /content/JAAD/rgb-images/video_0123
#
#
# video_0123
# /content/JAAD/rgb-images/video_0123
#
#
# video_0124
# /content/JAAD/rgb-images/video_0124
#
#
# video_0124
# /content/JAAD/rgb-images/video_0124
#
#
# video_0125
# /content/JAAD/rgb-images/video_0125
#
#
# video_0125
# /content/JAAD/rgb-images/video_0125
#
#
# video_0126
# /content/JAAD/rgb-images/video_0126
#
#
# video_0126
# /content/JAAD/rgb-images/video_0126
#
#
# video_0127
# /content/JAAD/rgb-images/video_0127
#
#
# video_0127
# /content/JAAD/rgb-images/video_0127
#
#
# video_0128
# /content/JAAD/rgb-images/video_0128
#
#
# video_0128
# /content/JAAD/rgb-images/video_0128
#
#
# video_0129
# /content/JAAD/rgb-images/video_0129
#
#
# video_0129
# /content/JAAD/rgb-images/video_0129
#
#
# video_0130
# /content/JAAD/rgb-images/video_0130
#
#
# video_0130
# /content/JAAD/rgb-images/video_0130
#
#
# video_0131
# /content/JAAD/rgb-images/video_0131
#
#
# video_0131
# /content/JAAD/rgb-images/video_0131
#
#
# video_0132
# /content/JAAD/rgb-images/video_0132
#
#
# video_0132
# /content/JAAD/rgb-images/video_0132
#
#
# video_0133
# /content/JAAD/rgb-images/video_0133
#
#
# video_0133
# /content/JAAD/rgb-images/video_0133
#
#
# video_0134
# /content/JAAD/rgb-images/video_0134
#
#
# video_0134
# /content/JAAD/rgb-images/video_0134
#
#
# video_0135
# /content/JAAD/rgb-images/video_0135
#
#
# video_0135
# /content/JAAD/rgb-images/video_0135
#
#
# video_0136
# /content/JAAD/rgb-images/video_0136
#
#
# video_0136
# /content/JAAD/rgb-images/video_0136
#
#
# video_0137
# /content/JAAD/rgb-images/video_0137
#
#
# video_0137
# /content/JAAD/rgb-images/video_0137
#
#
# video_0138
# /content/JAAD/rgb-images/video_0138
#
#
# video_0138
# /content/JAAD/rgb-images/video_0138
#
#
# video_0139
# /content/JAAD/rgb-images/video_0139
#
#
# video_0139
# /content/JAAD/rgb-images/video_0139
#
#
# video_0140
# /content/JAAD/rgb-images/video_0140
#
#
# video_0140
# /content/JAAD/rgb-images/video_0140
#
#
# video_0141
# /content/JAAD/rgb-images/video_0141
#
#
# video_0141
# /content/JAAD/rgb-images/video_0141
#
#
# video_0142
# /content/JAAD/rgb-images/video_0142
#
#
# video_0142
# /content/JAAD/rgb-images/video_0142
#
#
# video_0143
# /content/JAAD/rgb-images/video_0143
#
#
# video_0143
# /content/JAAD/rgb-images/video_0143
#
#
# video_0144
# /content/JAAD/rgb-images/video_0144
#
#
# video_0144
# /content/JAAD/rgb-images/video_0144
#
#
# video_0145
# /content/JAAD/rgb-images/video_0145
#
#
# video_0145
# /content/JAAD/rgb-images/video_0145
#
#
# video_0146
# /content/JAAD/rgb-images/video_0146
#
#
# video_0146
# /content/JAAD/rgb-images/video_0146
#
#
# video_0147
# /content/JAAD/rgb-images/video_0147
#
#
# video_0147
# /content/JAAD/rgb-images/video_0147
#
#
# video_0148
# /content/JAAD/rgb-images/video_0148
#
#
# video_0148
# /content/JAAD/rgb-images/video_0148
#
#
# video_0149
# /content/JAAD/rgb-images/video_0149
#
#
# video_0149
# /content/JAAD/rgb-images/video_0149
#
#
# video_0150
# /content/JAAD/rgb-images/video_0150
#
#
# video_0150
# /content/JAAD/rgb-images/video_0150
#
#
# video_0151
# /content/JAAD/rgb-images/video_0151
#
#
# video_0151
# /content/JAAD/rgb-images/video_0151
#
#
# video_0152
# /content/JAAD/rgb-images/video_0152
#
#
# video_0152
# /content/JAAD/rgb-images/video_0152
#
#
# video_0153
# /content/JAAD/rgb-images/video_0153
#
#
# video_0153
# /content/JAAD/rgb-images/video_0153
#
#
# video_0154
# /content/JAAD/rgb-images/video_0154
#
#
# video_0154
# /content/JAAD/rgb-images/video_0154
#
#
# video_0155
# /content/JAAD/rgb-images/video_0155
#
#
# video_0155
# /content/JAAD/rgb-images/video_0155
#
#
# video_0156
# /content/JAAD/rgb-images/video_0156
#
#
# video_0156
# /content/JAAD/rgb-images/video_0156
#
#
# video_0157
# /content/JAAD/rgb-images/video_0157
#
#
# video_0157
# /content/JAAD/rgb-images/video_0157
#
#
# video_0158
# /content/JAAD/rgb-images/video_0158
#
#
# video_0158
# /content/JAAD/rgb-images/video_0158
#
#
# video_0159
# /content/JAAD/rgb-images/video_0159
#
#
# video_0159
# /content/JAAD/rgb-images/video_0159
#
#
# video_0160
# /content/JAAD/rgb-images/video_0160
#
#
# video_0160
# /content/JAAD/rgb-images/video_0160
#
#
# video_0161
# /content/JAAD/rgb-images/video_0161
#
#
# video_0161
# /content/JAAD/rgb-images/video_0161
#
#
# video_0162
# /content/JAAD/rgb-images/video_0162
#
#
# video_0162
# /content/JAAD/rgb-images/video_0162
#
#
# video_0163
# /content/JAAD/rgb-images/video_0163
#
#
# video_0163
# /content/JAAD/rgb-images/video_0163
#
#
# video_0164
# /content/JAAD/rgb-images/video_0164
#
#
# video_0164
# ...
#
#
# video_0184
# /content/JAAD/rgb-images/video_0184
#
#
# video_0184
# /content/JAAD/rgb-images/video_0184
#
#
# video_0185
# /content/JAAD/rgb-images/video_0185
#
#
# video_0185
# /content/JAAD/rgb-images/video_0185
#
#
# video_0186
# /content/JAAD/rgb-images/video_0186
#
#
# video_0186
# /content/JAAD/rgb-images/video_0186
#
#
# video_0187
# /content/JAAD/rgb-images/video_0187
#
#
# video_0187
# /content/JAAD/rgb-images/video_0187
#
#
# video_0188
# /content/JAAD/rgb-images/video_0188
#
#
# video_0188
# /content/JAAD/rgb-images/video_0188
#
#
# video_0189
# /content/JAAD/rgb-images/video_0189
#
#
# video_0189
# /content/JAAD/rgb-images/video_0189
#
#
# video_0190
# /content/JAAD/rgb-images/video_0190
#
#
# video_0190
# /content/JAAD/rgb-images/video_0190
#
#
# video_0191
# /content/JAAD/rgb-images/video_0191
#
#
# video_0191
# /content/JAAD/rgb-images/video_0191
#
#
# video_0192
# /content/JAAD/rgb-images/video_0192
#
#
# video_0192
# /content/JAAD/rgb-images/video_0192
#
#
# video_0193
# /content/JAAD/rgb-images/video_0193
#
#
# video_0193
# /content/JAAD/rgb-images/video_0193
#
#
# video_0194
# /content/JAAD/rgb-images/video_0194
#
#
# video_0194
# /content/JAAD/rgb-images/video_0194
#
#
# video_0195
# /content/JAAD/rgb-images/video_0195
#
#
# video_0195
# /content/JAAD/rgb-images/video_0195
#
#
# video_0196
# /content/JAAD/rgb-images/video_0196
#
#
# video_0196
# /content/JAAD/rgb-images/video_0196
#
#
# video_0197
# /content/JAAD/rgb-images/video_0197
#
#
# video_0197
# /content/JAAD/rgb-images/video_0197
#
#
# video_0198
# /content/JAAD/rgb-images/video_0198
#
#
# video_0198
# /content/JAAD/rgb-images/video_0198
#
#
# video_0199
# /content/JAAD/rgb-images/video_0199
#
#
# video_0199
# /content/JAAD/rgb-images/video_0199
#
#
# video_0200
# /content/JAAD/rgb-images/video_0200
#
#
# video_0200
# /content/JAAD/rgb-images/video_0200
#
#
# video_0201
# /content/JAAD/rgb-images/video_0201
#
#
# video_0201
# /content/JAAD/rgb-images/video_0201
#
#
# video_0202
# /content/JAAD/rgb-images/video_0202
#
#
# video_0202
# /content/JAAD/rgb-images/video_0202
#
#
# video_0203
# /content/JAAD/rgb-images/video_0203
#
#
# video_0203
# /content/JAAD/rgb-images/video_0203
#
#
# video_0204
# /content/JAAD/rgb-images/video_0204
#
#
# video_0204
# /content/JAAD/rgb-images/video_0204
#
#
# video_0205
# /content/JAAD/rgb-images/video_0205
#
#
# video_0205
# /content/JAAD/rgb-images/video_0205
#
#
# video_0206
# /content/JAAD/rgb-images/video_0206
#
#
# video_0206
# /content/JAAD/rgb-images/video_0206
#
#
# video_0207
# /content/JAAD/rgb-images/video_0207
#
#
# video_0207
# /content/JAAD/rgb-images/video_0207
#
#
# video_0208
# /content/JAAD/rgb-images/video_0208
#
#
# video_0208
# /content/JAAD/rgb-images/video_0208
#
#
# video_0209
# /content/JAAD/rgb-images/video_0209
#
#
# video_0209
# /content/JAAD/rgb-images/video_0209
#
#
# video_0210
# /content/JAAD/rgb-images/video_0210
#
#
# video_0210
# /content/JAAD/rgb-images/video_0210
#
#
# video_0211
# /content/JAAD/rgb-images/video_0211
#
#
# video_0211
# /content/JAAD/rgb-images/video_0211
#
#
# video_0212
# /content/JAAD/rgb-images/video_0212
#
#
# video_0212
# /content/JAAD/rgb-images/video_0212
#
#
# video_0213
# /content/JAAD/rgb-images/video_0213
#
#
# video_0213
# /content/JAAD/rgb-images/video_0213
#
#
# video_0214
# /content/JAAD/rgb-images/video_0214
#
#
# video_0214
# /content/JAAD/rgb-images/video_0214
#
#
# video_0215
# /content/JAAD/rgb-images/video_0215
#
#
# video_0215
# /content/JAAD/rgb-images/video_0215
#
#
# video_0216
# /content/JAAD/rgb-images/video_0216
#
#
# video_0216
# /content/JAAD/rgb-images/video_0216
#
#
# video_0217
# /content/JAAD/rgb-images/video_0217
#
#
# video_0217
# /content/JAAD/rgb-images/video_0217
#
#
# video_0218
# /content/JAAD/rgb-images/video_0218
#
#
# video_0218
# /content/JAAD/rgb-images/video_0218
#
#
# video_0219
# /content/JAAD/rgb-images/video_0219
#
#
# video_0219
# /content/JAAD/rgb-images/video_0219
#
#
# video_0220
# /content/JAAD/rgb-images/video_0220
#
#
# video_0220
# /content/JAAD/rgb-images/video_0220
#
#
# video_0221
# /content/JAAD/rgb-images/video_0221
#
#
# video_0221
# /content/JAAD/rgb-images/video_0221
#
#
# video_0222
# /content/JAAD/rgb-images/video_0222
#
#
# video_0222
# /content/JAAD/rgb-images/video_0222
#
#
# video_0223
# /content/JAAD/rgb-images/video_0223
#
#
# video_0223
# /content/JAAD/rgb-images/video_0223
#
#
# video_0224
# /content/JAAD/rgb-images/video_0224
#
#
# video_0224
# /content/JAAD/rgb-images/video_0224
#
#
# video_0225
# /content/JAAD/rgb-images/video_0225
#
#
# video_0225
# /content/JAAD/rgb-images/video_0225
#
#
# video_0226
# /content/JAAD/rgb-images/video_0226
#
#
# video_0226
# /content/JAAD/rgb-images/video_0226
#
#
# video_0227
# /content/JAAD/rgb-images/video_0227
#
#
# video_0227
# /content/JAAD/rgb-images/video_0227
#
#
# video_0228
# /content/JAAD/rgb-images/video_0228
#
#
# video_0228
# /content/JAAD/rgb-images/video_0228
#
#
# video_0229
# /content/JAAD/rgb-images/video_0229
#
#
# video_0229
# /content/JAAD/rgb-images/video_0229
#
#
# video_0230
# /content/JAAD/rgb-images/video_0230
#
#
# video_0230
# /content/JAAD/rgb-images/video_0230
#
#
# video_0231
# /content/JAAD/rgb-images/video_0231
#
#
# video_0231
# /content/JAAD/rgb-images/video_0231
#
#
# video_0232
# /content/JAAD/rgb-images/video_0232
#
#
# video_0232
# /content/JAAD/rgb-images/video_0232
#
#
# video_0233
# /content/JAAD/rgb-images/video_0233
#
#
# video_0233
# /content/JAAD/rgb-images/video_0233
#
#
# video_0234
# /content/JAAD/rgb-images/video_0234
#
#
# video_0234
# /content/JAAD/rgb-images/video_0234
#
#
# video_0235
# /content/JAAD/rgb-images/video_0235
#
#
# video_0235
# /content/JAAD/rgb-images/video_0235
#
#
# video_0236
# /content/JAAD/rgb-images/video_0236
#
#
# video_0236
# /content/JAAD/rgb-images/video_0236
#
#
# video_0237
# /content/JAAD/rgb-images/video_0237
#
#
# video_0237
# /content/JAAD/rgb-images/video_0237
#
#
# video_0238
# /content/JAAD/rgb-images/video_0238
#
#
# video_0238
# /content/JAAD/rgb-images/video_0238
#
#
# video_0239
# /content/JAAD/rgb-images/video_0239
#
#
# video_0239
# /content/JAAD/rgb-images/video_0239
#
#
# video_0240
# /content/JAAD/rgb-images/video_0240
#
#
# video_0240
# /content/JAAD/rgb-images/video_0240
#
#
# video_0241
# /content/JAAD/rgb-images/video_0241
#
#
# video_0241
# /content/JAAD/rgb-images/video_0241
#
#
# video_0242
# /content/JAAD/rgb-images/video_0242
#
#
# video_0242
# /content/JAAD/rgb-images/video_0242
#
#
# video_0243
# /content/JAAD/rgb-images/video_0243
#
#
# video_0243
# /content/JAAD/rgb-images/video_0243
#
#
# video_0244
# /content/JAAD/rgb-images/video_0244
#
#
# video_0244
# /content/JAAD/rgb-images/video_0244
#
#
# video_0245
# /content/JAAD/rgb-images/video_0245
#
#
# video_0245
# /content/JAAD/rgb-images/video_0245
#
#
# video_0246
# /content/JAAD/rgb-images/video_0246
#
#
# video_0246
# /content/JAAD/rgb-images/video_0246
#
#
# video_0247
# /content/JAAD/rgb-images/video_0247
#
#
# video_0247
# /content/JAAD/rgb-images/video_0247
#
#
# video_0248
# /content/JAAD/rgb-images/video_0248
#
#
# video_0248
# /content/JAAD/rgb-images/video_0248
#
#
# video_0249
# /content/JAAD/rgb-images/video_0249
#
#
# video_0249
# /content/JAAD/rgb-images/video_0249
#
#
# video_0250
# /content/JAAD/rgb-images/video_0250
#
#
# video_0250
# /content/JAAD/rgb-images/video_0250
#
#
# video_0251
# /content/JAAD/rgb-images/video_0251
#
#
# video_0251
# /content/JAAD/rgb-images/video_0251
#
#
# video_0252
# /content/JAAD/rgb-images/video_0252
#
#
# video_0252
# /content/JAAD/rgb-images/video_0252
#
#
# video_0253
# /content/JAAD/rgb-images/video_0253
#
#
# video_0253
# /content/JAAD/rgb-images/video_0253
#
#
# video_0254
# /content/JAAD/rgb-images/video_0254
#
#
# video_0254
# /content/JAAD/rgb-images/video_0254
#
#
# video_0255
# /content/JAAD/rgb-images/video_0255
#
#
# video_0255
# /content/JAAD/rgb-images/video_0255
#
#
# video_0256
# /content/JAAD/rgb-images/video_0256
#
#
# video_0256
# /content/JAAD/rgb-images/video_0256
#
#
# video_0257
# /content/JAAD/rgb-images/video_0257
#
#
# video_0257
# /content/JAAD/rgb-images/video_0257
#
#
# video_0258
# /content/JAAD/rgb-images/video_0258
#
#
# video_0258
# /content/JAAD/rgb-images/video_0258
#
#
# video_0259
# /content/JAAD/rgb-images/video_0259
#
#
# video_0259
# /content/JAAD/rgb-images/video_0259
#
#
# video_0260
# /content/JAAD/rgb-images/video_0260
#
#
# video_0260
# /content/JAAD/rgb-images/video_0260
#
#
# video_0261
# /content/JAAD/rgb-images/video_0261
#
#
# video_0261
# /content/JAAD/rgb-images/video_0261
#
#
# video_0262
# /content/JAAD/rgb-images/video_0262
#
#
# video_0262
# /content/JAAD/rgb-images/video_0262
#
#
# video_0263
# /content/JAAD/rgb-images/video_0263
#
#
# video_0263
# /content/JAAD/rgb-images/video_0263
#
#
# video_0264
# /content/JAAD/rgb-images/video_0264
#
#
# video_0264
# /content/JAAD/rgb-images/video_0264
#
#
# video_0265
# /content/JAAD/rgb-images/video_0265
#
#
# video_0265
# /content/JAAD/rgb-images/video_0265
#
#
# video_0266
# /content/JAAD/rgb-images/video_0266
#
#
# video_0266
# /content/JAAD/rgb-images/video_0266
#
#
# video_0267
# /content/JAAD/rgb-images/video_0267
#
#
# video_0267
# /content/JAAD/rgb-images/video_0267
#
#
# video_0268
# /content/JAAD/rgb-images/video_0268
#
#
# video_0268
# /content/JAAD/rgb-images/video_0268
#
#
# video_0269
# /content/JAAD/rgb-images/video_0269
#
#
# video_0269
# /content/JAAD/rgb-images/video_0269
#
#
# video_0270
# /content/JAAD/rgb-images/video_0270
#
#
# video_0270
# /content/JAAD/rgb-images/video_0270
#
#
# video_0271
# /content/JAAD/rgb-images/video_0271
#
#
# video_0271
# /content/JAAD/rgb-images/video_0271
#
#
# video_0272
# /content/JAAD/rgb-images/video_0272
#
#
# video_0272
# /content/JAAD/rgb-images/video_0272
#
#
# video_0273
# /content/JAAD/rgb-images/video_0273
#
#
# video_0273
# /content/JAAD/rgb-images/video_0273
#
#
# video_0274
# /content/JAAD/rgb-images/video_0274
#
#
# video_0274
# /content/JAAD/rgb-images/video_0274
#
#
# video_0275
# /content/JAAD/rgb-images/video_0275
#
#
# video_0275
# /content/JAAD/rgb-images/video_0275
#
#
# video_0276
# /content/JAAD/rgb-images/video_0276
#
#
# video_0276
# /content/JAAD/rgb-images/video_0276
#
#
# video_0277
# /content/JAAD/rgb-images/video_0277
#
#
# video_0277
# /content/JAAD/rgb-images/video_0277
#
#
# video_0278
# /content/JAAD/rgb-images/video_0278
#
#
# video_0278
# /content/JAAD/rgb-images/video_0278
#
#
# video_0279
# /content/JAAD/rgb-images/video_0279
#
#
# video_0279
# /content/JAAD/rgb-images/video_0279
#
#
# video_0280
# /content/JAAD/rgb-images/video_0280
#
#
# video_0280
# /content/JAAD/rgb-images/video_0280
#
#
# video_0281
# /content/JAAD/rgb-images/video_0281
#
#
# video_0281
# /content/JAAD/rgb-images/video_0281
#
#
# video_0282
# /content/JAAD/rgb-images/video_0282
#
#
# video_0282
# /content/JAAD/rgb-images/video_0282
#
#
# video_0283
# /content/JAAD/rgb-images/video_0283
#
#
# video_0283
# /content/JAAD/rgb-images/video_0283
#
#
# video_0284
# /content/JAAD/rgb-images/video_0284
#
#
# video_0284
# /content/JAAD/rgb-images/video_0284
#
#
# video_0285
# /content/JAAD/rgb-images/video_0285
#
#
# video_0285
# /content/JAAD/rgb-images/video_0285
#
#
# video_0286
# /content/JAAD/rgb-images/video_0286
#
#
# video_0286
# /content/JAAD/rgb-images/video_0286
#
#
# video_0287
# /content/JAAD/rgb-images/video_0287
#
#
# video_0287
# /content/JAAD/rgb-images/video_0287
#
#
# video_0288
# /content/JAAD/rgb-images/video_0288
#
#
# video_0288
# /content/JAAD/rgb-images/video_0288
#
#
# video_0289
# /content/JAAD/rgb-images/video_0289
#
#
# video_0289
# /content/JAAD/rgb-images/video_0289
#
#
# video_0290
# /content/JAAD/rgb-images/video_0290
#
#
# video_0290
# /content/JAAD/rgb-images/video_0290
#
#
# video_0291
# /content/JAAD/rgb-images/video_0291
#
#
# video_0291
# /content/JAAD/rgb-images/video_0291
#
#
# video_0292
# /content/JAAD/rgb-images/video_0292
#
#
# video_0292
# /content/JAAD/rgb-images/video_0292
#
#
# video_0293
# /content/JAAD/rgb-images/video_0293
#
#
# video_0293
# /content/JAAD/rgb-images/video_0293
#
#
# video_0294
# /content/JAAD/rgb-images/video_0294
#
#
# video_0294
# /content/JAAD/rgb-images/video_0294
#
#
# video_0295
# /content/JAAD/rgb-images/video_0295
#
#
# video_0295
# /content/JAAD/rgb-images/video_0295
#
#
# video_0296
# /content/JAAD/rgb-images/video_0296
#
#
# video_0296
# /content/JAAD/rgb-images/video_0296
#
#
# video_0297
# /content/JAAD/rgb-images/video_0297
#
#
# video_0297
# /content/JAAD/rgb-images/video_0297
#
#
# video_0298
# /content/JAAD/rgb-images/video_0298
#
#
# video_0298
# /content/JAAD/rgb-images/video_0298
#
#
# video_0299
# /content/JAAD/rgb-images/video_0299
#
#
# video_0299
# /content/JAAD/rgb-images/video_0299
#
#
# video_0300
# /content/JAAD/rgb-images/video_0300
#
#
# video_0300
# /content/JAAD/rgb-images/video_0300
#
#
# video_0301
# /content/JAAD/rgb-images/video_0301
#
#
# video_0301
# /content/JAAD/rgb-images/video_0301
#
#
# video_0302
# /content/JAAD/rgb-images/video_0302
#
#
# video_0302
# /content/JAAD/rgb-images/video_0302
#
#
# video_0303
# /content/JAAD/rgb-images/video_0303
#
#
# video_0303
# /content/JAAD/rgb-images/video_0303
#
#
# video_0304
# /content/JAAD/rgb-images/video_0304
#
#
# video_0304
# /content/JAAD/rgb-images/video_0304
#
#
# video_0305
# /content/JAAD/rgb-images/video_0305
#
#
# video_0305
# /content/JAAD/rgb-images/video_0305
#
#
# video_0306
# /content/JAAD/rgb-images/video_0306
#
#
# video_0306
# /content/JAAD/rgb-images/video_0306
#
#
# video_0307
# /content/JAAD/rgb-images/video_0307
#
#
# video_0307
# /content/JAAD/rgb-images/video_0307
#
#
# video_0308
# /content/JAAD/rgb-images/video_0308
#
#
# video_0308
# /content/JAAD/rgb-images/video_0308
#
#
# video_0309
# /content/JAAD/rgb-images/video_0309
#
#
# video_0309
# /content/JAAD/rgb-images/video_0309
#
#
# video_0310
# /content/JAAD/rgb-images/video_0310
#
#
# video_0310
# /content/JAAD/rgb-images/video_0310
#
#
# video_0311
# /content/JAAD/rgb-images/video_0311
#
#
# video_0311
# /content/JAAD/rgb-images/video_0311
#
#
# video_0312
# /content/JAAD/rgb-images/video_0312
#
#
# video_0312
# /content/JAAD/rgb-images/video_0312
#
#
# video_0313
# /content/JAAD/rgb-images/video_0313
#
#
# video_0313
# /content/JAAD/rgb-images/video_0313
#
#
# video_0314
# /content/JAAD/rgb-images/video_0314
#
#
# video_0314
# /content/JAAD/rgb-images/video_0314
#
#
# video_0315
# /content/JAAD/rgb-images/video_0315
#
#
# video_0315
# /content/JAAD/rgb-images/video_0315
#
#
# video_0316
# /content/JAAD/rgb-images/video_0316
#
#
# video_0316
# /content/JAAD/rgb-images/video_0316
#
#
# video_0317
# /content/JAAD/rgb-images/video_0317
#
#
# video_0317
# /content/JAAD/rgb-images/video_0317
#
#
# video_0318
# /content/JAAD/rgb-images/video_0318
#
#
# video_0318
# /content/JAAD/rgb-images/video_0318
#
#
# video_0319
# /content/JAAD/rgb-images/video_0319
#
#
# video_0319
# /content/JAAD/rgb-images/video_0319
#
#
# video_0320
# /content/JAAD/rgb-images/video_0320
#
#
# video_0320
# /content/JAAD/rgb-images/video_0320
#
#
# video_0321
# /content/JAAD/rgb-images/video_0321
#
#
# video_0321
# /content/JAAD/rgb-images/video_0321
#
#
# video_0322
# /content/JAAD/rgb-images/video_0322
#
#
# video_0322
# /content/JAAD/rgb-images/video_0322
#
#
# video_0323
# /content/JAAD/rgb-images/video_0323
#
#
# video_0323
# /content/JAAD/rgb-images/video_0323
#
#
# video_0324
# /content/JAAD/rgb-images/video_0324
#
#
# video_0324
# /content/JAAD/rgb-images/video_0324
#
#
# video_0325
# /content/JAAD/rgb-images/video_0325
#
#
# video_0325
# /content/JAAD/rgb-images/video_0325
#
#
# video_0326
# /content/JAAD/rgb-images/video_0326
#
#
# video_0326
# /content/JAAD/rgb-images/video_0326
#
#
# video_0327
# /content/JAAD/rgb-images/video_0327
#
#
# video_0327
# /content/JAAD/rgb-images/video_0327
#
#
# video_0328
# /content/JAAD/rgb-images/video_0328
#
#
# video_0328
# /content/JAAD/rgb-images/video_0328
#
#
# video_0329
# /content/JAAD/rgb-images/video_0329
#
#
# video_0329
# /content/JAAD/rgb-images/video_0329
#
#
# video_0330
# /content/JAAD/rgb-images/video_0330
#
#
# video_0330
# /content/JAAD/rgb-images/video_0330
#
#
# video_0331
# /content/JAAD/rgb-images/video_0331
#
#
# video_0331
# /content/JAAD/rgb-images/video_0331
#
#
# video_0332
# /content/JAAD/rgb-images/video_0332
#
#
# video_0332
# /content/JAAD/rgb-images/video_0332
#
#
# video_0333
# /content/JAAD/rgb-images/video_0333
#
#
# video_0333
# /content/JAAD/rgb-images/video_0333
#
#
# video_0334
# /content/JAAD/rgb-images/video_0334
#
#
# video_0334
# /content/JAAD/rgb-images/video_0334
#
#
# video_0335
# /content/JAAD/rgb-images/video_0335
#
#
# video_0335
# /content/JAAD/rgb-images/video_0335
#
#
# video_0336
# /content/JAAD/rgb-images/video_0336
#
#
# video_0336
# /content/JAAD/rgb-images/video_0336
#
#
# video_0337
# /content/JAAD/rgb-images/video_0337
#
#
# video_0337
# /content/JAAD/rgb-images/video_0337
#
#
# video_0338
# /content/JAAD/rgb-images/video_0338
#
#
# video_0338
# /content/JAAD/rgb-images/video_0338
#
#
# video_0339
# /content/JAAD/rgb-images/video_0339
#
#
# video_0339
# /content/JAAD/rgb-images/video_0339
#
#
# video_0340
# /content/JAAD/rgb-images/video_0340
#
#
# video_0340
# /content/JAAD/rgb-images/video_0340
#
#
# video_0341
# /content/JAAD/rgb-images/video_0341
#
#
# video_0341
# /content/JAAD/rgb-images/video_0341
#
#
# video_0342
# /content/JAAD/rgb-images/video_0342
#
#
# video_0342
# /content/JAAD/rgb-images/video_0342
#
#
# video_0343
# /content/JAAD/rgb-images/video_0343
#
#
# video_0343
# /content/JAAD/rgb-images/video_0343
#
#
# video_0344
# /content/JAAD/rgb-images/video_0344
#
#
# video_0344
# /content/JAAD/rgb-images/video_0344
#
#
# video_0345
# /content/JAAD/rgb-images/video_0345
#
#
# video_0345
# /content/JAAD/rgb-images/video_0345
#
#
# video_0346
# /content/JAAD/rgb-images/video_0346
#
#
# video_0346
# /content/JAAD/rgb-images/video_0346

# %% [markdown]
# # train list and test list prep

# %%
# import numpy as np
# num_videos = 346
# x = np.arange(1,num_videos+1)

# %%
# from sklearn.model_selection import train_test_split
# vid_train, vid_test = train_test_split(x, test_size = 0.2, random_state=42)
# print(len(vid_train)) # 276
# print(len(vid_test))  # 70

# %%
# train_vid_list = []
# test_vid_list = []
# vid_list = os.listdir('/content/JAAD/annotations_yowo')
# for vid in vid_list:
#   vid_num = int(vid[-4:])
#   if vid_num in vid_train:
#     train_vid_list.append(vid)
#   else:
#     test_vid_list.append(vid)
# def get_annotation_list(vid_list):
#   base_path = '/content/JAAD/annotations_yowo'
#   annotation_list = []
#   for vid in vid_list:
#     for frame in sorted(os.listdir(os.path.join(base_path, vid))): 
#       # annotation_list.append(os.path.join(base_path, vid, frame))
#       annotation_list.append(os.path.join(vid, frame))      
#   return annotation_list
# trainlist = get_annotation_list(train_vid_list)
# testlist = get_annotation_list(test_vid_list)
# print(len(trainlist))
# print(len(testlist))
# trainlist[:3]

# %%
# os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/data')
# with open('trainlist.txt', 'w') as f:
#     for item in trainlist:
#         f.write("%s\n" % item)
# with open('testlist.txt', 'w') as f:
#     for item in testlist:
#         f.write("%s\n" % item)

# %%
# !mv /content/JAAD/annotations_yowo /content/drive/MyDrive/NLP_and_CV_Projects/CV/data/annotations_yowo

# %% [markdown]
# # Import YOWO

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch.autograd import Variable

from cfg import *
from cfam import CFAMBlock
from backbones_2d import darknet
from backbones_3d import mobilenet, shufflenet, mobilenetv2, shufflenetv2, resnext, resnet

num_classes = 2 # 24 is the number of classes of ucf101 dataset, 
#if we set this differently, we need to specify to not import pretrained weights of the last layer

class YOWO(nn.Module): # model.py
    def __init__(self):
        super(YOWO, self).__init__()
        
        ##### 2D Backbone #####
        # if opt.backbone_2d == "darknet":
        self.backbone_2d = darknet.Darknet("cfg/yolo.cfg")
        num_ch_2d = 425 # Number of output channels for backbone_2d
        # load pretrained weights
        self.backbone_2d.load_weights("weights/yolo.weights")

        ##### 3D Backbone ##### # resnet18: lighter but no pre-trained
        # default = "resnext101":
        self.backbone_3d = resnext.resnext101()
        num_ch_3d = 2048 # Number of output channels for backbone_3d
        # load 3d pretrained weights
        self.backbone_3d = self.backbone_3d.cuda()
        self.backbone_3d = nn.DataParallel(self.backbone_3d, device_ids=None) # Because the pretrained backbone models are saved in Dataparalled mode
        pretrained_3d_backbone = torch.load('weights/resnext-101-kinetics.pth')
        backbone_3d_dict = self.backbone_3d.state_dict()
        pretrained_3d_backbone_dict = {k: v for k, v in pretrained_3d_backbone['state_dict'].items() if k in backbone_3d_dict} # 1. filter out unnecessary keys
        backbone_3d_dict.update(pretrained_3d_backbone_dict) # 2. overwrite entries in the existing state dict
        self.backbone_3d.load_state_dict(backbone_3d_dict) # 3. load the new state dict
        self.backbone_3d = self.backbone_3d.module # remove the dataparallel wrapper


        ##### Attention & Final Conv #####f
        self.cfam = CFAMBlock(num_ch_2d+num_ch_3d, 1024)
        self.conv_final = nn.Conv2d(1024, 5*(num_classes+4+1), kernel_size=1, bias=False) # 5: number of anchors, num_classes, 4: coordinates, 1: confidence score
        self.seen = 0



    def forward(self, input):
        x_3d = input # Input clip (None, num_channels, clip_duration, W, H) W and H must be divisible to 32 (480, 256?)
        x_2d = input[:, :, -1, :, :] # Last frame of the clip that is read

        x_2d = self.backbone_2d(x_2d)
        x_3d = self.backbone_3d(x_3d)
        x_3d = torch.squeeze(x_3d, dim=2)

        x = torch.cat((x_3d, x_2d), dim=1)
        x = self.cfam(x)

        out = self.conv_final(x)

        return out


def get_fine_tuning_parameters(model, freeze_backbone_2d = False, freeze_backbone_3d = False):
    ft_module_names = ['cfam', 'conv_final'] # Always fine tune 'cfam' and 'conv_final'
    if not freeze_backbone_2d:
        ft_module_names.append('backbone_2d') # Fine tune complete backbone_2d
    else:
        ft_module_names.append('backbone_2d.models.29') # Fine tune only layer 29 and 30
        ft_module_names.append('backbone_2d.models.30') # Fine tune only layer 29 and 30

    if not freeze_backbone_3d:
        ft_module_names.append('backbone_3d') # Fine tune complete backbone_3d
    else:
        ft_module_names.append('backbone_3d.layer4') # Fine tune only layer 4

    parameters = [] # trainable parameteres
    for k, v in model.named_parameters():
        for ft_module in ft_module_names:
            if ft_module in k:
                parameters.append({'params': v})
                break
            else:
                parameters.append({'params': v, 'lr': 0.0}) # freeze layers
    
    return parameters

# %%
# model       = YOWO()
# model       = model.cuda()
# model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
# model.seen  = 0
# # print(model)

# parameters = get_fine_tuning_parameters(model)#, opt)
# print(parameters)
# optimizer = optim.SGD(model.parameters(), lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)

# %%
# count = 0
# weights1 = []
# for v in model.parameters():
#   if count < 5:
#     weights1.append(v)
#   count += 1
# weights2 = []
# count = 0
# for k, v in model.named_parameters():
#   if count <5:
#     weights2.append(v)
#   count += 1
# print(weights1[0]==weights2[0])

# %%
# count = 0
# for k, v in model.named_parameters():
#   if count < 2:
#     print('k = ', k)
#     print('v = ', v)
#   count += 1

# %%
# model       = YOWO()
# model       = model.cuda()
# model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
# print(model)

# %%
# model_state = torch.load('./backup/yowo_ucf101-24_16f_best.pth') # load pre-trained model on ucf101 dataset

# %%
# model.load_state_dict(model_state['state_dict']) #

# %%
# from torchsummary import summary
# summary(model, (3, 16,480,256)) # channel x frames x W x H 480x256

# %% [markdown]
# # Setup and train function

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

from __future__ import print_function
import sys
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torchvision import datasets, transforms

import dataset
import random
import math
import os
# from opts import parse_opts
from utils import *
from cfg import parse_cfg
from region_loss import RegionLoss

# from model import YOWO, get_fine_tuning_parameters

# # Training settings
# opt = parse_opts()
# # which dataset to use
# dataset_use   = opt.dataset

dataset_use = 'jaad'

# assert dataset_use == 'ucf101-24' or dataset_use == 'jhmdb-21', 'invalid dataset'
# # path for dataset of training and validation
# datacfg       = opt.data_cfg
# # path for cfg file
# cfgfile       = opt.cfg_file

# data_options  = read_data_cfg(datacfg)
# net_options   = parse_cfg(cfgfile)[0]

# obtain list for training and testing
basepath      = '/content/JAAD/'#data_options['base'] # /content/data/rgb-images
trainlist     = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/data/trainlist.txt' # /content/data/trainlist.txt
testlist      = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/data/testlist.txt'# /content/data/testlist.txt

###
backupdir     = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup'
# number of training samples
nsamples      = file_lines(trainlist)
gpus          = '0' #data_options['gpus']  # e.g. 0   ,1,2,3
ngpus         = len(gpus.split(','))
num_workers   = 4  #?int(data_options['num_workers']) 0, 4, 10?

batch_size    = 4        #int(net_options['batch']) # 12 8 4
clip_duration = 16        #int(net_options['clip_duration']) # 16 frames
max_batches   = 200000    #int(net_options['max_batches']) # 100000
learning_rate = 0.001    #float(net_options['learning_rate']) # 0.0001
momentum      = 0.9       # float(net_options['momentum']) # 0.9
decay         = 0.0005    #float(net_options['decay']) # 0.0005
steps         = [10000,20000,30000,40000]#,50000,60000]   # [float(step) for step in net_options['steps'].split(',')] # [10000,20000,30000,40000] or [30000,40000,50000,60000]
scales        = [0.5,0.5,0.5,0.5]#,0.5,0.5]           #[float(scale) for scale in net_options['scales'].split(',')] # [0.5,0.5,0.5,0.5]

# loss parameters
# loss_options               = parse_cfg(cfgfile)[1]
region_loss                = RegionLoss()
# anchors                    = loss_options['anchors'].split(',')
region_loss.anchors        = [0.70458, 1.18803, 1.26654, 2.55121, 1.59382, 4.08321, 2.30548, 4.94180, 3.52332, 5.91979]
#[float(i) for i in anchors] #anchors = 0.70458, 1.18803, 1.26654, 2.55121, 1.59382, 4.08321, 2.30548, 4.94180, 3.52332, 5.91979
region_loss.num_classes    = 2   # int(loss_options['classes']) # 24
region_loss.num_anchors    = 5    #int(loss_options['num']) # 5
region_loss.anchor_step    = len(region_loss.anchors)//region_loss.num_anchors #
region_loss.object_scale   = 10. # float(loss_options['object_scale']) # 5 25 16
region_loss.noobject_scale = 1. # float(loss_options['noobject_scale']) # 1
region_loss.class_scale    = 1. # float(loss_options['class_scale']) # 1
region_loss.coord_scale    = 20. # float(loss_options['coord_scale']) # 1 10 20
region_loss.batch          = batch_size #batch_size # 12



#Train parameters
max_epochs    = max_batches*batch_size//nsamples+1
use_cuda      = True 
seed          = int(time.time())
# seed          = 42
eps           = 1e-5
best_fscore   = 0   # initialize best fscore
begin_epoch = 1
end_epoch = 10


# Test parameters
nms_thresh    = 0.4 # non_maximum suppression threshold 0.4 0.5
iou_thresh    = 0.5 # >=iou_threshold => correctly identified 0.5
# proposals when confidence score >= 0.25

# # print('N_samples = ', nsamples)
# print('num of batches per epoch =', nsamples//batch_size+1)

# print('nms_thresh =', nms_thresh)
# print('iou_thresh =', iou_thresh)

if not os.path.exists(backupdir):
    os.mkdir(backupdir)
    
torch.manual_seed(seed)
if use_cuda:
    os.environ['CUDA_VISIBLE_DEVICES'] = gpus
    torch.cuda.manual_seed(seed)

# Create model
# model = YOWO(opt)
model       = YOWO()
model       = model.cuda()
model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
model.seen  = 0
# print(model)

# parameters = get_fine_tuning_parameters(model)#, opt)
# optimizer = optim.SGD(parameters, lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)
optimizer = optim.SGD(model.parameters(), lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)

kwargs = {'num_workers': num_workers, 'pin_memory': True} if use_cuda else {}
################


# resume_path = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_vali_3_16f_checkpoint.pth'
resume_path = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_manual_tune4_coord20_ob16_e4_16f_checkpoint.pth'


#############
# Load resume path if necessary
# if opt.resume_path:
if os.path.exists(resume_path):
    print("===================================================================")
    print('loading checkpoint {}'.format(resume_path))
    checkpoint = torch.load(resume_path) # opt.resume_path
    # opt.begin_epoch = checkpoint['epoch'] + 1
    begin_epoch = checkpoint['epoch'] + 1
    best_fscore = checkpoint['fscore']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    model.seen = checkpoint['epoch'] * nsamples
    print("Loaded model fscore: ", checkpoint['fscore'])
    print("===================================================================")

region_loss.seen  = model.seen
processed_batches = model.seen//batch_size

init_width        = 480 # int(net_options['width']) # 224  480
init_height       = 256 # int(net_options['height']) # 224  270
init_epoch        = model.seen//nsamples 

##########################

def adjust_learning_rate(optimizer, batch):
    lr = learning_rate
    for i in range(len(steps)):
        scale = scales[i] if i < len(scales) else 1
        if batch >= steps[i]:
            lr = lr * scale
            if batch == steps[i]:
                break
        else:
            break
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr/batch_size
    return lr



def train(epoch):
    global processed_batches
    t0 = time.time()
    cur_model = model.module
    region_loss.l_x.reset()
    region_loss.l_y.reset()
    region_loss.l_w.reset()
    region_loss.l_h.reset()
    region_loss.l_conf.reset()
    region_loss.l_cls.reset()
    region_loss.l_total.reset()

    train_loader = torch.utils.data.DataLoader(
        dataset.listDataset(basepath, trainlist, dataset_use=dataset_use, shape=(init_width, init_height),
                       shuffle=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                       ]), 
                       train=True, 
                       seen=cur_model.seen,
                       batch_size=batch_size,
                       clip_duration=clip_duration,
                       num_workers=num_workers),
        batch_size=batch_size, shuffle=False, **kwargs)

    lr = adjust_learning_rate(optimizer, processed_batches)
    logging('training at epoch %d, lr %f' % (epoch, lr))

    model.train()

    for batch_idx, (data, target) in enumerate(train_loader):
        # print(data.size)
        # print(target.size)
        adjust_learning_rate(optimizer, processed_batches)
        processed_batches = processed_batches + 1

        if use_cuda:
            data = data.cuda()

        optimizer.zero_grad()
        output = model(data)
        region_loss.seen = region_loss.seen + data.data.size(0)
        loss = region_loss(output, target)
        loss.backward()
        optimizer.step()

        # save result every 500 batches
        if processed_batches % 500 == 0: # From time to time, reset averagemeters to see improvements
            region_loss.l_x.reset()
            region_loss.l_y.reset()
            region_loss.l_w.reset()
            region_loss.l_h.reset()
            region_loss.l_conf.reset()
            region_loss.l_cls.reset()
            region_loss.l_total.reset()

    t1 = time.time()
    logging('trained with %f samples/s' % (len(train_loader.dataset)/(t1-t0)))
    print('')
# Out:
# ===================================================================
# loading checkpoint /content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_manual_tune4_coord20_ob16_e4_16f_checkpoint.pth
# Loaded model fscore:  0
# ===================================================================

# %%
print('epoch of checkpoint =',checkpoint['epoch'])
# Out:
# epoch of checkpoint = 4

# %% [markdown]
# # Test function

# %%
def test(epoch):
    def truths_length(truths):
        for i in range(50):
            if truths[i][1] == 0:
                return i

    test_loader = torch.utils.data.DataLoader(
    dataset.listDataset(basepath, testlist, dataset_use=dataset_use, shape=(init_width, init_height),
                   shuffle=False,
                   transform=transforms.Compose([
                       transforms.ToTensor()
                   ]), train=False),
    batch_size=batch_size, shuffle=False, **kwargs)

    num_classes = region_loss.num_classes
    anchors     = region_loss.anchors
    num_anchors = region_loss.num_anchors
    conf_thresh_valid = 0.005
    total       = 0.0
    proposals   = 0.0
    correct     = 0.0
    fscore = 0.0

    correct_classification = 0.0
    total_detected = 0.0

    nbatch      = file_lines(testlist) // batch_size

    logging('validation at epoch %d' % (epoch))
    model.eval()

    for batch_idx, (frame_idx, data, target) in enumerate(test_loader):
        if use_cuda:
            data = data.cuda()
        with torch.no_grad():
            output = model(data).data
            all_boxes = get_region_boxes(output, conf_thresh_valid, num_classes, anchors, num_anchors, 0, 1)
            # output (batch size, anchor*(4+1+num_classes), h, w) ; h, w: grid size
            for i in range(output.size(0)): # size(0): batch size
                boxes = all_boxes[i]
                boxes = nms(boxes, nms_thresh)
                if dataset_use == 'ucf101-24':
                    detection_path = os.path.join('ucf_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join('ucf_detections', 'detections_'+str(epoch))
                    if not os.path.exists('ucf_detections'):
                        os.mkdir('ucf_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                elif dataset_use == 'jaad': 
                    detection_path = os.path.join('jaad_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join('jaad_detections', 'detections_'+str(epoch))
                    if not os.path.exists('jaad_detections'):
                        os.mkdir('jaad_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                else:
                    detection_path = os.path.join(dataset_use+'_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join(dataset_use+'_detections', 'detections_'+str(epoch))
                    if not os.path.exists(dataset_use+'_detections'):
                        os.mkdir(dataset_use+'_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                
                # print all the boxes
                # boxes = n_boxes * [x_center, y_center, w, h, confidence score, prob of the activity, int of class predicted]
                
                # with open(detection_path, 'w+') as f_detect:
                #     for box in boxes:
                #         x1 = round(float(box[0]-box[2]/2.0) * 320.0)
                #         y1 = round(float(box[1]-box[3]/2.0) * 240.0)
                #         x2 = round(float(box[0]+box[2]/2.0) * 320.0)
                #         y2 = round(float(box[1]+box[3]/2.0) * 240.0)

                #         det_conf = float(box[4])  # detected confidence > 0.25 is detected
                #         for j in range((len(box)-5)//2):
                #             cls_conf = float(box[5+2*j].item()) # class confidence

                #             if type(box[6+2*j]) == torch.Tensor:
                #                 cls_id = int(box[6+2*j].item())
                #             else:
                #                 cls_id = int(box[6+2*j])
                #             prob = det_conf * cls_conf  # means = detected confidence * class confidence

                #             # f_detect.write(str(int(box[6])+1) + ' ' + str(prob) + ' ' + str(x1) + ' ' + str(y1) + ' ' + str(x2) + ' ' + str(y2) + '\n')
                #             f_detect.write(str(int(box[6])+1) + ' ' + str(det_conf) + ' ' + str(cls_conf) + ' ' + str(x1) + ' ' + str(y1) + ' ' + str(x2) + ' ' + str(y2) + '\n')
                
                truths = target[i].view(-1, 5)
                num_gts = truths_length(truths)
        
                total = total + num_gts  # total ground truths
    
                for i in range(len(boxes)): # for all proposal boxes in that frame
                    if boxes[i][4] > 0.25: # det_confs: detection confidence score
                        proposals = proposals+1

                for i in range(num_gts):
                    box_gt = [truths[i][1], truths[i][2], truths[i][3], truths[i][4], 1.0, 1.0, truths[i][0]]
                    best_iou = 0
                    best_j = -1
                    for j in range(len(boxes)): # find the best box (highest iou)
                        iou = bbox_iou(box_gt, boxes[j], x1y1x2y2=False)
                        if iou > best_iou:
                            best_j = j
                            best_iou = iou

                    if best_iou > iou_thresh:
                        total_detected += 1
                        if int(boxes[best_j][6]) == box_gt[6]: # correctly classified
                            correct_classification += 1

                    if best_iou > iou_thresh and int(boxes[best_j][6]) == box_gt[6]: # correct localization AND classification
                        correct = correct+1

            precision = 1.0*correct/(proposals+eps) # how accurate is the prediction
            recall = 1.0*correct/(total+eps)  # correctly localized AND classify
            fscore = 2.0*precision*recall/(precision+recall+eps)
            logging("[%d/%d] precision: %f, recall: %f, fscore: %f" % (batch_idx, nbatch, precision, recall, fscore))

    classification_accuracy = 1.0 * correct_classification / (total_detected + eps)  # accuracy of the classification if detected
    localization_recall = 1.0 * total_detected / (total + eps) # correct localization

    print("Classification accuracy: %.3f" % classification_accuracy)
    print("Localization recall: %.3f" % localization_recall)

    return classification_accuracy, localization_recall, precision, recall, fscore

# %% [markdown]
# # Main: Train model without test

# %%
backupdir
# Out:
# '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup'

# %%
begin_epoch
# Out:
# 5

# %%
# begin_epoch = 4

# %%
namedataset = 'jaad'
evaluate = False

if evaluate == True:
    logging('evaluating ...')
    test(0)
else:
    # for epoch in range(opt.begin_epoch, opt.end_epoch + 1):
    # begin_epoch = 6
    # end_epoch = 25
    # for epoch in range(begin_epoch, end_epoch):
    for epoch in range(begin_epoch, begin_epoch+1):
        # Train the model for 1 epoch
        train(epoch)
        # save checkpoint epoch
        
        state = {
          'epoch': epoch,
          'state_dict': model.state_dict(),
          'optimizer': optimizer.state_dict(),
          'fscore': 0 ## fscores are saved in ./jaad_detections/
          }
        is_best = False

        # coord_scale = 20, object_scale = 16 e4 then 10 e5
        #
        save_checkpoint(state, is_best, backupdir, namedataset+'_train_tune4_coord20_ob16_'+str(epoch), clip_duration)
      
        logging(' Weights are saved to backup directory: %s' % (backupdir))

        # Validate the model
        # classification_accuracy, localization_recall, precision, recall, fscore = test(epoch)

        # is_best = fscore > best_fscore
        # if is_best:
        #     print("New best fscore is achieved: ", fscore)
        #     print("Previous fscore was: ", best_fscore)
        #     best_fscore = fscore

        # Save the model to backup directory
    
        # state = {
        #     'epoch': epoch,
        #     'state_dict': model.state_dict(),
        #     'optimizer': optimizer.state_dict(),
        #     'fscore': fscore
        #     }
        # save_checkpoint(state, is_best=False, backupdir, namedataset+'_vali_'+str(epoch), clip_duration)
        # save_checkpoint(state, is_best, backupdir, namedataset+str(epoch), clip_duration) # save a checkpoint AND a best model
        # save_checkpoint(state, is_best, backupdir, opt.dataset, clip_duration)
        # save_checkpoint(state, is_best, backupdir, namedataset, clip_duration)
        
        # logging('Weights are saved to backup directory: %s' % (backupdir))
        
        # eval_result = {'class_acc': classification_accuracy,
        #               'loc_recall': localization_recall, 
        #               'precision': precision, 
        #               'recall': recall, 
        #               'fscore': fscore} 
        # fileout = 'jaad_eval_result_e' + str(epoch)
        # import json
        # with open(f'./jaad_detections/{fileout}.json', 'w') as fp:
        #     json.dump(eval_result, fp)
# Out:
# 2021-01-21 17:45:57 training at epoch 5, lr 0.000063
# 260092: nGT 5, recall 3, proposals 3, loss: x 1.74(1.74), y 1.06(1.06), w 1.68(1.68), h 0.84(0.84), conf 4.61(4.61), cls 0.64(0.64), total 10.57(10.57)
# 260096: nGT 5, recall 0, proposals 0, loss: x 1.61(1.68), y 0.06(0.56), w 4.04(2.86), h 0.28(0.56), conf 0.71(2.66), cls 0.64(0.64), total 7.34(8.95)
# 260100: nGT 3, recall 0, proposals 6, loss: x 0.78(1.38), y 0.94(0.69), w 0.07(1.93), h 0.21(0.44), conf 2.10(2.47), cls 0.76(0.68), total 4.85(7.59)
# 260104: nGT 1, recall 0, proposals 0, loss: x 0.14(1.07), y 0.01(0.52), w 0.03(1.45), h 0.12(0.36), conf 0.48(1.97), cls 0.08(0.53), total 0.86(5.91)
# 260108: nGT 4, recall 1, proposals 9, loss: x 1.39(1.13), y 1.55(0.73), w 1.33(1.43), h 1.25(0.54), conf 3.64(2.31), cls 0.38(0.50), total 9.54(6.63)
# 260112: nGT 4, recall 4, proposals 21, loss: x 0.39(1.01), y 0.16(0.63), w 1.02(1.36), h 0.26(0.49), conf 5.46(2.83), cls 0.23(0.46), total 7.51(6.78)
# 260116: nGT 6, recall 2, proposals 0, loss: x 0.86(0.99), y 2.90(0.95), w 1.30(1.35), h 2.17(0.73), conf 2.42(2.77), cls 0.55(0.47), total 10.20(7.27)
# 260120: nGT 4, recall 1, proposals 1, loss: x 1.77(1.08), y 1.86(1.07), w 6.69(2.02), h 5.19(1.29), conf 1.55(2.62), cls 0.61(0.49), total 17.68(8.57)
# 260124: nGT 6, recall 2, proposals 5, loss: x 2.70(1.26), y 2.55(1.23), w 0.38(1.84), h 1.13(1.27), conf 3.98(2.77), cls 0.96(0.54), total 11.71(8.92)
# 260128: nGT 4, recall 0, proposals 0, loss: x 3.35(1.47), y 1.95(1.30), w 0.46(1.70), h 2.05(1.35), conf 0.99(2.59), cls 0.47(0.53), total 9.28(8.95)
# 260132: nGT 8, recall 4, proposals 8, loss: x 2.84(1.60), y 0.33(1.22), w 4.37(1.94), h 0.83(1.30), conf 6.01(2.91), cls 1.99(0.66), total 16.38(9.63)
# 260136: nGT 2, recall 1, proposals 7, loss: x 0.09(1.47), y 0.53(1.16), w 0.53(1.83), h 0.02(1.20), conf 2.30(2.86), cls 0.18(0.62), total 3.66(9.13)
# 260140: nGT 5, recall 3, proposals 11, loss: x 2.14(1.52), y 2.71(1.28), w 2.45(1.87), h 0.86(1.17), conf 1.95(2.79), cls 0.85(0.64), total 10.96(9.27)
# 260144: nGT 1, recall 0, proposals 0, loss: x 0.67(1.46), y 0.24(1.20), w 0.41(1.77), h 0.02(1.09), conf 0.31(2.61), cls 0.05(0.60), total 1.70(8.73)
# 260148: nGT 7, recall 2, proposals 8, loss: x 1.91(1.49), y 0.83(1.18), w 36.97(4.12), h 0.83(1.07), conf 2.30(2.59), cls 1.14(0.64), total 43.99(11.08)
# 260152: nGT 2, recall 0, proposals 0, loss: x 0.56(1.43), y 1.40(1.19), w 0.14(3.87), h 1.73(1.11), conf 0.31(2.45), cls 0.35(0.62), total 4.50(10.67)
# 260156: nGT 8, recall 1, proposals 0, loss: x 1.47(1.44), y 1.67(1.22), w 12.51(4.38), h 1.60(1.14), conf 3.63(2.52), cls 1.59(0.68), total 22.47(11.36)
# 260160: nGT 6, recall 2, proposals 13, loss: x 1.45(1.44), y 0.54(1.18), w 0.24(4.15), h 0.04(1.08), conf 3.67(2.58), cls 0.45(0.66), total 6.39(11.09)
# 260164: nGT 5, recall 2, proposals 2, loss: x 2.64(1.50), y 2.60(1.26), w 1.81(4.02), h 1.24(1.09), conf 2.11(2.56), cls 0.54(0.66), total 10.94(11.08)
# 260168: nGT 8, recall 3, proposals 12, loss: x 1.07(1.48), y 0.52(1.22), w 3.98(4.02), h 0.66(1.07), conf 2.97(2.58), cls 0.98(0.67), total 10.18(11.03)
# 260172: nGT 5, recall 1, proposals 11, loss: x 1.24(1.47), y 0.37(1.18), w 1.55(3.90), h 1.33(1.08), conf 2.79(2.59), cls 0.87(0.68), total 8.15(10.90)
# 260176: nGT 6, recall 1, proposals 0, loss: x 1.34(1.46), y 0.78(1.16), w 1.41(3.79), h 0.23(1.04), conf 0.71(2.50), cls 0.33(0.67), total 4.79(10.62)
# 260180: nGT 7, recall 3, proposals 12, loss: x 1.00(1.44), y 0.56(1.14), w 2.12(3.72), h 3.69(1.16), conf 6.22(2.66), cls 0.80(0.67), total 14.38(10.78)
# 260184: nGT 6, recall 3, proposals 0, loss: x 0.66(1.41), y 0.23(1.10), w 1.69(3.63), h 1.06(1.15), conf 6.18(2.81), cls 0.58(0.67), total 10.38(10.77)
# 260188: nGT 9, recall 2, proposals 7, loss: x 1.95(1.43), y 1.05(1.10), w 3.26(3.62), h 2.12(1.19), conf 5.09(2.90), cls 0.82(0.67), total 14.30(10.91)
# 260192: nGT 5, recall 1, proposals 4, loss: x 0.02(1.38), y 0.10(1.06), w 0.26(3.49), h 0.58(1.17), conf 2.68(2.89), cls 0.36(0.66), total 4.00(10.64)
# 260196: nGT 4, recall 1, proposals 0, loss: x 1.59(1.38), y 0.26(1.03), w 2.28(3.44), h 1.07(1.16), conf 1.86(2.85), cls 0.70(0.66), total 7.76(10.54)
# 260200: nGT 6, recall 4, proposals 15, loss: x 1.76(1.40), y 2.92(1.10), w 0.99(3.36), h 0.35(1.13), conf 4.17(2.90), cls 0.84(0.67), total 11.04(10.55)
# 260204: nGT 3, recall 2, proposals 0, loss: x 0.32(1.36), y 0.90(1.09), w 1.02(3.28), h 0.48(1.11), conf 3.39(2.92), cls 0.38(0.66), total 6.48(10.41)
# 260208: nGT 5, recall 3, proposals 0, loss: x 1.06(1.35), y 0.31(1.06), w 4.11(3.30), h 0.51(1.09), conf 5.42(3.00), cls 1.23(0.68), total 12.64(10.49)
# 260212: nGT 3, recall 2, proposals 1, loss: x 0.51(1.32), y 0.46(1.04), w 0.16(3.20), h 0.42(1.07), conf 3.52(3.02), cls 0.48(0.67), total 5.55(10.33)
# 260216: nGT 2, recall 0, proposals 0, loss: x 0.83(1.31), y 0.15(1.02), w 0.19(3.11), h 0.23(1.04), conf 0.22(2.93), cls 0.21(0.66), total 1.82(10.06)
# 260220: nGT 1, recall 0, proposals 0, loss: x 0.66(1.29), y 0.12(0.99), w 0.02(3.01), h 0.74(1.03), conf 0.31(2.85), cls 0.14(0.64), total 1.99(9.82)
# 260224: nGT 6, recall 1, proposals 3, loss: x 1.83(1.30), y 0.11(0.96), w 0.51(2.94), h 0.61(1.02), conf 0.88(2.79), cls 0.50(0.64), total 4.43(9.66)
# 260228: nGT 6, recall 2, proposals 16, loss: x 2.35(1.33), y 0.89(0.96), w 0.83(2.88), h 0.86(1.02), conf 2.01(2.77), cls 0.46(0.63), total 7.40(9.59)
# 260232: nGT 1, recall 0, proposals 0, loss: x 0.17(1.30), y 0.01(0.93), w 0.10(2.80), h 0.22(0.99), conf 0.31(2.70), cls 0.06(0.62), total 0.88(9.35)
# 260236: nGT 6, recall 3, proposals 1, loss: x 0.50(1.28), y 0.13(0.91), w 1.93(2.78), h 0.69(0.99), conf 3.28(2.72), cls 0.44(0.61), total 6.96(9.29)
# 260240: nGT 5, recall 0, proposals 10, loss: x 3.32(1.33), y 3.91(0.99), w 0.65(2.72), h 0.01(0.96), conf 1.06(2.67), cls 0.79(0.62), total 9.73(9.30)
# 260244: nGT 9, recall 1, proposals 10, loss: x 3.20(1.38), y 1.32(1.00), w 12.31(2.97), h 2.12(0.99), conf 2.26(2.66), cls 1.09(0.63), total 22.31(9.63)
# 260248: nGT 2, recall 0, proposals 0, loss: x 0.07(1.35), y 0.25(0.98), w 1.34(2.93), h 2.05(1.02), conf 0.97(2.62), cls 0.23(0.62), total 4.91(9.51)
# 260252: nGT 4, recall 1, proposals 8, loss: x 0.57(1.33), y 1.29(0.99), w 0.23(2.86), h 2.36(1.05), conf 1.93(2.60), cls 0.32(0.61), total 6.69(9.45)
# 260256: nGT 3, recall 0, proposals 0, loss: x 1.16(1.33), y 2.83(1.03), w 11.49(3.07), h 5.31(1.15), conf 0.47(2.55), cls 1.96(0.64), total 23.22(9.77)
# 260260: nGT 3, recall 0, proposals 0, loss: x 2.91(1.36), y 2.51(1.07), w 4.78(3.11), h 3.38(1.20), conf 0.53(2.51), cls 0.63(0.64), total 14.74(9.89)
# 260264: nGT 3, recall 2, proposals 7, loss: x 0.18(1.34), y 0.38(1.05), w 1.54(3.07), h 0.43(1.19), conf 3.34(2.53), cls 0.31(0.64), total 6.19(9.81)
# 260268: nGT 4, recall 1, proposals 0, loss: x 2.37(1.36), y 0.34(1.04), w 0.64(3.02), h 0.37(1.17), conf 3.34(2.54), cls 0.91(0.64), total 7.97(9.76)
# 260272: nGT 12, recall 3, proposals 6, loss: x 4.15(1.42), y 1.50(1.05), w 18.81(3.36), h 13.35(1.43), conf 3.83(2.57), cls 1.15(0.65), total 42.81(10.48)
# 260276: nGT 5, recall 2, proposals 15, loss: x 1.64(1.42), y 0.44(1.03), w 2.65(3.35), h 0.51(1.41), conf 1.38(2.55), cls 0.09(0.64), total 6.71(10.40)
# 260280: nGT 3, recall 2, proposals 14, loss: x 0.27(1.40), y 0.07(1.01), w 5.06(3.38), h 0.17(1.39), conf 2.11(2.54), cls 0.15(0.63), total 7.84(10.35)
# 260284: nGT 5, recall 3, proposals 7, loss: x 1.37(1.40), y 0.38(1.00), w 0.92(3.33), h 2.40(1.41), conf 3.14(2.55), cls 0.21(0.62), total 8.42(10.31)
# 260288: nGT 6, recall 4, proposals 0, loss: x 0.50(1.38), y 0.88(1.00), w 1.09(3.29), h 0.60(1.39), conf 9.21(2.68), cls 1.02(0.63), total 13.29(10.37)
# 260292: nGT 7, recall 1, proposals 0, loss: x 4.03(1.43), y 0.38(0.99), w 1.13(3.25), h 0.83(1.38), conf 0.53(2.64), cls 0.57(0.63), total 7.47(10.31)
# 260296: nGT 3, recall 1, proposals 0, loss: x 1.19(1.43), y 1.78(1.00), w 1.12(3.20), h 0.23(1.36), conf 0.53(2.60), cls 0.21(0.62), total 5.05(10.21)
# 260300: nGT 7, recall 2, proposals 15, loss: x 3.07(1.46), y 0.42(0.99), w 2.86(3.20), h 2.02(1.37), conf 1.85(2.59), cls 0.60(0.62), total 10.82(10.22)
# 260304: nGT 7, recall 2, proposals 8, loss: x 2.28(1.47), y 2.21(1.01), w 5.90(3.25), h 3.70(1.41), conf 5.42(2.64), cls 0.58(0.62), total 20.09(10.41)
# 260308: nGT 4, recall 0, proposals 0, loss: x 1.05(1.47), y 0.77(1.01), w 5.79(3.29), h 5.11(1.48), conf 1.33(2.61), cls 0.45(0.62), total 14.51(10.48)
# 260312: nGT 8, recall 5, proposals 17, loss: x 2.32(1.48), y 0.80(1.00), w 0.29(3.24), h 0.30(1.46), conf 4.34(2.65), cls 0.38(0.61), total 8.44(10.44)
# 260316: nGT 2, recall 0, proposals 3, loss: x 0.25(1.46), y 0.48(0.99), w 5.66(3.28), h 1.02(1.45), conf 0.75(2.61), cls 0.78(0.62), total 8.94(10.42)
# 260320: nGT 7, recall 0, proposals 0, loss: x 4.19(1.51), y 0.88(0.99), w 1.44(3.25), h 0.79(1.44), conf 0.57(2.58), cls 0.95(0.62), total 8.81(10.39)
# 260324: nGT 3, recall 2, proposals 0, loss: x 1.08(1.50), y 0.06(0.98), w 0.22(3.20), h 0.25(1.42), conf 2.68(2.58), cls 0.46(0.62), total 4.75(10.29)
# 260328: nGT 8, recall 2, proposals 0, loss: x 2.49(1.52), y 0.83(0.97), w 3.39(3.20), h 1.27(1.42), conf 3.33(2.59), cls 0.67(0.62), total 11.98(10.32)
# 260332: nGT 0, recall 0, proposals 0, loss: x 0.00(1.49), y 0.00(0.96), w 0.00(3.15), h 0.00(1.39), conf 0.28(2.55), cls 0.00(0.61), total 0.28(10.16)
# 260336: nGT 1, recall 1, proposals 0, loss: x 0.04(1.47), y 0.01(0.94), w 0.29(3.10), h 0.83(1.39), conf 1.77(2.54), cls 0.14(0.60), total 3.09(10.04)
# 260340: nGT 6, recall 0, proposals 0, loss: x 0.75(1.46), y 0.30(0.93), w 1.14(3.07), h 2.44(1.40), conf 1.47(2.52), cls 0.31(0.60), total 6.40(9.99)
# 260344: nGT 5, recall 1, proposals 0, loss: x 1.43(1.46), y 0.39(0.92), w 1.37(3.05), h 0.23(1.38), conf 2.58(2.52), cls 0.35(0.59), total 6.36(9.93)
# 260348: nGT 10, recall 5, proposals 10, loss: x 1.89(1.46), y 2.05(0.94), w 19.70(3.30), h 2.24(1.40), conf 4.78(2.56), cls 0.57(0.59), total 31.23(10.26)
# 260352: nGT 9, recall 1, proposals 12, loss: x 4.47(1.51), y 0.37(0.93), w 4.79(3.33), h 6.68(1.48), conf 4.48(2.59), cls 0.45(0.59), total 21.25(10.42)
# 260356: nGT 2, recall 2, proposals 3, loss: x 0.01(1.49), y 0.07(0.92), w 0.16(3.28), h 0.06(1.46), conf 1.90(2.58), cls 0.01(0.58), total 2.23(10.30)
# 260360: nGT 8, recall 2, proposals 0, loss: x 1.84(1.49), y 0.63(0.92), w 0.93(3.24), h 2.74(1.48), conf 6.52(2.64), cls 0.61(0.58), total 13.27(10.34)
# 260364: nGT 5, recall 0, proposals 0, loss: x 3.03(1.51), y 1.75(0.93), w 3.97(3.25), h 0.29(1.46), conf 0.25(2.60), cls 0.46(0.58), total 9.75(10.34)
# 260368: nGT 3, recall 0, proposals 3, loss: x 1.62(1.52), y 0.82(0.93), w 0.16(3.21), h 0.34(1.44), conf 0.93(2.58), cls 0.26(0.58), total 4.13(10.25)
# 260372: nGT 10, recall 4, proposals 6, loss: x 2.10(1.52), y 0.87(0.93), w 5.10(3.24), h 2.34(1.45), conf 4.13(2.60), cls 0.62(0.58), total 15.16(10.32)
# 260376: nGT 1, recall 0, proposals 0, loss: x 0.72(1.51), y 0.00(0.91), w 0.02(3.19), h 0.08(1.44), conf 0.47(2.57), cls 0.41(0.57), total 1.70(10.20)
# 260380: nGT 5, recall 3, proposals 5, loss: x 0.91(1.50), y 1.40(0.92), w 3.48(3.20), h 3.03(1.46), conf 4.65(2.60), cls 0.76(0.58), total 14.22(10.25)
# 260384: nGT 6, recall 2, proposals 0, loss: x 1.57(1.51), y 0.84(0.92), w 2.24(3.18), h 0.08(1.44), conf 1.51(2.58), cls 0.26(0.57), total 6.50(10.20)
# 260388: nGT 4, recall 2, proposals 9, loss: x 1.68(1.51), y 1.82(0.93), w 2.69(3.18), h 0.73(1.43), conf 3.17(2.59), cls 0.60(0.57), total 10.69(10.21)
# 260392: nGT 8, recall 2, proposals 9, loss: x 3.53(1.53), y 2.56(0.95), w 2.76(3.17), h 0.59(1.42), conf 4.47(2.62), cls 0.63(0.57), total 14.55(10.26)
# 260396: nGT 5, recall 3, proposals 0, loss: x 1.30(1.53), y 1.14(0.95), w 0.53(3.14), h 2.82(1.44), conf 2.95(2.62), cls 0.28(0.57), total 9.02(10.25)
# 260400: nGT 8, recall 2, proposals 1, loss: x 2.04(1.54), y 1.28(0.96), w 4.31(3.15), h 2.01(1.44), conf 2.83(2.62), cls 1.21(0.58), total 13.69(10.29)
# 260404: nGT 6, recall 2, proposals 0, loss: x 2.57(1.55), y 0.88(0.96), w 0.57(3.12), h 0.29(1.43), conf 4.32(2.64), cls 0.37(0.58), total 9.01(10.28)
# 260408: nGT 5, recall 1, proposals 6, loss: x 1.69(1.55), y 0.37(0.95), w 3.87(3.13), h 0.44(1.42), conf 3.46(2.65), cls 1.09(0.58), total 10.93(10.28)
# 260412: nGT 2, recall 0, proposals 6, loss: x 1.89(1.56), y 0.12(0.94), w 0.94(3.10), h 0.31(1.40), conf 1.98(2.65), cls 0.06(0.58), total 5.30(10.22)
# 260416: nGT 3, recall 0, proposals 7, loss: x 1.29(1.55), y 1.04(0.94), w 1.44(3.08), h 0.07(1.39), conf 1.48(2.63), cls 0.29(0.57), total 5.60(10.17)
# 260420: nGT 4, recall 1, proposals 4, loss: x 1.06(1.55), y 0.50(0.94), w 0.44(3.05), h 0.45(1.38), conf 1.83(2.62), cls 0.56(0.57), total 4.84(10.10)
# 260424: nGT 6, recall 2, proposals 3, loss: x 1.51(1.55), y 1.11(0.94), w 1.90(3.04), h 1.22(1.37), conf 2.11(2.62), cls 0.63(0.57), total 8.48(10.08)
# 260428: nGT 9, recall 2, proposals 0, loss: x 1.01(1.54), y 2.37(0.95), w 1.56(3.02), h 1.99(1.38), conf 2.95(2.62), cls 0.67(0.57), total 10.55(10.09)
# 260432: nGT 3, recall 1, proposals 1, loss: x 1.08(1.54), y 0.07(0.94), w 0.22(2.99), h 0.02(1.37), conf 3.46(2.63), cls 0.37(0.57), total 5.22(10.03)
# 260436: nGT 2, recall 0, proposals 0, loss: x 1.29(1.53), y 0.21(0.94), w 1.13(2.96), h 0.68(1.36), conf 0.35(2.60), cls 0.29(0.57), total 3.94(9.96)
# 260440: nGT 7, recall 2, proposals 9, loss: x 2.06(1.54), y 1.16(0.94), w 2.77(2.96), h 2.80(1.37), conf 4.39(2.62), cls 0.75(0.57), total 13.94(10.01)
# 260444: nGT 4, recall 2, proposals 6, loss: x 1.35(1.54), y 0.04(0.93), w 2.20(2.95), h 2.99(1.39), conf 3.65(2.64), cls 0.37(0.57), total 10.60(10.01)
# 260448: nGT 4, recall 1, proposals 8, loss: x 1.36(1.53), y 1.11(0.93), w 3.27(2.96), h 0.70(1.38), conf 1.96(2.63), cls 0.84(0.57), total 9.23(10.01)
# 260452: nGT 2, recall 1, proposals 0, loss: x 0.07(1.52), y 0.93(0.93), w 1.22(2.94), h 2.38(1.40), conf 1.91(2.62), cls 0.19(0.57), total 6.71(9.97)
# 260456: nGT 4, recall 4, proposals 2, loss: x 0.38(1.51), y 0.91(0.93), w 1.15(2.92), h 0.06(1.38), conf 7.05(2.67), cls 0.60(0.57), total 10.15(9.97)
# 260460: nGT 7, recall 4, proposals 0, loss: x 0.75(1.50), y 2.03(0.94), w 3.11(2.92), h 5.19(1.42), conf 5.26(2.70), cls 0.80(0.57), total 17.13(10.05)
# 260464: nGT 3, recall 0, proposals 0, loss: x 1.64(1.50), y 0.23(0.93), w 1.47(2.90), h 1.37(1.42), conf 0.36(2.67), cls 0.38(0.57), total 5.45(10.00)
# 260468: nGT 6, recall 2, proposals 8, loss: x 1.27(1.50), y 1.36(0.94), w 3.39(2.91), h 0.55(1.41), conf 2.96(2.67), cls 1.19(0.57), total 10.71(10.01)
# 260472: nGT 11, recall 1, proposals 5, loss: x 1.72(1.50), y 1.57(0.95), w 2.82(2.91), h 4.99(1.45), conf 2.81(2.68), cls 1.38(0.58), total 15.28(10.06)
# 260476: nGT 5, recall 2, proposals 9, loss: x 1.10(1.50), y 3.29(0.97), w 1.32(2.89), h 0.46(1.44), conf 3.99(2.69), cls 0.38(0.58), total 10.53(10.07)
# 260480: nGT 4, recall 3, proposals 5, loss: x 0.69(1.49), y 1.25(0.97), w 2.03(2.88), h 0.75(1.43), conf 4.75(2.71), cls 0.28(0.58), total 9.75(10.06)
# 260484: nGT 5, recall 0, proposals 0, loss: x 1.53(1.49), y 2.08(0.98), w 0.11(2.86), h 0.69(1.42), conf 0.46(2.69), cls 0.25(0.57), total 5.12(10.01)
# 260488: nGT 2, recall 0, proposals 1, loss: x 0.61(1.48), y 0.37(0.98), w 0.17(2.83), h 0.03(1.41), conf 0.81(2.67), cls 0.09(0.57), total 2.09(9.93)
# 260492: nGT 3, recall 2, proposals 6, loss: x 1.24(1.48), y 0.51(0.97), w 1.07(2.81), h 0.18(1.40), conf 4.28(2.69), cls 0.14(0.56), total 7.41(9.91)
# 260496: nGT 11, recall 1, proposals 0, loss: x 7.27(1.53), y 0.94(0.97), w 9.84(2.88), h 9.65(1.48), conf 0.90(2.67), cls 1.71(0.58), total 30.32(10.11)
# 260500: nGT 7, recall 1, proposals 8, loss: x 1.32(1.53), y 0.63(0.97), w 1.85(2.87), h 3.79(1.50), conf 2.01(2.66), cls 1.42(0.58), total 11.02(10.12)
# 260504: nGT 6, recall 1, proposals 1, loss: x 2.22(1.54), y 0.16(0.96), w 1.63(2.86), h 2.74(1.51), conf 1.49(2.65), cls 0.59(0.58), total 8.82(10.11)
# 260508: nGT 4, recall 1, proposals 0, loss: x 1.63(1.54), y 0.59(0.96), w 16.13(2.99), h 0.55(1.50), conf 1.86(2.64), cls 0.37(0.58), total 21.14(10.21)
# 260512: nGT 5, recall 1, proposals 0, loss: x 3.00(1.55), y 2.44(0.97), w 1.26(2.97), h 2.16(1.51), conf 1.90(2.64), cls 0.39(0.58), total 11.15(10.22)
# 260516: nGT 4, recall 0, proposals 0, loss: x 0.36(1.54), y 0.12(0.96), w 3.86(2.98), h 1.78(1.51), conf 0.41(2.61), cls 0.23(0.58), total 6.77(10.19)
# 260520: nGT 8, recall 2, proposals 8, loss: x 3.51(1.56), y 1.94(0.97), w 0.31(2.95), h 0.39(1.50), conf 3.86(2.63), cls 0.91(0.58), total 10.92(10.19)
# 260524: nGT 7, recall 4, proposals 12, loss: x 2.05(1.56), y 0.81(0.97), w 4.79(2.97), h 1.09(1.50), conf 3.30(2.63), cls 0.44(0.58), total 12.49(10.22)
# 260528: nGT 4, recall 1, proposals 4, loss: x 1.96(1.57), y 0.34(0.97), w 0.32(2.95), h 0.64(1.49), conf 1.53(2.62), cls 0.46(0.58), total 5.25(10.17)
# 260532: nGT 4, recall 0, proposals 0, loss: x 1.33(1.57), y 2.74(0.98), w 4.97(2.96), h 3.40(1.51), conf 0.57(2.60), cls 0.83(0.58), total 13.85(10.20)
# 260536: nGT 5, recall 4, proposals 6, loss: x 0.97(1.56), y 1.78(0.99), w 0.49(2.94), h 0.25(1.50), conf 5.48(2.63), cls 0.39(0.58), total 9.37(10.20)
# 260540: nGT 9, recall 2, proposals 13, loss: x 4.25(1.58), y 2.10(1.00), w 7.33(2.98), h 3.63(1.52), conf 1.99(2.62), cls 1.17(0.58), total 20.48(10.29)
# 260544: nGT 5, recall 2, proposals 0, loss: x 1.91(1.59), y 1.18(1.00), w 1.01(2.96), h 1.55(1.52), conf 3.97(2.64), cls 0.90(0.59), total 10.52(10.29)
# 260548: nGT 2, recall 1, proposals 0, loss: x 0.23(1.57), y 0.13(0.99), w 0.63(2.94), h 0.24(1.51), conf 2.39(2.63), cls 0.34(0.58), total 3.95(10.23)
# 260552: nGT 2, recall 0, proposals 1, loss: x 0.78(1.57), y 0.99(0.99), w 2.17(2.94), h 1.77(1.51), conf 0.92(2.62), cls 0.09(0.58), total 6.72(10.20)
# 260556: nGT 7, recall 1, proposals 8, loss: x 2.58(1.58), y 3.20(1.01), w 2.06(2.93), h 1.46(1.51), conf 3.87(2.63), cls 0.98(0.58), total 14.15(10.24)
# 260560: nGT 5, recall 0, proposals 7, loss: x 1.98(1.58), y 2.29(1.02), w 2.53(2.93), h 1.06(1.50), conf 1.60(2.62), cls 0.47(0.58), total 9.94(10.23)
# 260564: nGT 5, recall 0, proposals 0, loss: x 2.60(1.59), y 0.55(1.02), w 1.54(2.91), h 2.43(1.51), conf 0.68(2.60), cls 0.44(0.58), total 8.24(10.22)
# 260568: nGT 7, recall 0, proposals 0, loss: x 2.35(1.59), y 1.22(1.02), w 2.58(2.91), h 3.50(1.53), conf 1.17(2.59), cls 0.41(0.58), total 11.22(10.23)
# 260572: nGT 6, recall 1, proposals 6, loss: x 1.72(1.60), y 1.05(1.02), w 3.03(2.91), h 0.50(1.52), conf 1.73(2.59), cls 0.53(0.58), total 8.56(10.21)
# 260576: nGT 7, recall 2, proposals 11, loss: x 2.49(1.60), y 0.34(1.01), w 1.70(2.90), h 1.07(1.52), conf 3.48(2.59), cls 1.49(0.59), total 10.57(10.22)
# 260580: nGT 4, recall 1, proposals 0, loss: x 1.69(1.60), y 0.45(1.01), w 1.13(2.89), h 0.40(1.51), conf 2.09(2.59), cls 0.34(0.59), total 6.10(10.18)
# 260584: nGT 4, recall 2, proposals 0, loss: x 0.14(1.59), y 0.72(1.01), w 0.90(2.87), h 0.87(1.50), conf 4.71(2.61), cls 0.56(0.59), total 7.90(10.16)
# 260588: nGT 4, recall 4, proposals 0, loss: x 0.17(1.58), y 1.01(1.01), w 2.15(2.87), h 1.03(1.50), conf 5.25(2.63), cls 0.90(0.59), total 10.53(10.17)
# 260592: nGT 3, recall 0, proposals 9, loss: x 1.01(1.58), y 0.13(1.00), w 0.46(2.85), h 0.23(1.49), conf 2.25(2.62), cls 0.04(0.58), total 4.12(10.12)
# 260596: nGT 5, recall 0, proposals 5, loss: x 3.89(1.59), y 0.35(1.00), w 0.96(2.83), h 0.23(1.48), conf 0.62(2.61), cls 0.54(0.58), total 6.59(10.09)
# 260600: nGT 3, recall 2, proposals 6, loss: x 1.00(1.59), y 0.01(0.99), w 0.30(2.81), h 0.01(1.47), conf 3.68(2.62), cls 0.21(0.58), total 5.20(10.05)
# 260604: nGT 8, recall 3, proposals 5, loss: x 3.62(1.61), y 1.69(0.99), w 6.26(2.84), h 0.54(1.46), conf 4.63(2.63), cls 0.95(0.58), total 17.69(10.11)
# 260608: nGT 2, recall 0, proposals 6, loss: x 0.47(1.60), y 0.04(0.99), w 0.80(2.82), h 0.86(1.45), conf 0.52(2.62), cls 0.03(0.58), total 2.72(10.05)
# 260612: nGT 5, recall 1, proposals 6, loss: x 1.40(1.60), y 0.63(0.98), w 5.85(2.85), h 3.01(1.47), conf 2.32(2.61), cls 0.89(0.58), total 14.10(10.09)
# 260616: nGT 7, recall 4, proposals 17, loss: x 2.75(1.60), y 0.32(0.98), w 2.53(2.84), h 0.43(1.46), conf 6.49(2.64), cls 0.40(0.58), total 12.93(10.11)
# 260620: nGT 6, recall 2, proposals 0, loss: x 1.89(1.61), y 0.32(0.97), w 2.92(2.84), h 2.53(1.47), conf 2.53(2.64), cls 0.47(0.58), total 10.65(10.11)
# 260624: nGT 4, recall 1, proposals 7, loss: x 2.51(1.61), y 0.34(0.97), w 0.23(2.82), h 0.29(1.46), conf 1.46(2.63), cls 0.57(0.58), total 5.40(10.08)
# 260628: nGT 6, recall 2, proposals 7, loss: x 2.37(1.62), y 1.21(0.97), w 2.16(2.82), h 1.32(1.46), conf 2.06(2.63), cls 0.20(0.58), total 9.33(10.07)
# 260632: nGT 1, recall 1, proposals 14, loss: x 0.63(1.61), y 0.06(0.96), w 0.39(2.80), h 0.01(1.45), conf 1.52(2.62), cls 0.03(0.57), total 2.64(10.02)
# 260636: nGT 6, recall 1, proposals 4, loss: x 1.34(1.61), y 1.40(0.97), w 4.08(2.81), h 3.51(1.46), conf 1.46(2.61), cls 0.72(0.57), total 12.52(10.03)
# 260640: nGT 10, recall 1, proposals 0, loss: x 4.84(1.63), y 4.04(0.99), w 3.97(2.82), h 3.18(1.47), conf 4.46(2.63), cls 2.05(0.58), total 22.55(10.12)
# 260644: nGT 7, recall 0, proposals 0, loss: x 4.05(1.65), y 0.47(0.99), w 7.64(2.85), h 0.16(1.46), conf 0.49(2.61), cls 0.47(0.58), total 13.29(10.15)
# 260648: nGT 9, recall 1, proposals 0, loss: x 3.49(1.66), y 1.39(0.99), w 6.83(2.88), h 5.41(1.49), conf 1.96(2.61), cls 0.94(0.59), total 20.02(10.22)
# 260652: nGT 8, recall 1, proposals 10, loss: x 2.99(1.67), y 4.11(1.01), w 3.92(2.89), h 2.79(1.50), conf 2.34(2.60), cls 0.97(0.59), total 17.12(10.27)
# 260656: nGT 5, recall 0, proposals 0, loss: x 1.03(1.67), y 0.94(1.01), w 5.78(2.91), h 0.59(1.49), conf 1.58(2.60), cls 0.83(0.59), total 10.74(10.27)
# 260660: nGT 3, recall 1, proposals 0, loss: x 2.41(1.67), y 0.54(1.01), w 0.55(2.89), h 0.37(1.49), conf 1.62(2.59), cls 1.16(0.59), total 6.65(10.25)
# 260664: nGT 6, recall 3, proposals 3, loss: x 1.87(1.67), y 2.47(1.02), w 2.89(2.89), h 3.13(1.50), conf 4.75(2.60), cls 1.16(0.60), total 16.27(10.29)
# 260668: nGT 7, recall 2, proposals 7, loss: x 2.34(1.68), y 0.79(1.02), w 3.83(2.90), h 0.97(1.49), conf 4.19(2.62), cls 0.66(0.60), total 12.77(10.30)
# 260672: nGT 6, recall 2, proposals 0, loss: x 3.27(1.69), y 1.23(1.02), w 3.63(2.91), h 3.19(1.51), conf 3.08(2.62), cls 0.73(0.60), total 15.13(10.34)
# 260676: nGT 6, recall 1, proposals 12, loss: x 2.80(1.70), y 0.45(1.01), w 0.71(2.89), h 0.16(1.50), conf 2.25(2.62), cls 0.63(0.60), total 7.01(10.31)
# 260680: nGT 9, recall 5, proposals 19, loss: x 1.84(1.70), y 1.94(1.02), w 2.18(2.89), h 0.47(1.49), conf 8.65(2.66), cls 0.67(0.60), total 15.75(10.35)
# 260684: nGT 4, recall 3, proposals 8, loss: x 0.20(1.69), y 0.12(1.01), w 2.34(2.88), h 0.32(1.48), conf 4.06(2.67), cls 0.21(0.60), total 7.26(10.33)
# 260688: nGT 5, recall 1, proposals 4, loss: x 2.55(1.69), y 1.41(1.02), w 8.47(2.92), h 1.45(1.48), conf 1.58(2.66), cls 0.86(0.60), total 16.33(10.37)
# 260692: nGT 2, recall 0, proposals 0, loss: x 0.18(1.68), y 0.08(1.01), w 1.98(2.91), h 4.22(1.50), conf 0.57(2.65), cls 0.49(0.60), total 7.53(10.35)
# 260696: nGT 7, recall 1, proposals 0, loss: x 0.27(1.68), y 0.50(1.01), w 2.44(2.91), h 0.89(1.50), conf 2.84(2.65), cls 0.89(0.60), total 7.83(10.34)
# 260700: nGT 7, recall 5, proposals 3, loss: x 0.47(1.67), y 3.26(1.02), w 3.35(2.91), h 1.21(1.49), conf 8.02(2.68), cls 0.85(0.60), total 17.16(10.38)
# 260704: nGT 4, recall 0, proposals 8, loss: x 0.89(1.66), y 1.00(1.02), w 1.43(2.90), h 0.88(1.49), conf 1.62(2.68), cls 0.64(0.60), total 6.47(10.35)
# 260708: nGT 1, recall 0, proposals 0, loss: x 0.11(1.65), y 0.00(1.01), w 0.54(2.89), h 0.08(1.48), conf 1.38(2.67), cls 0.42(0.60), total 2.53(10.30)
# 260712: nGT 6, recall 0, proposals 0, loss: x 3.66(1.66), y 1.52(1.02), w 4.24(2.90), h 5.16(1.50), conf 0.65(2.65), cls 0.91(0.60), total 16.14(10.34)
# 260716: nGT 10, recall 1, proposals 0, loss: x 2.99(1.67), y 0.51(1.01), w 0.86(2.88), h 0.51(1.50), conf 0.92(2.64), cls 0.64(0.60), total 6.43(10.32)
# 260720: nGT 3, recall 0, proposals 0, loss: x 1.68(1.67), y 2.06(1.02), w 0.38(2.87), h 0.37(1.49), conf 1.16(2.63), cls 0.54(0.60), total 6.19(10.29)
# 260724: nGT 3, recall 0, proposals 0, loss: x 2.15(1.68), y 0.44(1.02), w 2.01(2.86), h 0.83(1.49), conf 1.14(2.62), cls 0.32(0.60), total 6.89(10.27)
# 260728: nGT 7, recall 1, proposals 8, loss: x 4.48(1.69), y 3.17(1.03), w 2.48(2.86), h 2.01(1.49), conf 3.04(2.63), cls 0.43(0.60), total 15.61(10.30)
# 260732: nGT 3, recall 3, proposals 7, loss: x 1.14(1.69), y 0.17(1.03), w 0.51(2.85), h 0.55(1.48), conf 2.73(2.63), cls 0.42(0.60), total 5.51(10.27)
# 260736: nGT 5, recall 1, proposals 2, loss: x 1.48(1.69), y 1.96(1.03), w 1.99(2.84), h 0.73(1.48), conf 3.05(2.63), cls 0.67(0.60), total 9.87(10.27)
# 260740: nGT 6, recall 2, proposals 7, loss: x 0.72(1.68), y 0.30(1.03), w 4.65(2.85), h 1.35(1.48), conf 1.95(2.63), cls 0.51(0.60), total 9.49(10.27)
# 260744: nGT 3, recall 1, proposals 1, loss: x 1.47(1.68), y 0.90(1.03), w 0.68(2.84), h 0.07(1.47), conf 2.68(2.63), cls 0.16(0.60), total 5.96(10.24)
# 260748: nGT 11, recall 3, proposals 12, loss: x 3.68(1.69), y 0.81(1.02), w 8.74(2.87), h 2.67(1.48), conf 5.26(2.64), cls 0.63(0.60), total 21.80(10.31)
# 260752: nGT 6, recall 2, proposals 4, loss: x 1.28(1.69), y 0.33(1.02), w 2.94(2.87), h 1.21(1.48), conf 0.61(2.63), cls 0.69(0.60), total 7.06(10.29)
# 260756: nGT 5, recall 2, proposals 8, loss: x 1.05(1.69), y 0.86(1.02), w 0.08(2.86), h 0.45(1.47), conf 2.40(2.63), cls 0.79(0.60), total 5.62(10.26)
# 260760: nGT 7, recall 3, proposals 8, loss: x 1.48(1.69), y 1.68(1.02), w 1.59(2.85), h 0.48(1.46), conf 3.95(2.64), cls 0.50(0.60), total 9.68(10.26)
# 260764: nGT 3, recall 1, proposals 0, loss: x 0.93(1.68), y 0.64(1.02), w 2.25(2.85), h 0.32(1.46), conf 2.88(2.64), cls 0.21(0.59), total 7.22(10.24)
# 260768: nGT 5, recall 1, proposals 8, loss: x 2.43(1.69), y 2.16(1.03), w 1.41(2.84), h 0.24(1.45), conf 2.35(2.64), cls 0.24(0.59), total 8.84(10.23)
# 260772: nGT 12, recall 4, proposals 6, loss: x 3.30(1.70), y 1.72(1.03), w 1.51(2.83), h 1.32(1.45), conf 5.17(2.65), cls 0.73(0.59), total 13.74(10.25)
# 260776: nGT 2, recall 1, proposals 0, loss: x 0.64(1.69), y 0.09(1.03), w 2.65(2.83), h 0.35(1.44), conf 2.74(2.65), cls 0.23(0.59), total 6.70(10.23)
# 260780: nGT 7, recall 0, proposals 11, loss: x 3.71(1.70), y 3.63(1.04), w 2.59(2.83), h 1.37(1.44), conf 2.14(2.65), cls 0.66(0.59), total 14.10(10.25)
# 260784: nGT 2, recall 1, proposals 3, loss: x 0.13(1.69), y 0.14(1.04), w 2.57(2.83), h 0.74(1.44), conf 1.35(2.64), cls 0.12(0.59), total 5.04(10.22)
# 260788: nGT 6, recall 1, proposals 6, loss: x 1.99(1.69), y 1.65(1.04), w 3.86(2.83), h 1.28(1.44), conf 3.21(2.64), cls 0.60(0.59), total 12.58(10.24)
# 260792: nGT 11, recall 6, proposals 14, loss: x 1.93(1.70), y 0.68(1.04), w 5.39(2.85), h 0.38(1.43), conf 5.66(2.66), cls 0.29(0.59), total 14.32(10.26)
# 260796: nGT 3, recall 1, proposals 0, loss: x 0.38(1.69), y 0.58(1.04), w 1.70(2.84), h 0.17(1.42), conf 2.16(2.66), cls 0.32(0.59), total 5.32(10.23)
# 260800: nGT 4, recall 1, proposals 0, loss: x 0.42(1.68), y 1.48(1.04), w 6.88(2.86), h 3.17(1.43), conf 2.07(2.66), cls 0.63(0.59), total 14.65(10.26)
# 260804: nGT 6, recall 1, proposals 4, loss: x 1.74(1.68), y 1.01(1.04), w 2.64(2.86), h 0.96(1.43), conf 3.43(2.66), cls 0.64(0.59), total 10.43(10.26)
# 260808: nGT 5, recall 3, proposals 8, loss: x 1.68(1.68), y 1.22(1.04), w 1.90(2.86), h 1.12(1.43), conf 1.82(2.65), cls 0.26(0.58), total 8.01(10.25)
# 260812: nGT 3, recall 0, proposals 8, loss: x 2.23(1.68), y 0.89(1.04), w 1.72(2.85), h 0.37(1.42), conf 1.08(2.65), cls 0.22(0.58), total 6.51(10.23)
# 260816: nGT 4, recall 0, proposals 0, loss: x 2.08(1.69), y 0.32(1.03), w 4.14(2.86), h 1.52(1.42), conf 0.48(2.63), cls 0.89(0.58), total 9.43(10.22)
# 260820: nGT 15, recall 2, proposals 5, loss: x 7.46(1.72), y 1.46(1.04), w 5.08(2.87), h 3.28(1.43), conf 5.00(2.65), cls 0.76(0.59), total 23.03(10.29)
# 260824: nGT 3, recall 2, proposals 0, loss: x 0.63(1.71), y 0.17(1.03), w 1.32(2.86), h 0.08(1.43), conf 2.86(2.65), cls 0.21(0.58), total 5.27(10.26)
# 260828: nGT 5, recall 1, proposals 0, loss: x 0.59(1.71), y 1.04(1.03), w 1.53(2.85), h 0.62(1.42), conf 3.93(2.66), cls 0.54(0.58), total 8.26(10.25)
# 260832: nGT 3, recall 1, proposals 6, loss: x 1.02(1.70), y 0.80(1.03), w 0.71(2.84), h 0.48(1.42), conf 0.89(2.65), cls 0.57(0.58), total 4.47(10.22)
# 260836: nGT 6, recall 3, proposals 11, loss: x 3.10(1.71), y 1.70(1.03), w 1.27(2.83), h 0.18(1.41), conf 4.64(2.66), cls 0.35(0.58), total 11.25(10.23)
# 260840: nGT 3, recall 3, proposals 8, loss: x 0.10(1.70), y 0.95(1.03), w 1.25(2.83), h 0.66(1.41), conf 4.23(2.66), cls 0.44(0.58), total 7.63(10.21)
# 260844: nGT 2, recall 0, proposals 0, loss: x 0.49(1.69), y 1.06(1.03), w 2.10(2.82), h 2.82(1.42), conf 0.23(2.65), cls 0.48(0.58), total 7.18(10.20)
# 260848: nGT 6, recall 0, proposals 7, loss: x 1.59(1.69), y 2.17(1.04), w 2.80(2.82), h 1.60(1.42), conf 1.38(2.65), cls 0.55(0.58), total 10.10(10.20)
# 260852: nGT 6, recall 1, proposals 0, loss: x 2.04(1.70), y 0.11(1.03), w 2.58(2.82), h 0.88(1.41), conf 2.42(2.64), cls 0.53(0.58), total 8.56(10.19)
# 260856: nGT 6, recall 4, proposals 2, loss: x 1.71(1.70), y 1.06(1.03), w 1.81(2.81), h 0.33(1.41), conf 6.04(2.66), cls 1.27(0.58), total 12.22(10.20)
# 260860: nGT 7, recall 2, proposals 7, loss: x 3.25(1.70), y 0.12(1.03), w 1.56(2.81), h 0.85(1.40), conf 3.18(2.66), cls 0.43(0.58), total 9.39(10.19)
# 260864: nGT 4, recall 0, proposals 10, loss: x 1.61(1.70), y 0.48(1.03), w 0.27(2.80), h 0.40(1.40), conf 1.80(2.66), cls 0.16(0.58), total 4.72(10.17)
# 260868: nGT 4, recall 2, proposals 2, loss: x 1.17(1.70), y 1.03(1.03), w 0.26(2.78), h 0.09(1.39), conf 5.65(2.68), cls 0.38(0.58), total 8.59(10.16)
# 260872: nGT 5, recall 2, proposals 2, loss: x 1.77(1.70), y 0.25(1.02), w 0.31(2.77), h 1.82(1.39), conf 2.92(2.68), cls 0.92(0.58), total 7.99(10.15)
# 260876: nGT 6, recall 3, proposals 12, loss: x 1.37(1.70), y 0.54(1.02), w 2.89(2.77), h 0.95(1.39), conf 2.93(2.68), cls 0.36(0.58), total 9.04(10.14)
# 260880: nGT 4, recall 0, proposals 3, loss: x 3.22(1.71), y 0.26(1.02), w 0.72(2.76), h 1.31(1.39), conf 1.17(2.67), cls 0.38(0.58), total 7.06(10.13)
# 260884: nGT 6, recall 1, proposals 13, loss: x 3.53(1.72), y 0.50(1.01), w 2.37(2.76), h 1.85(1.39), conf 4.30(2.68), cls 0.32(0.58), total 12.89(10.14)
# 260888: nGT 4, recall 2, proposals 14, loss: x 1.06(1.71), y 0.92(1.01), w 0.64(2.75), h 0.57(1.39), conf 2.73(2.68), cls 0.30(0.58), total 6.21(10.12)
# 260892: nGT 3, recall 1, proposals 15, loss: x 1.69(1.71), y 0.73(1.01), w 0.51(2.74), h 0.21(1.38), conf 1.70(2.67), cls 0.20(0.57), total 5.05(10.10)
# 260896: nGT 6, recall 2, proposals 3, loss: x 2.78(1.72), y 0.92(1.01), w 1.88(2.73), h 0.27(1.38), conf 1.63(2.67), cls 0.93(0.58), total 8.42(10.09)
# 260900: nGT 6, recall 3, proposals 5, loss: x 1.64(1.72), y 0.66(1.01), w 8.56(2.76), h 5.34(1.40), conf 3.88(2.67), cls 1.15(0.58), total 21.23(10.14)
# 260904: nGT 4, recall 3, proposals 10, loss: x 1.56(1.72), y 1.54(1.01), w 0.77(2.75), h 0.34(1.39), conf 3.47(2.68), cls 0.70(0.58), total 8.38(10.13)
# 260908: nGT 3, recall 2, proposals 23, loss: x 2.18(1.72), y 0.18(1.01), w 0.08(2.74), h 0.28(1.39), conf 6.06(2.70), cls 0.45(0.58), total 9.24(10.13)
# 260912: nGT 6, recall 2, proposals 0, loss: x 2.17(1.72), y 1.35(1.01), w 2.15(2.74), h 2.04(1.39), conf 4.07(2.70), cls 0.66(0.58), total 12.45(10.14)
# 260916: nGT 4, recall 0, proposals 2, loss: x 0.99(1.72), y 0.49(1.01), w 3.26(2.74), h 0.25(1.39), conf 1.93(2.70), cls 0.14(0.58), total 7.06(10.13)
# 260920: nGT 8, recall 2, proposals 0, loss: x 1.16(1.72), y 1.28(1.01), w 1.72(2.73), h 0.72(1.38), conf 4.12(2.71), cls 0.73(0.58), total 9.72(10.12)
# 260924: nGT 5, recall 1, proposals 8, loss: x 1.48(1.71), y 1.57(1.01), w 3.88(2.74), h 0.61(1.38), conf 4.41(2.71), cls 0.62(0.58), total 12.57(10.14)
# 260928: nGT 3, recall 1, proposals 6, loss: x 0.85(1.71), y 0.71(1.01), w 0.32(2.73), h 0.13(1.37), conf 3.04(2.71), cls 0.15(0.58), total 5.19(10.11)
# 260932: nGT 2, recall 1, proposals 4, loss: x 0.20(1.70), y 0.39(1.01), w 0.65(2.72), h 0.48(1.37), conf 2.14(2.71), cls 0.27(0.57), total 4.13(10.08)
# 260936: nGT 5, recall 1, proposals 1, loss: x 2.71(1.71), y 2.04(1.01), w 1.48(2.71), h 0.41(1.36), conf 3.61(2.72), cls 0.34(0.57), total 10.59(10.09)
# 260940: nGT 5, recall 1, proposals 6, loss: x 1.27(1.71), y 0.70(1.01), w 0.68(2.70), h 0.07(1.36), conf 1.60(2.71), cls 0.57(0.57), total 4.88(10.06)
# 260944: nGT 5, recall 0, proposals 0, loss: x 2.83(1.71), y 0.28(1.01), w 13.44(2.75), h 0.36(1.35), conf 1.05(2.70), cls 1.27(0.58), total 19.23(10.10)
# 260948: nGT 5, recall 2, proposals 6, loss: x 1.73(1.71), y 2.80(1.02), w 1.88(2.75), h 0.53(1.35), conf 3.43(2.71), cls 1.07(0.58), total 11.46(10.11)
# 260952: nGT 3, recall 2, proposals 0, loss: x 0.49(1.71), y 2.23(1.02), w 0.90(2.74), h 0.65(1.35), conf 3.47(2.71), cls 0.47(0.58), total 8.22(10.10)
# 260956: nGT 11, recall 4, proposals 8, loss: x 3.05(1.71), y 1.36(1.02), w 1.72(2.73), h 1.48(1.35), conf 7.22(2.73), cls 1.26(0.58), total 16.09(10.13)
# 260960: nGT 4, recall 0, proposals 0, loss: x 0.88(1.71), y 0.20(1.02), w 1.65(2.73), h 0.89(1.34), conf 0.41(2.72), cls 0.33(0.58), total 4.36(10.10)
# 260964: nGT 13, recall 7, proposals 14, loss: x 4.76(1.72), y 1.80(1.02), w 3.40(2.73), h 1.42(1.35), conf 5.99(2.74), cls 0.30(0.58), total 17.67(10.14)
# 260968: nGT 4, recall 1, proposals 2, loss: x 1.87(1.72), y 1.72(1.03), w 3.24(2.73), h 0.26(1.34), conf 1.47(2.73), cls 1.10(0.58), total 9.66(10.14)
# 260972: nGT 1, recall 0, proposals 0, loss: x 0.52(1.72), y 0.05(1.02), w 0.00(2.72), h 0.12(1.33), conf 0.61(2.72), cls 0.10(0.58), total 1.41(10.10)
# 260976: nGT 5, recall 1, proposals 5, loss: x 0.73(1.71), y 0.31(1.02), w 0.62(2.71), h 0.71(1.33), conf 1.87(2.72), cls 0.57(0.58), total 4.80(10.07)
# 260980: nGT 8, recall 1, proposals 0, loss: x 2.51(1.72), y 0.81(1.02), w 1.79(2.71), h 3.63(1.34), conf 2.08(2.71), cls 0.67(0.58), total 11.49(10.08)
# 260984: nGT 8, recall 1, proposals 1, loss: x 4.20(1.73), y 1.19(1.02), w 3.13(2.71), h 0.86(1.34), conf 1.28(2.71), cls 1.12(0.58), total 11.78(10.09)
# 260988: nGT 6, recall 2, proposals 6, loss: x 2.84(1.73), y 0.82(1.02), w 19.71(2.79), h 0.18(1.33), conf 3.84(2.71), cls 0.45(0.58), total 27.84(10.16)
# 260992: nGT 7, recall 1, proposals 0, loss: x 1.20(1.73), y 0.70(1.02), w 1.85(2.78), h 0.96(1.33), conf 1.79(2.71), cls 0.62(0.58), total 7.11(10.15)
# 260996: nGT 3, recall 1, proposals 4, loss: x 0.59(1.72), y 0.27(1.01), w 0.23(2.77), h 0.11(1.33), conf 1.94(2.70), cls 0.10(0.58), total 3.24(10.12)
# 261000: nGT 5, recall 2, proposals 0, loss: x 1.13(1.72), y 0.33(1.01), w 2.24(2.77), h 1.81(1.33), conf 4.62(2.71), cls 0.64(0.58), total 10.78(10.12)
# 261004: nGT 7, recall 0, proposals 6, loss: x 3.86(1.73), y 0.15(1.01), w 1.16(2.76), h 2.09(1.33), conf 0.85(2.70), cls 0.98(0.58), total 9.10(10.12)
# 261008: nGT 5, recall 2, proposals 7, loss: x 2.55(1.74), y 0.99(1.01), w 4.52(2.77), h 1.48(1.33), conf 2.23(2.70), cls 0.17(0.58), total 11.93(10.13)
# 261012: nGT 3, recall 1, proposals 6, loss: x 1.33(1.73), y 0.06(1.00), w 1.47(2.76), h 0.83(1.33), conf 2.54(2.70), cls 0.85(0.58), total 7.08(10.11)
# 261016: nGT 7, recall 2, proposals 14, loss: x 1.71(1.73), y 2.09(1.01), w 2.04(2.76), h 0.51(1.33), conf 2.53(2.70), cls 0.68(0.58), total 9.57(10.11)
# 261020: nGT 4, recall 0, proposals 9, loss: x 2.34(1.74), y 0.52(1.00), w 15.02(2.81), h 0.02(1.32), conf 1.23(2.69), cls 0.36(0.58), total 19.49(10.15)
# 261024: nGT 7, recall 1, proposals 7, loss: x 3.22(1.74), y 0.99(1.00), w 3.52(2.82), h 1.78(1.32), conf 3.94(2.70), cls 1.03(0.58), total 14.48(10.17)
# 261028: nGT 3, recall 1, proposals 0, loss: x 1.00(1.74), y 0.83(1.00), w 3.06(2.82), h 0.70(1.32), conf 1.70(2.70), cls 0.63(0.58), total 7.92(10.16)
# 261032: nGT 7, recall 2, proposals 5, loss: x 1.05(1.74), y 0.57(1.00), w 1.83(2.81), h 0.32(1.32), conf 3.97(2.70), cls 0.53(0.58), total 8.27(10.15)
# 261036: nGT 2, recall 1, proposals 0, loss: x 1.16(1.73), y 0.64(1.00), w 0.87(2.80), h 0.20(1.31), conf 3.31(2.70), cls 0.72(0.58), total 6.90(10.14)
# 261040: nGT 2, recall 0, proposals 0, loss: x 0.75(1.73), y 0.30(1.00), w 0.69(2.80), h 1.02(1.31), conf 0.43(2.69), cls 0.44(0.58), total 3.63(10.11)
# 261044: nGT 3, recall 0, proposals 4, loss: x 1.05(1.73), y 0.75(1.00), w 0.09(2.78), h 0.12(1.31), conf 1.57(2.69), cls 0.37(0.58), total 3.96(10.09)
# 261048: nGT 1, recall 0, proposals 0, loss: x 0.06(1.72), y 0.03(0.99), w 0.04(2.77), h 0.04(1.30), conf 0.71(2.68), cls 0.09(0.58), total 0.97(10.05)
# 261052: nGT 4, recall 1, proposals 0, loss: x 1.01(1.72), y 0.28(0.99), w 1.55(2.77), h 0.95(1.30), conf 2.49(2.68), cls 0.54(0.58), total 6.82(10.03)
# 261056: nGT 5, recall 1, proposals 6, loss: x 2.50(1.72), y 2.36(0.99), w 2.87(2.77), h 1.41(1.30), conf 2.16(2.68), cls 0.67(0.58), total 11.98(10.04)
# 261060: nGT 4, recall 0, proposals 0, loss: x 1.09(1.72), y 0.44(0.99), w 0.67(2.76), h 0.45(1.30), conf 0.82(2.67), cls 0.52(0.58), total 4.00(10.02)
# 261064: nGT 6, recall 1, proposals 4, loss: x 2.82(1.72), y 2.16(1.00), w 2.95(2.76), h 1.21(1.30), conf 2.17(2.67), cls 2.43(0.59), total 13.74(10.03)
# 261068: nGT 4, recall 0, proposals 0, loss: x 2.33(1.72), y 1.21(1.00), w 2.36(2.76), h 1.69(1.30), conf 0.80(2.66), cls 0.60(0.59), total 8.99(10.03)
# 261072: nGT 5, recall 2, proposals 0, loss: x 1.97(1.73), y 1.12(1.00), w 1.30(2.75), h 0.29(1.29), conf 2.17(2.66), cls 0.46(0.59), total 7.32(10.02)
# 261076: nGT 7, recall 1, proposals 5, loss: x 2.78(1.73), y 4.65(1.01), w 6.28(2.77), h 0.81(1.29), conf 3.08(2.66), cls 0.74(0.59), total 18.34(10.05)
# 261080: nGT 5, recall 0, proposals 0, loss: x 3.04(1.74), y 0.20(1.01), w 3.09(2.77), h 4.71(1.31), conf 0.75(2.65), cls 0.54(0.59), total 12.34(10.06)
# 261084: nGT 3, recall 1, proposals 14, loss: x 1.85(1.74), y 0.33(1.01), w 1.94(2.77), h 0.10(1.30), conf 1.06(2.65), cls 0.45(0.59), total 5.73(10.04)
# 261088: nGT 8, recall 0, proposals 2, loss: x 1.73(1.74), y 0.31(1.00), w 1.29(2.76), h 2.31(1.31), conf 2.11(2.64), cls 0.59(0.59), total 8.34(10.04)
# 261092: nGT 4, recall 0, proposals 0, loss: x 2.35(1.74), y 0.83(1.00), w 1.49(2.75), h 0.55(1.30), conf 1.36(2.64), cls 0.33(0.59), total 6.92(10.02)
# 261096: nGT 10, recall 0, proposals 0, loss: x 4.06(1.75), y 1.74(1.01), w 4.75(2.76), h 1.46(1.30), conf 0.53(2.63), cls 0.84(0.59), total 13.38(10.04)
# 261100: nGT 6, recall 0, proposals 1, loss: x 1.86(1.75), y 0.45(1.00), w 6.61(2.78), h 0.23(1.30), conf 1.46(2.63), cls 0.38(0.59), total 10.98(10.04)
# 261104: nGT 1, recall 1, proposals 0, loss: x 0.00(1.74), y 0.47(1.00), w 0.54(2.77), h 0.22(1.29), conf 1.29(2.62), cls 0.03(0.58), total 2.56(10.01)
# 261108: nGT 4, recall 0, proposals 5, loss: x 0.85(1.74), y 0.07(1.00), w 0.27(2.76), h 1.25(1.29), conf 0.52(2.61), cls 0.48(0.58), total 3.44(9.99)
# 261112: nGT 5, recall 0, proposals 3, loss: x 3.25(1.74), y 0.80(1.00), w 6.26(2.77), h 2.83(1.30), conf 1.22(2.61), cls 0.57(0.58), total 14.91(10.00)
# 261116: nGT 4, recall 0, proposals 0, loss: x 0.89(1.74), y 0.26(1.00), w 0.41(2.76), h 0.69(1.30), conf 1.51(2.60), cls 0.37(0.58), total 4.14(9.98)
# 261120: nGT 3, recall 1, proposals 6, loss: x 1.20(1.74), y 0.93(0.99), w 0.40(2.75), h 0.21(1.29), conf 3.19(2.61), cls 0.49(0.58), total 6.43(9.97)
# 261124: nGT 2, recall 1, proposals 7, loss: x 0.16(1.73), y 0.16(0.99), w 0.60(2.75), h 0.73(1.29), conf 1.47(2.60), cls 0.18(0.58), total 3.29(9.94)
# 261128: nGT 6, recall 0, proposals 0, loss: x 2.98(1.74), y 3.14(1.00), w 5.01(2.75), h 0.27(1.29), conf 1.40(2.60), cls 0.87(0.58), total 13.67(9.96)
# 261132: nGT 5, recall 3, proposals 0, loss: x 1.16(1.73), y 0.17(1.00), w 2.39(2.75), h 0.75(1.29), conf 4.41(2.60), cls 0.46(0.58), total 9.35(9.95)
# 261136: nGT 5, recall 2, proposals 13, loss: x 2.20(1.74), y 2.05(1.00), w 2.63(2.75), h 1.44(1.29), conf 1.39(2.60), cls 0.96(0.58), total 10.67(9.96)
# 261140: nGT 3, recall 1, proposals 0, loss: x 0.95(1.73), y 0.43(1.00), w 1.41(2.75), h 1.58(1.29), conf 2.31(2.60), cls 0.44(0.58), total 7.13(9.95)
# 261144: nGT 3, recall 0, proposals 5, loss: x 1.31(1.73), y 0.15(1.00), w 0.22(2.74), h 0.11(1.28), conf 0.52(2.59), cls 0.35(0.58), total 2.66(9.92)
# 261148: nGT 5, recall 2, proposals 3, loss: x 1.39(1.73), y 1.97(1.00), w 1.09(2.73), h 0.54(1.28), conf 2.20(2.59), cls 0.42(0.58), total 7.59(9.91)
# 261152: nGT 4, recall 0, proposals 0, loss: x 2.76(1.73), y 0.19(1.00), w 0.21(2.72), h 0.36(1.28), conf 0.74(2.58), cls 0.65(0.58), total 4.91(9.89)
# 261156: nGT 11, recall 1, proposals 0, loss: x 4.45(1.74), y 1.99(1.00), w 4.56(2.73), h 2.42(1.28), conf 2.60(2.58), cls 1.32(0.58), total 17.34(9.92)
# 261160: nGT 7, recall 3, proposals 8, loss: x 3.30(1.75), y 0.61(1.00), w 0.78(2.72), h 0.93(1.28), conf 2.68(2.58), cls 0.60(0.58), total 8.90(9.92)
# 261164: nGT 7, recall 1, proposals 6, loss: x 2.55(1.75), y 0.70(1.00), w 1.41(2.72), h 0.42(1.28), conf 1.09(2.58), cls 0.69(0.58), total 6.86(9.90)
# 261168: nGT 0, recall 0, proposals 0, loss: x 0.00(1.75), y 0.00(0.99), w 0.00(2.71), h 0.00(1.27), conf 0.26(2.57), cls 0.00(0.58), total 0.26(9.87)
# 261172: nGT 6, recall 3, proposals 8, loss: x 1.52(1.75), y 0.25(0.99), w 2.06(2.70), h 0.18(1.27), conf 7.06(2.58), cls 0.33(0.58), total 11.40(9.87)
# 261176: nGT 4, recall 1, proposals 2, loss: x 0.31(1.74), y 0.07(0.99), w 1.13(2.70), h 0.43(1.26), conf 2.27(2.58), cls 0.42(0.58), total 4.63(9.85)
# 261180: nGT 2, recall 1, proposals 4, loss: x 1.07(1.74), y 0.46(0.99), w 1.80(2.70), h 0.02(1.26), conf 1.56(2.58), cls 0.07(0.58), total 4.97(9.84)
# 261184: nGT 7, recall 1, proposals 5, loss: x 2.96(1.74), y 3.73(1.00), w 5.51(2.71), h 0.77(1.26), conf 3.19(2.58), cls 0.79(0.58), total 16.97(9.86)
# 261188: nGT 8, recall 3, proposals 12, loss: x 2.49(1.75), y 0.95(1.00), w 1.18(2.70), h 0.18(1.25), conf 4.09(2.59), cls 0.15(0.58), total 9.03(9.86)
# 261192: nGT 7, recall 1, proposals 5, loss: x 2.22(1.75), y 0.71(0.99), w 28.81(2.79), h 0.74(1.25), conf 1.44(2.58), cls 0.43(0.58), total 34.36(9.95)
# 261196: nGT 5, recall 1, proposals 3, loss: x 1.94(1.75), y 3.47(1.00), w 1.24(2.79), h 3.91(1.26), conf 2.20(2.58), cls 0.99(0.58), total 13.74(9.96)
# 261200: nGT 3, recall 1, proposals 0, loss: x 1.56(1.75), y 0.10(1.00), w 0.30(2.78), h 0.28(1.26), conf 3.40(2.58), cls 0.20(0.58), total 5.84(9.95)
# 261204: nGT 5, recall 0, proposals 0, loss: x 1.35(1.75), y 0.46(1.00), w 2.45(2.78), h 1.45(1.26), conf 1.75(2.58), cls 0.42(0.58), total 7.88(9.94)
# 261208: nGT 5, recall 0, proposals 1, loss: x 2.17(1.75), y 0.66(1.00), w 0.74(2.77), h 0.42(1.26), conf 0.77(2.57), cls 0.48(0.58), total 5.23(9.92)
# 261212: nGT 10, recall 2, proposals 0, loss: x 5.21(1.76), y 2.96(1.00), w 8.73(2.79), h 3.36(1.26), conf 3.22(2.58), cls 1.29(0.58), total 24.77(9.98)
# 261216: nGT 6, recall 1, proposals 0, loss: x 2.95(1.76), y 2.63(1.01), w 1.26(2.79), h 0.88(1.26), conf 1.41(2.57), cls 1.21(0.58), total 10.34(9.98)
# 261220: nGT 9, recall 1, proposals 0, loss: x 0.20(1.76), y 0.61(1.01), w 1.11(2.78), h 1.65(1.26), conf 1.19(2.57), cls 1.02(0.58), total 5.77(9.96)
# 261224: nGT 6, recall 1, proposals 1, loss: x 4.17(1.77), y 0.69(1.01), w 4.24(2.79), h 1.46(1.26), conf 0.89(2.56), cls 0.78(0.58), total 12.23(9.97)
# 261228: nGT 6, recall 3, proposals 6, loss: x 1.50(1.77), y 0.65(1.01), w 1.25(2.78), h 0.11(1.26), conf 5.58(2.57), cls 1.02(0.59), total 10.10(9.97)
# 261232: nGT 3, recall 1, proposals 3, loss: x 0.54(1.76), y 0.26(1.00), w 0.25(2.77), h 0.08(1.26), conf 1.77(2.57), cls 0.40(0.58), total 3.30(9.95)
# 261236: nGT 8, recall 0, proposals 0, loss: x 3.45(1.77), y 0.41(1.00), w 1.83(2.77), h 2.65(1.26), conf 0.36(2.56), cls 1.15(0.59), total 9.86(9.95)
# 261240: nGT 4, recall 3, proposals 0, loss: x 1.47(1.77), y 0.92(1.00), w 1.05(2.76), h 0.23(1.26), conf 5.05(2.57), cls 0.55(0.59), total 9.27(9.94)
# 261244: nGT 3, recall 0, proposals 3, loss: x 1.23(1.76), y 0.20(1.00), w 2.04(2.76), h 0.14(1.25), conf 2.06(2.57), cls 0.30(0.59), total 5.98(9.93)
# 261248: nGT 4, recall 0, proposals 15, loss: x 1.76(1.76), y 1.17(1.00), w 0.25(2.75), h 0.15(1.25), conf 0.86(2.56), cls 0.30(0.58), total 4.50(9.91)
# 261252: nGT 4, recall 1, proposals 0, loss: x 1.44(1.76), y 0.41(1.00), w 1.86(2.75), h 0.18(1.25), conf 3.20(2.57), cls 0.24(0.58), total 7.32(9.90)
# 261256: nGT 6, recall 2, proposals 14, loss: x 2.46(1.77), y 1.37(1.00), w 3.45(2.75), h 0.35(1.24), conf 4.00(2.57), cls 1.24(0.59), total 12.87(9.91)
# 261260: nGT 3, recall 2, proposals 0, loss: x 0.33(1.76), y 1.32(1.00), w 0.65(2.74), h 0.07(1.24), conf 5.35(2.58), cls 0.50(0.59), total 8.21(9.91)
# 261264: nGT 7, recall 1, proposals 0, loss: x 4.28(1.77), y 0.97(1.00), w 4.41(2.75), h 4.17(1.25), conf 2.41(2.58), cls 0.91(0.59), total 17.14(9.93)
# 261268: nGT 3, recall 0, proposals 0, loss: x 1.69(1.77), y 0.27(1.00), w 0.38(2.74), h 1.14(1.25), conf 0.22(2.57), cls 0.67(0.59), total 4.38(9.91)
# 261272: nGT 8, recall 3, proposals 0, loss: x 3.40(1.77), y 1.07(1.00), w 3.44(2.74), h 1.71(1.25), conf 5.16(2.58), cls 0.46(0.59), total 15.24(9.93)
# 261276: nGT 3, recall 3, proposals 6, loss: x 0.17(1.77), y 0.77(1.00), w 0.28(2.74), h 0.09(1.25), conf 5.31(2.59), cls 0.28(0.59), total 6.90(9.92)
# 261280: nGT 8, recall 6, proposals 0, loss: x 2.38(1.77), y 1.62(1.00), w 1.23(2.73), h 0.27(1.24), conf 9.20(2.61), cls 0.68(0.59), total 15.39(9.94)
# 261284: nGT 6, recall 1, proposals 0, loss: x 1.85(1.77), y 1.29(1.00), w 0.92(2.72), h 2.13(1.25), conf 1.49(2.61), cls 0.64(0.59), total 8.31(9.93)
# 261288: nGT 6, recall 0, proposals 8, loss: x 2.84(1.77), y 1.39(1.00), w 1.55(2.72), h 0.45(1.24), conf 2.28(2.61), cls 0.39(0.58), total 8.88(9.93)
# 261292: nGT 1, recall 0, proposals 0, loss: x 0.67(1.77), y 0.03(1.00), w 0.56(2.71), h 0.25(1.24), conf 0.19(2.60), cls 0.29(0.58), total 1.99(9.90)
# 261296: nGT 7, recall 3, proposals 4, loss: x 0.81(1.77), y 1.05(1.00), w 4.72(2.72), h 1.65(1.24), conf 3.85(2.60), cls 0.54(0.58), total 12.62(9.91)
# 261300: nGT 3, recall 0, proposals 0, loss: x 1.90(1.77), y 0.19(0.99), w 0.05(2.71), h 0.09(1.24), conf 0.67(2.60), cls 0.10(0.58), total 3.00(9.89)
# 261304: nGT 4, recall 1, proposals 0, loss: x 1.65(1.77), y 1.11(1.00), w 0.96(2.71), h 0.37(1.23), conf 3.13(2.60), cls 0.35(0.58), total 7.58(9.88)
# 261308: nGT 12, recall 1, proposals 6, loss: x 1.98(1.77), y 1.73(1.00), w 16.44(2.75), h 3.85(1.24), conf 3.59(2.60), cls 1.11(0.58), total 28.70(9.94)
# 261312: nGT 7, recall 2, proposals 2, loss: x 2.80(1.77), y 1.23(1.00), w 7.26(2.77), h 3.13(1.25), conf 5.49(2.61), cls 0.89(0.58), total 20.79(9.98)
# 261316: nGT 4, recall 1, proposals 0, loss: x 0.97(1.77), y 0.42(1.00), w 5.91(2.78), h 0.79(1.25), conf 3.20(2.61), cls 0.23(0.58), total 11.52(9.99)
# 261320: nGT 3, recall 2, proposals 0, loss: x 0.96(1.77), y 0.81(1.00), w 4.39(2.78), h 2.29(1.25), conf 2.96(2.61), cls 0.52(0.58), total 11.93(9.99)
# 261324: nGT 10, recall 4, proposals 4, loss: x 2.87(1.77), y 1.78(1.00), w 8.12(2.80), h 1.45(1.25), conf 4.81(2.62), cls 1.24(0.59), total 20.27(10.02)
# 261328: nGT 3, recall 1, proposals 0, loss: x 0.64(1.77), y 0.30(1.00), w 5.10(2.81), h 0.36(1.25), conf 2.29(2.62), cls 0.18(0.58), total 8.87(10.02)
# 261332: nGT 5, recall 4, proposals 4, loss: x 0.92(1.76), y 1.14(1.00), w 0.34(2.80), h 0.16(1.25), conf 2.96(2.62), cls 0.40(0.58), total 5.93(10.01)
# 261336: nGT 11, recall 3, proposals 0, loss: x 5.17(1.77), y 1.70(1.00), w 1.64(2.79), h 0.88(1.24), conf 3.03(2.62), cls 0.53(0.58), total 12.95(10.02)
# 261340: nGT 7, recall 0, proposals 7, loss: x 3.79(1.78), y 0.92(1.00), w 3.60(2.80), h 4.72(1.26), conf 2.37(2.62), cls 0.33(0.58), total 15.72(10.04)
# 261344: nGT 4, recall 0, proposals 0, loss: x 2.85(1.78), y 0.10(1.00), w 11.14(2.82), h 3.09(1.26), conf 0.94(2.62), cls 0.13(0.58), total 18.24(10.06)
# 261348: nGT 7, recall 4, proposals 7, loss: x 2.16(1.79), y 0.89(1.00), w 3.59(2.83), h 1.12(1.26), conf 5.19(2.62), cls 0.75(0.58), total 13.70(10.07)
# 261352: nGT 6, recall 2, proposals 8, loss: x 1.31(1.78), y 0.59(0.99), w 1.82(2.82), h 0.71(1.26), conf 2.09(2.62), cls 0.32(0.58), total 6.84(10.06)
# ...
# 276340: nGT 4, recall 0, proposals 8, loss: x 0.69(1.60), y 0.85(0.85), w 1.19(2.12), h 0.82(1.12), conf 1.99(2.55), cls 0.51(0.46), total 6.05(8.69)
# 276344: nGT 5, recall 1, proposals 13, loss: x 1.60(1.60), y 1.28(0.85), w 0.32(2.10), h 1.89(1.13), conf 3.49(2.56), cls 0.39(0.46), total 8.97(8.70)
# 276348: nGT 2, recall 0, proposals 6, loss: x 0.03(1.58), y 0.65(0.85), w 0.03(2.08), h 1.39(1.14), conf 0.97(2.54), cls 0.10(0.45), total 3.17(8.63)
# 276352: nGT 4, recall 0, proposals 0, loss: x 0.72(1.57), y 0.10(0.84), w 0.52(2.06), h 1.29(1.14), conf 0.59(2.52), cls 0.25(0.45), total 3.47(8.58)
# 276356: nGT 2, recall 1, proposals 0, loss: x 0.39(1.56), y 0.43(0.84), w 0.12(2.04), h 0.11(1.13), conf 2.75(2.52), cls 0.39(0.45), total 4.18(8.53)
# 276360: nGT 7, recall 1, proposals 2, loss: x 1.98(1.56), y 1.05(0.84), w 1.18(2.03), h 2.89(1.15), conf 2.05(2.51), cls 0.61(0.45), total 9.76(8.54)
# 276364: nGT 7, recall 3, proposals 13, loss: x 2.10(1.57), y 1.16(0.84), w 1.97(2.03), h 0.28(1.14), conf 5.17(2.54), cls 0.27(0.45), total 10.97(8.57)
# 276368: nGT 2, recall 0, proposals 0, loss: x 2.53(1.58), y 0.04(0.84), w 9.84(2.11), h 0.62(1.13), conf 1.09(2.53), cls 0.36(0.45), total 14.48(8.63)
# 276372: nGT 8, recall 0, proposals 0, loss: x 1.77(1.58), y 1.03(0.84), w 1.28(2.10), h 1.08(1.13), conf 0.91(2.51), cls 0.28(0.45), total 6.34(8.61)
# 276376: nGT 2, recall 0, proposals 13, loss: x 0.31(1.57), y 0.35(0.83), w 1.92(2.10), h 0.17(1.12), conf 1.54(2.50), cls 0.11(0.44), total 4.40(8.56)
# 276380: nGT 5, recall 0, proposals 6, loss: x 1.77(1.57), y 0.09(0.82), w 2.16(2.10), h 1.69(1.13), conf 1.97(2.49), cls 1.43(0.45), total 9.11(8.57)
# 276384: nGT 3, recall 1, proposals 6, loss: x 0.44(1.56), y 0.90(0.83), w 4.01(2.12), h 2.82(1.14), conf 3.42(2.50), cls 0.17(0.45), total 11.76(8.60)
# 276388: nGT 5, recall 1, proposals 0, loss: x 3.60(1.58), y 1.17(0.83), w 0.64(2.11), h 1.27(1.14), conf 2.53(2.50), cls 0.62(0.45), total 9.83(8.61)
# 276392: nGT 6, recall 0, proposals 0, loss: x 0.91(1.57), y 0.03(0.82), w 2.10(2.11), h 0.62(1.14), conf 0.32(2.48), cls 0.09(0.45), total 4.08(8.57)
# 276396: nGT 6, recall 3, proposals 6, loss: x 1.91(1.58), y 0.92(0.82), w 2.02(2.10), h 0.45(1.13), conf 1.67(2.47), cls 0.28(0.45), total 7.25(8.55)
# 276400: nGT 4, recall 1, proposals 17, loss: x 2.72(1.59), y 0.22(0.82), w 0.12(2.08), h 0.42(1.13), conf 2.41(2.47), cls 0.14(0.44), total 6.03(8.53)
# 276404: nGT 2, recall 2, proposals 0, loss: x 0.32(1.57), y 0.09(0.81), w 0.16(2.07), h 0.00(1.11), conf 2.24(2.47), cls 0.16(0.44), total 2.97(8.47)
# 276408: nGT 5, recall 4, proposals 5, loss: x 0.25(1.56), y 0.40(0.80), w 1.73(2.06), h 0.05(1.10), conf 5.23(2.50), cls 0.33(0.44), total 7.99(8.47)
# 276412: nGT 5, recall 0, proposals 0, loss: x 3.05(1.58), y 0.37(0.80), w 2.24(2.06), h 0.19(1.09), conf 0.34(2.48), cls 0.66(0.44), total 6.85(8.45)
# 276416: nGT 6, recall 2, proposals 1, loss: x 1.11(1.57), y 0.48(0.80), w 5.61(2.10), h 1.18(1.10), conf 2.27(2.47), cls 0.71(0.45), total 11.36(8.48)
# 276420: nGT 2, recall 1, proposals 0, loss: x 0.62(1.56), y 0.48(0.79), w 0.68(2.08), h 0.46(1.09), conf 1.24(2.46), cls 0.78(0.45), total 4.27(8.44)
# 276424: nGT 10, recall 1, proposals 1, loss: x 3.09(1.58), y 2.96(0.81), w 5.38(2.12), h 3.82(1.12), conf 5.44(2.49), cls 1.27(0.46), total 21.95(8.57)
# 276428: nGT 4, recall 2, proposals 15, loss: x 1.43(1.57), y 0.90(0.82), w 1.11(2.11), h 0.03(1.11), conf 4.92(2.51), cls 0.36(0.46), total 8.74(8.57)
# 276432: nGT 6, recall 3, proposals 8, loss: x 2.33(1.58), y 0.34(0.81), w 1.35(2.10), h 0.56(1.10), conf 3.86(2.53), cls 0.32(0.45), total 8.76(8.57)
# 276436: nGT 10, recall 6, proposals 0, loss: x 3.00(1.59), y 1.33(0.82), w 9.11(2.16), h 2.75(1.12), conf 7.56(2.57), cls 0.35(0.45), total 24.10(8.71)
# 276440: nGT 9, recall 4, proposals 11, loss: x 4.22(1.62), y 1.00(0.82), w 17.66(2.30), h 0.62(1.11), conf 3.10(2.58), cls 1.20(0.46), total 27.80(8.89)
# 276444: nGT 2, recall 0, proposals 3, loss: x 1.06(1.61), y 0.43(0.81), w 0.01(2.28), h 0.13(1.10), conf 0.98(2.56), cls 0.08(0.46), total 2.68(8.83)
# 276448: nGT 4, recall 1, proposals 5, loss: x 1.82(1.62), y 1.11(0.82), w 2.96(2.29), h 0.49(1.10), conf 1.25(2.55), cls 0.58(0.46), total 8.22(8.83)
# 276452: nGT 9, recall 3, proposals 7, loss: x 5.12(1.65), y 2.69(0.83), w 2.77(2.29), h 2.23(1.11), conf 5.43(2.58), cls 0.54(0.46), total 18.79(8.91)
# 276456: nGT 12, recall 1, proposals 8, loss: x 3.10(1.66), y 3.11(0.85), w 4.92(2.32), h 4.60(1.14), conf 2.17(2.57), cls 1.47(0.47), total 19.35(9.01)
# 276460: nGT 3, recall 0, proposals 0, loss: x 1.58(1.66), y 0.96(0.85), w 1.31(2.31), h 1.69(1.14), conf 0.14(2.55), cls 0.61(0.47), total 6.30(8.98)
# 276464: nGT 8, recall 1, proposals 3, loss: x 2.56(1.67), y 2.36(0.87), w 5.41(2.34), h 1.51(1.15), conf 2.82(2.55), cls 1.24(0.47), total 15.90(9.04)
# 276468: nGT 4, recall 0, proposals 0, loss: x 2.06(1.67), y 0.60(0.86), w 0.60(2.32), h 0.71(1.14), conf 1.53(2.54), cls 0.27(0.47), total 5.77(9.01)
# 276472: nGT 5, recall 0, proposals 7, loss: x 2.63(1.68), y 1.93(0.87), w 2.19(2.32), h 0.50(1.14), conf 1.73(2.54), cls 0.15(0.47), total 9.14(9.02)
# 276476: nGT 7, recall 0, proposals 0, loss: x 4.49(1.70), y 1.89(0.88), w 7.05(2.36), h 5.45(1.17), conf 0.86(2.52), cls 1.01(0.47), total 20.75(9.11)
# 276480: nGT 2, recall 0, proposals 3, loss: x 1.84(1.70), y 0.26(0.88), w 0.85(2.35), h 0.19(1.16), conf 0.53(2.51), cls 0.27(0.47), total 3.95(9.07)
# 276484: nGT 3, recall 0, proposals 0, loss: x 2.05(1.71), y 0.88(0.88), w 1.21(2.34), h 0.13(1.16), conf 1.18(2.50), cls 0.20(0.47), total 5.64(9.04)
# 276488: nGT 3, recall 1, proposals 0, loss: x 1.25(1.70), y 0.27(0.87), w 0.09(2.32), h 0.61(1.15), conf 2.27(2.49), cls 0.49(0.47), total 4.97(9.01)
# 276492: nGT 6, recall 0, proposals 0, loss: x 5.69(1.73), y 1.05(0.87), w 8.23(2.37), h 11.77(1.24), conf 0.39(2.48), cls 1.05(0.48), total 28.18(9.16)
# 276496: nGT 6, recall 1, proposals 0, loss: x 2.59(1.74), y 0.74(0.87), w 1.90(2.36), h 0.26(1.23), conf 3.31(2.48), cls 1.67(0.49), total 10.47(9.18)
# 276500: nGT 4, recall 1, proposals 7, loss: x 2.53(1.75), y 1.21(0.88), w 0.85(2.35), h 0.33(1.22), conf 1.62(2.48), cls 0.30(0.48), total 6.83(9.16)
# 276504: nGT 10, recall 0, proposals 1, loss: x 5.78(1.78), y 1.63(0.88), w 3.95(2.36), h 2.03(1.23), conf 1.64(2.47), cls 0.63(0.49), total 15.67(9.21)
# 276508: nGT 5, recall 1, proposals 8, loss: x 1.64(1.78), y 1.58(0.89), w 3.57(2.37), h 0.42(1.22), conf 3.55(2.48), cls 0.81(0.49), total 11.56(9.23)
# 276512: nGT 3, recall 1, proposals 1, loss: x 0.34(1.77), y 0.35(0.88), w 1.09(2.36), h 0.37(1.22), conf 2.76(2.48), cls 0.31(0.49), total 5.21(9.20)
# 276516: nGT 8, recall 2, proposals 7, loss: x 2.23(1.77), y 1.43(0.89), w 4.41(2.38), h 1.02(1.21), conf 2.09(2.48), cls 0.44(0.49), total 11.62(9.21)
# 276520: nGT 3, recall 1, proposals 0, loss: x 1.03(1.77), y 0.21(0.88), w 0.23(2.36), h 0.18(1.21), conf 2.27(2.48), cls 0.30(0.48), total 4.23(9.18)
# 276524: nGT 1, recall 0, proposals 0, loss: x 0.32(1.75), y 0.46(0.88), w 0.04(2.34), h 0.00(1.20), conf 0.47(2.46), cls 0.20(0.48), total 1.49(9.12)
# 276528: nGT 4, recall 0, proposals 12, loss: x 0.71(1.75), y 3.83(0.90), w 2.49(2.35), h 0.42(1.19), conf 3.93(2.47), cls 0.57(0.48), total 11.95(9.14)
# 276532: nGT 3, recall 0, proposals 0, loss: x 0.27(1.73), y 0.30(0.90), w 2.29(2.35), h 0.92(1.19), conf 0.42(2.46), cls 0.24(0.48), total 4.43(9.10)
# 276536: nGT 5, recall 1, proposals 4, loss: x 1.74(1.73), y 0.73(0.89), w 6.04(2.37), h 2.37(1.20), conf 1.69(2.45), cls 0.10(0.48), total 12.67(9.13)
# 276540: nGT 8, recall 4, proposals 13, loss: x 2.84(1.74), y 1.74(0.90), w 13.31(2.45), h 3.96(1.22), conf 7.14(2.49), cls 2.75(0.50), total 31.75(9.30)
# 276544: nGT 8, recall 2, proposals 0, loss: x 3.09(1.75), y 2.47(0.91), w 3.00(2.46), h 3.00(1.23), conf 3.83(2.50), cls 0.82(0.50), total 16.21(9.35)
# 276548: nGT 3, recall 1, proposals 12, loss: x 0.96(1.75), y 0.47(0.91), w 1.74(2.45), h 0.37(1.23), conf 2.73(2.50), cls 0.42(0.50), total 6.69(9.33)
# 276552: nGT 7, recall 1, proposals 8, loss: x 3.39(1.76), y 2.24(0.92), w 1.16(2.44), h 1.70(1.23), conf 2.41(2.50), cls 1.06(0.50), total 11.96(9.35)
# 276556: nGT 11, recall 4, proposals 6, loss: x 4.39(1.78), y 2.99(0.93), w 4.45(2.46), h 2.55(1.24), conf 7.33(2.53), cls 1.59(0.51), total 23.29(9.45)
# 276560: nGT 8, recall 0, proposals 0, loss: x 1.78(1.78), y 0.38(0.93), w 4.20(2.47), h 1.86(1.24), conf 1.07(2.52), cls 1.32(0.51), total 10.60(9.46)
# 276564: nGT 3, recall 2, proposals 4, loss: x 0.21(1.77), y 0.14(0.92), w 1.35(2.46), h 0.10(1.23), conf 1.31(2.51), cls 0.27(0.51), total 3.38(9.41)
# 276568: nGT 9, recall 3, proposals 12, loss: x 4.54(1.79), y 1.60(0.93), w 3.19(2.47), h 0.44(1.23), conf 4.71(2.53), cls 1.28(0.52), total 15.76(9.46)
# 276572: nGT 8, recall 4, proposals 2, loss: x 2.16(1.79), y 1.33(0.93), w 2.93(2.47), h 0.90(1.23), conf 4.16(2.54), cls 0.55(0.52), total 12.04(9.48)
# 276576: nGT 3, recall 2, proposals 5, loss: x 0.66(1.78), y 0.82(0.93), w 1.19(2.46), h 0.48(1.22), conf 3.50(2.55), cls 0.27(0.52), total 6.93(9.46)
# 276580: nGT 7, recall 1, proposals 7, loss: x 0.87(1.77), y 0.80(0.93), w 0.20(2.45), h 1.79(1.23), conf 2.28(2.54), cls 0.74(0.52), total 6.68(9.44)
# 276584: nGT 3, recall 3, proposals 6, loss: x 0.31(1.76), y 0.50(0.93), w 0.88(2.44), h 0.75(1.22), conf 4.35(2.56), cls 0.42(0.52), total 7.22(9.42)
# 276588: nGT 8, recall 1, proposals 5, loss: x 4.52(1.78), y 1.86(0.93), w 16.19(2.53), h 0.80(1.22), conf 3.84(2.57), cls 0.60(0.52), total 27.80(9.55)
# 276592: nGT 3, recall 0, proposals 0, loss: x 0.19(1.77), y 0.50(0.93), w 4.29(2.54), h 4.14(1.24), conf 0.50(2.55), cls 0.13(0.52), total 9.75(9.55)
# 276596: nGT 1, recall 0, proposals 0, loss: x 0.61(1.77), y 0.02(0.92), w 0.08(2.52), h 0.05(1.23), conf 0.25(2.54), cls 0.04(0.51), total 1.06(9.49)
# 276600: nGT 5, recall 2, proposals 0, loss: x 2.87(1.77), y 0.48(0.92), w 1.83(2.52), h 2.91(1.24), conf 2.59(2.54), cls 0.37(0.51), total 11.05(9.50)
# 276604: nGT 2, recall 0, proposals 0, loss: x 1.33(1.77), y 0.15(0.92), w 1.64(2.51), h 6.55(1.28), conf 0.21(2.52), cls 0.13(0.51), total 10.02(9.51)
# 276608: nGT 5, recall 0, proposals 0, loss: x 2.69(1.78), y 0.33(0.91), w 10.92(2.57), h 2.22(1.28), conf 0.36(2.51), cls 0.19(0.51), total 16.71(9.55)
# 276612: nGT 6, recall 0, proposals 1, loss: x 1.45(1.77), y 0.04(0.91), w 1.15(2.56), h 0.27(1.28), conf 0.90(2.50), cls 0.39(0.51), total 4.20(9.52)
# 276616: nGT 5, recall 0, proposals 0, loss: x 1.39(1.77), y 0.54(0.90), w 2.23(2.56), h 0.31(1.27), conf 0.38(2.48), cls 0.72(0.51), total 5.56(9.49)
# 276620: nGT 8, recall 2, proposals 0, loss: x 3.23(1.78), y 1.87(0.91), w 10.83(2.61), h 1.32(1.27), conf 4.52(2.50), cls 1.24(0.51), total 23.02(9.58)
# 276624: nGT 2, recall 0, proposals 0, loss: x 0.24(1.77), y 0.36(0.91), w 3.57(2.62), h 1.56(1.27), conf 0.91(2.49), cls 0.16(0.51), total 6.80(9.56)
# 276628: nGT 3, recall 2, proposals 0, loss: x 1.08(1.77), y 0.01(0.90), w 0.26(2.60), h 0.63(1.27), conf 0.94(2.48), cls 0.24(0.51), total 3.16(9.52)
# 276632: nGT 8, recall 4, proposals 8, loss: x 2.27(1.77), y 0.55(0.90), w 1.23(2.59), h 0.16(1.26), conf 5.18(2.49), cls 0.32(0.51), total 9.71(9.52)
# 276636: nGT 4, recall 2, proposals 0, loss: x 1.64(1.77), y 1.38(0.90), w 1.80(2.59), h 0.64(1.26), conf 2.72(2.49), cls 0.51(0.51), total 8.69(9.52)
# 276640: nGT 5, recall 3, proposals 0, loss: x 0.23(1.76), y 0.15(0.90), w 1.69(2.58), h 1.08(1.26), conf 5.40(2.51), cls 0.42(0.51), total 8.97(9.52)
# 276644: nGT 11, recall 3, proposals 3, loss: x 4.30(1.77), y 0.39(0.89), w 1.11(2.57), h 1.30(1.26), conf 2.68(2.51), cls 1.58(0.51), total 11.36(9.53)
# 276648: nGT 7, recall 3, proposals 0, loss: x 1.03(1.77), y 1.03(0.90), w 4.73(2.59), h 2.58(1.26), conf 6.28(2.54), cls 0.94(0.52), total 16.60(9.57)
# 276652: nGT 3, recall 1, proposals 0, loss: x 0.41(1.76), y 0.78(0.89), w 1.42(2.58), h 0.05(1.26), conf 1.49(2.53), cls 0.13(0.51), total 4.28(9.54)
# 276656: nGT 7, recall 1, proposals 7, loss: x 2.99(1.77), y 0.30(0.89), w 1.34(2.57), h 3.72(1.27), conf 1.45(2.52), cls 0.64(0.51), total 10.44(9.54)
# 276660: nGT 2, recall 0, proposals 0, loss: x 0.54(1.76), y 0.01(0.89), w 0.32(2.56), h 0.14(1.27), conf 0.37(2.51), cls 0.16(0.51), total 1.54(9.49)
# 276664: nGT 4, recall 1, proposals 0, loss: x 1.98(1.76), y 0.21(0.88), w 1.80(2.55), h 0.05(1.26), conf 1.53(2.50), cls 0.59(0.51), total 6.16(9.47)
# 276668: nGT 7, recall 1, proposals 5, loss: x 1.82(1.76), y 0.92(0.88), w 10.12(2.60), h 2.68(1.27), conf 2.41(2.50), cls 0.85(0.51), total 18.78(9.53)
# 276672: nGT 8, recall 2, proposals 0, loss: x 2.35(1.77), y 1.46(0.89), w 2.66(2.60), h 0.51(1.26), conf 3.70(2.51), cls 1.42(0.52), total 12.10(9.55)
# 276676: nGT 6, recall 1, proposals 0, loss: x 2.51(1.77), y 0.03(0.88), w 1.79(2.60), h 0.45(1.26), conf 0.25(2.50), cls 0.95(0.52), total 6.00(9.52)
# 276680: nGT 4, recall 0, proposals 0, loss: x 0.84(1.77), y 0.97(0.88), w 2.46(2.59), h 13.70(1.33), conf 0.82(2.49), cls 0.22(0.52), total 19.01(9.58)
# 276684: nGT 5, recall 3, proposals 0, loss: x 0.90(1.76), y 1.06(0.88), w 0.57(2.58), h 2.49(1.34), conf 4.63(2.50), cls 0.87(0.52), total 10.52(9.59)
# 276688: nGT 5, recall 0, proposals 0, loss: x 2.54(1.77), y 0.21(0.88), w 0.20(2.57), h 1.74(1.34), conf 1.11(2.49), cls 0.73(0.52), total 6.52(9.57)
# 276692: nGT 4, recall 1, proposals 0, loss: x 0.82(1.76), y 1.19(0.88), w 2.16(2.57), h 0.43(1.33), conf 1.31(2.49), cls 0.66(0.52), total 6.57(9.55)
# 276696: nGT 5, recall 5, proposals 8, loss: x 0.98(1.76), y 1.72(0.88), w 3.57(2.57), h 0.10(1.33), conf 7.76(2.52), cls 0.85(0.53), total 14.98(9.58)
# 276700: nGT 10, recall 2, proposals 12, loss: x 4.42(1.77), y 1.08(0.89), w 6.57(2.59), h 1.58(1.33), conf 3.15(2.52), cls 1.60(0.53), total 18.40(9.63)
# 276704: nGT 3, recall 1, proposals 0, loss: x 1.44(1.77), y 0.57(0.88), w 0.73(2.58), h 0.25(1.32), conf 1.75(2.52), cls 0.81(0.53), total 5.55(9.61)
# 276708: nGT 5, recall 2, proposals 16, loss: x 3.00(1.78), y 1.00(0.88), w 1.10(2.58), h 1.91(1.33), conf 2.56(2.52), cls 0.40(0.53), total 9.97(9.61)
# 276712: nGT 3, recall 0, proposals 0, loss: x 1.86(1.78), y 0.93(0.88), w 3.03(2.58), h 0.44(1.32), conf 0.47(2.50), cls 0.36(0.53), total 7.08(9.60)
# 276716: nGT 6, recall 1, proposals 0, loss: x 1.61(1.78), y 1.18(0.89), w 1.20(2.57), h 0.18(1.31), conf 2.76(2.51), cls 0.83(0.53), total 7.75(9.59)
# 276720: nGT 3, recall 0, proposals 0, loss: x 1.64(1.77), y 0.73(0.89), w 0.47(2.56), h 0.57(1.31), conf 0.42(2.49), cls 0.70(0.54), total 4.53(9.56)
# 276724: nGT 6, recall 0, proposals 0, loss: x 3.82(1.79), y 1.25(0.89), w 3.64(2.57), h 3.15(1.32), conf 1.29(2.49), cls 0.66(0.54), total 13.81(9.58)
# 276728: nGT 9, recall 1, proposals 0, loss: x 2.81(1.79), y 2.48(0.90), w 1.78(2.56), h 2.95(1.33), conf 2.54(2.49), cls 1.03(0.54), total 13.58(9.60)
# 276732: nGT 5, recall 4, proposals 13, loss: x 1.38(1.79), y 0.28(0.89), w 0.81(2.55), h 1.44(1.33), conf 2.03(2.48), cls 0.16(0.54), total 6.11(9.59)
# 276736: nGT 4, recall 0, proposals 0, loss: x 2.32(1.79), y 0.40(0.89), w 5.90(2.57), h 0.53(1.33), conf 1.26(2.48), cls 0.56(0.54), total 10.96(9.59)
# 276740: nGT 6, recall 0, proposals 0, loss: x 1.32(1.79), y 1.18(0.89), w 1.60(2.56), h 0.90(1.32), conf 0.83(2.47), cls 0.92(0.54), total 6.74(9.58)
# 276744: nGT 5, recall 2, proposals 7, loss: x 1.48(1.79), y 0.52(0.89), w 2.55(2.56), h 0.84(1.32), conf 1.99(2.47), cls 0.40(0.54), total 7.78(9.57)
# 276748: nGT 5, recall 2, proposals 5, loss: x 2.22(1.79), y 0.39(0.89), w 0.95(2.56), h 1.49(1.32), conf 3.57(2.47), cls 0.27(0.54), total 8.89(9.56)
# 276752: nGT 6, recall 1, proposals 0, loss: x 3.28(1.80), y 1.30(0.89), w 4.07(2.56), h 0.16(1.32), conf 3.23(2.48), cls 1.18(0.54), total 13.23(9.58)
# 276756: nGT 11, recall 1, proposals 0, loss: x 2.08(1.80), y 1.62(0.89), w 3.15(2.57), h 4.22(1.33), conf 3.47(2.48), cls 1.15(0.54), total 15.70(9.62)
# 276760: nGT 5, recall 1, proposals 0, loss: x 0.61(1.79), y 0.30(0.89), w 3.51(2.57), h 0.59(1.33), conf 1.46(2.48), cls 0.35(0.54), total 6.82(9.60)

# %%
## Save checkpoint
epoch = begin_epoch
state = {
  'epoch': epoch,
  'state_dict': model.state_dict(),
  'optimizer': optimizer.state_dict(),# aa
  'fscore': 0 ##
  }
is_best = False
save_checkpoint(state, is_best, backupdir, namedataset+'_manual_tune4_coord20_ob16_e'+str(epoch), clip_duration)
# save_checkpoint(state, is_best, backupdir, namedataset+'_manual_tune_1_'+str(epoch), clip_duration)
# manual 1: coord_scale = class_scale = 0.1, result: l_cls = 0.1, l_
logging('Weights are saved to backup directory: %s' % (backupdir))
# Out:
# 2021-01-21 17:40:45 Weights are saved to backup directory: /content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup

# %% [markdown]
# # Test tuning

# %%
epoch = checkpoint['epoch']
epoch
# Out:
# 4

# %%
namedataset = 'jaad'
evaluate = True
# if opt.evaluate:
if evaluate == True:
    logging('evaluating ...')
    # classification_accuracy, localization_recall, precision, recall, fscore = test(0) # 0 means evaluation, >0 means test at that epoch
# Validate the model
    classification_accuracy, localization_recall, precision, recall, fscore = test(epoch)

    # is_best = fscore > best_fscore
    # if is_best:
    #     print("New best fscore is achieved: ", fscore)
    #     print("Previous fscore was: ", best_fscore)
    #     best_fscore = fscore



    # Save the model to backup directory
    state = {
        'epoch': epoch,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'fscore': fscore
        }
    is_best = False
    save_checkpoint(state, is_best, backupdir, namedataset+'_vali_auto_1_'+str(epoch), clip_duration)
    # save_checkpoint(state, is_best, backupdir, opt.dataset, clip_duration)
    # save_checkpoint(state, is_best, backupdir, namedataset, clip_duration)
    
    logging('Weights are saved to backup directory: %s' % (backupdir))
    # Save the evaluation result
    eval_result = {'class_acc': classification_accuracy,
                  'loc_recall': localization_recall, 
                  'precision': precision, 
                  'recall': recall, 
                  'fscore': fscore} 
    fileout = 'jaad_eval_result_auto_e' + str(epoch)
    import json
    with open(f'./jaad_detections/{fileout}.json', 'w') as fp:
        json.dump(eval_result, fp)
# Out:
# 2021-01-19 17:00:40 evaluating ...
# 2021-01-19 17:00:41 validation at epoch 4
# /content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/utils.py:280: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   cls_confs = torch.nn.Softmax()(Variable(output[5:5+num_classes].transpose(0,1))).data #softmax_class
# 2021-01-19 17:00:47 [0/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:49 [1/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:51 [2/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:52 [3/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:54 [4/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:56 [5/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:57 [6/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:59 [7/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:00 [8/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:02 [9/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:04 [10/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:05 [11/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:07 [12/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:09 [13/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:11 [14/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:13 [15/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:16 [16/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:18 [17/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:21 [18/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:24 [19/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:26 [20/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:29 [21/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:31 [22/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:33 [23/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:35 [24/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:37 [25/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:39 [26/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:41 [27/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:43 [28/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:45 [29/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:47 [30/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:49 [31/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:51 [32/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:53 [33/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:55 [34/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:56 [35/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:58 [36/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:59 [37/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:01 [38/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:02 [39/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:04 [40/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:05 [41/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:07 [42/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:09 [43/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:10 [44/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:13 [45/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:15 [46/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:16 [47/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:19 [48/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:21 [49/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:23 [50/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:26 [51/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:28 [52/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:30 [53/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:32 [54/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:35 [55/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:37 [56/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:39 [57/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
