# %%
# !nvidia-smi
# Out:
# Sat Jan 23 03:56:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

# %% [markdown]
# # Data preparation

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/data')

# %%
# %run data_prepare_new.ipynb
# Out:
# Cloning into 'JAAD'...
# remote: Enumerating objects: 355, done.
# remote: Counting objects: 100% (355/355), done.
# remote: Compressing objects: 100% (322/322), done.
# remote: Total 5786 (delta 326), reused 39 (delta 33), pack-reused 5431
# Receiving objects: 100% (5786/5786), 39.50 MiB | 7.63 MiB/s, done.
# Resolving deltas: 100% (5145/5145), done.
# Downloading...
# From: https://drive.google.com/uc?id=1ZwVzmXYlvaD9ifqTU6TKfKQSGkLNauLQ
# To: /content/videos.rar
# 1.07GB [00:07, 148MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1d9hAOhpLO9Cm59szoG4F7agT05L_c5ky
# To: /content/jaad_database_resized.pkl
# 65.0MB [00:00, 246MB/s]
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from videos.rar
#
# Creating    JAAD/videos                                               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    JAAD/videos/video_0001                                    OK
# Creating    JAAD/videos/video_0002                                    OK
# Creating    JAAD/videos/video_0003                                    OK
# Creating    JAAD/videos/video_0004                                    OK
# Creating    JAAD/videos/video_0005                                    OK
# Creating    JAAD/videos/video_0006                                    OK
# Creating    JAAD/videos/video_0007                                    OK
# Creating    JAAD/videos/video_0008                                    OK
# Creating    JAAD/videos/video_0009                                    OK
# Creating    JAAD/videos/video_0010                                    OK
# Creating    JAAD/videos/video_0011                                    OK
# Creating    JAAD/videos/video_0012                                    OK
# Creating    JAAD/videos/video_0013                                    OK
# Creating    JAAD/videos/video_0014                                    OK
# Creating    JAAD/videos/video_0015                                    OK
# Creating    JAAD/videos/video_0016                                    OK
# Creating    JAAD/videos/video_0017                                    OK
# Creating    JAAD/videos/video_0018                                    OK
# Creating    JAAD/videos/video_0019                                    OK
# Creating    JAAD/videos/video_0020                                    OK
# Creating    JAAD/videos/video_0021                                    OK
# Creating    JAAD/videos/video_0022                                    OK
# Creating    JAAD/videos/video_0023                                    OK
# Creating    JAAD/videos/video_0024                                    OK
# Creating    JAAD/videos/video_0025                                    OK
# Creating    JAAD/videos/video_0026                                    OK
# Creating    JAAD/videos/video_0027                                    OK
# Creating    JAAD/videos/video_0028                                    OK
# Creating    JAAD/videos/video_0029                                    OK
# Creating    JAAD/videos/video_0030                                    OK
# Creating    JAAD/videos/video_0031                                    OK
# Creating    JAAD/videos/video_0032                                    OK
# Creating    JAAD/videos/video_0033                                    OK
# Creating    JAAD/videos/video_0034                                    OK
# Creating    JAAD/videos/video_0035                                    OK
# Creating    JAAD/videos/video_0036                                    OK
# Creating    JAAD/videos/video_0037                                    OK
# Creating    JAAD/videos/video_0038                                    OK
# Creating    JAAD/videos/video_0039                                    OK
# Creating    JAAD/videos/video_0040                                    OK
# Creating    JAAD/videos/video_0041                                    OK
# Creating    JAAD/videos/video_0042                                    OK
# Creating    JAAD/videos/video_0043                                    OK
# Creating    JAAD/videos/video_0044                                    OK
# Creating    JAAD/videos/video_0045                                    OK
# Creating    JAAD/videos/video_0046                                    OK
# Creating    JAAD/videos/video_0047                                    OK
# Creating    JAAD/videos/video_0048                                    OK
# Creating    JAAD/videos/video_0049                                    OK
# Creating    JAAD/videos/video_0050                                    OK
# Creating    JAAD/videos/video_0051                                    OK
# Creating    JAAD/videos/video_0052                                    OK
# Creating    JAAD/videos/video_0053                                    OK
# Creating    JAAD/videos/video_0054                                    OK
# Creating    JAAD/videos/video_0055                                    OK
# Creating    JAAD/videos/video_0056                                    OK
# Creating    JAAD/videos/video_0057                                    OK
# Creating    JAAD/videos/video_0058                                    OK
# Creating    JAAD/videos/video_0059                                    OK
# Creating    JAAD/videos/video_0060                                    OK
# Creating    JAAD/videos/video_0061                                    OK
# Creating    JAAD/videos/video_0062                                    OK
# Creating    JAAD/videos/video_0063                                    OK
# Creating    JAAD/videos/video_0064                                    OK
# Creating    JAAD/videos/video_0065                                    OK
# Creating    JAAD/videos/video_0066                                    OK
# Creating    JAAD/videos/video_0067                                    OK
# Creating    JAAD/videos/video_0068                                    OK
# Creating    JAAD/videos/video_0069                                    OK
# Creating    JAAD/videos/video_0070                                    OK
# Creating    JAAD/videos/video_0071                                    OK
# Creating    JAAD/videos/video_0072                                    OK
# Creating    JAAD/videos/video_0073                                    OK
# Creating    JAAD/videos/video_0074                                    OK
# Creating    JAAD/videos/video_0075                                    OK
# Creating    JAAD/videos/video_0076                                    OK
# Creating    JAAD/videos/video_0077                                    OK
# Creating    JAAD/videos/video_0078                                    OK
# Creating    JAAD/videos/video_0079                                    OK
# Creating    JAAD/videos/video_0080                                    OK
# Creating    JAAD/videos/video_0081                                    OK
# Creating    JAAD/videos/video_0082                                    OK
# Creating    JAAD/videos/video_0083                                    OK
# Creating    JAAD/videos/video_0084                                    OK
# Creating    JAAD/videos/video_0085                                    OK
# Creating    JAAD/videos/video_0086                                    OK
# Creating    JAAD/videos/video_0087                                    OK
# Creating    JAAD/videos/video_0088                                    OK
# Creating    JAAD/videos/video_0089                                    OK
# Creating    JAAD/videos/video_0090                                    OK
# Creating    JAAD/videos/video_0091                                    OK
# Creating    JAAD/videos/video_0092                                    OK
# Creating    JAAD/videos/video_0093                                    OK
# Creating    JAAD/videos/video_0094                                    OK
# Creating    JAAD/videos/video_0095                                    OK
# Creating    JAAD/videos/video_0096                                    OK
# Creating    JAAD/videos/video_0097                                    OK
# Creating    JAAD/videos/video_0098                                    OK
# Creating    JAAD/videos/video_0099                                    OK
# Creating    JAAD/videos/video_0100                                    OK
# Creating    JAAD/videos/video_0101                                    OK
# Creating    JAAD/videos/video_0102                                    OK
# Creating    JAAD/videos/video_0103                                    OK
# Creating    JAAD/videos/video_0104                                    OK
# Creating    JAAD/videos/video_0105                                    OK
# Creating    JAAD/videos/video_0106                                    OK
# Creating    JAAD/videos/video_0107                                    OK
# Creating    JAAD/videos/video_0108                                    OK
# Creating    JAAD/videos/video_0109                                    OK
# Creating    JAAD/videos/video_0110                                    OK
# Creating    JAAD/videos/video_0111                                    OK
# Creating    JAAD/videos/video_0112                                    OK
# Creating    JAAD/videos/video_0113                                    OK
# Creating    JAAD/videos/video_0114                                    OK
# Creating    JAAD/videos/video_0115                                    OK
# Creating    JAAD/videos/video_0116                                    OK
# Creating    JAAD/videos/video_0117                                    OK
# Creating    JAAD/videos/video_0118                                    OK
# Creating    JAAD/videos/video_0119                                    OK
# Creating    JAAD/videos/video_0120                                    OK
# Creating    JAAD/videos/video_0121                                    OK
# Creating    JAAD/videos/video_0122                                    OK
# Creating    JAAD/videos/video_0123                                    OK
# Creating    JAAD/videos/video_0124                                    OK
# Creating    JAAD/videos/video_0125                                    OK
# Creating    JAAD/videos/video_0126                                    OK
# Creating    JAAD/videos/video_0127                                    OK
# Creating    JAAD/videos/video_0128                                    OK
# Creating    JAAD/videos/video_0129                                    OK
# Creating    JAAD/videos/video_0130                                    OK
# Creating    JAAD/videos/video_0131                                    OK
# Creating    JAAD/videos/video_0132                                    OK
# Creating    JAAD/videos/video_0133                                    OK
# Creating    JAAD/videos/video_0134                                    OK
# Creating    JAAD/videos/video_0135                                    OK
# Creating    JAAD/videos/video_0136                                    OK
# Creating    JAAD/videos/video_0137                                    OK
# Creating    JAAD/videos/video_0138                                    OK
# Creating    JAAD/videos/video_0139                                    OK
# Creating    JAAD/videos/video_0140                                    OK
# Creating    JAAD/videos/video_0141                                    OK
# Creating    JAAD/videos/video_0142                                    OK
# Creating    JAAD/videos/video_0143                                    OK
# Creating    JAAD/videos/video_0144                                    OK
# Creating    JAAD/videos/video_0145                                    OK
# Creating    JAAD/videos/video_0146                                    OK
# Creating    JAAD/videos/video_0147                                    OK
# Creating    JAAD/videos/video_0148                                    OK
# Creating    JAAD/videos/video_0149                                    OK
# Creating    JAAD/videos/video_0150                                    OK
# Creating    JAAD/videos/video_0151                                    OK
# Creating    JAAD/videos/video_0152                                    OK
# Creating    JAAD/videos/video_0153                                    OK
# Creating    JAAD/videos/video_0154                                    OK
# Creating    JAAD/videos/video_0155                                    OK
# Creating    JAAD/videos/video_0156                                    OK
# Creating    JAAD/videos/video_0157                                    OK
# Creating    JAAD/videos/video_0158                                    OK
# Creating    JAAD/videos/video_0159                                    OK
# Creating    JAAD/videos/video_0160                                    OK
# Creating    JAAD/videos/video_0161                                    OK
# Creating    JAAD/videos/video_0162                                    OK
# Creating    JAAD/videos/video_0163                                    OK
# Creating    JAAD/videos/video_0164                                    OK
# Creating    JAAD/videos/video_0165                                    OK
# Creating    JAAD/videos/video_0166                                    OK
# Creating    JAAD/videos/video_0167                                    OK
# Creating    JAAD/videos/video_0168                                    OK
# Creating    JAAD/videos/video_0169                                    OK
# Creating    JAAD/videos/video_0170                                    OK
# Creating    JAAD/videos/video_0171                                    OK
# Creating    JAAD/videos/video_0172                                    OK
# Creating    JAAD/videos/video_0173                                    OK
# Creating    JAAD/videos/video_0174                                    OK
# Creating    JAAD/videos/video_0175                                    OK
# Creating    JAAD/videos/video_0176                                    OK
# Creating    JAAD/videos/video_0177                                    OK
# Creating    JAAD/videos/video_0178                                    OK
# Creating    JAAD/videos/video_0179                                    OK
# Creating    JAAD/videos/video_0180                                    OK
# Creating    JAAD/videos/video_0181                                    OK
# Creating    JAAD/videos/video_0182                                    OK
# Creating    JAAD/videos/video_0183                                    OK
# Creating    JAAD/videos/video_0184                                    OK
# Creating    JAAD/videos/video_0185                                    OK
# Creating    JAAD/videos/video_0186                                    OK
# Creating    JAAD/videos/video_0187                                    OK
# Creating    JAAD/videos/video_0188                                    OK
# Creating    JAAD/videos/video_0189                                    OK
# Creating    JAAD/videos/video_0190                                    OK
# Creating    JAAD/videos/video_0191                                    OK
# Creating    JAAD/videos/video_0192                                    OK
# Creating    JAAD/videos/video_0193                                    OK
# Creating    JAAD/videos/video_0194                                    OK
# Creating    JAAD/videos/video_0195                                    OK
# Creating    JAAD/videos/video_0196                                    OK
# Creating    JAAD/videos/video_0197                                    OK
# Creating    JAAD/videos/video_0198                                    OK
# Creating    JAAD/videos/video_0199                                    OK
# Creating    JAAD/videos/video_0200                                    OK
# Creating    JAAD/videos/video_0201                                    OK
# Creating    JAAD/videos/video_0202                                    OK
# Creating    JAAD/videos/video_0203                                    OK
# Creating    JAAD/videos/video_0204                                    OK
# Creating    JAAD/videos/video_0205                                    OK
# Creating    JAAD/videos/video_0206                                    OK
# Creating    JAAD/videos/video_0207                                    OK
# Creating    JAAD/videos/video_0208                                    OK
# Creating    JAAD/videos/video_0209                                    OK
# Creating    JAAD/videos/video_0210                                    OK
# Creating    JAAD/videos/video_0211                                    OK
# Creating    JAAD/videos/video_0212                                    OK
# Creating    JAAD/videos/video_0213                                    OK
# Creating    JAAD/videos/video_0214                                    OK
# Creating    JAAD/videos/video_0215                                    OK
# Creating    JAAD/videos/video_0216                                    OK
# Creating    JAAD/videos/video_0217                                    OK
# Creating    JAAD/videos/video_0218                                    OK
# Creating    JAAD/videos/video_0219                                    OK
# Creating    JAAD/videos/video_0220                                    OK
# Creating    JAAD/videos/video_0221                                    OK
# Creating    JAAD/videos/video_0222                                    OK
# Creating    JAAD/videos/video_0223                                    OK
# Creating    JAAD/videos/video_0224                                    OK
# Creating    JAAD/videos/video_0225                                    OK
# Creating    JAAD/videos/video_0226                                    OK
# Creating    JAAD/videos/video_0227                                    OK
# Creating    JAAD/videos/video_0228                                    OK
# Creating    JAAD/videos/video_0229                                    OK
# Creating    JAAD/videos/video_0230                                    OK
# Creating    JAAD/videos/video_0231                                    OK
# Creating    JAAD/videos/video_0232                                    OK
# Creating    JAAD/videos/video_0233                                    OK
# Creating    JAAD/videos/video_0234                                    OK
# Creating    JAAD/videos/video_0235                                    OK
# Creating    JAAD/videos/video_0236                                    OK
# Creating    JAAD/videos/video_0237                                    OK
# Creating    JAAD/videos/video_0238                                    OK
# Creating    JAAD/videos/video_0239                                    OK
# Creating    JAAD/videos/video_0240                                    OK
# Creating    JAAD/videos/video_0241                                    OK
# Creating    JAAD/videos/video_0242                                    OK
# Creating    JAAD/videos/video_0243                                    OK
# Creating    JAAD/videos/video_0244                                    OK
# Creating    JAAD/videos/video_0245                                    OK
# Creating    JAAD/videos/video_0246                                    OK
# Creating    JAAD/videos/video_0247                                    OK
# Creating    JAAD/videos/video_0248                                    OK
# Creating    JAAD/videos/video_0249                                    OK
# Creating    JAAD/videos/video_0250                                    OK
# Creating    JAAD/videos/video_0251                                    OK
# Creating    JAAD/videos/video_0252                                    OK
# Creating    JAAD/videos/video_0253                                    OK
# Creating    JAAD/videos/video_0254                                    OK
# Creating    JAAD/videos/video_0255                                    OK
# Creating    JAAD/videos/video_0256                                    OK
# Creating    JAAD/videos/video_0257                                    OK
# Creating    JAAD/videos/video_0258                                    OK
# Creating    JAAD/videos/video_0259                                    OK
# Creating    JAAD/videos/video_0260                                    OK
# Creating    JAAD/videos/video_0261                                    OK
# Creating    JAAD/videos/video_0262                                    OK
# Creating    JAAD/videos/video_0263                                    OK
# Creating    JAAD/videos/video_0264                                    OK
# Creating    JAAD/videos/video_0265                                    OK
# Creating    JAAD/videos/video_0266                                    OK
# Creating    JAAD/videos/video_0267                                    OK
# Creating    JAAD/videos/video_0268                                    OK
# Creating    JAAD/videos/video_0269                                    OK
# Creating    JAAD/videos/video_0270                                    OK
# Creating    JAAD/videos/video_0271                                    OK
# Creating    JAAD/videos/video_0272                                    OK
# Creating    JAAD/videos/video_0273                                    OK
# Creating    JAAD/videos/video_0274                                    OK
# Creating    JAAD/videos/video_0275                                    OK
# Creating    JAAD/videos/video_0276                                    OK
# Creating    JAAD/videos/video_0277                                    OK
# Creating    JAAD/videos/video_0278                                    OK
# Creating    JAAD/videos/video_0279                                    OK
# Creating    JAAD/videos/video_0280                                    OK
# Creating    JAAD/videos/video_0281                                    OK
# Creating    JAAD/videos/video_0282                                    OK
# Creating    JAAD/videos/video_0283                                    OK
# Creating    JAAD/videos/video_0284                                    OK
# Creating    JAAD/videos/video_0285                                    OK
# Creating    JAAD/videos/video_0286                                    OK
# Creating    JAAD/videos/video_0287                                    OK
# Creating    JAAD/videos/video_0288                                    OK
# Creating    JAAD/videos/video_0289                                    OK
# Creating    JAAD/videos/video_0290                                    OK
# Creating    JAAD/videos/video_0291                                    OK
# Creating    JAAD/videos/video_0292                                    OK
# Creating    JAAD/videos/video_0293                                    OK
# Creating    JAAD/videos/video_0294                                    OK
# Creating    JAAD/videos/video_0295                                    OK
# Creating    JAAD/videos/video_0296                                    OK
# Creating    JAAD/videos/video_0297                                    OK
# Creating    JAAD/videos/video_0298                                    OK
# Creating    JAAD/videos/video_0299                                    OK
# Creating    JAAD/videos/video_0300                                    OK
# Creating    JAAD/videos/video_0301                                    OK
# Creating    JAAD/videos/video_0302                                    OK
# Creating    JAAD/videos/video_0303                                    OK
# Creating    JAAD/videos/video_0304                                    OK
# Creating    JAAD/videos/video_0305                                    OK
# Creating    JAAD/videos/video_0306                                    OK
# Creating    JAAD/videos/video_0307                                    OK
# Creating    JAAD/videos/video_0308                                    OK
# Creating    JAAD/videos/video_0309                                    OK
# Creating    JAAD/videos/video_0310                                    OK
# Creating    JAAD/videos/video_0311                                    OK
# Creating    JAAD/videos/video_0312                                    OK
# Creating    JAAD/videos/video_0313                                    OK
# Creating    JAAD/videos/video_0314                                    OK
# Creating    JAAD/videos/video_0315                                    OK
# Creating    JAAD/videos/video_0316                                    OK
# Creating    JAAD/videos/video_0317                                    OK
# Creating    JAAD/videos/video_0318                                    OK
# Creating    JAAD/videos/video_0319                                    OK
# Creating    JAAD/videos/video_0320                                    OK
# Creating    JAAD/videos/video_0321                                    OK
# Creating    JAAD/videos/video_0322                                    OK
# Creating    JAAD/videos/video_0323                                    OK
# Creating    JAAD/videos/video_0324                                    OK
# Creating    JAAD/videos/video_0325                                    OK
# Creating    JAAD/videos/video_0326                                    OK
# Creating    JAAD/videos/video_0327                                    OK
# Creating    JAAD/videos/video_0328                                    OK
# Creating    JAAD/videos/video_0329                                    OK
# Creating    JAAD/videos/video_0330                                    OK
# Creating    JAAD/videos/video_0331                                    OK
# Creating    JAAD/videos/video_0332                                    OK
# Creating    JAAD/videos/video_0333                                    OK
# Creating    JAAD/videos/video_0334                                    OK
# Creating    JAAD/videos/video_0335                                    OK
# Creating    JAAD/videos/video_0336                                    OK
# Creating    JAAD/videos/video_0337                                    OK
# Creating    JAAD/videos/video_0338                                    OK
# Creating    JAAD/videos/video_0339                                    OK
# Creating    JAAD/videos/video_0340                                    OK
# Creating    JAAD/videos/video_0341                                    OK
# Creating    JAAD/videos/video_0342                                    OK
# Creating    JAAD/videos/video_0343                                    OK
# Creating    JAAD/videos/video_0344                                    OK
# Creating    JAAD/videos/video_0345                                    OK
# Creating    JAAD/videos/video_0346                                    OK
# All OK
# /content/JAAD
# video_0001
# video_0002
# video_0003
# video_0004
# video_0005
# video_0006
# video_0007
# video_0008
# video_0009
# video_0010
# video_0011
# video_0012
# video_0013
# video_0014
# video_0015
# video_0016
# video_0017
# video_0018
# video_0019
# video_0020
# video_0021
# video_0022
# video_0023
# video_0024
# video_0025
# video_0026
# video_0027
# video_0028
# video_0029
# video_0030
# video_0031
# video_0032
# video_0033
# video_0034
# video_0035
# video_0036
# video_0037
# video_0038
# video_0039
# video_0040
# video_0041
# video_0042
# video_0043
# video_0044
# video_0045
# video_0046
# video_0047
# video_0048
# video_0049
# video_0050
# video_0051
# video_0052
# video_0053
# video_0054
# video_0055
# video_0056
# video_0057
# video_0058
# video_0059
# video_0060
# video_0061
# video_0062
# video_0063
# video_0064
# video_0065
# video_0066
# video_0067
# video_0068
# video_0069
# video_0070
# video_0071
# video_0072
# video_0073
# video_0074
# video_0075
# video_0076
# video_0077
# video_0078
# video_0079
# video_0080
# video_0081
# video_0082
# video_0083
# video_0084
# video_0085
# video_0086
# video_0087
# video_0088
# video_0089
# video_0090
# video_0091
# video_0092
# video_0093
# video_0094
# video_0095
# video_0096
# video_0097
# video_0098
# video_0099
# video_0100
# video_0101
# video_0102
# video_0103
# video_0104
# video_0105
# video_0106
# video_0107
# video_0108
# video_0109
# video_0110
# video_0111
# video_0112
# video_0113
# video_0114
# video_0115
# video_0116
# video_0117
# video_0118
# video_0119
# video_0120
# video_0121
# video_0122
# video_0123
# video_0124
# video_0125
# video_0126
# video_0127
# video_0128
# video_0129
# video_0130
# video_0131
# video_0132
# video_0133
# video_0134
# video_0135
# video_0136
# video_0137
# video_0138
# video_0139
# video_0140
# video_0141
# video_0142
# video_0143
# video_0144
# video_0145
# video_0146
# video_0147
# video_0148
# video_0149
# video_0150
# video_0151
# video_0152
# video_0153
# video_0154
# video_0155
# video_0156
# video_0157
# video_0158
# video_0159
# video_0160
# video_0161
# video_0162
# video_0163
# video_0164
# video_0165
# video_0166
# video_0167
# video_0168
# video_0169
# video_0170
# video_0171
# video_0172
# video_0173
# video_0174
# video_0175
# video_0176
# video_0177
# video_0178
# video_0179
# video_0180
# video_0181
# video_0182
# video_0183
# video_0184
# video_0185
# video_0186
# video_0187
# video_0188
# video_0189
# video_0190
# video_0191
# video_0192
# video_0193
# video_0194
# video_0195
# video_0196
# video_0197
# video_0198
# video_0199
# video_0200
# video_0201
# video_0202
# video_0203
# video_0204
# video_0205
# video_0206
# video_0207
# video_0208
# video_0209
# video_0210
# video_0211
# video_0212
# video_0213
# video_0214
# video_0215
# video_0216
# video_0217
# video_0218
# video_0219
# video_0220
# video_0221
# video_0222
# video_0223
# video_0224
# video_0225
# video_0226
# video_0227
# video_0228
# video_0229
# video_0230
# video_0231
# video_0232
# video_0233
# video_0234
# video_0235
# video_0236
# video_0237
# video_0238
# video_0239
# video_0240
# video_0241
# video_0242
# video_0243
# video_0244
# video_0245
# video_0246
# video_0247
# video_0248
# video_0249
# video_0250
# video_0251
# video_0252
# video_0253
# video_0254
# video_0255
# video_0256
# video_0257
# video_0258
# video_0259
# video_0260
# video_0261
# video_0262
# video_0263
# video_0264
# video_0265
# video_0266
# video_0267
# video_0268
# video_0269
# video_0270
# video_0271
# video_0272
# video_0273
# video_0274
# video_0275
# video_0276
# video_0277
# video_0278
# video_0279
# video_0280
# video_0281
# video_0282
# video_0283
# video_0284
# video_0285
# video_0286
# video_0287
# video_0288
# video_0289
# video_0290
# video_0291
# video_0292
# video_0293
# video_0294
# video_0295
# video_0296
# video_0297
# video_0298
# video_0299
# video_0300
# video_0301
# video_0302
# video_0303
# video_0304
# video_0305
# video_0306
# video_0307
# video_0308
# video_0309
# video_0310
# video_0311
# video_0312
# video_0313
# video_0314
# video_0315
# video_0316
# video_0317
# video_0318
# video_0319
# video_0320
# video_0321
# video_0322
# video_0323
# video_0324
# video_0325
# video_0326
# video_0327
# video_0328
# video_0329
# video_0330
# video_0331
# video_0332
# video_0333
# video_0334
# video_0335
# video_0336
# video_0337
# video_0338
# video_0339
# video_0340
# video_0341
# video_0342
# video_0343
# video_0344
# video_0345
# video_0346
# video_0001
# /content/JAAD/rgb-images/video_0001
#
#
# video_0001
# /content/JAAD/rgb-images/video_0001
#
#
# video_0002
# /content/JAAD/rgb-images/video_0002
#
#
# video_0002
# /content/JAAD/rgb-images/video_0002
#
#
# video_0003
# /content/JAAD/rgb-images/video_0003
#
#
# video_0003
# /content/JAAD/rgb-images/video_0003
#
#
# video_0004
# /content/JAAD/rgb-images/video_0004
#
#
# video_0004
# /content/JAAD/rgb-images/video_0004
#
#
# video_0005
# /content/JAAD/rgb-images/video_0005
#
#
# video_0005
# /content/JAAD/rgb-images/video_0005
#
#
# video_0006
# /content/JAAD/rgb-images/video_0006
#
#
# video_0006
# /content/JAAD/rgb-images/video_0006
#
#
# video_0007
# /content/JAAD/rgb-images/video_0007
#
#
# video_0007
# /content/JAAD/rgb-images/video_0007
#
#
# video_0008
# /content/JAAD/rgb-images/video_0008
#
#
# video_0008
# /content/JAAD/rgb-images/video_0008
#
#
# video_0009
# /content/JAAD/rgb-images/video_0009
#
#
# video_0009
# /content/JAAD/rgb-images/video_0009
#
#
# video_0010
# /content/JAAD/rgb-images/video_0010
#
#
# video_0010
# /content/JAAD/rgb-images/video_0010
#
#
# video_0011
# /content/JAAD/rgb-images/video_0011
#
#
# video_0011
# /content/JAAD/rgb-images/video_0011
#
#
# video_0012
# /content/JAAD/rgb-images/video_0012
#
#
# video_0012
# /content/JAAD/rgb-images/video_0012
#
#
# video_0013
# /content/JAAD/rgb-images/video_0013
#
#
# video_0013
# /content/JAAD/rgb-images/video_0013
#
#
# video_0014
# /content/JAAD/rgb-images/video_0014
#
#
# video_0014
# /content/JAAD/rgb-images/video_0014
#
#
# video_0015
# /content/JAAD/rgb-images/video_0015
#
#
# video_0015
# /content/JAAD/rgb-images/video_0015
#
#
# video_0016
# /content/JAAD/rgb-images/video_0016
#
#
# video_0016
# /content/JAAD/rgb-images/video_0016
#
#
# video_0017
# /content/JAAD/rgb-images/video_0017
#
#
# video_0017
# /content/JAAD/rgb-images/video_0017
#
#
# video_0018
# /content/JAAD/rgb-images/video_0018
#
#
# video_0018
# /content/JAAD/rgb-images/video_0018
#
#
# video_0019
# /content/JAAD/rgb-images/video_0019
#
#
# video_0019
# /content/JAAD/rgb-images/video_0019
#
#
# video_0020
# /content/JAAD/rgb-images/video_0020
#
#
# video_0020
# /content/JAAD/rgb-images/video_0020
#
#
# video_0021
# /content/JAAD/rgb-images/video_0021
#
#
# video_0021
# /content/JAAD/rgb-images/video_0021
#
#
# video_0022
# /content/JAAD/rgb-images/video_0022
#
#
# video_0022
# /content/JAAD/rgb-images/video_0022
#
#
# video_0023
# /content/JAAD/rgb-images/video_0023
#
#
# video_0023
# /content/JAAD/rgb-images/video_0023
#
#
# video_0024
# /content/JAAD/rgb-images/video_0024
#
#
# video_0024
# /content/JAAD/rgb-images/video_0024
#
#
# video_0025
# /content/JAAD/rgb-images/video_0025
#
#
# video_0025
# /content/JAAD/rgb-images/video_0025
#
#
# video_0026
# /content/JAAD/rgb-images/video_0026
#
#
# video_0026
# /content/JAAD/rgb-images/video_0026
#
#
# video_0027
# /content/JAAD/rgb-images/video_0027
#
#
# video_0027
# /content/JAAD/rgb-images/video_0027
#
#
# video_0028
# /content/JAAD/rgb-images/video_0028
#
#
# video_0028
# /content/JAAD/rgb-images/video_0028
#
#
# video_0029
# /content/JAAD/rgb-images/video_0029
#
#
# video_0029
# /content/JAAD/rgb-images/video_0029
#
#
# video_0030
# /content/JAAD/rgb-images/video_0030
#
#
# video_0030
# /content/JAAD/rgb-images/video_0030
#
#
# video_0031
# /content/JAAD/rgb-images/video_0031
#
#
# video_0031
# /content/JAAD/rgb-images/video_0031
#
#
# video_0032
# /content/JAAD/rgb-images/video_0032
#
#
# video_0032
# /content/JAAD/rgb-images/video_0032
#
#
# video_0033
# /content/JAAD/rgb-images/video_0033
#
#
# video_0033
# /content/JAAD/rgb-images/video_0033
#
#
# video_0034
# /content/JAAD/rgb-images/video_0034
#
#
# video_0034
# /content/JAAD/rgb-images/video_0034
#
#
# video_0035
# /content/JAAD/rgb-images/video_0035
#
#
# video_0035
# /content/JAAD/rgb-images/video_0035
#
#
# video_0036
# /content/JAAD/rgb-images/video_0036
#
#
# video_0036
# /content/JAAD/rgb-images/video_0036
#
#
# video_0037
# /content/JAAD/rgb-images/video_0037
#
#
# video_0037
# /content/JAAD/rgb-images/video_0037
#
#
# video_0038
# /content/JAAD/rgb-images/video_0038
#
#
# video_0038
# /content/JAAD/rgb-images/video_0038
#
#
# video_0039
# /content/JAAD/rgb-images/video_0039
#
#
# video_0039
# /content/JAAD/rgb-images/video_0039
#
#
# video_0040
# /content/JAAD/rgb-images/video_0040
#
#
# video_0040
# /content/JAAD/rgb-images/video_0040
#
#
# video_0041
# /content/JAAD/rgb-images/video_0041
#
#
# video_0041
# /content/JAAD/rgb-images/video_0041
#
#
# video_0042
# /content/JAAD/rgb-images/video_0042
#
#
# video_0042
# /content/JAAD/rgb-images/video_0042
#
#
# video_0043
# /content/JAAD/rgb-images/video_0043
#
#
# video_0043
# /content/JAAD/rgb-images/video_0043
#
#
# video_0044
# /content/JAAD/rgb-images/video_0044
#
#
# video_0044
# /content/JAAD/rgb-images/video_0044
#
#
# video_0045
# /content/JAAD/rgb-images/video_0045
#
#
# video_0045
# /content/JAAD/rgb-images/video_0045
#
#
# video_0046
# /content/JAAD/rgb-images/video_0046
#
#
# video_0046
# /content/JAAD/rgb-images/video_0046
#
#
# video_0047
# /content/JAAD/rgb-images/video_0047
#
#
# video_0047
# /content/JAAD/rgb-images/video_0047
#
#
# video_0048
# /content/JAAD/rgb-images/video_0048
#
#
# video_0048
# /content/JAAD/rgb-images/video_0048
#
#
# video_0049
# /content/JAAD/rgb-images/video_0049
#
#
# video_0049
# /content/JAAD/rgb-images/video_0049
#
#
# video_0050
# /content/JAAD/rgb-images/video_0050
#
#
# video_0050
# /content/JAAD/rgb-images/video_0050
#
#
# video_0051
# /content/JAAD/rgb-images/video_0051
#
#
# video_0051
# /content/JAAD/rgb-images/video_0051
#
#
# video_0052
# /content/JAAD/rgb-images/video_0052
#
#
# video_0052
# /content/JAAD/rgb-images/video_0052
#
#
# video_0053
# /content/JAAD/rgb-images/video_0053
#
#
# video_0053
# /content/JAAD/rgb-images/video_0053
#
#
# video_0054
# /content/JAAD/rgb-images/video_0054
#
#
# video_0054
# /content/JAAD/rgb-images/video_0054
#
#
# video_0055
# /content/JAAD/rgb-images/video_0055
#
#
# video_0055
# /content/JAAD/rgb-images/video_0055
#
#
# video_0056
# /content/JAAD/rgb-images/video_0056
#
#
# video_0056
# /content/JAAD/rgb-images/video_0056
#
#
# video_0057
# /content/JAAD/rgb-images/video_0057
#
#
# video_0057
# /content/JAAD/rgb-images/video_0057
#
#
# video_0058
# /content/JAAD/rgb-images/video_0058
#
#
# video_0058
# /content/JAAD/rgb-images/video_0058
#
#
# video_0059
# /content/JAAD/rgb-images/video_0059
#
#
# video_0059
# /content/JAAD/rgb-images/video_0059
#
#
# video_0060
# /content/JAAD/rgb-images/video_0060
#
#
# video_0060
# /content/JAAD/rgb-images/video_0060
#
#
# video_0061
# /content/JAAD/rgb-images/video_0061
#
#
# video_0061
# /content/JAAD/rgb-images/video_0061
#
#
# video_0062
# /content/JAAD/rgb-images/video_0062
#
#
# video_0062
# /content/JAAD/rgb-images/video_0062
#
#
# video_0063
# /content/JAAD/rgb-images/video_0063
#
#
# video_0063
# /content/JAAD/rgb-images/video_0063
#
#
# video_0064
# /content/JAAD/rgb-images/video_0064
#
#
# video_0064
# /content/JAAD/rgb-images/video_0064
#
#
# video_0065
# /content/JAAD/rgb-images/video_0065
#
#
# video_0065
# /content/JAAD/rgb-images/video_0065
#
#
# video_0066
# /content/JAAD/rgb-images/video_0066
#
#
# video_0066
# /content/JAAD/rgb-images/video_0066
#
#
# video_0067
# /content/JAAD/rgb-images/video_0067
#
#
# video_0067
# /content/JAAD/rgb-images/video_0067
#
#
# video_0068
# /content/JAAD/rgb-images/video_0068
#
#
# video_0068
# /content/JAAD/rgb-images/video_0068
#
#
# video_0069
# /content/JAAD/rgb-images/video_0069
#
#
# video_0069
# /content/JAAD/rgb-images/video_0069
#
#
# video_0070
# /content/JAAD/rgb-images/video_0070
#
#
# video_0070
# /content/JAAD/rgb-images/video_0070
#
#
# video_0071
# /content/JAAD/rgb-images/video_0071
#
#
# video_0071
# /content/JAAD/rgb-images/video_0071
#
#
# video_0072
# /content/JAAD/rgb-images/video_0072
#
#
# video_0072
# /content/JAAD/rgb-images/video_0072
#
#
# video_0073
# /content/JAAD/rgb-images/video_0073
#
#
# video_0073
# /content/JAAD/rgb-images/video_0073
#
#
# video_0074
# /content/JAAD/rgb-images/video_0074
#
#
# video_0074
# /content/JAAD/rgb-images/video_0074
#
#
# video_0075
# /content/JAAD/rgb-images/video_0075
#
#
# video_0075
# /content/JAAD/rgb-images/video_0075
#
#
# video_0076
# /content/JAAD/rgb-images/video_0076
#
#
# video_0076
# /content/JAAD/rgb-images/video_0076
#
#
# video_0077
# /content/JAAD/rgb-images/video_0077
#
#
# video_0077
# /content/JAAD/rgb-images/video_0077
#
#
# video_0078
# /content/JAAD/rgb-images/video_0078
#
#
# video_0078
# /content/JAAD/rgb-images/video_0078
#
#
# video_0079
# /content/JAAD/rgb-images/video_0079
#
#
# video_0079
# /content/JAAD/rgb-images/video_0079
#
#
# video_0080
# /content/JAAD/rgb-images/video_0080
#
#
# video_0080
# /content/JAAD/rgb-images/video_0080
#
#
# video_0081
# /content/JAAD/rgb-images/video_0081
#
#
# video_0081
# /content/JAAD/rgb-images/video_0081
#
#
# video_0082
# /content/JAAD/rgb-images/video_0082
#
#
# video_0082
# /content/JAAD/rgb-images/video_0082
#
#
# video_0083
# /content/JAAD/rgb-images/video_0083
#
#
# video_0083
# /content/JAAD/rgb-images/video_0083
#
#
# video_0084
# /content/JAAD/rgb-images/video_0084
#
#
# video_0084
# /content/JAAD/rgb-images/video_0084
#
#
# video_0085
# /content/JAAD/rgb-images/video_0085
#
#
# video_0085
# /content/JAAD/rgb-images/video_0085
#
#
# video_0086
# /content/JAAD/rgb-images/video_0086
#
#
# video_0086
# /content/JAAD/rgb-images/video_0086
#
#
# video_0087
# /content/JAAD/rgb-images/video_0087
#
#
# video_0087
# /content/JAAD/rgb-images/video_0087
#
#
# video_0088
# /content/JAAD/rgb-images/video_0088
#
#
# video_0088
# /content/JAAD/rgb-images/video_0088
#
#
# video_0089
# /content/JAAD/rgb-images/video_0089
#
#
# video_0089
# /content/JAAD/rgb-images/video_0089
#
#
# video_0090
# /content/JAAD/rgb-images/video_0090
#
#
# video_0090
# /content/JAAD/rgb-images/video_0090
#
#
# video_0091
# /content/JAAD/rgb-images/video_0091
#
#
# video_0091
# /content/JAAD/rgb-images/video_0091
#
#
# video_0092
# /content/JAAD/rgb-images/video_0092
#
#
# video_0092
# /content/JAAD/rgb-images/video_0092
#
#
# video_0093
# /content/JAAD/rgb-images/video_0093
#
#
# video_0093
# /content/JAAD/rgb-images/video_0093
#
#
# video_0094
# /content/JAAD/rgb-images/video_0094
#
#
# video_0094
# /content/JAAD/rgb-images/video_0094
#
#
# video_0095
# /content/JAAD/rgb-images/video_0095
#
#
# video_0095
# /content/JAAD/rgb-images/video_0095
#
#
# video_0096
# /content/JAAD/rgb-images/video_0096
#
#
# video_0096
# /content/JAAD/rgb-images/video_0096
#
#
# video_0097
# /content/JAAD/rgb-images/video_0097
#
#
# video_0097
# /content/JAAD/rgb-images/video_0097
#
#
# video_0098
# /content/JAAD/rgb-images/video_0098
#
#
# video_0098
# /content/JAAD/rgb-images/video_0098
#
#
# video_0099
# /content/JAAD/rgb-images/video_0099
#
#
# video_0099
# /content/JAAD/rgb-images/video_0099
#
#
# video_0100
# /content/JAAD/rgb-images/video_0100
#
#
# video_0100
# /content/JAAD/rgb-images/video_0100
#
#
# video_0101
# /content/JAAD/rgb-images/video_0101
#
#
# video_0101
# /content/JAAD/rgb-images/video_0101
#
#
# video_0102
# /content/JAAD/rgb-images/video_0102
#
#
# video_0102
# /content/JAAD/rgb-images/video_0102
#
#
# video_0103
# /content/JAAD/rgb-images/video_0103
#
#
# video_0103
# /content/JAAD/rgb-images/video_0103
#
#
# video_0104
# /content/JAAD/rgb-images/video_0104
#
#
# video_0104
# /content/JAAD/rgb-images/video_0104
#
#
# video_0105
# /content/JAAD/rgb-images/video_0105
#
#
# video_0105
# /content/JAAD/rgb-images/video_0105
#
#
# video_0106
# /content/JAAD/rgb-images/video_0106
#
#
# video_0106
# /content/JAAD/rgb-images/video_0106
#
#
# video_0107
# /content/JAAD/rgb-images/video_0107
#
#
# video_0107
# /content/JAAD/rgb-images/video_0107
#
#
# video_0108
# /content/JAAD/rgb-images/video_0108
#
#
# video_0108
# /content/JAAD/rgb-images/video_0108
#
#
# video_0109
# /content/JAAD/rgb-images/video_0109
#
#
# video_0109
# /content/JAAD/rgb-images/video_0109
#
#
# video_0110
# /content/JAAD/rgb-images/video_0110
#
#
# video_0110
# /content/JAAD/rgb-images/video_0110
#
#
# video_0111
# /content/JAAD/rgb-images/video_0111
#
#
# video_0111
# /content/JAAD/rgb-images/video_0111
#
#
# video_0112
# /content/JAAD/rgb-images/video_0112
#
#
# video_0112
# /content/JAAD/rgb-images/video_0112
#
#
# video_0113
# /content/JAAD/rgb-images/video_0113
#
#
# video_0113
# /content/JAAD/rgb-images/video_0113
#
#
# video_0114
# /content/JAAD/rgb-images/video_0114
#
#
# video_0114
# /content/JAAD/rgb-images/video_0114
#
#
# video_0115
# /content/JAAD/rgb-images/video_0115
#
#
# video_0115
# /content/JAAD/rgb-images/video_0115
#
#
# video_0116
# /content/JAAD/rgb-images/video_0116
#
#
# video_0116
# /content/JAAD/rgb-images/video_0116
#
#
# video_0117
# /content/JAAD/rgb-images/video_0117
#
#
# video_0117
# /content/JAAD/rgb-images/video_0117
#
#
# video_0118
# /content/JAAD/rgb-images/video_0118
#
#
# video_0118
# /content/JAAD/rgb-images/video_0118
#
#
# video_0119
# /content/JAAD/rgb-images/video_0119
#
#
# video_0119
# /content/JAAD/rgb-images/video_0119
#
#
# video_0120
# /content/JAAD/rgb-images/video_0120
#
#
# video_0120
# /content/JAAD/rgb-images/video_0120
#
#
# video_0121
# /content/JAAD/rgb-images/video_0121
#
#
# video_0121
# /content/JAAD/rgb-images/video_0121
#
#
# video_0122
# /content/JAAD/rgb-images/video_0122
#
#
# video_0122
# /content/JAAD/rgb-images/video_0122
#
#
# video_0123
# /content/JAAD/rgb-images/video_0123
#
#
# video_0123
# /content/JAAD/rgb-images/video_0123
#
#
# video_0124
# /content/JAAD/rgb-images/video_0124
#
#
# video_0124
# /content/JAAD/rgb-images/video_0124
#
#
# video_0125
# /content/JAAD/rgb-images/video_0125
#
#
# video_0125
# /content/JAAD/rgb-images/video_0125
#
#
# video_0126
# /content/JAAD/rgb-images/video_0126
#
#
# video_0126
# /content/JAAD/rgb-images/video_0126
#
#
# video_0127
# /content/JAAD/rgb-images/video_0127
#
#
# video_0127
# /content/JAAD/rgb-images/video_0127
#
#
# video_0128
# /content/JAAD/rgb-images/video_0128
#
#
# video_0128
# /content/JAAD/rgb-images/video_0128
#
#
# video_0129
# /content/JAAD/rgb-images/video_0129
#
#
# video_0129
# /content/JAAD/rgb-images/video_0129
#
#
# video_0130
# /content/JAAD/rgb-images/video_0130
#
#
# video_0130
# /content/JAAD/rgb-images/video_0130
#
#
# video_0131
# /content/JAAD/rgb-images/video_0131
#
#
# video_0131
# /content/JAAD/rgb-images/video_0131
#
#
# video_0132
# /content/JAAD/rgb-images/video_0132
#
#
# video_0132
# /content/JAAD/rgb-images/video_0132
#
#
# video_0133
# /content/JAAD/rgb-images/video_0133
#
#
# video_0133
# /content/JAAD/rgb-images/video_0133
#
#
# video_0134
# /content/JAAD/rgb-images/video_0134
#
#
# video_0134
# /content/JAAD/rgb-images/video_0134
#
#
# video_0135
# /content/JAAD/rgb-images/video_0135
#
#
# video_0135
# /content/JAAD/rgb-images/video_0135
#
#
# video_0136
# /content/JAAD/rgb-images/video_0136
#
#
# video_0136
# /content/JAAD/rgb-images/video_0136
#
#
# video_0137
# /content/JAAD/rgb-images/video_0137
#
#
# video_0137
# /content/JAAD/rgb-images/video_0137
#
#
# video_0138
# /content/JAAD/rgb-images/video_0138
#
#
# video_0138
# /content/JAAD/rgb-images/video_0138
#
#
# video_0139
# /content/JAAD/rgb-images/video_0139
#
#
# video_0139
# /content/JAAD/rgb-images/video_0139
#
#
# video_0140
# /content/JAAD/rgb-images/video_0140
#
#
# video_0140
# /content/JAAD/rgb-images/video_0140
#
#
# video_0141
# /content/JAAD/rgb-images/video_0141
#
#
# video_0141
# /content/JAAD/rgb-images/video_0141
#
#
# video_0142
# /content/JAAD/rgb-images/video_0142
#
#
# video_0142
# /content/JAAD/rgb-images/video_0142
#
#
# video_0143
# /content/JAAD/rgb-images/video_0143
#
#
# video_0143
# /content/JAAD/rgb-images/video_0143
#
#
# video_0144
# /content/JAAD/rgb-images/video_0144
#
#
# video_0144
# /content/JAAD/rgb-images/video_0144
#
#
# video_0145
# /content/JAAD/rgb-images/video_0145
#
#
# video_0145
# /content/JAAD/rgb-images/video_0145
#
#
# video_0146
# /content/JAAD/rgb-images/video_0146
#
#
# video_0146
# /content/JAAD/rgb-images/video_0146
#
#
# video_0147
# /content/JAAD/rgb-images/video_0147
#
#
# video_0147
# /content/JAAD/rgb-images/video_0147
#
#
# video_0148
# /content/JAAD/rgb-images/video_0148
#
#
# video_0148
# /content/JAAD/rgb-images/video_0148
#
#
# video_0149
# /content/JAAD/rgb-images/video_0149
#
#
# video_0149
# /content/JAAD/rgb-images/video_0149
#
#
# video_0150
# /content/JAAD/rgb-images/video_0150
#
#
# video_0150
# /content/JAAD/rgb-images/video_0150
#
#
# video_0151
# /content/JAAD/rgb-images/video_0151
#
#
# video_0151
# /content/JAAD/rgb-images/video_0151
#
#
# video_0152
# /content/JAAD/rgb-images/video_0152
#
#
# video_0152
# /content/JAAD/rgb-images/video_0152
#
#
# video_0153
# /content/JAAD/rgb-images/video_0153
#
#
# video_0153
# /content/JAAD/rgb-images/video_0153
#
#
# video_0154
# /content/JAAD/rgb-images/video_0154
#
#
# video_0154
# /content/JAAD/rgb-images/video_0154
#
#
# video_0155
# /content/JAAD/rgb-images/video_0155
#
#
# video_0155
# /content/JAAD/rgb-images/video_0155
#
#
# video_0156
# /content/JAAD/rgb-images/video_0156
#
#
# video_0156
# /content/JAAD/rgb-images/video_0156
#
#
# video_0157
# /content/JAAD/rgb-images/video_0157
#
#
# video_0157
# /content/JAAD/rgb-images/video_0157
#
#
# video_0158
# /content/JAAD/rgb-images/video_0158
#
#
# video_0158
# /content/JAAD/rgb-images/video_0158
#
#
# video_0159
# /content/JAAD/rgb-images/video_0159
#
#
# video_0159
# /content/JAAD/rgb-images/video_0159
#
#
# video_0160
# /content/JAAD/rgb-images/video_0160
#
#
# video_0160
# /content/JAAD/rgb-images/video_0160
#
#
# video_0161
# /content/JAAD/rgb-images/video_0161
#
#
# video_0161
# /content/JAAD/rgb-images/video_0161
#
#
# video_0162
# /content/JAAD/rgb-images/video_0162
#
#
# video_0162
# /content/JAAD/rgb-images/video_0162
#
#
# video_0163
# /content/JAAD/rgb-images/video_0163
#
#
# video_0163
# /content/JAAD/rgb-images/video_0163
#
#
# video_0164
# /content/JAAD/rgb-images/video_0164
#
#
# video_0164
# ...
#
#
# video_0184
# /content/JAAD/rgb-images/video_0184
#
#
# video_0184
# /content/JAAD/rgb-images/video_0184
#
#
# video_0185
# /content/JAAD/rgb-images/video_0185
#
#
# video_0185
# /content/JAAD/rgb-images/video_0185
#
#
# video_0186
# /content/JAAD/rgb-images/video_0186
#
#
# video_0186
# /content/JAAD/rgb-images/video_0186
#
#
# video_0187
# /content/JAAD/rgb-images/video_0187
#
#
# video_0187
# /content/JAAD/rgb-images/video_0187
#
#
# video_0188
# /content/JAAD/rgb-images/video_0188
#
#
# video_0188
# /content/JAAD/rgb-images/video_0188
#
#
# video_0189
# /content/JAAD/rgb-images/video_0189
#
#
# video_0189
# /content/JAAD/rgb-images/video_0189
#
#
# video_0190
# /content/JAAD/rgb-images/video_0190
#
#
# video_0190
# /content/JAAD/rgb-images/video_0190
#
#
# video_0191
# /content/JAAD/rgb-images/video_0191
#
#
# video_0191
# /content/JAAD/rgb-images/video_0191
#
#
# video_0192
# /content/JAAD/rgb-images/video_0192
#
#
# video_0192
# /content/JAAD/rgb-images/video_0192
#
#
# video_0193
# /content/JAAD/rgb-images/video_0193
#
#
# video_0193
# /content/JAAD/rgb-images/video_0193
#
#
# video_0194
# /content/JAAD/rgb-images/video_0194
#
#
# video_0194
# /content/JAAD/rgb-images/video_0194
#
#
# video_0195
# /content/JAAD/rgb-images/video_0195
#
#
# video_0195
# /content/JAAD/rgb-images/video_0195
#
#
# video_0196
# /content/JAAD/rgb-images/video_0196
#
#
# video_0196
# /content/JAAD/rgb-images/video_0196
#
#
# video_0197
# /content/JAAD/rgb-images/video_0197
#
#
# video_0197
# /content/JAAD/rgb-images/video_0197
#
#
# video_0198
# /content/JAAD/rgb-images/video_0198
#
#
# video_0198
# /content/JAAD/rgb-images/video_0198
#
#
# video_0199
# /content/JAAD/rgb-images/video_0199
#
#
# video_0199
# /content/JAAD/rgb-images/video_0199
#
#
# video_0200
# /content/JAAD/rgb-images/video_0200
#
#
# video_0200
# /content/JAAD/rgb-images/video_0200
#
#
# video_0201
# /content/JAAD/rgb-images/video_0201
#
#
# video_0201
# /content/JAAD/rgb-images/video_0201
#
#
# video_0202
# /content/JAAD/rgb-images/video_0202
#
#
# video_0202
# /content/JAAD/rgb-images/video_0202
#
#
# video_0203
# /content/JAAD/rgb-images/video_0203
#
#
# video_0203
# /content/JAAD/rgb-images/video_0203
#
#
# video_0204
# /content/JAAD/rgb-images/video_0204
#
#
# video_0204
# /content/JAAD/rgb-images/video_0204
#
#
# video_0205
# /content/JAAD/rgb-images/video_0205
#
#
# video_0205
# /content/JAAD/rgb-images/video_0205
#
#
# video_0206
# /content/JAAD/rgb-images/video_0206
#
#
# video_0206
# /content/JAAD/rgb-images/video_0206
#
#
# video_0207
# /content/JAAD/rgb-images/video_0207
#
#
# video_0207
# /content/JAAD/rgb-images/video_0207
#
#
# video_0208
# /content/JAAD/rgb-images/video_0208
#
#
# video_0208
# /content/JAAD/rgb-images/video_0208
#
#
# video_0209
# /content/JAAD/rgb-images/video_0209
#
#
# video_0209
# /content/JAAD/rgb-images/video_0209
#
#
# video_0210
# /content/JAAD/rgb-images/video_0210
#
#
# video_0210
# /content/JAAD/rgb-images/video_0210
#
#
# video_0211
# /content/JAAD/rgb-images/video_0211
#
#
# video_0211
# /content/JAAD/rgb-images/video_0211
#
#
# video_0212
# /content/JAAD/rgb-images/video_0212
#
#
# video_0212
# /content/JAAD/rgb-images/video_0212
#
#
# video_0213
# /content/JAAD/rgb-images/video_0213
#
#
# video_0213
# /content/JAAD/rgb-images/video_0213
#
#
# video_0214
# /content/JAAD/rgb-images/video_0214
#
#
# video_0214
# /content/JAAD/rgb-images/video_0214
#
#
# video_0215
# /content/JAAD/rgb-images/video_0215
#
#
# video_0215
# /content/JAAD/rgb-images/video_0215
#
#
# video_0216
# /content/JAAD/rgb-images/video_0216
#
#
# video_0216
# /content/JAAD/rgb-images/video_0216
#
#
# video_0217
# /content/JAAD/rgb-images/video_0217
#
#
# video_0217
# /content/JAAD/rgb-images/video_0217
#
#
# video_0218
# /content/JAAD/rgb-images/video_0218
#
#
# video_0218
# /content/JAAD/rgb-images/video_0218
#
#
# video_0219
# /content/JAAD/rgb-images/video_0219
#
#
# video_0219
# /content/JAAD/rgb-images/video_0219
#
#
# video_0220
# /content/JAAD/rgb-images/video_0220
#
#
# video_0220
# /content/JAAD/rgb-images/video_0220
#
#
# video_0221
# /content/JAAD/rgb-images/video_0221
#
#
# video_0221
# /content/JAAD/rgb-images/video_0221
#
#
# video_0222
# /content/JAAD/rgb-images/video_0222
#
#
# video_0222
# /content/JAAD/rgb-images/video_0222
#
#
# video_0223
# /content/JAAD/rgb-images/video_0223
#
#
# video_0223
# /content/JAAD/rgb-images/video_0223
#
#
# video_0224
# /content/JAAD/rgb-images/video_0224
#
#
# video_0224
# /content/JAAD/rgb-images/video_0224
#
#
# video_0225
# /content/JAAD/rgb-images/video_0225
#
#
# video_0225
# /content/JAAD/rgb-images/video_0225
#
#
# video_0226
# /content/JAAD/rgb-images/video_0226
#
#
# video_0226
# /content/JAAD/rgb-images/video_0226
#
#
# video_0227
# /content/JAAD/rgb-images/video_0227
#
#
# video_0227
# /content/JAAD/rgb-images/video_0227
#
#
# video_0228
# /content/JAAD/rgb-images/video_0228
#
#
# video_0228
# /content/JAAD/rgb-images/video_0228
#
#
# video_0229
# /content/JAAD/rgb-images/video_0229
#
#
# video_0229
# /content/JAAD/rgb-images/video_0229
#
#
# video_0230
# /content/JAAD/rgb-images/video_0230
#
#
# video_0230
# /content/JAAD/rgb-images/video_0230
#
#
# video_0231
# /content/JAAD/rgb-images/video_0231
#
#
# video_0231
# /content/JAAD/rgb-images/video_0231
#
#
# video_0232
# /content/JAAD/rgb-images/video_0232
#
#
# video_0232
# /content/JAAD/rgb-images/video_0232
#
#
# video_0233
# /content/JAAD/rgb-images/video_0233
#
#
# video_0233
# /content/JAAD/rgb-images/video_0233
#
#
# video_0234
# /content/JAAD/rgb-images/video_0234
#
#
# video_0234
# /content/JAAD/rgb-images/video_0234
#
#
# video_0235
# /content/JAAD/rgb-images/video_0235
#
#
# video_0235
# /content/JAAD/rgb-images/video_0235
#
#
# video_0236
# /content/JAAD/rgb-images/video_0236
#
#
# video_0236
# /content/JAAD/rgb-images/video_0236
#
#
# video_0237
# /content/JAAD/rgb-images/video_0237
#
#
# video_0237
# /content/JAAD/rgb-images/video_0237
#
#
# video_0238
# /content/JAAD/rgb-images/video_0238
#
#
# video_0238
# /content/JAAD/rgb-images/video_0238
#
#
# video_0239
# /content/JAAD/rgb-images/video_0239
#
#
# video_0239
# /content/JAAD/rgb-images/video_0239
#
#
# video_0240
# /content/JAAD/rgb-images/video_0240
#
#
# video_0240
# /content/JAAD/rgb-images/video_0240
#
#
# video_0241
# /content/JAAD/rgb-images/video_0241
#
#
# video_0241
# /content/JAAD/rgb-images/video_0241
#
#
# video_0242
# /content/JAAD/rgb-images/video_0242
#
#
# video_0242
# /content/JAAD/rgb-images/video_0242
#
#
# video_0243
# /content/JAAD/rgb-images/video_0243
#
#
# video_0243
# /content/JAAD/rgb-images/video_0243
#
#
# video_0244
# /content/JAAD/rgb-images/video_0244
#
#
# video_0244
# /content/JAAD/rgb-images/video_0244
#
#
# video_0245
# /content/JAAD/rgb-images/video_0245
#
#
# video_0245
# /content/JAAD/rgb-images/video_0245
#
#
# video_0246
# /content/JAAD/rgb-images/video_0246
#
#
# video_0246
# /content/JAAD/rgb-images/video_0246
#
#
# video_0247
# /content/JAAD/rgb-images/video_0247
#
#
# video_0247
# /content/JAAD/rgb-images/video_0247
#
#
# video_0248
# /content/JAAD/rgb-images/video_0248
#
#
# video_0248
# /content/JAAD/rgb-images/video_0248
#
#
# video_0249
# /content/JAAD/rgb-images/video_0249
#
#
# video_0249
# /content/JAAD/rgb-images/video_0249
#
#
# video_0250
# /content/JAAD/rgb-images/video_0250
#
#
# video_0250
# /content/JAAD/rgb-images/video_0250
#
#
# video_0251
# /content/JAAD/rgb-images/video_0251
#
#
# video_0251
# /content/JAAD/rgb-images/video_0251
#
#
# video_0252
# /content/JAAD/rgb-images/video_0252
#
#
# video_0252
# /content/JAAD/rgb-images/video_0252
#
#
# video_0253
# /content/JAAD/rgb-images/video_0253
#
#
# video_0253
# /content/JAAD/rgb-images/video_0253
#
#
# video_0254
# /content/JAAD/rgb-images/video_0254
#
#
# video_0254
# /content/JAAD/rgb-images/video_0254
#
#
# video_0255
# /content/JAAD/rgb-images/video_0255
#
#
# video_0255
# /content/JAAD/rgb-images/video_0255
#
#
# video_0256
# /content/JAAD/rgb-images/video_0256
#
#
# video_0256
# /content/JAAD/rgb-images/video_0256
#
#
# video_0257
# /content/JAAD/rgb-images/video_0257
#
#
# video_0257
# /content/JAAD/rgb-images/video_0257
#
#
# video_0258
# /content/JAAD/rgb-images/video_0258
#
#
# video_0258
# /content/JAAD/rgb-images/video_0258
#
#
# video_0259
# /content/JAAD/rgb-images/video_0259
#
#
# video_0259
# /content/JAAD/rgb-images/video_0259
#
#
# video_0260
# /content/JAAD/rgb-images/video_0260
#
#
# video_0260
# /content/JAAD/rgb-images/video_0260
#
#
# video_0261
# /content/JAAD/rgb-images/video_0261
#
#
# video_0261
# /content/JAAD/rgb-images/video_0261
#
#
# video_0262
# /content/JAAD/rgb-images/video_0262
#
#
# video_0262
# /content/JAAD/rgb-images/video_0262
#
#
# video_0263
# /content/JAAD/rgb-images/video_0263
#
#
# video_0263
# /content/JAAD/rgb-images/video_0263
#
#
# video_0264
# /content/JAAD/rgb-images/video_0264
#
#
# video_0264
# /content/JAAD/rgb-images/video_0264
#
#
# video_0265
# /content/JAAD/rgb-images/video_0265
#
#
# video_0265
# /content/JAAD/rgb-images/video_0265
#
#
# video_0266
# /content/JAAD/rgb-images/video_0266
#
#
# video_0266
# /content/JAAD/rgb-images/video_0266
#
#
# video_0267
# /content/JAAD/rgb-images/video_0267
#
#
# video_0267
# /content/JAAD/rgb-images/video_0267
#
#
# video_0268
# /content/JAAD/rgb-images/video_0268
#
#
# video_0268
# /content/JAAD/rgb-images/video_0268
#
#
# video_0269
# /content/JAAD/rgb-images/video_0269
#
#
# video_0269
# /content/JAAD/rgb-images/video_0269
#
#
# video_0270
# /content/JAAD/rgb-images/video_0270
#
#
# video_0270
# /content/JAAD/rgb-images/video_0270
#
#
# video_0271
# /content/JAAD/rgb-images/video_0271
#
#
# video_0271
# /content/JAAD/rgb-images/video_0271
#
#
# video_0272
# /content/JAAD/rgb-images/video_0272
#
#
# video_0272
# /content/JAAD/rgb-images/video_0272
#
#
# video_0273
# /content/JAAD/rgb-images/video_0273
#
#
# video_0273
# /content/JAAD/rgb-images/video_0273
#
#
# video_0274
# /content/JAAD/rgb-images/video_0274
#
#
# video_0274
# /content/JAAD/rgb-images/video_0274
#
#
# video_0275
# /content/JAAD/rgb-images/video_0275
#
#
# video_0275
# /content/JAAD/rgb-images/video_0275
#
#
# video_0276
# /content/JAAD/rgb-images/video_0276
#
#
# video_0276
# /content/JAAD/rgb-images/video_0276
#
#
# video_0277
# /content/JAAD/rgb-images/video_0277
#
#
# video_0277
# /content/JAAD/rgb-images/video_0277
#
#
# video_0278
# /content/JAAD/rgb-images/video_0278
#
#
# video_0278
# /content/JAAD/rgb-images/video_0278
#
#
# video_0279
# /content/JAAD/rgb-images/video_0279
#
#
# video_0279
# /content/JAAD/rgb-images/video_0279
#
#
# video_0280
# /content/JAAD/rgb-images/video_0280
#
#
# video_0280
# /content/JAAD/rgb-images/video_0280
#
#
# video_0281
# /content/JAAD/rgb-images/video_0281
#
#
# video_0281
# /content/JAAD/rgb-images/video_0281
#
#
# video_0282
# /content/JAAD/rgb-images/video_0282
#
#
# video_0282
# /content/JAAD/rgb-images/video_0282
#
#
# video_0283
# /content/JAAD/rgb-images/video_0283
#
#
# video_0283
# /content/JAAD/rgb-images/video_0283
#
#
# video_0284
# /content/JAAD/rgb-images/video_0284
#
#
# video_0284
# /content/JAAD/rgb-images/video_0284
#
#
# video_0285
# /content/JAAD/rgb-images/video_0285
#
#
# video_0285
# /content/JAAD/rgb-images/video_0285
#
#
# video_0286
# /content/JAAD/rgb-images/video_0286
#
#
# video_0286
# /content/JAAD/rgb-images/video_0286
#
#
# video_0287
# /content/JAAD/rgb-images/video_0287
#
#
# video_0287
# /content/JAAD/rgb-images/video_0287
#
#
# video_0288
# /content/JAAD/rgb-images/video_0288
#
#
# video_0288
# /content/JAAD/rgb-images/video_0288
#
#
# video_0289
# /content/JAAD/rgb-images/video_0289
#
#
# video_0289
# /content/JAAD/rgb-images/video_0289
#
#
# video_0290
# /content/JAAD/rgb-images/video_0290
#
#
# video_0290
# /content/JAAD/rgb-images/video_0290
#
#
# video_0291
# /content/JAAD/rgb-images/video_0291
#
#
# video_0291
# /content/JAAD/rgb-images/video_0291
#
#
# video_0292
# /content/JAAD/rgb-images/video_0292
#
#
# video_0292
# /content/JAAD/rgb-images/video_0292
#
#
# video_0293
# /content/JAAD/rgb-images/video_0293
#
#
# video_0293
# /content/JAAD/rgb-images/video_0293
#
#
# video_0294
# /content/JAAD/rgb-images/video_0294
#
#
# video_0294
# /content/JAAD/rgb-images/video_0294
#
#
# video_0295
# /content/JAAD/rgb-images/video_0295
#
#
# video_0295
# /content/JAAD/rgb-images/video_0295
#
#
# video_0296
# /content/JAAD/rgb-images/video_0296
#
#
# video_0296
# /content/JAAD/rgb-images/video_0296
#
#
# video_0297
# /content/JAAD/rgb-images/video_0297
#
#
# video_0297
# /content/JAAD/rgb-images/video_0297
#
#
# video_0298
# /content/JAAD/rgb-images/video_0298
#
#
# video_0298
# /content/JAAD/rgb-images/video_0298
#
#
# video_0299
# /content/JAAD/rgb-images/video_0299
#
#
# video_0299
# /content/JAAD/rgb-images/video_0299
#
#
# video_0300
# /content/JAAD/rgb-images/video_0300
#
#
# video_0300
# /content/JAAD/rgb-images/video_0300
#
#
# video_0301
# /content/JAAD/rgb-images/video_0301
#
#
# video_0301
# /content/JAAD/rgb-images/video_0301
#
#
# video_0302
# /content/JAAD/rgb-images/video_0302
#
#
# video_0302
# /content/JAAD/rgb-images/video_0302
#
#
# video_0303
# /content/JAAD/rgb-images/video_0303
#
#
# video_0303
# /content/JAAD/rgb-images/video_0303
#
#
# video_0304
# /content/JAAD/rgb-images/video_0304
#
#
# video_0304
# /content/JAAD/rgb-images/video_0304
#
#
# video_0305
# /content/JAAD/rgb-images/video_0305
#
#
# video_0305
# /content/JAAD/rgb-images/video_0305
#
#
# video_0306
# /content/JAAD/rgb-images/video_0306
#
#
# video_0306
# /content/JAAD/rgb-images/video_0306
#
#
# video_0307
# /content/JAAD/rgb-images/video_0307
#
#
# video_0307
# /content/JAAD/rgb-images/video_0307
#
#
# video_0308
# /content/JAAD/rgb-images/video_0308
#
#
# video_0308
# /content/JAAD/rgb-images/video_0308
#
#
# video_0309
# /content/JAAD/rgb-images/video_0309
#
#
# video_0309
# /content/JAAD/rgb-images/video_0309
#
#
# video_0310
# /content/JAAD/rgb-images/video_0310
#
#
# video_0310
# /content/JAAD/rgb-images/video_0310
#
#
# video_0311
# /content/JAAD/rgb-images/video_0311
#
#
# video_0311
# /content/JAAD/rgb-images/video_0311
#
#
# video_0312
# /content/JAAD/rgb-images/video_0312
#
#
# video_0312
# /content/JAAD/rgb-images/video_0312
#
#
# video_0313
# /content/JAAD/rgb-images/video_0313
#
#
# video_0313
# /content/JAAD/rgb-images/video_0313
#
#
# video_0314
# /content/JAAD/rgb-images/video_0314
#
#
# video_0314
# /content/JAAD/rgb-images/video_0314
#
#
# video_0315
# /content/JAAD/rgb-images/video_0315
#
#
# video_0315
# /content/JAAD/rgb-images/video_0315
#
#
# video_0316
# /content/JAAD/rgb-images/video_0316
#
#
# video_0316
# /content/JAAD/rgb-images/video_0316
#
#
# video_0317
# /content/JAAD/rgb-images/video_0317
#
#
# video_0317
# /content/JAAD/rgb-images/video_0317
#
#
# video_0318
# /content/JAAD/rgb-images/video_0318
#
#
# video_0318
# /content/JAAD/rgb-images/video_0318
#
#
# video_0319
# /content/JAAD/rgb-images/video_0319
#
#
# video_0319
# /content/JAAD/rgb-images/video_0319
#
#
# video_0320
# /content/JAAD/rgb-images/video_0320
#
#
# video_0320
# /content/JAAD/rgb-images/video_0320
#
#
# video_0321
# /content/JAAD/rgb-images/video_0321
#
#
# video_0321
# /content/JAAD/rgb-images/video_0321
#
#
# video_0322
# /content/JAAD/rgb-images/video_0322
#
#
# video_0322
# /content/JAAD/rgb-images/video_0322
#
#
# video_0323
# /content/JAAD/rgb-images/video_0323
#
#
# video_0323
# /content/JAAD/rgb-images/video_0323
#
#
# video_0324
# /content/JAAD/rgb-images/video_0324
#
#
# video_0324
# /content/JAAD/rgb-images/video_0324
#
#
# video_0325
# /content/JAAD/rgb-images/video_0325
#
#
# video_0325
# /content/JAAD/rgb-images/video_0325
#
#
# video_0326
# /content/JAAD/rgb-images/video_0326
#
#
# video_0326
# /content/JAAD/rgb-images/video_0326
#
#
# video_0327
# /content/JAAD/rgb-images/video_0327
#
#
# video_0327
# /content/JAAD/rgb-images/video_0327
#
#
# video_0328
# /content/JAAD/rgb-images/video_0328
#
#
# video_0328
# /content/JAAD/rgb-images/video_0328
#
#
# video_0329
# /content/JAAD/rgb-images/video_0329
#
#
# video_0329
# /content/JAAD/rgb-images/video_0329
#
#
# video_0330
# /content/JAAD/rgb-images/video_0330
#
#
# video_0330
# /content/JAAD/rgb-images/video_0330
#
#
# video_0331
# /content/JAAD/rgb-images/video_0331
#
#
# video_0331
# /content/JAAD/rgb-images/video_0331
#
#
# video_0332
# /content/JAAD/rgb-images/video_0332
#
#
# video_0332
# /content/JAAD/rgb-images/video_0332
#
#
# video_0333
# /content/JAAD/rgb-images/video_0333
#
#
# video_0333
# /content/JAAD/rgb-images/video_0333
#
#
# video_0334
# /content/JAAD/rgb-images/video_0334
#
#
# video_0334
# /content/JAAD/rgb-images/video_0334
#
#
# video_0335
# /content/JAAD/rgb-images/video_0335
#
#
# video_0335
# /content/JAAD/rgb-images/video_0335
#
#
# video_0336
# /content/JAAD/rgb-images/video_0336
#
#
# video_0336
# /content/JAAD/rgb-images/video_0336
#
#
# video_0337
# /content/JAAD/rgb-images/video_0337
#
#
# video_0337
# /content/JAAD/rgb-images/video_0337
#
#
# video_0338
# /content/JAAD/rgb-images/video_0338
#
#
# video_0338
# /content/JAAD/rgb-images/video_0338
#
#
# video_0339
# /content/JAAD/rgb-images/video_0339
#
#
# video_0339
# /content/JAAD/rgb-images/video_0339
#
#
# video_0340
# /content/JAAD/rgb-images/video_0340
#
#
# video_0340
# /content/JAAD/rgb-images/video_0340
#
#
# video_0341
# /content/JAAD/rgb-images/video_0341
#
#
# video_0341
# /content/JAAD/rgb-images/video_0341
#
#
# video_0342
# /content/JAAD/rgb-images/video_0342
#
#
# video_0342
# /content/JAAD/rgb-images/video_0342
#
#
# video_0343
# /content/JAAD/rgb-images/video_0343
#
#
# video_0343
# /content/JAAD/rgb-images/video_0343
#
#
# video_0344
# /content/JAAD/rgb-images/video_0344
#
#
# video_0344
# /content/JAAD/rgb-images/video_0344
#
#
# video_0345
# /content/JAAD/rgb-images/video_0345
#
#
# video_0345
# /content/JAAD/rgb-images/video_0345
#
#
# video_0346
# /content/JAAD/rgb-images/video_0346
#
#
# video_0346
# /content/JAAD/rgb-images/video_0346

# %% [markdown]
# # Import YOWO

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch.autograd import Variable

from cfg import *
from cfam import CFAMBlock
from backbones_2d import darknet
from backbones_3d import mobilenet, shufflenet, mobilenetv2, shufflenetv2, resnext, resnet



num_classes = 2 # 24 is the number of classes of ucf101 dataset, 
#if we set this differently, we need to specify to not import pretrained weights of the last layer



class YOWO(nn.Module): # model.py
    def __init__(self):
        super(YOWO, self).__init__()
        
        ##### 2D Backbone #####
        # if opt.backbone_2d == "darknet":
        self.backbone_2d = darknet.Darknet("cfg/yolo.cfg")
        num_ch_2d = 425 # Number of output channels for backbone_2d
        # load pretrained weights
        self.backbone_2d.load_weights("weights/yolo.weights")

        ##### 3D Backbone ##### # resnet18: lighter but no pre-trained
        # default = "resnext101":
        self.backbone_3d = resnext.resnext101()
        num_ch_3d = 2048 # Number of output channels for backbone_3d
        # load 3d pretrained weights
        self.backbone_3d = self.backbone_3d.cuda()
        self.backbone_3d = nn.DataParallel(self.backbone_3d, device_ids=None) # Because the pretrained backbone models are saved in Dataparalled mode
        pretrained_3d_backbone = torch.load('weights/resnext-101-kinetics.pth')
        backbone_3d_dict = self.backbone_3d.state_dict()
        pretrained_3d_backbone_dict = {k: v for k, v in pretrained_3d_backbone['state_dict'].items() if k in backbone_3d_dict} # 1. filter out unnecessary keys
        backbone_3d_dict.update(pretrained_3d_backbone_dict) # 2. overwrite entries in the existing state dict
        self.backbone_3d.load_state_dict(backbone_3d_dict) # 3. load the new state dict
        self.backbone_3d = self.backbone_3d.module # remove the dataparallel wrapper


        ##### Attention & Final Conv #####f
        self.cfam = CFAMBlock(num_ch_2d+num_ch_3d, 1024)
        self.conv_final = nn.Conv2d(1024, 5*(num_classes+4+1), kernel_size=1, bias=False) # 5: number of anchors, num_classes, 4: coordinates, 1: confidence score
        self.seen = 0



    def forward(self, input):
        x_3d = input # Input clip (None, num_channels, num_frames, W, H) W and H must be divisible to 32 (480, 256?)
        x_2d = input[:, :, -1, :, :] # Last frame of the clip that is read

        x_2d = self.backbone_2d(x_2d)
        x_3d = self.backbone_3d(x_3d)
        x_3d = torch.squeeze(x_3d, dim=2)

        x = torch.cat((x_3d, x_2d), dim=1)
        x = self.cfam(x)

        out = self.conv_final(x)

        return out


def get_fine_tuning_parameters(model, freeze_backbone_2d = False, freeze_backbone_3d = False):
    ft_module_names = ['cfam', 'conv_final'] # Always fine tune 'cfam' and 'conv_final'
    if not freeze_backbone_2d:
        ft_module_names.append('backbone_2d') # Fine tune complete backbone_2d
    else:
        ft_module_names.append('backbone_2d.models.29') # Fine tune only layer 29 and 30
        ft_module_names.append('backbone_2d.models.30') # Fine tune only layer 29 and 30

    if not freeze_backbone_3d:
        ft_module_names.append('backbone_3d') # Fine tune complete backbone_3d
    else:
        ft_module_names.append('backbone_3d.layer4') # Fine tune only layer 4

    parameters = [] # trainable parameteres
    for k, v in model.named_parameters():
        for ft_module in ft_module_names:
            if ft_module in k:
                parameters.append({'params': v})
                break
            else:
                parameters.append({'params': v, 'lr': 0.0}) # freeze layers
    
    return parameters

# %%
# model       = YOWO()
# model       = model.cuda()
# model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
# model.seen  = 0
# # print(model)

# parameters = get_fine_tuning_parameters(model)#, opt)
# print(parameters)
# optimizer = optim.SGD(model.parameters(), lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)

# %%
# count = 0
# weights1 = []
# for v in model.parameters():
#   if count < 5:
#     weights1.append(v)
#   count += 1
# weights2 = []
# count = 0
# for k, v in model.named_parameters():
#   if count <5:
#     weights2.append(v)
#   count += 1
# print(weights1[0]==weights2[0])

# %%
# count = 0
# for k, v in model.named_parameters():
#   if count < 2:
#     print('k = ', k)
#     print('v = ', v)
#   count += 1

# %%
# model       = YOWO()
# model       = model.cuda()
# model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
# print(model)

# %%
# model_state = torch.load('./backup/yowo_ucf101-24_16f_best.pth') # load pre-trained model on ucf101 dataset

# %%
# model.load_state_dict(model_state['state_dict']) #

# %%
# from torchsummary import summary
# summary(model, (3, 16,480,256)) # channel x frames x W x H 480x256

# %% [markdown]
# # Setup and train function

# %%
from __future__ import print_function
import sys
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torchvision import datasets, transforms

import dataset
import random
import math
import os
# from opts import parse_opts
from utils import *
from cfg import parse_cfg
from region_loss import RegionLoss

# from model import YOWO, get_fine_tuning_parameters

# # Training settings
# opt = parse_opts()
# # which dataset to use
# dataset_use   = opt.dataset

dataset_use = 'jaad'

# assert dataset_use == 'ucf101-24' or dataset_use == 'jhmdb-21', 'invalid dataset'
# # path for dataset of training and validation
# datacfg       = opt.data_cfg
# # path for cfg file
# cfgfile       = opt.cfg_file

# data_options  = read_data_cfg(datacfg)
# net_options   = parse_cfg(cfgfile)[0]

# obtain list for training and testing
basepath      = '/content/JAAD/'#data_options['base'] # /content/data/rgb-images
trainlist     = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/data/trainlist.txt' # /content/data/trainlist.txt
testlist      = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/data/testlist.txt'# /content/data/testlist.txt


backupdir     = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup'
# number of training samples
nsamples      = file_lines(trainlist)
gpus          = '0' #data_options['gpus']  # e.g. 0   ,1,2,3
ngpus         = len(gpus.split(','))
num_workers   = 4  #?int(data_options['num_workers']) 0, 4, 10?

batch_size    = 8        #int(net_options['batch']) # 12
clip_duration = 16        #int(net_options['clip_duration']) # 16 frames
max_batches   = 200000    #int(net_options['max_batches']) # 100000
learning_rate = 0.001    #float(net_options['learning_rate']) # 0.0001
momentum      = 0.9       # float(net_options['momentum']) # 0.9
decay         = 0.0005    #float(net_options['decay']) # 0.0005
steps         = [10000,20000,30000,40000]   # [float(step) for step in net_options['steps'].split(',')] # [10000,20000,30000,40000] or [30000,40000,50000,60000]
scales        = [0.5,0.5,0.5,0.5]           #[float(scale) for scale in net_options['scales'].split(',')] # [0.5,0.5,0.5,0.5]

# loss parameters
# loss_options               = parse_cfg(cfgfile)[1]
region_loss                = RegionLoss()
# anchors                    = loss_options['anchors'].split(',')
region_loss.anchors        = [0.70458, 1.18803, 1.26654, 2.55121, 1.59382, 4.08321, 2.30548, 4.94180, 3.52332, 5.91979]
#[float(i) for i in anchors] #anchors = 0.70458, 1.18803, 1.26654, 2.55121, 1.59382, 4.08321, 2.30548, 4.94180, 3.52332, 5.91979
region_loss.num_classes    = 2   # int(loss_options['classes']) # 24
region_loss.num_anchors    = 5    #int(loss_options['num']) # 5
region_loss.anchor_step    = len(region_loss.anchors)//region_loss.num_anchors #
region_loss.object_scale   = 10. # float(loss_options['object_scale']) # 5
region_loss.noobject_scale = 1. # float(loss_options['noobject_scale']) # 1 
region_loss.class_scale    = 1. # float(loss_options['class_scale']) # 1
region_loss.coord_scale    = 100. # float(loss_options['coord_scale']) # 1
region_loss.batch          = batch_size #batch_size # 12



#Train parameters
max_epochs    = max_batches*batch_size//nsamples+1
use_cuda      = True #True
seed          = int(time.time())
# seed          = 42
eps           = 1e-5
best_fscore   = 0   # initialize best fscore
begin_epoch = 1
end_epoch = 25


# Test parameters
nms_thresh    = 0.2 # non_maximum suppression threshold 0.4 0.5 0.3   0.2
iou_thresh    = 0.3 # >=iou threshold => correctly identified 0.5 0.5 0.4
# proposals when confidence score >= 0.25

# # print('N_samples = ', nsamples)
# print('num of batches per epoch =', nsamples//batch_size+1)

# print('nms_thresh =', nms_thresh)
# print('iou_thresh =', iou_thresh)

if not os.path.exists(backupdir):
    os.mkdir(backupdir)
    
torch.manual_seed(seed)
if use_cuda:
    os.environ['CUDA_VISIBLE_DEVICES'] = gpus
    torch.cuda.manual_seed(seed)

# Create model
# model = YOWO(opt)
model       = YOWO()
model       = model.cuda()
model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
model.seen  = 0
# print(model)

# parameters = get_fine_tuning_parameters(model)#, opt)
# optimizer = optim.SGD(parameters, lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)
optimizer = optim.SGD(model.parameters(), lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)

kwargs = {'num_workers': num_workers, 'pin_memory': True} if use_cuda else {}

resume_path = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_manual_tune5_coord100_ob25_e4_16f_checkpoint.pth'

# Load resume path if necessary
# if opt.resume_path:
if os.path.exists(resume_path):
    print("===================================================================")
    print('loading checkpoint {}'.format(resume_path))
    checkpoint = torch.load(resume_path) # opt.resume_path
    # opt.begin_epoch = checkpoint['epoch'] + 1
    begin_epoch = checkpoint['epoch'] + 1
    best_fscore = checkpoint['fscore']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    model.seen = checkpoint['epoch'] * nsamples
    print("Loaded model fscore: ", checkpoint['fscore'])
    print("===================================================================")

region_loss.seen  = model.seen
processed_batches = model.seen//batch_size

init_width        = 480 # int(net_options['width']) # 224 480 480
init_height       = 256 # int(net_options['height']) # 224 270 256
init_epoch        = model.seen//nsamples 

##########################

def adjust_learning_rate(optimizer, batch):
    lr = learning_rate
    for i in range(len(steps)):
        scale = scales[i] if i < len(scales) else 1
        if batch >= steps[i]:
            lr = lr * scale
            if batch == steps[i]:
                break
        else:
            break
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr/batch_size
    return lr



def train(epoch):
    global processed_batches
    t0 = time.time()
    cur_model = model.module
    region_loss.l_x.reset()
    region_loss.l_y.reset()
    region_loss.l_w.reset()
    region_loss.l_h.reset()
    region_loss.l_conf.reset()
    region_loss.l_cls.reset()
    region_loss.l_total.reset()

    train_loader = torch.utils.data.DataLoader(
        dataset.listDataset(basepath, trainlist, dataset_use=dataset_use, shape=(init_width, init_height),
                       shuffle=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                       ]), 
                       train=True, 
                       seen=cur_model.seen,
                       batch_size=batch_size,
                       clip_duration=clip_duration,
                       num_workers=num_workers),
        batch_size=batch_size, shuffle=False, **kwargs)

    lr = adjust_learning_rate(optimizer, processed_batches)
    logging('training at epoch %d, lr %f' % (epoch, lr))

    model.train()

    for batch_idx, (data, target) in enumerate(train_loader):
        # print(data.size)
        # print(target.size)
        adjust_learning_rate(optimizer, processed_batches)
        processed_batches = processed_batches + 1

        if use_cuda:
            data = data.cuda()

        optimizer.zero_grad()
        output = model(data)
        region_loss.seen = region_loss.seen + data.data.size(0)
        loss = region_loss(output, target)
        loss.backward()
        optimizer.step()

        # save result every 500 batches
        if processed_batches % 500 == 0: # From time to time, reset averagemeters to see improvements
            region_loss.l_x.reset()
            region_loss.l_y.reset()
            region_loss.l_w.reset()
            region_loss.l_h.reset()
            region_loss.l_conf.reset()
            region_loss.l_cls.reset()
            region_loss.l_total.reset()

    t1 = time.time()
    logging('trained with %f samples/s' % (len(train_loader.dataset)/(t1-t0)))
    print('')
# Out:
# ===================================================================
# loading checkpoint /content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_manual_tune5_coord100_ob25_e4_16f_checkpoint.pth
# Loaded model fscore:  0
# ===================================================================

# %%
print('epoch of checkpoint =',checkpoint['epoch'])
# Out:
# epoch of checkpoint = 4

# %% [markdown]
# # Test function

# %%
def test(epoch):
    def truths_length(truths):
        for i in range(50):
            if truths[i][1] == 0:
                return i

    test_loader = torch.utils.data.DataLoader(
    dataset.listDataset(basepath, testlist, dataset_use=dataset_use, shape=(init_width, init_height),
                   shuffle=False,
                   transform=transforms.Compose([
                       transforms.ToTensor()
                   ]), train=False),
    batch_size=batch_size, shuffle=False, **kwargs)

    num_classes = region_loss.num_classes
    anchors     = region_loss.anchors
    num_anchors = region_loss.num_anchors
    conf_thresh_valid = 0.005
    total       = 0.0
    proposals   = 0.0
    correct     = 0.0
    fscore = 0.0

    correct_classification = 0.0
    total_detected = 0.0

    nbatch      = file_lines(testlist) // batch_size

    logging('validation at epoch %d' % (epoch))
    model.eval()

    for batch_idx, (frame_idx, data, target) in enumerate(test_loader):
        if use_cuda:
            data = data.cuda()
        with torch.no_grad():
            output = model(data).data
            all_boxes = get_region_boxes(output, conf_thresh_valid, num_classes, anchors, num_anchors, 0, 1)
            #output (batch size, anchor*(4+1+num_classes), h, w) ; h, w: grid size
            for i in range(output.size(0)): # size(0): batch size
                boxes = all_boxes[i]
                boxes = nms(boxes, nms_thresh)
                if dataset_use == 'ucf101-24':
                    detection_path = os.path.join('ucf_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join('ucf_detections', 'detections_'+str(epoch))
                    if not os.path.exists('ucf_detections'):
                        os.mkdir('ucf_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                elif dataset_use == 'jaad': 
                    detection_path = os.path.join('jaad_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join('jaad_detections', 'detections_'+str(epoch))
                    if not os.path.exists('jaad_detections'):
                        os.mkdir('jaad_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                else:
                    detection_path = os.path.join(dataset_use+'_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join(dataset_use+'_detections', 'detections_'+str(epoch))
                    if not os.path.exists(dataset_use+'_detections'):
                        os.mkdir(dataset_use+'_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                # print all the boxes
                # boxes = n_boxes * [x_center, y_center, w, h, confidence score, prob of the activity, int of class predicted]
                # with open(detection_path, 'w+') as f_detect:
                #     for box in boxes:
                #         x1 = round(float(box[0]-box[2]/2.0) * 320.0)
                #         y1 = round(float(box[1]-box[3]/2.0) * 240.0)
                #         x2 = round(float(box[0]+box[2]/2.0) * 320.0)
                #         y2 = round(float(box[1]+box[3]/2.0) * 240.0)

                #         det_conf = float(box[4])  # detected confidence > 0.25 is detected
                #         for j in range((len(box)-5)//2):
                #             cls_conf = float(box[5+2*j].item()) # class confidence

                #             if type(box[6+2*j]) == torch.Tensor:
                #                 cls_id = int(box[6+2*j].item())
                #             else:
                #                 cls_id = int(box[6+2*j])
                #             prob = det_conf * cls_conf  # means = detected confidence * class confidence

                #             # f_detect.write(str(int(box[6])+1) + ' ' + str(prob) + ' ' + str(x1) + ' ' + str(y1) + ' ' + str(x2) + ' ' + str(y2) + '\n')
                #             f_detect.write(str(int(box[6])+1) + ' ' + str(det_conf) + ' ' + str(cls_conf) + ' ' + str(x1) + ' ' + str(y1) + ' ' + str(x2) + ' ' + str(y2) + '\n')
                
                truths = target[i].view(-1, 5)
                num_gts = truths_length(truths)
        
                total = total + num_gts  # total ground truths
    
                for i in range(len(boxes)): # for all proposal boxes in that frame
                    if boxes[i][4] > 0.25:
                        proposals = proposals+1

                for i in range(num_gts):
                    box_gt = [truths[i][1], truths[i][2], truths[i][3], truths[i][4], 1.0, 1.0, truths[i][0]]
                    best_iou = 0
                    best_j = -1
                    for j in range(len(boxes)): # find the best box (highest iou)
                        iou = bbox_iou(box_gt, boxes[j], x1y1x2y2=False)
                        if iou > best_iou:
                            best_j = j
                            best_iou = iou

                    if best_iou > iou_thresh:
                        total_detected += 1
                        if int(boxes[best_j][6]) == box_gt[6]: # correctly classified
                            correct_classification += 1

                    if best_iou > iou_thresh and int(boxes[best_j][6]) == box_gt[6]: # correct localization AND classification
                        correct = correct+1

            precision = 1.0*correct/(proposals+eps) # how accurate is the prediction
            recall = 1.0*correct/(total+eps)  # correctly localized AND classify
            fscore = 2.0*precision*recall/(precision+recall+eps)
            logging("[%d/%d] precision: %f, recall: %f, fscore: %f" % (batch_idx, nbatch, precision, recall, fscore))

    classification_accuracy = 1.0 * correct_classification / (total_detected + eps)  # accuracy of the classification if detected
    localization_recall = 1.0 * total_detected / (total + eps) # correct localization

    print("Classification accuracy: %.3f" % classification_accuracy)
    print("Localization recall: %.3f" % localization_recall)

    return classification_accuracy, localization_recall, precision, recall, fscore

# %% [markdown]
# # Main: Test model

# %%
backupdir
# Out:
# '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup'

# %%
epoch = checkpoint['epoch']

# %%
# epoch = 10
epoch
# Out:
# 4

# %%
namedataset = 'jaad'
evaluate = True
# if opt.evaluate:
if evaluate == True:
    logging('evaluating ...')
    # classification_accuracy, localization_recall, precision, recall, fscore = test(0) # 0 means evaluation, >0 means test at that epoch
# Validate the model
    classification_accuracy, localization_recall, precision, recall, fscore = test(epoch)

    # Save the model to backup directory
    # state = {
    #     'epoch': epoch,
    #     'state_dict': model.state_dict(),
    #     'optimizer': optimizer.state_dict(),
    #     'fscore': fscore
    #     }
    # is_best = False
    # save_checkpoint(state, is_best, backupdir, namedataset+'_vali_tune_5_e'+str(epoch), clip_duration)
    # save_checkpoint(state, is_best, backupdir, namedataset, clip_duration)
    
    # logging('Weights are saved to backup directory: %s' % (backupdir))
    
    # Save the evaluation result
    eval_result = {'class_acc': classification_accuracy,
                  'loc_recall': localization_recall, 
                  'precision': precision, 
                  'recall': recall, 
                  'fscore': fscore} 
    fileout = 'jaad_eval_result_tune_5_e' + str(epoch)
    import json
    with open(f'./jaad_detections/{fileout}.json', 'w') as fp:
        json.dump(eval_result, fp)
# Out:
# 2021-01-23 03:56:41 evaluating ...
# 2021-01-23 03:56:41 validation at epoch 4
# /content/drive/.shortcut-targets-by-id/13ujwaotnxl8JQ_LapEAWcXISoadgLan6/NLP_and_CV_Projects/CV/Model/YOWO/utils.py:280: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   cls_confs = torch.nn.Softmax()(Variable(output[5:5+num_classes].transpose(0,1))).data #softmax_class
# 2021-01-23 03:56:52 [0/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-23 03:56:54 [1/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-23 03:56:58 [2/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-23 03:57:01 [3/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-23 03:57:04 [4/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-23 03:57:07 [5/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-23 03:57:11 [6/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-23 03:57:14 [7/2126] precision: 0.011765, recall: 0.010417, fscore: 0.011045
# 2021-01-23 03:57:18 [8/2126] precision: 0.050459, recall: 0.050691, fscore: 0.050570
# 2021-01-23 03:57:22 [9/2126] precision: 0.099265, recall: 0.108434, fscore: 0.103642
# 2021-01-23 03:57:26 [10/2126] precision: 0.164634, recall: 0.187500, fscore: 0.175320
# 2021-01-23 03:57:29 [11/2126] precision: 0.222798, recall: 0.262195, fscore: 0.240891
# 2021-01-23 03:57:33 [12/2126] precision: 0.259594, recall: 0.312500, fscore: 0.283596
# 2021-01-23 03:57:37 [13/2126] precision: 0.288845, recall: 0.355392, fscore: 0.318676
# 2021-01-23 03:57:42 [14/2126] precision: 0.318345, recall: 0.395089, fscore: 0.352585
# 2021-01-23 03:57:47 [15/2126] precision: 0.339374, recall: 0.422131, fscore: 0.376251
# 2021-01-23 03:57:51 [16/2126] precision: 0.357466, recall: 0.448864, fscore: 0.397980
# 2021-01-23 03:57:55 [17/2126] precision: 0.376224, recall: 0.473592, fscore: 0.419325
# 2021-01-23 03:58:00 [18/2126] precision: 0.389542, recall: 0.490132, fscore: 0.434081
# 2021-01-23 03:58:04 [19/2126] precision: 0.405904, recall: 0.509259, fscore: 0.451740
# 2021-01-23 03:58:07 [20/2126] precision: 0.416957, recall: 0.521802, fscore: 0.463520
# 2021-01-23 03:58:11 [21/2126] precision: 0.426374, recall: 0.531507, fscore: 0.473166
# 2021-01-23 03:58:15 [22/2126] precision: 0.443170, recall: 0.546272, fscore: 0.489345
# 2021-01-23 03:58:19 [23/2126] precision: 0.453740, recall: 0.558111, fscore: 0.500538
# 2021-01-23 03:58:23 [24/2126] precision: 0.467351, recall: 0.573227, fscore: 0.514897
# 2021-01-23 03:58:26 [25/2126] precision: 0.476652, recall: 0.586768, fscore: 0.526004
# 2021-01-23 03:58:30 [26/2126] precision: 0.480801, recall: 0.593814, fscore: 0.531360
# 2021-01-23 03:58:33 [27/2126] precision: 0.490446, recall: 0.605108, fscore: 0.541772
# 2021-01-23 03:58:36 [28/2126] precision: 0.493171, recall: 0.609756, fscore: 0.545297
# 2021-01-23 03:58:40 [29/2126] precision: 0.496366, recall: 0.613106, fscore: 0.548589
# 2021-01-23 03:58:43 [30/2126] precision: 0.489525, recall: 0.604832, fscore: 0.541099
# 2021-01-23 03:58:47 [31/2126] precision: 0.481208, recall: 0.597998, fscore: 0.533279
# 2021-01-23 03:58:51 [32/2126] precision: 0.467181, recall: 0.583601, fscore: 0.518937
# 2021-01-23 03:58:55 [33/2126] precision: 0.453646, recall: 0.569434, fscore: 0.504983
# 2021-01-23 03:58:58 [34/2126] precision: 0.442193, recall: 0.558315, fscore: 0.493510
# 2021-01-23 03:59:02 [35/2126] precision: 0.432277, recall: 0.547845, fscore: 0.483242
# 2021-01-23 03:59:06 [36/2126] precision: 0.422991, recall: 0.537970, fscore: 0.473597
# 2021-01-23 03:59:10 [37/2126] precision: 0.413830, recall: 0.526099, fscore: 0.463255
# 2021-01-23 03:59:14 [38/2126] precision: 0.404600, recall: 0.514628, fscore: 0.453024
# 2021-01-23 03:59:18 [39/2126] precision: 0.395549, recall: 0.503866, fscore: 0.443180
# 2021-01-23 03:59:22 [40/2126] precision: 0.387825, recall: 0.493750, fscore: 0.434419
# 2021-01-23 03:59:26 [41/2126] precision: 0.380725, recall: 0.484223, fscore: 0.426277
# 2021-01-23 03:59:29 [42/2126] precision: 0.373148, recall: 0.476078, fscore: 0.418370
# 2021-01-23 03:59:33 [43/2126] precision: 0.367329, recall: 0.469706, fscore: 0.412251
# 2021-01-23 03:59:37 [44/2126] precision: 0.361148, recall: 0.462932, fscore: 0.405749
# 2021-01-23 03:59:41 [45/2126] precision: 0.354518, recall: 0.455809, fscore: 0.398828
# 2021-01-23 03:59:45 [46/2126] precision: 0.349382, recall: 0.447843, fscore: 0.392527
# 2021-01-23 03:59:48 [47/2126] precision: 0.344249, recall: 0.440150, fscore: 0.386332
# 2021-01-23 03:59:52 [48/2126] precision: 0.342523, recall: 0.432718, fscore: 0.382369
# 2021-01-23 03:59:56 [49/2126] precision: 0.336066, recall: 0.425532, fscore: 0.375539
# 2021-01-23 04:00:00 [50/2126] precision: 0.329582, recall: 0.418581, fscore: 0.368783
# 2021-01-23 04:00:04 [51/2126] precision: 0.323344, recall: 0.411853, fscore: 0.362266
# 2021-01-23 04:00:08 [52/2126] precision: 0.318498, recall: 0.406019, fscore: 0.356968
# 2021-01-23 04:00:13 [53/2126] precision: 0.318769, recall: 0.404532, fscore: 0.356561
# 2021-01-23 04:00:17 [54/2126] precision: 0.322388, recall: 0.407163, fscore: 0.359845
# 2021-01-23 04:00:22 [55/2126] precision: 0.328446, recall: 0.412903, fscore: 0.365859
# 2021-01-23 04:00:27 [56/2126] precision: 0.334294, recall: 0.418395, fscore: 0.371641
# 2021-01-23 04:00:32 [57/2126] precision: 0.342776, recall: 0.428129, fscore: 0.380723
# 2021-01-23 04:00:38 [58/2126] precision: 0.350975, recall: 0.438070, fscore: 0.389711
# 2021-01-23 04:00:43 [59/2126] precision: 0.358904, recall: 0.447672, fscore: 0.398398
# 2021-01-23 04:00:47 [60/2126] precision: 0.366577, recall: 0.456951, fscore: 0.406800
# 2021-01-23 04:00:52 [61/2126] precision: 0.374005, recall: 0.465923, fscore: 0.414930
# 2021-01-23 04:00:56 [62/2126] precision: 0.381201, recall: 0.474604, fscore: 0.422800
# 2021-01-23 04:01:01 [63/2126] precision: 0.388175, recall: 0.483007, fscore: 0.430424
# 2021-01-23 04:01:06 [64/2126] precision: 0.394937, recall: 0.491145, fscore: 0.437813
# 2021-01-23 04:01:11 [65/2126] precision: 0.401496, recall: 0.499031, fscore: 0.444977
# 2021-01-23 04:01:16 [66/2126] precision: 0.407862, recall: 0.506677, fscore: 0.451926
# 2021-01-23 04:01:21 [67/2126] precision: 0.413438, recall: 0.513341, fscore: 0.458000
# 2021-01-23 04:01:24 [68/2126] precision: 0.413484, recall: 0.513143, fscore: 0.457950
# 2021-01-23 04:01:28 [69/2126] precision: 0.407647, recall: 0.509184, fscore: 0.452788
# 2021-01-23 04:01:32 [70/2126] precision: 0.401972, recall: 0.506209, fscore: 0.448104
# 2021-01-23 04:01:36 [71/2126] precision: 0.396453, recall: 0.503268, fscore: 0.443515
# 2021-01-23 04:01:40 [72/2126] precision: 0.391084, recall: 0.500361, fscore: 0.439019
# 2021-01-23 04:01:44 [73/2126] precision: 0.385857, recall: 0.497487, fscore: 0.434614
# 2021-01-23 04:01:49 [74/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:01:52 [75/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:01:55 [76/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:01:58 [77/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:00 [78/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:03 [79/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:06 [80/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:09 [81/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:12 [82/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:15 [83/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:18 [84/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:22 [85/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:25 [86/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:29 [87/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:32 [88/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:35 [89/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:38 [90/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:42 [91/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:45 [92/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:48 [93/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:50 [94/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:53 [95/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:56 [96/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:02:59 [97/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:02 [98/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:05 [99/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:08 [100/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:11 [101/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:14 [102/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:17 [103/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:20 [104/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:23 [105/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:26 [106/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:29 [107/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:31 [108/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:34 [109/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:37 [110/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:40 [111/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:43 [112/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:48 [113/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:52 [114/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:03:56 [115/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:00 [116/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:03 [117/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:07 [118/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:10 [119/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:15 [120/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:20 [121/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:27 [122/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:34 [123/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:40 [124/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:44 [125/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:47 [126/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:50 [127/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:52 [128/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:55 [129/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:04:58 [130/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:05:01 [131/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:05:04 [132/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:05:07 [133/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:05:10 [134/2126] precision: 0.380769, recall: 0.494647, fscore: 0.430296
# 2021-01-23 04:05:13 [135/2126] precision: 0.380769, recall: 0.491838, fscore: 0.429230
# 2021-01-23 04:05:16 [136/2126] precision: 0.380769, recall: 0.489061, fscore: 0.428169
# 2021-01-23 04:05:20 [137/2126] precision: 0.380769, recall: 0.486316, fscore: 0.427114
# 2021-01-23 04:05:24 [138/2126] precision: 0.380769, recall: 0.483601, fscore: 0.426063
# 2021-01-23 04:05:28 [139/2126] precision: 0.380769, recall: 0.480916, fscore: 0.425018
# 2021-01-23 04:05:31 [140/2126] precision: 0.381319, recall: 0.478951, fscore: 0.424590
# 2021-01-23 04:05:35 [141/2126] precision: 0.382418, recall: 0.477694, fscore: 0.424774
# 2021-01-23 04:05:38 [142/2126] precision: 0.382418, recall: 0.475085, fscore: 0.423739
# 2021-01-23 04:05:42 [143/2126] precision: 0.382692, recall: 0.472845, fscore: 0.423014
# 2021-01-23 04:05:46 [144/2126] precision: 0.384890, recall: 0.472991, fscore: 0.424412
# 2021-01-23 04:05:50 [145/2126] precision: 0.387088, recall: 0.473136, fscore: 0.425803
# 2021-01-23 04:05:54 [146/2126] precision: 0.389286, recall: 0.473280, fscore: 0.427188
# 2021-01-23 04:05:59 [147/2126] precision: 0.389560, recall: 0.471096, fscore: 0.426461
# 2021-01-23 04:06:03 [148/2126] precision: 0.390934, recall: 0.470258, fscore: 0.426938
# 2021-01-23 04:06:08 [149/2126] precision: 0.393132, recall: 0.470414, fscore: 0.428310
# 2021-01-23 04:06:12 [150/2126] precision: 0.395330, recall: 0.470569, fscore: 0.429676
# 2021-01-23 04:06:17 [151/2126] precision: 0.396703, recall: 0.469746, fscore: 0.430141
# 2021-01-23 04:06:22 [152/2126] precision: 0.398901, recall: 0.469903, fscore: 0.431496
# 2021-01-23 04:06:26 [153/2126] precision: 0.401099, recall: 0.470058, fscore: 0.432844
# 2021-01-23 04:06:30 [154/2126] precision: 0.402473, recall: 0.469250, fscore: 0.433299
# 2021-01-23 04:06:34 [155/2126] precision: 0.405769, recall: 0.470682, fscore: 0.435817
# 2021-01-23 04:06:38 [156/2126] precision: 0.410165, recall: 0.473367, fscore: 0.439500
# 2021-01-23 04:06:42 [157/2126] precision: 0.413736, recall: 0.475079, fscore: 0.442286
# 2021-01-23 04:06:45 [158/2126] precision: 0.417582, recall: 0.477087, fscore: 0.445351
# 2021-01-23 04:06:49 [159/2126] precision: 0.421978, recall: 0.479700, fscore: 0.448987
# 2021-01-23 04:06:53 [160/2126] precision: 0.424725, recall: 0.480423, fscore: 0.450855
# 2021-01-23 04:06:57 [161/2126] precision: 0.426923, recall: 0.480519, fscore: 0.452134
# 2021-01-23 04:07:01 [162/2126] precision: 0.429121, recall: 0.480615, fscore: 0.453406
# 2021-01-23 04:07:05 [163/2126] precision: 0.431319, recall: 0.480710, fscore: 0.454672
# 2021-01-23 04:07:09 [164/2126] precision: 0.433516, recall: 0.480804, fscore: 0.455933
# 2021-01-23 04:07:13 [165/2126] precision: 0.434164, recall: 0.480898, fscore: 0.456332
# 2021-01-23 04:07:17 [166/2126] precision: 0.432917, recall: 0.480990, fscore: 0.455684
# 2021-01-23 04:07:20 [167/2126] precision: 0.431341, recall: 0.481081, fscore: 0.454850
# 2021-01-23 04:07:24 [168/2126] precision: 0.431404, recall: 0.482180, fscore: 0.455376
# 2021-01-23 04:07:28 [169/2126] precision: 0.433432, recall: 0.483418, fscore: 0.457057
# 2021-01-23 04:07:32 [170/2126] precision: 0.433699, recall: 0.483428, fscore: 0.457210
# 2021-01-23 04:07:35 [171/2126] precision: 0.433699, recall: 0.483428, fscore: 0.457210
# 2021-01-23 04:07:38 [172/2126] precision: 0.433699, recall: 0.483428, fscore: 0.457210
# 2021-01-23 04:07:41 [173/2126] precision: 0.433699, recall: 0.483428, fscore: 0.457210
# 2021-01-23 04:07:44 [174/2126] precision: 0.433699, recall: 0.483428, fscore: 0.457210
# 2021-01-23 04:07:48 [175/2126] precision: 0.433967, recall: 0.483294, fscore: 0.457299
# 2021-01-23 04:07:51 [176/2126] precision: 0.433271, recall: 0.482143, fscore: 0.456397
# 2021-01-23 04:07:54 [177/2126] precision: 0.433271, recall: 0.480998, fscore: 0.455884
# 2021-01-23 04:07:58 [178/2126] precision: 0.433271, recall: 0.479858, fscore: 0.455371
# 2021-01-23 04:08:01 [179/2126] precision: 0.433271, recall: 0.478723, fscore: 0.454860
# 2021-01-23 04:08:04 [180/2126] precision: 0.433271, recall: 0.477594, fscore: 0.454349
# 2021-01-23 04:08:07 [181/2126] precision: 0.433155, recall: 0.476471, fscore: 0.453777
# 2021-01-23 04:08:10 [182/2126] precision: 0.431310, recall: 0.475352, fscore: 0.452256
# 2021-01-23 04:08:14 [183/2126] precision: 0.427103, recall: 0.474239, fscore: 0.449433
# 2021-01-23 04:08:17 [184/2126] precision: 0.423640, recall: 0.473131, fscore: 0.447015
# 2021-01-23 04:08:21 [185/2126] precision: 0.423529, recall: 0.472028, fscore: 0.446460
# 2021-01-23 04:08:25 [186/2126] precision: 0.423419, recall: 0.470930, fscore: 0.445907
# 2021-01-23 04:08:29 [187/2126] precision: 0.423197, recall: 0.469838, fscore: 0.445295
# 2021-01-23 04:08:32 [188/2126] precision: 0.423197, recall: 0.468750, fscore: 0.444806
# 2021-01-23 04:08:37 [189/2126] precision: 0.423459, recall: 0.467956, fscore: 0.444592
# 2021-01-23 04:08:41 [190/2126] precision: 0.425549, recall: 0.469182, fscore: 0.446296
# 2021-01-23 04:08:46 [191/2126] precision: 0.427638, recall: 0.470402, fscore: 0.447997
# 2021-01-23 04:08:51 [192/2126] precision: 0.429728, recall: 0.471617, fscore: 0.449694
# 2021-01-23 04:08:55 [193/2126] precision: 0.431818, recall: 0.472826, fscore: 0.451388
# 2021-01-23 04:08:59 [194/2126] precision: 0.432439, recall: 0.474030, fscore: 0.452275
# 2021-01-23 04:09:02 [195/2126] precision: 0.429270, recall: 0.475228, fscore: 0.451076
# 2021-01-23 04:09:05 [196/2126] precision: 0.426067, recall: 0.476420, fscore: 0.449834
# 2021-01-23 04:09:09 [197/2126] precision: 0.424220, recall: 0.477608, fscore: 0.449328
# 2021-01-23 04:09:13 [198/2126] precision: 0.423058, recall: 0.477376, fscore: 0.448573
# 2021-01-23 04:09:17 [199/2126] precision: 0.422952, recall: 0.476298, fscore: 0.448037
# 2021-01-23 04:09:21 [200/2126] precision: 0.422952, recall: 0.475225, fscore: 0.447562
# 2021-01-23 04:09:23 [201/2126] precision: 0.422952, recall: 0.474157, fscore: 0.447088
# 2021-01-23 04:09:26 [202/2126] precision: 0.422952, recall: 0.473094, fscore: 0.446615
# 2021-01-23 04:09:29 [203/2126] precision: 0.422952, recall: 0.472036, fscore: 0.446143
# 2021-01-23 04:09:31 [204/2126] precision: 0.422952, recall: 0.470982, fscore: 0.445672
# 2021-01-23 04:09:33 [205/2126] precision: 0.422952, recall: 0.470982, fscore: 0.445672
# 2021-01-23 04:09:39 [206/2126] precision: 0.422952, recall: 0.470195, fscore: 0.445319
# 2021-01-23 04:09:45 [207/2126] precision: 0.422952, recall: 0.469150, fscore: 0.444849
# 2021-01-23 04:09:52 [208/2126] precision: 0.422952, recall: 0.467331, fscore: 0.444030
# 2021-01-23 04:10:00 [209/2126] precision: 0.423202, recall: 0.465546, fscore: 0.443360
# 2021-01-23 04:10:06 [210/2126] precision: 0.423202, recall: 0.463502, fscore: 0.442431
# 2021-01-23 04:10:12 [211/2126] precision: 0.423202, recall: 0.461475, fscore: 0.441506
# 2021-01-23 04:10:19 [212/2126] precision: 0.423202, recall: 0.459467, fscore: 0.440585
# 2021-01-23 04:10:29 [213/2126] precision: 0.424956, recall: 0.459372, fscore: 0.441489
# 2021-01-23 04:10:39 [214/2126] precision: 0.426710, recall: 0.459277, fscore: 0.442390
# 2021-01-23 04:10:48 [215/2126] precision: 0.424137, recall: 0.458647, fscore: 0.440712
# 2021-01-23 04:10:56 [216/2126] precision: 0.419553, recall: 0.456684, fscore: 0.437327
# 2021-01-23 04:11:03 [217/2126] precision: 0.417582, recall: 0.455272, fscore: 0.435608
# 2021-01-23 04:11:11 [218/2126] precision: 0.418071, recall: 0.453871, fscore: 0.435231
# 2021-01-23 04:11:18 [219/2126] precision: 0.418803, recall: 0.452746, fscore: 0.435109
# 2021-01-23 04:11:25 [220/2126] precision: 0.421001, recall: 0.453207, fscore: 0.436506
# 2021-01-23 04:11:32 [221/2126] precision: 0.423687, recall: 0.454188, fscore: 0.438403
# 2021-01-23 04:11:39 [222/2126] precision: 0.426862, recall: 0.455683, fscore: 0.440797
# 2021-01-23 04:11:45 [223/2126] precision: 0.428083, recall: 0.455088, fscore: 0.441168
# 2021-01-23 04:11:52 [224/2126] precision: 0.431258, recall: 0.456567, fscore: 0.443546
# 2021-01-23 04:11:58 [225/2126] precision: 0.431258, recall: 0.456567, fscore: 0.443546
# 2021-01-23 04:12:01 [226/2126] precision: 0.431258, recall: 0.455860, fscore: 0.443212
# 2021-01-23 04:12:05 [227/2126] precision: 0.431258, recall: 0.455624, fscore: 0.443101
# 2021-01-23 04:12:09 [228/2126] precision: 0.431258, recall: 0.454920, fscore: 0.442768
# 2021-01-23 04:12:12 [229/2126] precision: 0.431258, recall: 0.453985, fscore: 0.442324
# 2021-01-23 04:12:17 [230/2126] precision: 0.431258, recall: 0.453053, fscore: 0.441882
# 2021-01-23 04:12:23 [231/2126] precision: 0.431258, recall: 0.452125, fscore: 0.441440
# 2021-01-23 04:12:26 [232/2126] precision: 0.431502, recall: 0.451456, fscore: 0.441249
# 2021-01-23 04:12:29 [233/2126] precision: 0.432967, recall: 0.452065, fscore: 0.442305
# 2021-01-23 04:12:31 [234/2126] precision: 0.433211, recall: 0.451399, fscore: 0.442113
# 2021-01-23 04:12:33 [235/2126] precision: 0.433211, recall: 0.450482, fscore: 0.441673
# 2021-01-23 04:12:36 [236/2126] precision: 0.433211, recall: 0.449569, fscore: 0.441234
# 2021-01-23 04:12:38 [237/2126] precision: 0.434676, recall: 0.450177, fscore: 0.442286
# 2021-01-23 04:12:41 [238/2126] precision: 0.435897, recall: 0.450530, fscore: 0.443088
# 2021-01-23 04:12:45 [239/2126] precision: 0.437851, recall: 0.451637, fscore: 0.444632
# 2021-01-23 04:12:48 [240/2126] precision: 0.438095, recall: 0.450075, fscore: 0.443999
# 2021-01-23 04:12:52 [241/2126] precision: 0.438095, recall: 0.448276, fscore: 0.443122
# 2021-01-23 04:12:57 [242/2126] precision: 0.438095, recall: 0.446491, fscore: 0.442248
# 2021-01-23 04:13:00 [243/2126] precision: 0.438095, recall: 0.444720, fscore: 0.441378
# 2021-01-23 04:13:04 [244/2126] precision: 0.438095, recall: 0.442963, fscore: 0.440511
# 2021-01-23 04:13:08 [245/2126] precision: 0.438095, recall: 0.441220, fscore: 0.439647
# 2021-01-23 04:13:12 [246/2126] precision: 0.438095, recall: 0.439490, fscore: 0.438787
# 2021-01-23 04:13:15 [247/2126] precision: 0.438095, recall: 0.437775, fscore: 0.437930
# 2021-01-23 04:13:20 [248/2126] precision: 0.438095, recall: 0.436072, fscore: 0.437076
# 2021-01-23 04:13:24 [249/2126] precision: 0.438095, recall: 0.434383, fscore: 0.436226
# 2021-01-23 04:13:29 [250/2126] precision: 0.438339, recall: 0.432947, fscore: 0.435622
# 2021-01-23 04:13:33 [251/2126] precision: 0.438339, recall: 0.431283, fscore: 0.434778
# 2021-01-23 04:13:37 [252/2126] precision: 0.438339, recall: 0.429631, fscore: 0.433937
# 2021-01-23 04:13:41 [253/2126] precision: 0.438339, recall: 0.427992, fscore: 0.433099
# 2021-01-23 04:13:46 [254/2126] precision: 0.439316, recall: 0.427316, fscore: 0.433228
# 2021-01-23 04:13:51 [255/2126] precision: 0.440049, recall: 0.426408, fscore: 0.433116
# 2021-01-23 04:13:56 [256/2126] precision: 0.440049, recall: 0.424800, fscore: 0.432285
# 2021-01-23 04:14:03 [257/2126] precision: 0.440781, recall: 0.423908, fscore: 0.432175
# 2021-01-23 04:14:08 [258/2126] precision: 0.442735, recall: 0.424193, fscore: 0.433261
# 2021-01-23 04:14:13 [259/2126] precision: 0.444200, recall: 0.424009, fscore: 0.433865
# 2021-01-23 04:14:18 [260/2126] precision: 0.444933, recall: 0.423131, fscore: 0.433753
# 2021-01-23 04:14:22 [261/2126] precision: 0.446886, recall: 0.423415, fscore: 0.434829
# 2021-01-23 04:14:27 [262/2126] precision: 0.448352, recall: 0.423237, fscore: 0.435427
# 2021-01-23 04:14:32 [263/2126] precision: 0.450305, recall: 0.423519, fscore: 0.436496
# 2021-01-23 04:14:37 [264/2126] precision: 0.450549, recall: 0.422197, fscore: 0.435908
# 2021-01-23 04:14:41 [265/2126] precision: 0.450549, recall: 0.420657, fscore: 0.435085
# 2021-01-23 04:14:45 [266/2126] precision: 0.450549, recall: 0.419604, fscore: 0.434522
# 2021-01-23 04:14:50 [267/2126] precision: 0.450549, recall: 0.418842, fscore: 0.434113
# 2021-01-23 04:14:54 [268/2126] precision: 0.450549, recall: 0.418083, fscore: 0.433704
# 2021-01-23 04:14:58 [269/2126] precision: 0.450549, recall: 0.417326, fscore: 0.433297
# 2021-01-23 04:15:01 [270/2126] precision: 0.450549, recall: 0.416573, fscore: 0.432890
# 2021-01-23 04:15:05 [271/2126] precision: 0.450549, recall: 0.415822, fscore: 0.432484
# 2021-01-23 04:15:08 [272/2126] precision: 0.450549, recall: 0.415073, fscore: 0.432079
# 2021-01-23 04:15:12 [273/2126] precision: 0.450549, recall: 0.414327, fscore: 0.431675
# 2021-01-23 04:15:15 [274/2126] precision: 0.450549, recall: 0.413584, fscore: 0.431271
# 2021-01-23 04:15:18 [275/2126] precision: 0.450549, recall: 0.413399, fscore: 0.431171
# 2021-01-23 04:15:21 [276/2126] precision: 0.450549, recall: 0.413399, fscore: 0.431171
# 2021-01-23 04:15:25 [277/2126] precision: 0.450549, recall: 0.413399, fscore: 0.431171
# 2021-01-23 04:15:28 [278/2126] precision: 0.450549, recall: 0.413399, fscore: 0.431171
# 2021-01-23 04:15:31 [279/2126] precision: 0.450549, recall: 0.413399, fscore: 0.431171
# 2021-01-23 04:15:34 [280/2126] precision: 0.450549, recall: 0.413399, fscore: 0.431171
# 2021-01-23 04:15:38 [281/2126] precision: 0.450549, recall: 0.412844, fscore: 0.430868
# 2021-01-23 04:15:41 [282/2126] precision: 0.450794, recall: 0.412330, fscore: 0.430700
# 2021-01-23 04:15:45 [283/2126] precision: 0.450794, recall: 0.411594, fscore: 0.430298
# 2021-01-23 04:15:48 [284/2126] precision: 0.450794, recall: 0.410770, fscore: 0.429847
# 2021-01-23 04:15:51 [285/2126] precision: 0.450794, recall: 0.409585, fscore: 0.429198
# 2021-01-23 04:15:53 [286/2126] precision: 0.450794, recall: 0.408136, fscore: 0.428401
# 2021-01-23 04:15:56 [287/2126] precision: 0.450794, recall: 0.406698, fscore: 0.427607
# 2021-01-23 04:15:59 [288/2126] precision: 0.450794, recall: 0.405269, fscore: 0.426816
# 2021-01-23 04:16:02 [289/2126] precision: 0.450354, recall: 0.403850, fscore: 0.425831
# 2021-01-23 04:16:05 [290/2126] precision: 0.449805, recall: 0.402442, fscore: 0.424802
# 2021-01-23 04:16:09 [291/2126] precision: 0.451023, recall: 0.402129, fscore: 0.425170
# 2021-01-23 04:16:12 [292/2126] precision: 0.451754, recall: 0.401386, fscore: 0.425078
# 2021-01-23 04:16:15 [293/2126] precision: 0.452242, recall: 0.400431, fscore: 0.424758
# 2021-01-23 04:16:19 [294/2126] precision: 0.452242, recall: 0.399054, fscore: 0.423981
# 2021-01-23 04:16:22 [295/2126] precision: 0.452242, recall: 0.397686, fscore: 0.423208
# 2021-01-23 04:16:25 [296/2126] precision: 0.452242, recall: 0.396327, fscore: 0.422437
# 2021-01-23 04:16:29 [297/2126] precision: 0.451935, recall: 0.395190, fscore: 0.421657
# 2021-01-23 04:16:32 [298/2126] precision: 0.451935, recall: 0.393849, fscore: 0.420893
# 2021-01-23 04:16:36 [299/2126] precision: 0.451935, recall: 0.392850, fscore: 0.420321
# 2021-01-23 04:16:40 [300/2126] precision: 0.451629, recall: 0.391735, fscore: 0.419550
# 2021-01-23 04:16:43 [301/2126] precision: 0.451629, recall: 0.390418, fscore: 0.418794
# 2021-01-23 04:16:46 [302/2126] precision: 0.451629, recall: 0.389110, fscore: 0.418040
# 2021-01-23 04:16:50 [303/2126] precision: 0.451629, recall: 0.387972, fscore: 0.417382
# 2021-01-23 04:16:54 [304/2126] precision: 0.451629, recall: 0.387325, fscore: 0.417008
# 2021-01-23 04:16:57 [305/2126] precision: 0.451629, recall: 0.386681, fscore: 0.416634
# 2021-01-23 04:17:00 [306/2126] precision: 0.451629, recall: 0.386038, fscore: 0.416260
# 2021-01-23 04:17:02 [307/2126] precision: 0.451629, recall: 0.385397, fscore: 0.415888
# 2021-01-23 04:17:04 [308/2126] precision: 0.451629, recall: 0.384759, fscore: 0.415516
# 2021-01-23 04:17:08 [309/2126] precision: 0.451629, recall: 0.384122, fscore: 0.415144
# 2021-01-23 04:17:11 [310/2126] precision: 0.451629, recall: 0.383488, fscore: 0.414773
# 2021-01-23 04:17:15 [311/2126] precision: 0.451629, recall: 0.382856, fscore: 0.414403
# 2021-01-23 04:17:19 [312/2126] precision: 0.451629, recall: 0.382226, fscore: 0.414034
# 2021-01-23 04:17:23 [313/2126] precision: 0.451629, recall: 0.381598, fscore: 0.413665
# 2021-01-23 04:17:27 [314/2126] precision: 0.451629, recall: 0.380972, fscore: 0.413297
# 2021-01-23 04:17:31 [315/2126] precision: 0.452381, recall: 0.381167, fscore: 0.413727
# 2021-01-23 04:17:35 [316/2126] precision: 0.451146, recall: 0.382179, fscore: 0.413803
# 2021-01-23 04:17:40 [317/2126] precision: 0.450036, recall: 0.383187, fscore: 0.413925
# 2021-01-23 04:17:44 [318/2126] precision: 0.447343, recall: 0.384192, fscore: 0.413365
# 2021-01-23 04:17:48 [319/2126] precision: 0.446698, recall: 0.385194, fscore: 0.413668
# 2021-01-23 04:17:51 [320/2126] precision: 0.447109, recall: 0.386193, fscore: 0.414419
# 2021-01-23 04:17:55 [321/2126] precision: 0.444807, recall: 0.387188, fscore: 0.413997
# 2021-01-23 04:17:59 [322/2126] precision: 0.441732, recall: 0.388181, fscore: 0.413224
# 2021-01-23 04:18:03 [323/2126] precision: 0.438824, recall: 0.389170, fscore: 0.412503
# 2021-01-23 04:18:06 [324/2126] precision: 0.436766, recall: 0.390155, fscore: 0.412142
# 2021-01-23 04:18:11 [325/2126] precision: 0.436699, recall: 0.391138, fscore: 0.412660
# 2021-01-23 04:18:15 [326/2126] precision: 0.435484, recall: 0.390990, fscore: 0.412034
# 2021-01-23 04:18:19 [327/2126] precision: 0.435289, recall: 0.390911, fscore: 0.411903
# 2021-01-23 04:18:23 [328/2126] precision: 0.435289, recall: 0.390283, fscore: 0.411554
# 2021-01-23 04:18:28 [329/2126] precision: 0.435289, recall: 0.389657, fscore: 0.411206
# 2021-01-23 04:18:32 [330/2126] precision: 0.435289, recall: 0.389033, fscore: 0.410858
# 2021-01-23 04:18:36 [331/2126] precision: 0.434997, recall: 0.388412, fscore: 0.410381
# 2021-01-23 04:18:41 [332/2126] precision: 0.434997, recall: 0.387792, fscore: 0.410035
# 2021-01-23 04:18:46 [333/2126] precision: 0.435347, recall: 0.387572, fscore: 0.410068
# 2021-01-23 04:18:52 [334/2126] precision: 0.436242, recall: 0.387751, fscore: 0.410565
# 2021-01-23 04:18:59 [335/2126] precision: 0.436997, recall: 0.388326, fscore: 0.411222
# 2021-01-23 04:19:05 [336/2126] precision: 0.437611, recall: 0.389296, fscore: 0.412037
# 2021-01-23 04:19:09 [337/2126] precision: 0.438222, recall: 0.390263, fscore: 0.412850
# 2021-01-23 04:19:14 [338/2126] precision: 0.434792, recall: 0.390634, fscore: 0.411527
# 2021-01-23 04:19:17 [339/2126] precision: 0.436072, recall: 0.391596, fscore: 0.412634
# 2021-01-23 04:19:21 [340/2126] precision: 0.436292, recall: 0.391176, fscore: 0.412499
# 2021-01-23 04:19:23 [341/2126] precision: 0.436292, recall: 0.390560, fscore: 0.412156
# 2021-01-23 04:19:26 [342/2126] precision: 0.436292, recall: 0.389947, fscore: 0.411815
# 2021-01-23 04:19:29 [343/2126] precision: 0.436292, recall: 0.389335, fscore: 0.411473
# 2021-01-23 04:19:32 [344/2126] precision: 0.436292, recall: 0.388726, fscore: 0.411133
# 2021-01-23 04:19:35 [345/2126] precision: 0.436292, recall: 0.388118, fscore: 0.410792
# 2021-01-23 04:19:38 [346/2126] precision: 0.437390, recall: 0.388488, fscore: 0.411486
# 2021-01-23 04:19:41 [347/2126] precision: 0.439148, recall: 0.389441, fscore: 0.412798
# 2021-01-23 04:19:45 [348/2126] precision: 0.440905, recall: 0.390391, fscore: 0.414108
# 2021-01-23 04:19:48 [349/2126] precision: 0.441687, recall: 0.390561, fscore: 0.414549
# 2021-01-23 04:19:51 [350/2126] precision: 0.439460, recall: 0.391313, fscore: 0.413986
# 2021-01-23 04:19:55 [351/2126] precision: 0.439194, recall: 0.392256, fscore: 0.414395
# 2021-01-23 04:19:57 [352/2126] precision: 0.437877, recall: 0.392422, fscore: 0.413901
# 2021-01-23 04:19:59 [353/2126] precision: 0.437877, recall: 0.391816, fscore: 0.413563
# 2021-01-23 04:20:00 [354/2126] precision: 0.437877, recall: 0.391212, fscore: 0.413227
# 2021-01-23 04:20:01 [355/2126] precision: 0.437877, recall: 0.390610, fscore: 0.412890
# 2021-01-23 04:20:02 [356/2126] precision: 0.437877, recall: 0.390010, fscore: 0.412555
# 2021-01-23 04:20:04 [357/2126] precision: 0.437877, recall: 0.389336, fscore: 0.412178
# 2021-01-23 04:20:05 [358/2126] precision: 0.437877, recall: 0.388220, fscore: 0.411551
# 2021-01-23 04:20:06 [359/2126] precision: 0.437877, recall: 0.387035, fscore: 0.410885
# 2021-01-23 04:20:07 [360/2126] precision: 0.437877, recall: 0.385858, fscore: 0.410220
# 2021-01-23 04:20:09 [361/2126] precision: 0.437877, recall: 0.384688, fscore: 0.409558
# 2021-01-23 04:20:10 [362/2126] precision: 0.437877, recall: 0.383525, fscore: 0.408898
# 2021-01-23 04:20:12 [363/2126] precision: 0.437877, recall: 0.382442, fscore: 0.408281
# 2021-01-23 04:20:13 [364/2126] precision: 0.437877, recall: 0.381651, fscore: 0.407830
# 2021-01-23 04:20:14 [365/2126] precision: 0.437877, recall: 0.380506, fscore: 0.407176
# 2021-01-23 04:20:16 [366/2126] precision: 0.437877, recall: 0.379368, fscore: 0.406524
# 2021-01-23 04:20:17 [367/2126] precision: 0.437877, recall: 0.378237, fscore: 0.405873
# 2021-01-23 04:20:18 [368/2126] precision: 0.437877, recall: 0.377113, fscore: 0.405225
# 2021-01-23 04:20:19 [369/2126] precision: 0.437877, recall: 0.375996, fscore: 0.404579
# 2021-01-23 04:20:21 [370/2126] precision: 0.437877, recall: 0.374885, fscore: 0.403935
# 2021-01-23 04:20:22 [371/2126] precision: 0.439172, recall: 0.374885, fscore: 0.404485
# 2021-01-23 04:20:24 [372/2126] precision: 0.440897, recall: 0.375252, fscore: 0.405430
# 2021-01-23 04:20:26 [373/2126] precision: 0.441760, recall: 0.374886, fscore: 0.405580
# 2021-01-23 04:20:28 [374/2126] precision: 0.441760, recall: 0.373791, fscore: 0.404938
# 2021-01-23 04:20:31 [375/2126] precision: 0.441760, recall: 0.372702, fscore: 0.404299
# 2021-01-23 04:20:34 [376/2126] precision: 0.441760, recall: 0.371620, fscore: 0.403661
# 2021-01-23 04:20:37 [377/2126] precision: 0.441760, recall: 0.370813, fscore: 0.403184
# 2021-01-23 04:20:42 [378/2126] precision: 0.441760, recall: 0.370411, fscore: 0.402946
# 2021-01-23 04:20:50 [379/2126] precision: 0.441760, recall: 0.369875, fscore: 0.402629
# 2021-01-23 04:20:55 [380/2126] precision: 0.441760, recall: 0.368876, fscore: 0.402037
# 2021-01-23 04:20:59 [381/2126] precision: 0.441760, recall: 0.367816, fscore: 0.401406
# 2021-01-23 04:21:03 [382/2126] precision: 0.441760, recall: 0.366762, fscore: 0.400778
# 2021-01-23 04:21:06 [383/2126] precision: 0.441760, recall: 0.365780, fscore: 0.400190
# 2021-01-23 04:21:10 [384/2126] precision: 0.441760, recall: 0.364802, fscore: 0.399605
# 2021-01-23 04:21:13 [385/2126] precision: 0.441760, recall: 0.363766, fscore: 0.398982
# 2021-01-23 04:21:16 [386/2126] precision: 0.441760, recall: 0.362735, fscore: 0.398361
# 2021-01-23 04:21:19 [387/2126] precision: 0.441760, recall: 0.361710, fscore: 0.397742
# 2021-01-23 04:21:22 [388/2126] precision: 0.441760, recall: 0.360690, fscore: 0.397125
# 2021-01-23 04:21:25 [389/2126] precision: 0.441760, recall: 0.359677, fscore: 0.396510
# 2021-01-23 04:21:28 [390/2126] precision: 0.441760, recall: 0.358669, fscore: 0.395897
# 2021-01-23 04:21:31 [391/2126] precision: 0.441760, recall: 0.357667, fscore: 0.395286
# 2021-01-23 04:21:34 [392/2126] precision: 0.441760, recall: 0.356670, fscore: 0.394676
# 2021-01-23 04:21:37 [393/2126] precision: 0.441760, recall: 0.355679, fscore: 0.394069
# 2021-01-23 04:21:40 [394/2126] precision: 0.441760, recall: 0.354509, fscore: 0.393350
# 2021-01-23 04:21:42 [395/2126] precision: 0.441760, recall: 0.353043, fscore: 0.392445
# 2021-01-23 04:21:45 [396/2126] precision: 0.441760, recall: 0.351588, fscore: 0.391545
# 2021-01-23 04:21:47 [397/2126] precision: 0.441760, recall: 0.350145, fscore: 0.390648
# 2021-01-23 04:21:50 [398/2126] precision: 0.442407, recall: 0.349225, fscore: 0.390327
# 2021-01-23 04:21:52 [399/2126] precision: 0.444133, recall: 0.349161, fscore: 0.390957
# 2021-01-23 04:21:54 [400/2126] precision: 0.445858, recall: 0.349096, fscore: 0.391584
# 2021-01-23 04:21:57 [401/2126] precision: 0.448663, recall: 0.349874, fscore: 0.393153
# 2021-01-23 04:22:00 [402/2126] precision: 0.449310, recall: 0.348970, fscore: 0.392829
# 2021-01-23 04:22:03 [403/2126] precision: 0.449741, recall: 0.347906, fscore: 0.392318
# 2021-01-23 04:22:06 [404/2126] precision: 0.449957, recall: 0.346684, fscore: 0.391622
# 2021-01-23 04:22:09 [405/2126] precision: 0.450173, recall: 0.345473, fscore: 0.390929
# 2021-01-23 04:22:13 [406/2126] precision: 0.451898, recall: 0.345425, fscore: 0.391547
# 2021-01-23 04:22:16 [407/2126] precision: 0.453624, recall: 0.345377, fscore: 0.392163
# 2021-01-23 04:22:20 [408/2126] precision: 0.454702, recall: 0.344839, fscore: 0.392218
# 2021-01-23 04:22:24 [409/2126] precision: 0.456428, recall: 0.344794, fscore: 0.392829
# 2021-01-23 04:22:27 [410/2126] precision: 0.457722, recall: 0.344425, fscore: 0.393067
# 2021-01-23 04:22:30 [411/2126] precision: 0.459664, recall: 0.344543, fscore: 0.393859
# 2021-01-23 04:22:33 [412/2126] precision: 0.461389, recall: 0.344500, fscore: 0.394463
# 2021-01-23 04:22:36 [413/2126] precision: 0.462468, recall: 0.343976, fscore: 0.394512
# 2021-01-23 04:22:40 [414/2126] precision: 0.463330, recall: 0.343296, fscore: 0.394377
# 2021-01-23 04:22:43 [415/2126] precision: 0.467213, recall: 0.344850, fscore: 0.396807
# 2021-01-23 04:22:48 [416/2126] precision: 0.469586, recall: 0.345282, fscore: 0.397948
# 2021-01-23 04:22:55 [417/2126] precision: 0.473469, recall: 0.346816, fscore: 0.400360
# 2021-01-23 04:23:06 [418/2126] precision: 0.477351, recall: 0.348339, fscore: 0.402762
# 2021-01-23 04:23:15 [419/2126] precision: 0.481881, recall: 0.350321, fscore: 0.405697
# 2021-01-23 04:23:19 [420/2126] precision: 0.481881, recall: 0.349883, fscore: 0.405403
# 2021-01-23 04:23:23 [421/2126] precision: 0.481881, recall: 0.349445, fscore: 0.405109
# 2021-01-23 04:23:30 [422/2126] precision: 0.482744, recall: 0.349360, fscore: 0.405356
# 2021-01-23 04:23:36 [423/2126] precision: 0.485548, recall: 0.350514, fscore: 0.407121
# 2021-01-23 04:23:43 [424/2126] precision: 0.487705, recall: 0.351196, fscore: 0.408339
# 2021-01-23 04:23:50 [425/2126] precision: 0.488136, recall: 0.350635, fscore: 0.408111
# 2021-01-23 04:23:57 [426/2126] precision: 0.490940, recall: 0.351777, fscore: 0.409864
# 2021-01-23 04:24:03 [427/2126] precision: 0.492019, recall: 0.351681, fscore: 0.410173
# 2021-01-23 04:24:10 [428/2126] precision: 0.495255, recall: 0.353122, fscore: 0.412277
# 2021-01-23 04:24:17 [429/2126] precision: 0.498059, recall: 0.354250, fscore: 0.414017
# 2021-01-23 04:24:22 [430/2126] precision: 0.499784, recall: 0.354607, fscore: 0.414856
# 2021-01-23 04:24:27 [431/2126] precision: 0.502157, recall: 0.355420, fscore: 0.416230
# 2021-01-23 04:24:32 [432/2126] precision: 0.505608, recall: 0.356991, fscore: 0.418492
# 2021-01-23 04:24:36 [433/2126] precision: 0.507964, recall: 0.358554, fscore: 0.420373
# 2021-01-23 04:24:41 [434/2126] precision: 0.511408, recall: 0.360109, fscore: 0.422621
# 2021-01-23 04:24:45 [435/2126] precision: 0.514077, recall: 0.361657, fscore: 0.424598
# 2021-01-23 04:24:50 [436/2126] precision: 0.513838, recall: 0.361673, fscore: 0.424528
# 2021-01-23 04:24:54 [437/2126] precision: 0.513838, recall: 0.361673, fscore: 0.424528
# 2021-01-23 04:24:58 [438/2126] precision: 0.513838, recall: 0.361564, fscore: 0.424452
# 2021-01-23 04:25:00 [439/2126] precision: 0.514482, recall: 0.361635, fscore: 0.424721
# 2021-01-23 04:25:03 [440/2126] precision: 0.515126, recall: 0.361270, fscore: 0.424688
# 2021-01-23 04:25:06 [441/2126] precision: 0.515126, recall: 0.360402, fscore: 0.424088
# 2021-01-23 04:25:10 [442/2126] precision: 0.515126, recall: 0.359539, fscore: 0.423489
# 2021-01-23 04:25:13 [443/2126] precision: 0.515126, recall: 0.358679, fscore: 0.422893
# 2021-01-23 04:25:16 [444/2126] precision: 0.515126, recall: 0.357824, fscore: 0.422298
# 2021-01-23 04:25:19 [445/2126] precision: 0.515555, recall: 0.357270, fscore: 0.422055
# 2021-01-23 04:25:22 [446/2126] precision: 0.515555, recall: 0.356422, fscore: 0.421463
# 2021-01-23 04:25:25 [447/2126] precision: 0.515555, recall: 0.355579, fscore: 0.420873
# 2021-01-23 04:25:27 [448/2126] precision: 0.515555, recall: 0.354739, fscore: 0.420284
# 2021-01-23 04:25:29 [449/2126] precision: 0.515555, recall: 0.353903, fscore: 0.419697
# 2021-01-23 04:25:32 [450/2126] precision: 0.518773, recall: 0.355275, fscore: 0.421727
# 2021-01-23 04:25:34 [451/2126] precision: 0.520489, recall: 0.355614, fscore: 0.422533
# 2021-01-23 04:25:37 [452/2126] precision: 0.521991, recall: 0.355806, fscore: 0.423162
# 2021-01-23 04:25:40 [453/2126] precision: 0.521991, recall: 0.354975, fscore: 0.422574
# 2021-01-23 04:25:43 [454/2126] precision: 0.521991, recall: 0.354148, fscore: 0.421988
# 2021-01-23 04:25:47 [455/2126] precision: 0.521991, recall: 0.353326, fscore: 0.421403
# 2021-01-23 04:25:50 [456/2126] precision: 0.522849, recall: 0.353086, fscore: 0.421512
# 2021-01-23 04:25:54 [457/2126] precision: 0.524566, recall: 0.353426, fscore: 0.422311
# 2021-01-23 04:25:57 [458/2126] precision: 0.526282, recall: 0.353764, fscore: 0.423109
# 2021-01-23 04:26:00 [459/2126] precision: 0.526496, recall: 0.353195, fscore: 0.422771
# 2021-01-23 04:26:04 [460/2126] precision: 0.527569, recall: 0.353508, fscore: 0.423340
# 2021-01-23 04:26:08 [461/2126] precision: 0.529286, recall: 0.354250, fscore: 0.424425
# 2021-01-23 04:26:11 [462/2126] precision: 0.530358, recall: 0.354561, fscore: 0.424993
# 2021-01-23 04:26:15 [463/2126] precision: 0.532075, recall: 0.355301, fscore: 0.426075
# 2021-01-23 04:26:18 [464/2126] precision: 0.533576, recall: 0.355896, fscore: 0.426985
# 2021-01-23 04:26:22 [465/2126] precision: 0.535063, recall: 0.356632, fscore: 0.427991
# 2021-01-23 04:26:26 [466/2126] precision: 0.535775, recall: 0.357082, fscore: 0.428542
# 2021-01-23 04:26:29 [467/2126] precision: 0.534284, recall: 0.357815, fscore: 0.428591
# 2021-01-23 04:26:32 [468/2126] precision: 0.530354, recall: 0.358405, fscore: 0.427741
# 2021-01-23 04:26:35 [469/2126] precision: 0.526382, recall: 0.359135, fscore: 0.426960
# 2021-01-23 04:26:38 [470/2126] precision: 0.523958, recall: 0.359164, fscore: 0.426180
# 2021-01-23 04:26:41 [471/2126] precision: 0.523958, recall: 0.359164, fscore: 0.426180
# 2021-01-23 04:26:44 [472/2126] precision: 0.523958, recall: 0.359164, fscore: 0.426180
# 2021-01-23 04:26:47 [473/2126] precision: 0.523958, recall: 0.359164, fscore: 0.426180
# 2021-01-23 04:26:50 [474/2126] precision: 0.523958, recall: 0.359164, fscore: 0.426180
# 2021-01-23 04:26:53 [475/2126] precision: 0.522873, recall: 0.359164, fscore: 0.425821
# 2021-01-23 04:26:56 [476/2126] precision: 0.523366, recall: 0.359517, fscore: 0.426233
# 2021-01-23 04:26:59 [477/2126] precision: 0.524607, recall: 0.359807, fscore: 0.426848
# 2021-01-23 04:27:02 [478/2126] precision: 0.524300, recall: 0.360266, fscore: 0.427069
# 2021-01-23 04:27:05 [479/2126] precision: 0.528407, recall: 0.362110, fscore: 0.429726
# 2021-01-23 04:27:09 [480/2126] precision: 0.532730, recall: 0.363841, fscore: 0.432373
# 2021-01-23 04:27:12 [481/2126] precision: 0.535810, recall: 0.365840, fscore: 0.434800
# 2021-01-23 04:27:16 [482/2126] precision: 0.537551, recall: 0.367826, fscore: 0.436775
# 2021-01-23 04:27:20 [483/2126] precision: 0.542245, recall: 0.369798, fscore: 0.439714
# 2021-01-23 04:27:24 [484/2126] precision: 0.545584, recall: 0.371896, fscore: 0.442295
# 2021-01-23 04:27:27 [485/2126] precision: 0.549016, recall: 0.373980, fscore: 0.444896
# 2021-01-23 04:27:31 [486/2126] precision: 0.550979, recall: 0.376051, fscore: 0.447006
# 2021-01-23 04:27:34 [487/2126] precision: 0.549110, recall: 0.377009, fscore: 0.447064
# 2021-01-23 04:27:37 [488/2126] precision: 0.545473, recall: 0.376865, fscore: 0.445753
# 2021-01-23 04:27:41 [489/2126] precision: 0.540922, recall: 0.376040, fscore: 0.443653
# 2021-01-23 04:27:45 [490/2126] precision: 0.536500, recall: 0.374813, fscore: 0.441308
# 2021-01-23 04:27:48 [491/2126] precision: 0.533695, recall: 0.373594, fscore: 0.439514
# 2021-01-23 04:27:51 [492/2126] precision: 0.533695, recall: 0.372382, fscore: 0.438674
# 2021-01-23 04:27:55 [493/2126] precision: 0.533695, recall: 0.371529, fscore: 0.438081
# 2021-01-23 04:27:58 [494/2126] precision: 0.533695, recall: 0.370729, fscore: 0.437525
# 2021-01-23 04:28:01 [495/2126] precision: 0.533695, recall: 0.370331, fscore: 0.437247
# 2021-01-23 04:28:06 [496/2126] precision: 0.533385, recall: 0.369933, fscore: 0.436866
# 2021-01-23 04:28:10 [497/2126] precision: 0.533772, recall: 0.369804, fscore: 0.436906
# 2021-01-23 04:28:13 [498/2126] precision: 0.533772, recall: 0.369408, fscore: 0.436629
# 2021-01-23 04:28:17 [499/2126] precision: 0.533772, recall: 0.369013, fscore: 0.436353
# 2021-01-23 04:28:20 [500/2126] precision: 0.534159, recall: 0.368885, fscore: 0.436393
# 2021-01-23 04:28:23 [501/2126] precision: 0.535320, recall: 0.369292, fscore: 0.437066
# 2021-01-23 04:28:26 [502/2126] precision: 0.535320, recall: 0.368898, fscore: 0.436789
# 2021-01-23 04:28:30 [503/2126] precision: 0.535320, recall: 0.368505, fscore: 0.436514
# 2021-01-23 04:28:34 [504/2126] precision: 0.535320, recall: 0.368113, fscore: 0.436238
# 2021-01-23 04:28:38 [505/2126] precision: 0.535320, recall: 0.367721, fscore: 0.435963
# 2021-01-23 04:28:41 [506/2126] precision: 0.535320, recall: 0.367331, fscore: 0.435689
# 2021-01-23 04:28:46 [507/2126] precision: 0.535320, recall: 0.366941, fscore: 0.435414
# 2021-01-23 04:28:51 [508/2126] precision: 0.534389, recall: 0.366552, fscore: 0.434832
# 2021-01-23 04:28:56 [509/2126] precision: 0.533771, recall: 0.366164, fscore: 0.434354
# 2021-01-23 04:29:01 [510/2126] precision: 0.529175, recall: 0.365776, fscore: 0.432554
# 2021-01-23 04:29:08 [511/2126] precision: 0.524360, recall: 0.365390, fscore: 0.430669
# 2021-01-23 04:29:15 [512/2126] precision: 0.519632, recall: 0.365004, fscore: 0.428799
# 2021-01-23 04:29:22 [513/2126] precision: 0.515084, recall: 0.364619, fscore: 0.426979
# 2021-01-23 04:29:28 [514/2126] precision: 0.510520, recall: 0.364235, fscore: 0.425141
# 2021-01-23 04:29:34 [515/2126] precision: 0.506037, recall: 0.363852, fscore: 0.423319
# 2021-01-23 04:29:38 [516/2126] precision: 0.503550, recall: 0.363469, fscore: 0.422189
# 2021-01-23 04:29:43 [517/2126] precision: 0.499188, recall: 0.363087, fscore: 0.420392
# 2021-01-23 04:29:48 [518/2126] precision: 0.494370, recall: 0.362707, fscore: 0.418420
# 2021-01-23 04:29:52 [519/2126] precision: 0.491318, recall: 0.363243, fscore: 0.417678
# 2021-01-23 04:29:57 [520/2126] precision: 0.488409, recall: 0.363910, fscore: 0.417062
# 2021-01-23 04:30:01 [521/2126] precision: 0.485297, recall: 0.364575, fscore: 0.416357
# 2021-01-23 04:30:05 [522/2126] precision: 0.482325, recall: 0.365239, fscore: 0.415690
# 2021-01-23 04:30:08 [523/2126] precision: 0.479733, recall: 0.365901, fscore: 0.415151
# 2021-01-23 04:30:12 [524/2126] precision: 0.478972, recall: 0.366562, fscore: 0.415290
# 2021-01-23 04:30:15 [525/2126] precision: 0.479653, recall: 0.366701, fscore: 0.415635
# 2021-01-23 04:30:18 [526/2126] precision: 0.477599, recall: 0.367360, fscore: 0.415284
# 2021-01-23 04:30:22 [527/2126] precision: 0.474698, recall: 0.368018, fscore: 0.414601
# 2021-01-23 04:30:26 [528/2126] precision: 0.471927, recall: 0.368674, fscore: 0.413954
# 2021-01-23 04:30:30 [529/2126] precision: 0.468663, recall: 0.369328, fscore: 0.413103
# 2021-01-23 04:30:34 [530/2126] precision: 0.465568, recall: 0.369464, fscore: 0.411981
# 2021-01-23 04:30:37 [531/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:39 [532/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:43 [533/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:45 [534/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:48 [535/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:50 [536/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:53 [537/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:55 [538/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:30:58 [539/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:00 [540/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:03 [541/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:05 [542/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:07 [543/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:10 [544/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:12 [545/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:14 [546/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# 2021-01-23 04:31:17 [547/2126] precision: 0.464280, recall: 0.369464, fscore: 0.411476
# ...
# 2021-01-23 05:55:18 [1946/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:55:23 [1947/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:55:29 [1948/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:55:35 [1949/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:55:42 [1950/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:55:48 [1951/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:55:52 [1952/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:55:56 [1953/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:56:00 [1954/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:56:03 [1955/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:56:06 [1956/2126] precision: 0.511868, recall: 0.300926, fscore: 0.379020
# 2021-01-23 05:56:09 [1957/2126] precision: 0.511868, recall: 0.300814, fscore: 0.378931
# 2021-01-23 05:56:12 [1958/2126] precision: 0.511868, recall: 0.300564, fscore: 0.378733
# 2021-01-23 05:56:15 [1959/2126] precision: 0.511868, recall: 0.300265, fscore: 0.378495
# 2021-01-23 05:56:18 [1960/2126] precision: 0.511868, recall: 0.299967, fscore: 0.378258
# 2021-01-23 05:56:21 [1961/2126] precision: 0.511868, recall: 0.299669, fscore: 0.378021
# 2021-01-23 05:56:24 [1962/2126] precision: 0.511868, recall: 0.299372, fscore: 0.377785
# 2021-01-23 05:56:27 [1963/2126] precision: 0.511868, recall: 0.299075, fscore: 0.377548
# 2021-01-23 05:56:31 [1964/2126] precision: 0.511868, recall: 0.298779, fscore: 0.377313
# 2021-01-23 05:56:34 [1965/2126] precision: 0.511868, recall: 0.298484, fscore: 0.377077
# 2021-01-23 05:56:37 [1966/2126] precision: 0.512009, recall: 0.298272, fscore: 0.376946
# 2021-01-23 05:56:39 [1967/2126] precision: 0.512009, recall: 0.297977, fscore: 0.376711
# 2021-01-23 05:56:42 [1968/2126] precision: 0.512009, recall: 0.297684, fscore: 0.376476
# 2021-01-23 05:56:45 [1969/2126] precision: 0.512009, recall: 0.297390, fscore: 0.376241
# 2021-01-23 05:56:48 [1970/2126] precision: 0.512009, recall: 0.297098, fscore: 0.376007
# 2021-01-23 05:56:52 [1971/2126] precision: 0.512009, recall: 0.296806, fscore: 0.375773
# 2021-01-23 05:56:55 [1972/2126] precision: 0.512009, recall: 0.296514, fscore: 0.375539
# 2021-01-23 05:56:58 [1973/2126] precision: 0.512009, recall: 0.296224, fscore: 0.375306
# 2021-01-23 05:57:01 [1974/2126] precision: 0.512504, recall: 0.296219, fscore: 0.375435
# 2021-01-23 05:57:05 [1975/2126] precision: 0.513069, recall: 0.296256, fscore: 0.375616
# 2021-01-23 05:57:08 [1976/2126] precision: 0.513493, recall: 0.296210, fscore: 0.375693
# 2021-01-23 05:57:11 [1977/2126] precision: 0.514058, recall: 0.296247, fscore: 0.375873
# 2021-01-23 05:57:15 [1978/2126] precision: 0.515188, recall: 0.296608, fscore: 0.376467
# 2021-01-23 05:57:18 [1979/2126] precision: 0.516318, recall: 0.296969, fscore: 0.377059
# 2021-01-23 05:57:21 [1980/2126] precision: 0.516954, recall: 0.297045, fscore: 0.377290
# 2021-01-23 05:57:25 [1981/2126] precision: 0.517943, recall: 0.297324, fscore: 0.377778
# 2021-01-23 05:57:29 [1982/2126] precision: 0.518932, recall: 0.297602, fscore: 0.378265
# 2021-01-23 05:57:32 [1983/2126] precision: 0.519918, recall: 0.297920, fscore: 0.378784
# 2021-01-23 05:57:35 [1984/2126] precision: 0.520353, recall: 0.298237, fscore: 0.379156
# 2021-01-23 05:57:39 [1985/2126] precision: 0.521114, recall: 0.298594, fscore: 0.379647
# 2021-01-23 05:57:42 [1986/2126] precision: 0.520690, recall: 0.298588, fscore: 0.379529
# 2021-01-23 05:57:45 [1987/2126] precision: 0.521106, recall: 0.298621, fscore: 0.379666
# 2021-01-23 05:57:48 [1988/2126] precision: 0.520107, recall: 0.298494, fscore: 0.379298
# 2021-01-23 05:57:52 [1989/2126] precision: 0.519742, recall: 0.298728, fscore: 0.379390
# 2021-01-23 05:57:55 [1990/2126] precision: 0.519118, recall: 0.299083, fscore: 0.379510
# 2021-01-23 05:57:58 [1991/2126] precision: 0.518068, recall: 0.299398, fscore: 0.379481
# 2021-01-23 05:58:01 [1992/2126] precision: 0.516917, recall: 0.299751, fscore: 0.379455
# 2021-01-23 05:58:05 [1993/2126] precision: 0.515465, recall: 0.299944, fscore: 0.379217
# 2021-01-23 05:58:08 [1994/2126] precision: 0.513751, recall: 0.299976, fscore: 0.378778
# 2021-01-23 05:58:12 [1995/2126] precision: 0.512052, recall: 0.300008, fscore: 0.378341
# 2021-01-23 05:58:15 [1996/2126] precision: 0.510368, recall: 0.300040, fscore: 0.377906
# 2021-01-23 05:58:18 [1997/2126] precision: 0.508767, recall: 0.300132, fscore: 0.377539
# 2021-01-23 05:58:22 [1998/2126] precision: 0.507286, recall: 0.300124, fscore: 0.377124
# 2021-01-23 05:58:25 [1999/2126] precision: 0.506637, recall: 0.300028, fscore: 0.376869
# 2021-01-23 05:58:28 [2000/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:58:31 [2001/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:58:36 [2002/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:58:40 [2003/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:58:43 [2004/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:58:47 [2005/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:58:51 [2006/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:58:55 [2007/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:59:00 [2008/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:59:07 [2009/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:59:14 [2010/2126] precision: 0.506603, recall: 0.299932, fscore: 0.376784
# 2021-01-23 05:59:21 [2011/2126] precision: 0.506569, recall: 0.299932, fscore: 0.376774
# 2021-01-23 05:59:27 [2012/2126] precision: 0.506569, recall: 0.299908, fscore: 0.376755
# 2021-01-23 05:59:33 [2013/2126] precision: 0.506569, recall: 0.299813, fscore: 0.376680
# 2021-01-23 05:59:39 [2014/2126] precision: 0.506569, recall: 0.299729, fscore: 0.376614
# 2021-01-23 05:59:45 [2015/2126] precision: 0.506569, recall: 0.299681, fscore: 0.376576
# 2021-01-23 05:59:52 [2016/2126] precision: 0.506569, recall: 0.299586, fscore: 0.376501
# 2021-01-23 05:59:58 [2017/2126] precision: 0.506569, recall: 0.299550, fscore: 0.376472
# 2021-01-23 06:00:04 [2018/2126] precision: 0.506569, recall: 0.299454, fscore: 0.376397
# 2021-01-23 06:00:11 [2019/2126] precision: 0.506569, recall: 0.299359, fscore: 0.376322
# 2021-01-23 06:00:18 [2020/2126] precision: 0.506569, recall: 0.299264, fscore: 0.376246
# 2021-01-23 06:00:27 [2021/2126] precision: 0.506569, recall: 0.299168, fscore: 0.376171
# 2021-01-23 06:00:34 [2022/2126] precision: 0.507040, recall: 0.299352, fscore: 0.376446
# 2021-01-23 06:00:40 [2023/2126] precision: 0.507512, recall: 0.299535, fscore: 0.376721
# 2021-01-23 06:00:47 [2024/2126] precision: 0.507512, recall: 0.299440, fscore: 0.376645
# 2021-01-23 06:00:50 [2025/2126] precision: 0.507512, recall: 0.299356, fscore: 0.376579
# 2021-01-23 06:00:53 [2026/2126] precision: 0.507512, recall: 0.299309, fscore: 0.376542
# 2021-01-23 06:00:56 [2027/2126] precision: 0.507512, recall: 0.299225, fscore: 0.376476
# 2021-01-23 06:00:59 [2028/2126] precision: 0.507512, recall: 0.299166, fscore: 0.376429
# 2021-01-23 06:01:02 [2029/2126] precision: 0.507512, recall: 0.299071, fscore: 0.376354
# 2021-01-23 06:01:05 [2030/2126] precision: 0.507512, recall: 0.298976, fscore: 0.376278
# 2021-01-23 06:01:08 [2031/2126] precision: 0.507512, recall: 0.298881, fscore: 0.376203
# 2021-01-23 06:01:11 [2032/2126] precision: 0.507512, recall: 0.298786, fscore: 0.376128
# 2021-01-23 06:01:14 [2033/2126] precision: 0.507512, recall: 0.298692, fscore: 0.376053
# 2021-01-23 06:01:17 [2034/2126] precision: 0.507512, recall: 0.298597, fscore: 0.375978
# 2021-01-23 06:01:19 [2035/2126] precision: 0.507984, recall: 0.298780, fscore: 0.376252
# 2021-01-23 06:01:21 [2036/2126] precision: 0.508388, recall: 0.298923, fscore: 0.376476
# 2021-01-23 06:01:24 [2037/2126] precision: 0.508388, recall: 0.298828, fscore: 0.376401
# 2021-01-23 06:01:28 [2038/2126] precision: 0.508859, recall: 0.299010, fscore: 0.376675
# 2021-01-23 06:01:31 [2039/2126] precision: 0.509196, recall: 0.299114, fscore: 0.376850
# 2021-01-23 06:01:33 [2040/2126] precision: 0.509196, recall: 0.299019, fscore: 0.376774
# 2021-01-23 06:01:36 [2041/2126] precision: 0.509196, recall: 0.298924, fscore: 0.376699
# 2021-01-23 06:01:40 [2042/2126] precision: 0.509196, recall: 0.298830, fscore: 0.376624
# 2021-01-23 06:01:43 [2043/2126] precision: 0.509196, recall: 0.298735, fscore: 0.376549
# 2021-01-23 06:01:46 [2044/2126] precision: 0.509196, recall: 0.298641, fscore: 0.376474
# 2021-01-23 06:01:50 [2045/2126] precision: 0.509196, recall: 0.298546, fscore: 0.376399
# 2021-01-23 06:01:54 [2046/2126] precision: 0.509196, recall: 0.298452, fscore: 0.376324
# 2021-01-23 06:01:57 [2047/2126] precision: 0.509196, recall: 0.298358, fscore: 0.376249
# 2021-01-23 06:02:00 [2048/2126] precision: 0.509196, recall: 0.298264, fscore: 0.376174
# 2021-01-23 06:02:03 [2049/2126] precision: 0.509196, recall: 0.298169, fscore: 0.376099
# 2021-01-23 06:02:06 [2050/2126] precision: 0.509196, recall: 0.298075, fscore: 0.376025
# 2021-01-23 06:02:09 [2051/2126] precision: 0.509196, recall: 0.297981, fscore: 0.375950
# 2021-01-23 06:02:12 [2052/2126] precision: 0.509196, recall: 0.297887, fscore: 0.375875
# 2021-01-23 06:02:15 [2053/2126] precision: 0.509196, recall: 0.297794, fscore: 0.375800
# 2021-01-23 06:02:18 [2054/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:20 [2055/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:23 [2056/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:26 [2057/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:29 [2058/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:32 [2059/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:35 [2060/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:38 [2061/2126] precision: 0.509196, recall: 0.297711, fscore: 0.375735
# 2021-01-23 06:02:41 [2062/2126] precision: 0.509196, recall: 0.297618, fscore: 0.375660
# 2021-01-23 06:02:45 [2063/2126] precision: 0.509196, recall: 0.297442, fscore: 0.375520
# 2021-01-23 06:02:48 [2064/2126] precision: 0.509196, recall: 0.297255, fscore: 0.375371
# 2021-01-23 06:02:51 [2065/2126] precision: 0.509264, recall: 0.297107, fscore: 0.375272
# 2021-01-23 06:02:53 [2066/2126] precision: 0.509803, recall: 0.297235, fscore: 0.375520
# 2021-01-23 06:02:57 [2067/2126] precision: 0.510342, recall: 0.297362, fscore: 0.375767
# 2021-01-23 06:03:00 [2068/2126] precision: 0.510881, recall: 0.297489, fscore: 0.376015
# 2021-01-23 06:03:04 [2069/2126] precision: 0.511015, recall: 0.297381, fscore: 0.375965
# 2021-01-23 06:03:06 [2070/2126] precision: 0.511420, recall: 0.297430, fscore: 0.376113
# 2021-01-23 06:03:09 [2071/2126] precision: 0.511958, recall: 0.297557, fscore: 0.376360
# 2021-01-23 06:03:11 [2072/2126] precision: 0.512902, recall: 0.297918, fscore: 0.376905
# 2021-01-23 06:03:13 [2073/2126] precision: 0.513441, recall: 0.298045, fscore: 0.377151
# 2021-01-23 06:03:16 [2074/2126] precision: 0.513575, recall: 0.297936, fscore: 0.377101
# 2021-01-23 06:03:19 [2075/2126] precision: 0.514653, recall: 0.298375, fscore: 0.377743
# 2021-01-23 06:03:22 [2076/2126] precision: 0.515327, recall: 0.298579, fscore: 0.378088
# 2021-01-23 06:03:25 [2077/2126] precision: 0.515388, recall: 0.298642, fscore: 0.378155
# 2021-01-23 06:03:29 [2078/2126] precision: 0.515388, recall: 0.298642, fscore: 0.378155
# 2021-01-23 06:03:34 [2079/2126] precision: 0.515388, recall: 0.298642, fscore: 0.378155
# 2021-01-23 06:03:40 [2080/2126] precision: 0.515388, recall: 0.298642, fscore: 0.378155
# 2021-01-23 06:03:45 [2081/2126] precision: 0.515388, recall: 0.298642, fscore: 0.378155
# 2021-01-23 06:03:51 [2082/2126] precision: 0.515388, recall: 0.298642, fscore: 0.378155
# 2021-01-23 06:03:55 [2083/2126] precision: 0.515388, recall: 0.298642, fscore: 0.378155
# 2021-01-23 06:03:59 [2084/2126] precision: 0.515354, recall: 0.298630, fscore: 0.378136
# 2021-01-23 06:04:02 [2085/2126] precision: 0.515284, recall: 0.298537, fscore: 0.378043
# 2021-01-23 06:04:06 [2086/2126] precision: 0.513866, recall: 0.298444, fscore: 0.377586
# 2021-01-23 06:04:09 [2087/2126] precision: 0.512409, recall: 0.298624, fscore: 0.377335
# 2021-01-23 06:04:13 [2088/2126] precision: 0.510726, recall: 0.298765, fscore: 0.376990
# 2021-01-23 06:04:17 [2089/2126] precision: 0.509022, recall: 0.298944, fscore: 0.376667
# 2021-01-23 06:04:21 [2090/2126] precision: 0.507399, recall: 0.299163, fscore: 0.376395
# 2021-01-23 06:04:25 [2091/2126] precision: 0.505723, recall: 0.299342, fscore: 0.376075
# 2021-01-23 06:04:30 [2092/2126] precision: 0.504127, recall: 0.299560, fscore: 0.375804
# 2021-01-23 06:04:35 [2093/2126] precision: 0.502544, recall: 0.299778, fscore: 0.375535
# 2021-01-23 06:04:40 [2094/2126] precision: 0.500909, recall: 0.299957, fscore: 0.375217
# 2021-01-23 06:04:45 [2095/2126] precision: 0.499029, recall: 0.299864, fscore: 0.374616
# 2021-01-23 06:04:50 [2096/2126] precision: 0.498352, recall: 0.299771, fscore: 0.374352
# 2021-01-23 06:04:54 [2097/2126] precision: 0.498320, recall: 0.299677, fscore: 0.374270
# 2021-01-23 06:04:58 [2098/2126] precision: 0.498320, recall: 0.299677, fscore: 0.374270
# 2021-01-23 06:05:02 [2099/2126] precision: 0.496907, recall: 0.299677, fscore: 0.373871
# 2021-01-23 06:05:05 [2100/2126] precision: 0.496907, recall: 0.299584, fscore: 0.373799
# 2021-01-23 06:05:08 [2101/2126] precision: 0.496907, recall: 0.299491, fscore: 0.373726
# 2021-01-23 06:05:11 [2102/2126] precision: 0.496907, recall: 0.299398, fscore: 0.373654
# 2021-01-23 06:05:14 [2103/2126] precision: 0.496907, recall: 0.299305, fscore: 0.373581
# 2021-01-23 06:05:16 [2104/2126] precision: 0.496907, recall: 0.299212, fscore: 0.373509
# 2021-01-23 06:05:19 [2105/2126] precision: 0.496907, recall: 0.299119, fscore: 0.373436
# 2021-01-23 06:05:22 [2106/2126] precision: 0.496907, recall: 0.299027, fscore: 0.373364
# 2021-01-23 06:05:24 [2107/2126] precision: 0.496907, recall: 0.298934, fscore: 0.373292
# 2021-01-23 06:05:26 [2108/2126] precision: 0.496971, recall: 0.298880, fscore: 0.373268
# 2021-01-23 06:05:29 [2109/2126] precision: 0.497422, recall: 0.299059, fscore: 0.373534
# 2021-01-23 06:05:31 [2110/2126] precision: 0.497680, recall: 0.299121, fscore: 0.373656
# 2021-01-23 06:05:33 [2111/2126] precision: 0.497745, recall: 0.299067, fscore: 0.373632
# 2021-01-23 06:05:35 [2112/2126] precision: 0.497745, recall: 0.298974, fscore: 0.373560
# 2021-01-23 06:05:37 [2113/2126] precision: 0.498067, recall: 0.299075, fscore: 0.373729
# 2021-01-23 06:05:40 [2114/2126] precision: 0.498582, recall: 0.299292, fscore: 0.374044
# 2021-01-23 06:05:42 [2115/2126] precision: 0.498711, recall: 0.299277, fscore: 0.374068
# 2021-01-23 06:05:45 [2116/2126] precision: 0.498711, recall: 0.299184, fscore: 0.373996
# 2021-01-23 06:05:48 [2117/2126] precision: 0.499227, recall: 0.299401, fscore: 0.374310
# 2021-01-23 06:05:51 [2118/2126] precision: 0.499484, recall: 0.299463, fscore: 0.374431
# 2021-01-23 06:05:53 [2119/2126] precision: 0.499484, recall: 0.299370, fscore: 0.374358
# 2021-01-23 06:05:55 [2120/2126] precision: 0.499484, recall: 0.299278, fscore: 0.374286
# 2021-01-23 06:05:58 [2121/2126] precision: 0.499484, recall: 0.299186, fscore: 0.374214
# 2021-01-23 06:06:01 [2122/2126] precision: 0.499484, recall: 0.299093, fscore: 0.374142
# 2021-01-23 06:06:04 [2123/2126] precision: 0.499484, recall: 0.299001, fscore: 0.374069
# 2021-01-23 06:06:08 [2124/2126] precision: 0.499484, recall: 0.298920, fscore: 0.374006
# 2021-01-23 06:06:11 [2125/2126] precision: 0.499484, recall: 0.298920, fscore: 0.374006
# 2021-01-23 06:06:12 [2126/2126] precision: 0.499484, recall: 0.298920, fscore: 0.374006
# Classification accuracy: 0.793
# Localization recall: 0.377

# %%
precision
# Out:
# 0.49948446932627627

# %%
recall
# Out:
# 0.29892016957234085

# %%
fscore
# Out:
# 0.3740061241254874

# %%
eval_result
# Out:
# {'class_acc': 0.7927789702436545,
#  'fscore': 0.3740061241254874,
#  'loc_recall': 0.37705360571652385,
#  'precision': 0.49948446932627627,
#  'recall': 0.29892016957234085}

# %%
'''
correct = iou>0.5 (location) AND class is correct
proposals = conf_score > 0.25

precision = correct/proposals, if I propose a box+class with confidence > 0.25, is it correct? 
recall = correct/total_ground_truths
fscore

Classification accuracy = classify_correct/total_detected, classification accuracy given detected
Localization recall = total_detected/total_gr_truths
'''

# %%
# eval_result = {'class_acc': classification_accuracy,
#                'loc_recall': localization_recall, 
#                'precision': precision, 
#                'recall': recall, 
#                'fscore': fscore} 
# fileout = 'jaad_eval_result_e' + str(epoch)
# import json
# with open(f'./jaad_detections/{fileout}.json', 'w') as fp:
#     json.dump(eval_result, fp)

# %%
import json
epoch = 2
with open(f'./jaad_detections/jaad_eval_result_e{epoch}.json', 'r') as fp:
    data_2 = json.load(fp)

# %%
data_1
# Out:
# {'class_acc': 0.849,
#  'fscore': 0.221766,
#  'loc_recall': 0.171,
#  'precision': 0.473691,
#  'recall': 0.144774}

# %%
data_2
# Out:
# {'class_acc': 0.9031082100861316,
#  'fscore': 0.26340573773337617,
#  'loc_recall': 0.20100269949826352,
#  'precision': 0.47986542921820224,
#  'recall': 0.18152718851464436}

# %%
data_3
# Out:
# {'class_acc': 0.8728975188609372,
#  'fscore': 0.2727895996208869,
#  'loc_recall': 0.2224064788961024,
#  'precision': 0.4585952441845721,
#  'recall': 0.19413806394364133}

# %%
data_4
# Out:
# {'class_acc': 0.8878576939089595,
#  'fscore': 0.30337033269287433,
#  'loc_recall': 0.24932510595860968,
#  'precision': 0.4819074800756381,
#  'recall': 0.22136521395242376}
