# %%
# !nvidia-smi
# Out:
# Sat Jan 23 06:50:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

# %% [markdown]
# # Data preparation

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/data')

# %%
# %run data_prepare_new.ipynb
# Out:
# Cloning into 'JAAD'...
# remote: Enumerating objects: 355, done.
# remote: Counting objects: 100% (355/355), done.
# remote: Compressing objects: 100% (322/322), done.
# remote: Total 5786 (delta 326), reused 39 (delta 33), pack-reused 5431
# Receiving objects: 100% (5786/5786), 39.50 MiB | 6.97 MiB/s, done.
# Resolving deltas: 100% (5145/5145), done.
# Downloading...
# From: https://drive.google.com/uc?id=1ZwVzmXYlvaD9ifqTU6TKfKQSGkLNauLQ
# To: /content/videos.rar
# 1.07GB [00:12, 84.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1d9hAOhpLO9Cm59szoG4F7agT05L_c5ky
# To: /content/jaad_database_resized.pkl
# 65.0MB [00:00, 140MB/s]
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from videos.rar
#
# Creating    JAAD/videos                                               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    JAAD/videos/video_0001                                    OK
# Creating    JAAD/videos/video_0002                                    OK
# Creating    JAAD/videos/video_0003                                    OK
# Creating    JAAD/videos/video_0004                                    OK
# Creating    JAAD/videos/video_0005                                    OK
# Creating    JAAD/videos/video_0006                                    OK
# Creating    JAAD/videos/video_0007                                    OK
# Creating    JAAD/videos/video_0008                                    OK
# Creating    JAAD/videos/video_0009                                    OK
# Creating    JAAD/videos/video_0010                                    OK
# Creating    JAAD/videos/video_0011                                    OK
# Creating    JAAD/videos/video_0012                                    OK
# Creating    JAAD/videos/video_0013                                    OK
# Creating    JAAD/videos/video_0014                                    OK
# Creating    JAAD/videos/video_0015                                    OK
# Creating    JAAD/videos/video_0016                                    OK
# Creating    JAAD/videos/video_0017                                    OK
# Creating    JAAD/videos/video_0018                                    OK
# Creating    JAAD/videos/video_0019                                    OK
# Creating    JAAD/videos/video_0020                                    OK
# Creating    JAAD/videos/video_0021                                    OK
# Creating    JAAD/videos/video_0022                                    OK
# Creating    JAAD/videos/video_0023                                    OK
# Creating    JAAD/videos/video_0024                                    OK
# Creating    JAAD/videos/video_0025                                    OK
# Creating    JAAD/videos/video_0026                                    OK
# Creating    JAAD/videos/video_0027                                    OK
# Creating    JAAD/videos/video_0028                                    OK
# Creating    JAAD/videos/video_0029                                    OK
# Creating    JAAD/videos/video_0030                                    OK
# Creating    JAAD/videos/video_0031                                    OK
# Creating    JAAD/videos/video_0032                                    OK
# Creating    JAAD/videos/video_0033                                    OK
# Creating    JAAD/videos/video_0034                                    OK
# Creating    JAAD/videos/video_0035                                    OK
# Creating    JAAD/videos/video_0036                                    OK
# Creating    JAAD/videos/video_0037                                    OK
# Creating    JAAD/videos/video_0038                                    OK
# Creating    JAAD/videos/video_0039                                    OK
# Creating    JAAD/videos/video_0040                                    OK
# Creating    JAAD/videos/video_0041                                    OK
# Creating    JAAD/videos/video_0042                                    OK
# Creating    JAAD/videos/video_0043                                    OK
# Creating    JAAD/videos/video_0044                                    OK
# Creating    JAAD/videos/video_0045                                    OK
# Creating    JAAD/videos/video_0046                                    OK
# Creating    JAAD/videos/video_0047                                    OK
# Creating    JAAD/videos/video_0048                                    OK
# Creating    JAAD/videos/video_0049                                    OK
# Creating    JAAD/videos/video_0050                                    OK
# Creating    JAAD/videos/video_0051                                    OK
# Creating    JAAD/videos/video_0052                                    OK
# Creating    JAAD/videos/video_0053                                    OK
# Creating    JAAD/videos/video_0054                                    OK
# Creating    JAAD/videos/video_0055                                    OK
# Creating    JAAD/videos/video_0056                                    OK
# Creating    JAAD/videos/video_0057                                    OK
# Creating    JAAD/videos/video_0058                                    OK
# Creating    JAAD/videos/video_0059                                    OK
# Creating    JAAD/videos/video_0060                                    OK
# Creating    JAAD/videos/video_0061                                    OK
# Creating    JAAD/videos/video_0062                                    OK
# Creating    JAAD/videos/video_0063                                    OK
# Creating    JAAD/videos/video_0064                                    OK
# Creating    JAAD/videos/video_0065                                    OK
# Creating    JAAD/videos/video_0066                                    OK
# Creating    JAAD/videos/video_0067                                    OK
# Creating    JAAD/videos/video_0068                                    OK
# Creating    JAAD/videos/video_0069                                    OK
# Creating    JAAD/videos/video_0070                                    OK
# Creating    JAAD/videos/video_0071                                    OK
# Creating    JAAD/videos/video_0072                                    OK
# Creating    JAAD/videos/video_0073                                    OK
# Creating    JAAD/videos/video_0074                                    OK
# Creating    JAAD/videos/video_0075                                    OK
# Creating    JAAD/videos/video_0076                                    OK
# Creating    JAAD/videos/video_0077                                    OK
# Creating    JAAD/videos/video_0078                                    OK
# Creating    JAAD/videos/video_0079                                    OK
# Creating    JAAD/videos/video_0080                                    OK
# Creating    JAAD/videos/video_0081                                    OK
# Creating    JAAD/videos/video_0082                                    OK
# Creating    JAAD/videos/video_0083                                    OK
# Creating    JAAD/videos/video_0084                                    OK
# Creating    JAAD/videos/video_0085                                    OK
# Creating    JAAD/videos/video_0086                                    OK
# Creating    JAAD/videos/video_0087                                    OK
# Creating    JAAD/videos/video_0088                                    OK
# Creating    JAAD/videos/video_0089                                    OK
# Creating    JAAD/videos/video_0090                                    OK
# Creating    JAAD/videos/video_0091                                    OK
# Creating    JAAD/videos/video_0092                                    OK
# Creating    JAAD/videos/video_0093                                    OK
# Creating    JAAD/videos/video_0094                                    OK
# Creating    JAAD/videos/video_0095                                    OK
# Creating    JAAD/videos/video_0096                                    OK
# Creating    JAAD/videos/video_0097                                    OK
# Creating    JAAD/videos/video_0098                                    OK
# Creating    JAAD/videos/video_0099                                    OK
# Creating    JAAD/videos/video_0100                                    OK
# Creating    JAAD/videos/video_0101                                    OK
# Creating    JAAD/videos/video_0102                                    OK
# Creating    JAAD/videos/video_0103                                    OK
# Creating    JAAD/videos/video_0104                                    OK
# Creating    JAAD/videos/video_0105                                    OK
# Creating    JAAD/videos/video_0106                                    OK
# Creating    JAAD/videos/video_0107                                    OK
# Creating    JAAD/videos/video_0108                                    OK
# Creating    JAAD/videos/video_0109                                    OK
# Creating    JAAD/videos/video_0110                                    OK
# Creating    JAAD/videos/video_0111                                    OK
# Creating    JAAD/videos/video_0112                                    OK
# Creating    JAAD/videos/video_0113                                    OK
# Creating    JAAD/videos/video_0114                                    OK
# Creating    JAAD/videos/video_0115                                    OK
# Creating    JAAD/videos/video_0116                                    OK
# Creating    JAAD/videos/video_0117                                    OK
# Creating    JAAD/videos/video_0118                                    OK
# Creating    JAAD/videos/video_0119                                    OK
# Creating    JAAD/videos/video_0120                                    OK
# Creating    JAAD/videos/video_0121                                    OK
# Creating    JAAD/videos/video_0122                                    OK
# Creating    JAAD/videos/video_0123                                    OK
# Creating    JAAD/videos/video_0124                                    OK
# Creating    JAAD/videos/video_0125                                    OK
# Creating    JAAD/videos/video_0126                                    OK
# Creating    JAAD/videos/video_0127                                    OK
# Creating    JAAD/videos/video_0128                                    OK
# Creating    JAAD/videos/video_0129                                    OK
# Creating    JAAD/videos/video_0130                                    OK
# Creating    JAAD/videos/video_0131                                    OK
# Creating    JAAD/videos/video_0132                                    OK
# Creating    JAAD/videos/video_0133                                    OK
# Creating    JAAD/videos/video_0134                                    OK
# Creating    JAAD/videos/video_0135                                    OK
# Creating    JAAD/videos/video_0136                                    OK
# Creating    JAAD/videos/video_0137                                    OK
# Creating    JAAD/videos/video_0138                                    OK
# Creating    JAAD/videos/video_0139                                    OK
# Creating    JAAD/videos/video_0140                                    OK
# Creating    JAAD/videos/video_0141                                    OK
# Creating    JAAD/videos/video_0142                                    OK
# Creating    JAAD/videos/video_0143                                    OK
# Creating    JAAD/videos/video_0144                                    OK
# Creating    JAAD/videos/video_0145                                    OK
# Creating    JAAD/videos/video_0146                                    OK
# Creating    JAAD/videos/video_0147                                    OK
# Creating    JAAD/videos/video_0148                                    OK
# Creating    JAAD/videos/video_0149                                    OK
# Creating    JAAD/videos/video_0150                                    OK
# Creating    JAAD/videos/video_0151                                    OK
# Creating    JAAD/videos/video_0152                                    OK
# Creating    JAAD/videos/video_0153                                    OK
# Creating    JAAD/videos/video_0154                                    OK
# Creating    JAAD/videos/video_0155                                    OK
# Creating    JAAD/videos/video_0156                                    OK
# Creating    JAAD/videos/video_0157                                    OK
# Creating    JAAD/videos/video_0158                                    OK
# Creating    JAAD/videos/video_0159                                    OK
# Creating    JAAD/videos/video_0160                                    OK
# Creating    JAAD/videos/video_0161                                    OK
# Creating    JAAD/videos/video_0162                                    OK
# Creating    JAAD/videos/video_0163                                    OK
# Creating    JAAD/videos/video_0164                                    OK
# Creating    JAAD/videos/video_0165                                    OK
# Creating    JAAD/videos/video_0166                                    OK
# Creating    JAAD/videos/video_0167                                    OK
# Creating    JAAD/videos/video_0168                                    OK
# Creating    JAAD/videos/video_0169                                    OK
# Creating    JAAD/videos/video_0170                                    OK
# Creating    JAAD/videos/video_0171                                    OK
# Creating    JAAD/videos/video_0172                                    OK
# Creating    JAAD/videos/video_0173                                    OK
# Creating    JAAD/videos/video_0174                                    OK
# Creating    JAAD/videos/video_0175                                    OK
# Creating    JAAD/videos/video_0176                                    OK
# Creating    JAAD/videos/video_0177                                    OK
# Creating    JAAD/videos/video_0178                                    OK
# Creating    JAAD/videos/video_0179                                    OK
# Creating    JAAD/videos/video_0180                                    OK
# Creating    JAAD/videos/video_0181                                    OK
# Creating    JAAD/videos/video_0182                                    OK
# Creating    JAAD/videos/video_0183                                    OK
# Creating    JAAD/videos/video_0184                                    OK
# Creating    JAAD/videos/video_0185                                    OK
# Creating    JAAD/videos/video_0186                                    OK
# Creating    JAAD/videos/video_0187                                    OK
# Creating    JAAD/videos/video_0188                                    OK
# Creating    JAAD/videos/video_0189                                    OK
# Creating    JAAD/videos/video_0190                                    OK
# Creating    JAAD/videos/video_0191                                    OK
# Creating    JAAD/videos/video_0192                                    OK
# Creating    JAAD/videos/video_0193                                    OK
# Creating    JAAD/videos/video_0194                                    OK
# Creating    JAAD/videos/video_0195                                    OK
# Creating    JAAD/videos/video_0196                                    OK
# Creating    JAAD/videos/video_0197                                    OK
# Creating    JAAD/videos/video_0198                                    OK
# Creating    JAAD/videos/video_0199                                    OK
# Creating    JAAD/videos/video_0200                                    OK
# Creating    JAAD/videos/video_0201                                    OK
# Creating    JAAD/videos/video_0202                                    OK
# Creating    JAAD/videos/video_0203                                    OK
# Creating    JAAD/videos/video_0204                                    OK
# Creating    JAAD/videos/video_0205                                    OK
# Creating    JAAD/videos/video_0206                                    OK
# Creating    JAAD/videos/video_0207                                    OK
# Creating    JAAD/videos/video_0208                                    OK
# Creating    JAAD/videos/video_0209                                    OK
# Creating    JAAD/videos/video_0210                                    OK
# Creating    JAAD/videos/video_0211                                    OK
# Creating    JAAD/videos/video_0212                                    OK
# Creating    JAAD/videos/video_0213                                    OK
# Creating    JAAD/videos/video_0214                                    OK
# Creating    JAAD/videos/video_0215                                    OK
# Creating    JAAD/videos/video_0216                                    OK
# Creating    JAAD/videos/video_0217                                    OK
# Creating    JAAD/videos/video_0218                                    OK
# Creating    JAAD/videos/video_0219                                    OK
# Creating    JAAD/videos/video_0220                                    OK
# Creating    JAAD/videos/video_0221                                    OK
# Creating    JAAD/videos/video_0222                                    OK
# Creating    JAAD/videos/video_0223                                    OK
# Creating    JAAD/videos/video_0224                                    OK
# Creating    JAAD/videos/video_0225                                    OK
# Creating    JAAD/videos/video_0226                                    OK
# Creating    JAAD/videos/video_0227                                    OK
# Creating    JAAD/videos/video_0228                                    OK
# Creating    JAAD/videos/video_0229                                    OK
# Creating    JAAD/videos/video_0230                                    OK
# Creating    JAAD/videos/video_0231                                    OK
# Creating    JAAD/videos/video_0232                                    OK
# Creating    JAAD/videos/video_0233                                    OK
# Creating    JAAD/videos/video_0234                                    OK
# Creating    JAAD/videos/video_0235                                    OK
# Creating    JAAD/videos/video_0236                                    OK
# Creating    JAAD/videos/video_0237                                    OK
# Creating    JAAD/videos/video_0238                                    OK
# Creating    JAAD/videos/video_0239                                    OK
# Creating    JAAD/videos/video_0240                                    OK
# Creating    JAAD/videos/video_0241                                    OK
# Creating    JAAD/videos/video_0242                                    OK
# Creating    JAAD/videos/video_0243                                    OK
# Creating    JAAD/videos/video_0244                                    OK
# Creating    JAAD/videos/video_0245                                    OK
# Creating    JAAD/videos/video_0246                                    OK
# Creating    JAAD/videos/video_0247                                    OK
# Creating    JAAD/videos/video_0248                                    OK
# Creating    JAAD/videos/video_0249                                    OK
# Creating    JAAD/videos/video_0250                                    OK
# Creating    JAAD/videos/video_0251                                    OK
# Creating    JAAD/videos/video_0252                                    OK
# Creating    JAAD/videos/video_0253                                    OK
# Creating    JAAD/videos/video_0254                                    OK
# Creating    JAAD/videos/video_0255                                    OK
# Creating    JAAD/videos/video_0256                                    OK
# Creating    JAAD/videos/video_0257                                    OK
# Creating    JAAD/videos/video_0258                                    OK
# Creating    JAAD/videos/video_0259                                    OK
# Creating    JAAD/videos/video_0260                                    OK
# Creating    JAAD/videos/video_0261                                    OK
# Creating    JAAD/videos/video_0262                                    OK
# Creating    JAAD/videos/video_0263                                    OK
# Creating    JAAD/videos/video_0264                                    OK
# Creating    JAAD/videos/video_0265                                    OK
# Creating    JAAD/videos/video_0266                                    OK
# Creating    JAAD/videos/video_0267                                    OK
# Creating    JAAD/videos/video_0268                                    OK
# Creating    JAAD/videos/video_0269                                    OK
# Creating    JAAD/videos/video_0270                                    OK
# Creating    JAAD/videos/video_0271                                    OK
# Creating    JAAD/videos/video_0272                                    OK
# Creating    JAAD/videos/video_0273                                    OK
# Creating    JAAD/videos/video_0274                                    OK
# Creating    JAAD/videos/video_0275                                    OK
# Creating    JAAD/videos/video_0276                                    OK
# Creating    JAAD/videos/video_0277                                    OK
# Creating    JAAD/videos/video_0278                                    OK
# Creating    JAAD/videos/video_0279                                    OK
# Creating    JAAD/videos/video_0280                                    OK
# Creating    JAAD/videos/video_0281                                    OK
# Creating    JAAD/videos/video_0282                                    OK
# Creating    JAAD/videos/video_0283                                    OK
# Creating    JAAD/videos/video_0284                                    OK
# Creating    JAAD/videos/video_0285                                    OK
# Creating    JAAD/videos/video_0286                                    OK
# Creating    JAAD/videos/video_0287                                    OK
# Creating    JAAD/videos/video_0288                                    OK
# Creating    JAAD/videos/video_0289                                    OK
# Creating    JAAD/videos/video_0290                                    OK
# Creating    JAAD/videos/video_0291                                    OK
# Creating    JAAD/videos/video_0292                                    OK
# Creating    JAAD/videos/video_0293                                    OK
# Creating    JAAD/videos/video_0294                                    OK
# Creating    JAAD/videos/video_0295                                    OK
# Creating    JAAD/videos/video_0296                                    OK
# Creating    JAAD/videos/video_0297                                    OK
# Creating    JAAD/videos/video_0298                                    OK
# Creating    JAAD/videos/video_0299                                    OK
# Creating    JAAD/videos/video_0300                                    OK
# Creating    JAAD/videos/video_0301                                    OK
# Creating    JAAD/videos/video_0302                                    OK
# Creating    JAAD/videos/video_0303                                    OK
# Creating    JAAD/videos/video_0304                                    OK
# Creating    JAAD/videos/video_0305                                    OK
# Creating    JAAD/videos/video_0306                                    OK
# Creating    JAAD/videos/video_0307                                    OK
# Creating    JAAD/videos/video_0308                                    OK
# Creating    JAAD/videos/video_0309                                    OK
# Creating    JAAD/videos/video_0310                                    OK
# Creating    JAAD/videos/video_0311                                    OK
# Creating    JAAD/videos/video_0312                                    OK
# Creating    JAAD/videos/video_0313                                    OK
# Creating    JAAD/videos/video_0314                                    OK
# Creating    JAAD/videos/video_0315                                    OK
# Creating    JAAD/videos/video_0316                                    OK
# Creating    JAAD/videos/video_0317                                    OK
# Creating    JAAD/videos/video_0318                                    OK
# Creating    JAAD/videos/video_0319                                    OK
# Creating    JAAD/videos/video_0320                                    OK
# Creating    JAAD/videos/video_0321                                    OK
# Creating    JAAD/videos/video_0322                                    OK
# Creating    JAAD/videos/video_0323                                    OK
# Creating    JAAD/videos/video_0324                                    OK
# Creating    JAAD/videos/video_0325                                    OK
# Creating    JAAD/videos/video_0326                                    OK
# Creating    JAAD/videos/video_0327                                    OK
# Creating    JAAD/videos/video_0328                                    OK
# Creating    JAAD/videos/video_0329                                    OK
# Creating    JAAD/videos/video_0330                                    OK
# Creating    JAAD/videos/video_0331                                    OK
# Creating    JAAD/videos/video_0332                                    OK
# Creating    JAAD/videos/video_0333                                    OK
# Creating    JAAD/videos/video_0334                                    OK
# Creating    JAAD/videos/video_0335                                    OK
# Creating    JAAD/videos/video_0336                                    OK
# Creating    JAAD/videos/video_0337                                    OK
# Creating    JAAD/videos/video_0338                                    OK
# Creating    JAAD/videos/video_0339                                    OK
# Creating    JAAD/videos/video_0340                                    OK
# Creating    JAAD/videos/video_0341                                    OK
# Creating    JAAD/videos/video_0342                                    OK
# Creating    JAAD/videos/video_0343                                    OK
# Creating    JAAD/videos/video_0344                                    OK
# Creating    JAAD/videos/video_0345                                    OK
# Creating    JAAD/videos/video_0346                                    OK
# All OK
# /content/JAAD
# video_0001
# video_0002
# video_0003
# video_0004
# video_0005
# video_0006
# video_0007
# video_0008
# video_0009
# video_0010
# video_0011
# video_0012
# video_0013
# video_0014
# video_0015
# video_0016
# video_0017
# video_0018
# video_0019
# video_0020
# video_0021
# video_0022
# video_0023
# video_0024
# video_0025
# video_0026
# video_0027
# video_0028
# video_0029
# video_0030
# video_0031
# video_0032
# video_0033
# video_0034
# video_0035
# video_0036
# video_0037
# video_0038
# video_0039
# video_0040
# video_0041
# video_0042
# video_0043
# video_0044
# video_0045
# video_0046
# video_0047
# video_0048
# video_0049
# video_0050
# video_0051
# video_0052
# video_0053
# video_0054
# video_0055
# video_0056
# video_0057
# video_0058
# video_0059
# video_0060
# video_0061
# video_0062
# video_0063
# video_0064
# video_0065
# video_0066
# video_0067
# video_0068
# video_0069
# video_0070
# video_0071
# video_0072
# video_0073
# video_0074
# video_0075
# video_0076
# video_0077
# video_0078
# video_0079
# video_0080
# video_0081
# video_0082
# video_0083
# video_0084
# video_0085
# video_0086
# video_0087
# video_0088
# video_0089
# video_0090
# video_0091
# video_0092
# video_0093
# video_0094
# video_0095
# video_0096
# video_0097
# video_0098
# video_0099
# video_0100
# video_0101
# video_0102
# video_0103
# video_0104
# video_0105
# video_0106
# video_0107
# video_0108
# video_0109
# video_0110
# video_0111
# video_0112
# video_0113
# video_0114
# video_0115
# video_0116
# video_0117
# video_0118
# video_0119
# video_0120
# video_0121
# video_0122
# video_0123
# video_0124
# video_0125
# video_0126
# video_0127
# video_0128
# video_0129
# video_0130
# video_0131
# video_0132
# video_0133
# video_0134
# video_0135
# video_0136
# video_0137
# video_0138
# video_0139
# video_0140
# video_0141
# video_0142
# video_0143
# video_0144
# video_0145
# video_0146
# video_0147
# video_0148
# video_0149
# video_0150
# video_0151
# video_0152
# video_0153
# video_0154
# video_0155
# video_0156
# video_0157
# video_0158
# video_0159
# video_0160
# video_0161
# video_0162
# video_0163
# video_0164
# video_0165
# video_0166
# video_0167
# video_0168
# video_0169
# video_0170
# video_0171
# video_0172
# video_0173
# video_0174
# video_0175
# video_0176
# video_0177
# video_0178
# video_0179
# video_0180
# video_0181
# video_0182
# video_0183
# video_0184
# video_0185
# video_0186
# video_0187
# video_0188
# video_0189
# video_0190
# video_0191
# video_0192
# video_0193
# video_0194
# video_0195
# video_0196
# video_0197
# video_0198
# video_0199
# video_0200
# video_0201
# video_0202
# video_0203
# video_0204
# video_0205
# video_0206
# video_0207
# video_0208
# video_0209
# video_0210
# video_0211
# video_0212
# video_0213
# video_0214
# video_0215
# video_0216
# video_0217
# video_0218
# video_0219
# video_0220
# video_0221
# video_0222
# video_0223
# video_0224
# video_0225
# video_0226
# video_0227
# video_0228
# video_0229
# video_0230
# video_0231
# video_0232
# video_0233
# video_0234
# video_0235
# video_0236
# video_0237
# video_0238
# video_0239
# video_0240
# video_0241
# video_0242
# video_0243
# video_0244
# video_0245
# video_0246
# video_0247
# video_0248
# video_0249
# video_0250
# video_0251
# video_0252
# video_0253
# video_0254
# video_0255
# video_0256
# video_0257
# video_0258
# video_0259
# video_0260
# video_0261
# video_0262
# video_0263
# video_0264
# video_0265
# video_0266
# video_0267
# video_0268
# video_0269
# video_0270
# video_0271
# video_0272
# video_0273
# video_0274
# video_0275
# video_0276
# video_0277
# video_0278
# video_0279
# video_0280
# video_0281
# video_0282
# video_0283
# video_0284
# video_0285
# video_0286
# video_0287
# video_0288
# video_0289
# video_0290
# video_0291
# video_0292
# video_0293
# video_0294
# video_0295
# video_0296
# video_0297
# video_0298
# video_0299
# video_0300
# video_0301
# video_0302
# video_0303
# video_0304
# video_0305
# video_0306
# video_0307
# video_0308
# video_0309
# video_0310
# video_0311
# video_0312
# video_0313
# video_0314
# video_0315
# video_0316
# video_0317
# video_0318
# video_0319
# video_0320
# video_0321
# video_0322
# video_0323
# video_0324
# video_0325
# video_0326
# video_0327
# video_0328
# video_0329
# video_0330
# video_0331
# video_0332
# video_0333
# video_0334
# video_0335
# video_0336
# video_0337
# video_0338
# video_0339
# video_0340
# video_0341
# video_0342
# video_0343
# video_0344
# video_0345
# video_0346
# video_0001
# /content/JAAD/rgb-images/video_0001
#
#
# video_0001
# /content/JAAD/rgb-images/video_0001
#
#
# video_0002
# /content/JAAD/rgb-images/video_0002
#
#
# video_0002
# /content/JAAD/rgb-images/video_0002
#
#
# video_0003
# /content/JAAD/rgb-images/video_0003
#
#
# video_0003
# /content/JAAD/rgb-images/video_0003
#
#
# video_0004
# /content/JAAD/rgb-images/video_0004
#
#
# video_0004
# /content/JAAD/rgb-images/video_0004
#
#
# video_0005
# /content/JAAD/rgb-images/video_0005
#
#
# video_0005
# /content/JAAD/rgb-images/video_0005
#
#
# video_0006
# /content/JAAD/rgb-images/video_0006
#
#
# video_0006
# /content/JAAD/rgb-images/video_0006
#
#
# video_0007
# /content/JAAD/rgb-images/video_0007
#
#
# video_0007
# /content/JAAD/rgb-images/video_0007
#
#
# video_0008
# /content/JAAD/rgb-images/video_0008
#
#
# video_0008
# /content/JAAD/rgb-images/video_0008
#
#
# video_0009
# /content/JAAD/rgb-images/video_0009
#
#
# video_0009
# /content/JAAD/rgb-images/video_0009
#
#
# video_0010
# /content/JAAD/rgb-images/video_0010
#
#
# video_0010
# /content/JAAD/rgb-images/video_0010
#
#
# video_0011
# /content/JAAD/rgb-images/video_0011
#
#
# video_0011
# /content/JAAD/rgb-images/video_0011
#
#
# video_0012
# /content/JAAD/rgb-images/video_0012
#
#
# video_0012
# /content/JAAD/rgb-images/video_0012
#
#
# video_0013
# /content/JAAD/rgb-images/video_0013
#
#
# video_0013
# /content/JAAD/rgb-images/video_0013
#
#
# video_0014
# /content/JAAD/rgb-images/video_0014
#
#
# video_0014
# /content/JAAD/rgb-images/video_0014
#
#
# video_0015
# /content/JAAD/rgb-images/video_0015
#
#
# video_0015
# /content/JAAD/rgb-images/video_0015
#
#
# video_0016
# /content/JAAD/rgb-images/video_0016
#
#
# video_0016
# /content/JAAD/rgb-images/video_0016
#
#
# video_0017
# /content/JAAD/rgb-images/video_0017
#
#
# video_0017
# /content/JAAD/rgb-images/video_0017
#
#
# video_0018
# /content/JAAD/rgb-images/video_0018
#
#
# video_0018
# /content/JAAD/rgb-images/video_0018
#
#
# video_0019
# /content/JAAD/rgb-images/video_0019
#
#
# video_0019
# /content/JAAD/rgb-images/video_0019
#
#
# video_0020
# /content/JAAD/rgb-images/video_0020
#
#
# video_0020
# /content/JAAD/rgb-images/video_0020
#
#
# video_0021
# /content/JAAD/rgb-images/video_0021
#
#
# video_0021
# /content/JAAD/rgb-images/video_0021
#
#
# video_0022
# /content/JAAD/rgb-images/video_0022
#
#
# video_0022
# /content/JAAD/rgb-images/video_0022
#
#
# video_0023
# /content/JAAD/rgb-images/video_0023
#
#
# video_0023
# /content/JAAD/rgb-images/video_0023
#
#
# video_0024
# /content/JAAD/rgb-images/video_0024
#
#
# video_0024
# /content/JAAD/rgb-images/video_0024
#
#
# video_0025
# /content/JAAD/rgb-images/video_0025
#
#
# video_0025
# /content/JAAD/rgb-images/video_0025
#
#
# video_0026
# /content/JAAD/rgb-images/video_0026
#
#
# video_0026
# /content/JAAD/rgb-images/video_0026
#
#
# video_0027
# /content/JAAD/rgb-images/video_0027
#
#
# video_0027
# /content/JAAD/rgb-images/video_0027
#
#
# video_0028
# /content/JAAD/rgb-images/video_0028
#
#
# video_0028
# /content/JAAD/rgb-images/video_0028
#
#
# video_0029
# /content/JAAD/rgb-images/video_0029
#
#
# video_0029
# /content/JAAD/rgb-images/video_0029
#
#
# video_0030
# /content/JAAD/rgb-images/video_0030
#
#
# video_0030
# /content/JAAD/rgb-images/video_0030
#
#
# video_0031
# /content/JAAD/rgb-images/video_0031
#
#
# video_0031
# /content/JAAD/rgb-images/video_0031
#
#
# video_0032
# /content/JAAD/rgb-images/video_0032
#
#
# video_0032
# /content/JAAD/rgb-images/video_0032
#
#
# video_0033
# /content/JAAD/rgb-images/video_0033
#
#
# video_0033
# /content/JAAD/rgb-images/video_0033
#
#
# video_0034
# /content/JAAD/rgb-images/video_0034
#
#
# video_0034
# /content/JAAD/rgb-images/video_0034
#
#
# video_0035
# /content/JAAD/rgb-images/video_0035
#
#
# video_0035
# /content/JAAD/rgb-images/video_0035
#
#
# video_0036
# /content/JAAD/rgb-images/video_0036
#
#
# video_0036
# /content/JAAD/rgb-images/video_0036
#
#
# video_0037
# /content/JAAD/rgb-images/video_0037
#
#
# video_0037
# /content/JAAD/rgb-images/video_0037
#
#
# video_0038
# /content/JAAD/rgb-images/video_0038
#
#
# video_0038
# /content/JAAD/rgb-images/video_0038
#
#
# video_0039
# /content/JAAD/rgb-images/video_0039
#
#
# video_0039
# /content/JAAD/rgb-images/video_0039
#
#
# video_0040
# /content/JAAD/rgb-images/video_0040
#
#
# video_0040
# /content/JAAD/rgb-images/video_0040
#
#
# video_0041
# /content/JAAD/rgb-images/video_0041
#
#
# video_0041
# /content/JAAD/rgb-images/video_0041
#
#
# video_0042
# /content/JAAD/rgb-images/video_0042
#
#
# video_0042
# /content/JAAD/rgb-images/video_0042
#
#
# video_0043
# /content/JAAD/rgb-images/video_0043
#
#
# video_0043
# /content/JAAD/rgb-images/video_0043
#
#
# video_0044
# /content/JAAD/rgb-images/video_0044
#
#
# video_0044
# /content/JAAD/rgb-images/video_0044
#
#
# video_0045
# /content/JAAD/rgb-images/video_0045
#
#
# video_0045
# /content/JAAD/rgb-images/video_0045
#
#
# video_0046
# /content/JAAD/rgb-images/video_0046
#
#
# video_0046
# /content/JAAD/rgb-images/video_0046
#
#
# video_0047
# /content/JAAD/rgb-images/video_0047
#
#
# video_0047
# /content/JAAD/rgb-images/video_0047
#
#
# video_0048
# /content/JAAD/rgb-images/video_0048
#
#
# video_0048
# /content/JAAD/rgb-images/video_0048
#
#
# video_0049
# /content/JAAD/rgb-images/video_0049
#
#
# video_0049
# /content/JAAD/rgb-images/video_0049
#
#
# video_0050
# /content/JAAD/rgb-images/video_0050
#
#
# video_0050
# /content/JAAD/rgb-images/video_0050
#
#
# video_0051
# /content/JAAD/rgb-images/video_0051
#
#
# video_0051
# /content/JAAD/rgb-images/video_0051
#
#
# video_0052
# /content/JAAD/rgb-images/video_0052
#
#
# video_0052
# /content/JAAD/rgb-images/video_0052
#
#
# video_0053
# /content/JAAD/rgb-images/video_0053
#
#
# video_0053
# /content/JAAD/rgb-images/video_0053
#
#
# video_0054
# /content/JAAD/rgb-images/video_0054
#
#
# video_0054
# /content/JAAD/rgb-images/video_0054
#
#
# video_0055
# /content/JAAD/rgb-images/video_0055
#
#
# video_0055
# /content/JAAD/rgb-images/video_0055
#
#
# video_0056
# /content/JAAD/rgb-images/video_0056
#
#
# video_0056
# /content/JAAD/rgb-images/video_0056
#
#
# video_0057
# /content/JAAD/rgb-images/video_0057
#
#
# video_0057
# /content/JAAD/rgb-images/video_0057
#
#
# video_0058
# /content/JAAD/rgb-images/video_0058
#
#
# video_0058
# /content/JAAD/rgb-images/video_0058
#
#
# video_0059
# /content/JAAD/rgb-images/video_0059
#
#
# video_0059
# /content/JAAD/rgb-images/video_0059
#
#
# video_0060
# /content/JAAD/rgb-images/video_0060
#
#
# video_0060
# /content/JAAD/rgb-images/video_0060
#
#
# video_0061
# /content/JAAD/rgb-images/video_0061
#
#
# video_0061
# /content/JAAD/rgb-images/video_0061
#
#
# video_0062
# /content/JAAD/rgb-images/video_0062
#
#
# video_0062
# /content/JAAD/rgb-images/video_0062
#
#
# video_0063
# /content/JAAD/rgb-images/video_0063
#
#
# video_0063
# /content/JAAD/rgb-images/video_0063
#
#
# video_0064
# /content/JAAD/rgb-images/video_0064
#
#
# video_0064
# /content/JAAD/rgb-images/video_0064
#
#
# video_0065
# /content/JAAD/rgb-images/video_0065
#
#
# video_0065
# /content/JAAD/rgb-images/video_0065
#
#
# video_0066
# /content/JAAD/rgb-images/video_0066
#
#
# video_0066
# /content/JAAD/rgb-images/video_0066
#
#
# video_0067
# /content/JAAD/rgb-images/video_0067
#
#
# video_0067
# /content/JAAD/rgb-images/video_0067
#
#
# video_0068
# /content/JAAD/rgb-images/video_0068
#
#
# video_0068
# /content/JAAD/rgb-images/video_0068
#
#
# video_0069
# /content/JAAD/rgb-images/video_0069
#
#
# video_0069
# /content/JAAD/rgb-images/video_0069
#
#
# video_0070
# /content/JAAD/rgb-images/video_0070
#
#
# video_0070
# /content/JAAD/rgb-images/video_0070
#
#
# video_0071
# /content/JAAD/rgb-images/video_0071
#
#
# video_0071
# /content/JAAD/rgb-images/video_0071
#
#
# video_0072
# /content/JAAD/rgb-images/video_0072
#
#
# video_0072
# /content/JAAD/rgb-images/video_0072
#
#
# video_0073
# /content/JAAD/rgb-images/video_0073
#
#
# video_0073
# /content/JAAD/rgb-images/video_0073
#
#
# video_0074
# /content/JAAD/rgb-images/video_0074
#
#
# video_0074
# /content/JAAD/rgb-images/video_0074
#
#
# video_0075
# /content/JAAD/rgb-images/video_0075
#
#
# video_0075
# /content/JAAD/rgb-images/video_0075
#
#
# video_0076
# /content/JAAD/rgb-images/video_0076
#
#
# video_0076
# /content/JAAD/rgb-images/video_0076
#
#
# video_0077
# /content/JAAD/rgb-images/video_0077
#
#
# video_0077
# /content/JAAD/rgb-images/video_0077
#
#
# video_0078
# /content/JAAD/rgb-images/video_0078
#
#
# video_0078
# /content/JAAD/rgb-images/video_0078
#
#
# video_0079
# /content/JAAD/rgb-images/video_0079
#
#
# video_0079
# /content/JAAD/rgb-images/video_0079
#
#
# video_0080
# /content/JAAD/rgb-images/video_0080
#
#
# video_0080
# /content/JAAD/rgb-images/video_0080
#
#
# video_0081
# /content/JAAD/rgb-images/video_0081
#
#
# video_0081
# /content/JAAD/rgb-images/video_0081
#
#
# video_0082
# /content/JAAD/rgb-images/video_0082
#
#
# video_0082
# /content/JAAD/rgb-images/video_0082
#
#
# video_0083
# /content/JAAD/rgb-images/video_0083
#
#
# video_0083
# /content/JAAD/rgb-images/video_0083
#
#
# video_0084
# /content/JAAD/rgb-images/video_0084
#
#
# video_0084
# /content/JAAD/rgb-images/video_0084
#
#
# video_0085
# /content/JAAD/rgb-images/video_0085
#
#
# video_0085
# /content/JAAD/rgb-images/video_0085
#
#
# video_0086
# /content/JAAD/rgb-images/video_0086
#
#
# video_0086
# /content/JAAD/rgb-images/video_0086
#
#
# video_0087
# /content/JAAD/rgb-images/video_0087
#
#
# video_0087
# /content/JAAD/rgb-images/video_0087
#
#
# video_0088
# /content/JAAD/rgb-images/video_0088
#
#
# video_0088
# /content/JAAD/rgb-images/video_0088
#
#
# video_0089
# /content/JAAD/rgb-images/video_0089
#
#
# video_0089
# /content/JAAD/rgb-images/video_0089
#
#
# video_0090
# /content/JAAD/rgb-images/video_0090
#
#
# video_0090
# /content/JAAD/rgb-images/video_0090
#
#
# video_0091
# /content/JAAD/rgb-images/video_0091
#
#
# video_0091
# /content/JAAD/rgb-images/video_0091
#
#
# video_0092
# /content/JAAD/rgb-images/video_0092
#
#
# video_0092
# /content/JAAD/rgb-images/video_0092
#
#
# video_0093
# /content/JAAD/rgb-images/video_0093
#
#
# video_0093
# /content/JAAD/rgb-images/video_0093
#
#
# video_0094
# /content/JAAD/rgb-images/video_0094
#
#
# video_0094
# /content/JAAD/rgb-images/video_0094
#
#
# video_0095
# /content/JAAD/rgb-images/video_0095
#
#
# video_0095
# /content/JAAD/rgb-images/video_0095
#
#
# video_0096
# /content/JAAD/rgb-images/video_0096
#
#
# video_0096
# /content/JAAD/rgb-images/video_0096
#
#
# video_0097
# /content/JAAD/rgb-images/video_0097
#
#
# video_0097
# /content/JAAD/rgb-images/video_0097
#
#
# video_0098
# /content/JAAD/rgb-images/video_0098
#
#
# video_0098
# /content/JAAD/rgb-images/video_0098
#
#
# video_0099
# /content/JAAD/rgb-images/video_0099
#
#
# video_0099
# /content/JAAD/rgb-images/video_0099
#
#
# video_0100
# /content/JAAD/rgb-images/video_0100
#
#
# video_0100
# /content/JAAD/rgb-images/video_0100
#
#
# video_0101
# /content/JAAD/rgb-images/video_0101
#
#
# video_0101
# /content/JAAD/rgb-images/video_0101
#
#
# video_0102
# /content/JAAD/rgb-images/video_0102
#
#
# video_0102
# /content/JAAD/rgb-images/video_0102
#
#
# video_0103
# /content/JAAD/rgb-images/video_0103
#
#
# video_0103
# /content/JAAD/rgb-images/video_0103
#
#
# video_0104
# /content/JAAD/rgb-images/video_0104
#
#
# video_0104
# /content/JAAD/rgb-images/video_0104
#
#
# video_0105
# /content/JAAD/rgb-images/video_0105
#
#
# video_0105
# /content/JAAD/rgb-images/video_0105
#
#
# video_0106
# /content/JAAD/rgb-images/video_0106
#
#
# video_0106
# /content/JAAD/rgb-images/video_0106
#
#
# video_0107
# /content/JAAD/rgb-images/video_0107
#
#
# video_0107
# /content/JAAD/rgb-images/video_0107
#
#
# video_0108
# /content/JAAD/rgb-images/video_0108
#
#
# video_0108
# /content/JAAD/rgb-images/video_0108
#
#
# video_0109
# /content/JAAD/rgb-images/video_0109
#
#
# video_0109
# /content/JAAD/rgb-images/video_0109
#
#
# video_0110
# /content/JAAD/rgb-images/video_0110
#
#
# video_0110
# /content/JAAD/rgb-images/video_0110
#
#
# video_0111
# /content/JAAD/rgb-images/video_0111
#
#
# video_0111
# /content/JAAD/rgb-images/video_0111
#
#
# video_0112
# /content/JAAD/rgb-images/video_0112
#
#
# video_0112
# /content/JAAD/rgb-images/video_0112
#
#
# video_0113
# /content/JAAD/rgb-images/video_0113
#
#
# video_0113
# /content/JAAD/rgb-images/video_0113
#
#
# video_0114
# /content/JAAD/rgb-images/video_0114
#
#
# video_0114
# /content/JAAD/rgb-images/video_0114
#
#
# video_0115
# /content/JAAD/rgb-images/video_0115
#
#
# video_0115
# /content/JAAD/rgb-images/video_0115
#
#
# video_0116
# /content/JAAD/rgb-images/video_0116
#
#
# video_0116
# /content/JAAD/rgb-images/video_0116
#
#
# video_0117
# /content/JAAD/rgb-images/video_0117
#
#
# video_0117
# /content/JAAD/rgb-images/video_0117
#
#
# video_0118
# /content/JAAD/rgb-images/video_0118
#
#
# video_0118
# /content/JAAD/rgb-images/video_0118
#
#
# video_0119
# /content/JAAD/rgb-images/video_0119
#
#
# video_0119
# /content/JAAD/rgb-images/video_0119
#
#
# video_0120
# /content/JAAD/rgb-images/video_0120
#
#
# video_0120
# /content/JAAD/rgb-images/video_0120
#
#
# video_0121
# /content/JAAD/rgb-images/video_0121
#
#
# video_0121
# /content/JAAD/rgb-images/video_0121
#
#
# video_0122
# /content/JAAD/rgb-images/video_0122
#
#
# video_0122
# /content/JAAD/rgb-images/video_0122
#
#
# video_0123
# /content/JAAD/rgb-images/video_0123
#
#
# video_0123
# /content/JAAD/rgb-images/video_0123
#
#
# video_0124
# /content/JAAD/rgb-images/video_0124
#
#
# video_0124
# /content/JAAD/rgb-images/video_0124
#
#
# video_0125
# /content/JAAD/rgb-images/video_0125
#
#
# video_0125
# /content/JAAD/rgb-images/video_0125
#
#
# video_0126
# /content/JAAD/rgb-images/video_0126
#
#
# video_0126
# /content/JAAD/rgb-images/video_0126
#
#
# video_0127
# /content/JAAD/rgb-images/video_0127
#
#
# video_0127
# /content/JAAD/rgb-images/video_0127
#
#
# video_0128
# /content/JAAD/rgb-images/video_0128
#
#
# video_0128
# /content/JAAD/rgb-images/video_0128
#
#
# video_0129
# /content/JAAD/rgb-images/video_0129
#
#
# video_0129
# /content/JAAD/rgb-images/video_0129
#
#
# video_0130
# /content/JAAD/rgb-images/video_0130
#
#
# video_0130
# /content/JAAD/rgb-images/video_0130
#
#
# video_0131
# /content/JAAD/rgb-images/video_0131
#
#
# video_0131
# /content/JAAD/rgb-images/video_0131
#
#
# video_0132
# /content/JAAD/rgb-images/video_0132
#
#
# video_0132
# /content/JAAD/rgb-images/video_0132
#
#
# video_0133
# /content/JAAD/rgb-images/video_0133
#
#
# video_0133
# /content/JAAD/rgb-images/video_0133
#
#
# video_0134
# /content/JAAD/rgb-images/video_0134
#
#
# video_0134
# /content/JAAD/rgb-images/video_0134
#
#
# video_0135
# /content/JAAD/rgb-images/video_0135
#
#
# video_0135
# /content/JAAD/rgb-images/video_0135
#
#
# video_0136
# /content/JAAD/rgb-images/video_0136
#
#
# video_0136
# /content/JAAD/rgb-images/video_0136
#
#
# video_0137
# /content/JAAD/rgb-images/video_0137
#
#
# video_0137
# /content/JAAD/rgb-images/video_0137
#
#
# video_0138
# /content/JAAD/rgb-images/video_0138
#
#
# video_0138
# /content/JAAD/rgb-images/video_0138
#
#
# video_0139
# /content/JAAD/rgb-images/video_0139
#
#
# video_0139
# /content/JAAD/rgb-images/video_0139
#
#
# video_0140
# /content/JAAD/rgb-images/video_0140
#
#
# video_0140
# /content/JAAD/rgb-images/video_0140
#
#
# video_0141
# /content/JAAD/rgb-images/video_0141
#
#
# video_0141
# /content/JAAD/rgb-images/video_0141
#
#
# video_0142
# /content/JAAD/rgb-images/video_0142
#
#
# video_0142
# /content/JAAD/rgb-images/video_0142
#
#
# video_0143
# /content/JAAD/rgb-images/video_0143
#
#
# video_0143
# /content/JAAD/rgb-images/video_0143
#
#
# video_0144
# /content/JAAD/rgb-images/video_0144
#
#
# video_0144
# /content/JAAD/rgb-images/video_0144
#
#
# video_0145
# /content/JAAD/rgb-images/video_0145
#
#
# video_0145
# /content/JAAD/rgb-images/video_0145
#
#
# video_0146
# /content/JAAD/rgb-images/video_0146
#
#
# video_0146
# /content/JAAD/rgb-images/video_0146
#
#
# video_0147
# /content/JAAD/rgb-images/video_0147
#
#
# video_0147
# /content/JAAD/rgb-images/video_0147
#
#
# video_0148
# /content/JAAD/rgb-images/video_0148
#
#
# video_0148
# /content/JAAD/rgb-images/video_0148
#
#
# video_0149
# /content/JAAD/rgb-images/video_0149
#
#
# video_0149
# /content/JAAD/rgb-images/video_0149
#
#
# video_0150
# /content/JAAD/rgb-images/video_0150
#
#
# video_0150
# /content/JAAD/rgb-images/video_0150
#
#
# video_0151
# /content/JAAD/rgb-images/video_0151
#
#
# video_0151
# /content/JAAD/rgb-images/video_0151
#
#
# video_0152
# /content/JAAD/rgb-images/video_0152
#
#
# video_0152
# /content/JAAD/rgb-images/video_0152
#
#
# video_0153
# /content/JAAD/rgb-images/video_0153
#
#
# video_0153
# /content/JAAD/rgb-images/video_0153
#
#
# video_0154
# /content/JAAD/rgb-images/video_0154
#
#
# video_0154
# /content/JAAD/rgb-images/video_0154
#
#
# video_0155
# /content/JAAD/rgb-images/video_0155
#
#
# video_0155
# /content/JAAD/rgb-images/video_0155
#
#
# video_0156
# /content/JAAD/rgb-images/video_0156
#
#
# video_0156
# /content/JAAD/rgb-images/video_0156
#
#
# video_0157
# /content/JAAD/rgb-images/video_0157
#
#
# video_0157
# /content/JAAD/rgb-images/video_0157
#
#
# video_0158
# /content/JAAD/rgb-images/video_0158
#
#
# video_0158
# /content/JAAD/rgb-images/video_0158
#
#
# video_0159
# /content/JAAD/rgb-images/video_0159
#
#
# video_0159
# /content/JAAD/rgb-images/video_0159
#
#
# video_0160
# /content/JAAD/rgb-images/video_0160
#
#
# video_0160
# /content/JAAD/rgb-images/video_0160
#
#
# video_0161
# /content/JAAD/rgb-images/video_0161
#
#
# video_0161
# /content/JAAD/rgb-images/video_0161
#
#
# video_0162
# /content/JAAD/rgb-images/video_0162
#
#
# video_0162
# /content/JAAD/rgb-images/video_0162
#
#
# video_0163
# /content/JAAD/rgb-images/video_0163
#
#
# video_0163
# /content/JAAD/rgb-images/video_0163
#
#
# video_0164
# /content/JAAD/rgb-images/video_0164
#
#
# video_0164
# ...
#
#
# video_0184
# /content/JAAD/rgb-images/video_0184
#
#
# video_0184
# /content/JAAD/rgb-images/video_0184
#
#
# video_0185
# /content/JAAD/rgb-images/video_0185
#
#
# video_0185
# /content/JAAD/rgb-images/video_0185
#
#
# video_0186
# /content/JAAD/rgb-images/video_0186
#
#
# video_0186
# /content/JAAD/rgb-images/video_0186
#
#
# video_0187
# /content/JAAD/rgb-images/video_0187
#
#
# video_0187
# /content/JAAD/rgb-images/video_0187
#
#
# video_0188
# /content/JAAD/rgb-images/video_0188
#
#
# video_0188
# /content/JAAD/rgb-images/video_0188
#
#
# video_0189
# /content/JAAD/rgb-images/video_0189
#
#
# video_0189
# /content/JAAD/rgb-images/video_0189
#
#
# video_0190
# /content/JAAD/rgb-images/video_0190
#
#
# video_0190
# /content/JAAD/rgb-images/video_0190
#
#
# video_0191
# /content/JAAD/rgb-images/video_0191
#
#
# video_0191
# /content/JAAD/rgb-images/video_0191
#
#
# video_0192
# /content/JAAD/rgb-images/video_0192
#
#
# video_0192
# /content/JAAD/rgb-images/video_0192
#
#
# video_0193
# /content/JAAD/rgb-images/video_0193
#
#
# video_0193
# /content/JAAD/rgb-images/video_0193
#
#
# video_0194
# /content/JAAD/rgb-images/video_0194
#
#
# video_0194
# /content/JAAD/rgb-images/video_0194
#
#
# video_0195
# /content/JAAD/rgb-images/video_0195
#
#
# video_0195
# /content/JAAD/rgb-images/video_0195
#
#
# video_0196
# /content/JAAD/rgb-images/video_0196
#
#
# video_0196
# /content/JAAD/rgb-images/video_0196
#
#
# video_0197
# /content/JAAD/rgb-images/video_0197
#
#
# video_0197
# /content/JAAD/rgb-images/video_0197
#
#
# video_0198
# /content/JAAD/rgb-images/video_0198
#
#
# video_0198
# /content/JAAD/rgb-images/video_0198
#
#
# video_0199
# /content/JAAD/rgb-images/video_0199
#
#
# video_0199
# /content/JAAD/rgb-images/video_0199
#
#
# video_0200
# /content/JAAD/rgb-images/video_0200
#
#
# video_0200
# /content/JAAD/rgb-images/video_0200
#
#
# video_0201
# /content/JAAD/rgb-images/video_0201
#
#
# video_0201
# /content/JAAD/rgb-images/video_0201
#
#
# video_0202
# /content/JAAD/rgb-images/video_0202
#
#
# video_0202
# /content/JAAD/rgb-images/video_0202
#
#
# video_0203
# /content/JAAD/rgb-images/video_0203
#
#
# video_0203
# /content/JAAD/rgb-images/video_0203
#
#
# video_0204
# /content/JAAD/rgb-images/video_0204
#
#
# video_0204
# /content/JAAD/rgb-images/video_0204
#
#
# video_0205
# /content/JAAD/rgb-images/video_0205
#
#
# video_0205
# /content/JAAD/rgb-images/video_0205
#
#
# video_0206
# /content/JAAD/rgb-images/video_0206
#
#
# video_0206
# /content/JAAD/rgb-images/video_0206
#
#
# video_0207
# /content/JAAD/rgb-images/video_0207
#
#
# video_0207
# /content/JAAD/rgb-images/video_0207
#
#
# video_0208
# /content/JAAD/rgb-images/video_0208
#
#
# video_0208
# /content/JAAD/rgb-images/video_0208
#
#
# video_0209
# /content/JAAD/rgb-images/video_0209
#
#
# video_0209
# /content/JAAD/rgb-images/video_0209
#
#
# video_0210
# /content/JAAD/rgb-images/video_0210
#
#
# video_0210
# /content/JAAD/rgb-images/video_0210
#
#
# video_0211
# /content/JAAD/rgb-images/video_0211
#
#
# video_0211
# /content/JAAD/rgb-images/video_0211
#
#
# video_0212
# /content/JAAD/rgb-images/video_0212
#
#
# video_0212
# /content/JAAD/rgb-images/video_0212
#
#
# video_0213
# /content/JAAD/rgb-images/video_0213
#
#
# video_0213
# /content/JAAD/rgb-images/video_0213
#
#
# video_0214
# /content/JAAD/rgb-images/video_0214
#
#
# video_0214
# /content/JAAD/rgb-images/video_0214
#
#
# video_0215
# /content/JAAD/rgb-images/video_0215
#
#
# video_0215
# /content/JAAD/rgb-images/video_0215
#
#
# video_0216
# /content/JAAD/rgb-images/video_0216
#
#
# video_0216
# /content/JAAD/rgb-images/video_0216
#
#
# video_0217
# /content/JAAD/rgb-images/video_0217
#
#
# video_0217
# /content/JAAD/rgb-images/video_0217
#
#
# video_0218
# /content/JAAD/rgb-images/video_0218
#
#
# video_0218
# /content/JAAD/rgb-images/video_0218
#
#
# video_0219
# /content/JAAD/rgb-images/video_0219
#
#
# video_0219
# /content/JAAD/rgb-images/video_0219
#
#
# video_0220
# /content/JAAD/rgb-images/video_0220
#
#
# video_0220
# /content/JAAD/rgb-images/video_0220
#
#
# video_0221
# /content/JAAD/rgb-images/video_0221
#
#
# video_0221
# /content/JAAD/rgb-images/video_0221
#
#
# video_0222
# /content/JAAD/rgb-images/video_0222
#
#
# video_0222
# /content/JAAD/rgb-images/video_0222
#
#
# video_0223
# /content/JAAD/rgb-images/video_0223
#
#
# video_0223
# /content/JAAD/rgb-images/video_0223
#
#
# video_0224
# /content/JAAD/rgb-images/video_0224
#
#
# video_0224
# /content/JAAD/rgb-images/video_0224
#
#
# video_0225
# /content/JAAD/rgb-images/video_0225
#
#
# video_0225
# /content/JAAD/rgb-images/video_0225
#
#
# video_0226
# /content/JAAD/rgb-images/video_0226
#
#
# video_0226
# /content/JAAD/rgb-images/video_0226
#
#
# video_0227
# /content/JAAD/rgb-images/video_0227
#
#
# video_0227
# /content/JAAD/rgb-images/video_0227
#
#
# video_0228
# /content/JAAD/rgb-images/video_0228
#
#
# video_0228
# /content/JAAD/rgb-images/video_0228
#
#
# video_0229
# /content/JAAD/rgb-images/video_0229
#
#
# video_0229
# /content/JAAD/rgb-images/video_0229
#
#
# video_0230
# /content/JAAD/rgb-images/video_0230
#
#
# video_0230
# /content/JAAD/rgb-images/video_0230
#
#
# video_0231
# /content/JAAD/rgb-images/video_0231
#
#
# video_0231
# /content/JAAD/rgb-images/video_0231
#
#
# video_0232
# /content/JAAD/rgb-images/video_0232
#
#
# video_0232
# /content/JAAD/rgb-images/video_0232
#
#
# video_0233
# /content/JAAD/rgb-images/video_0233
#
#
# video_0233
# /content/JAAD/rgb-images/video_0233
#
#
# video_0234
# /content/JAAD/rgb-images/video_0234
#
#
# video_0234
# /content/JAAD/rgb-images/video_0234
#
#
# video_0235
# /content/JAAD/rgb-images/video_0235
#
#
# video_0235
# /content/JAAD/rgb-images/video_0235
#
#
# video_0236
# /content/JAAD/rgb-images/video_0236
#
#
# video_0236
# /content/JAAD/rgb-images/video_0236
#
#
# video_0237
# /content/JAAD/rgb-images/video_0237
#
#
# video_0237
# /content/JAAD/rgb-images/video_0237
#
#
# video_0238
# /content/JAAD/rgb-images/video_0238
#
#
# video_0238
# /content/JAAD/rgb-images/video_0238
#
#
# video_0239
# /content/JAAD/rgb-images/video_0239
#
#
# video_0239
# /content/JAAD/rgb-images/video_0239
#
#
# video_0240
# /content/JAAD/rgb-images/video_0240
#
#
# video_0240
# /content/JAAD/rgb-images/video_0240
#
#
# video_0241
# /content/JAAD/rgb-images/video_0241
#
#
# video_0241
# /content/JAAD/rgb-images/video_0241
#
#
# video_0242
# /content/JAAD/rgb-images/video_0242
#
#
# video_0242
# /content/JAAD/rgb-images/video_0242
#
#
# video_0243
# /content/JAAD/rgb-images/video_0243
#
#
# video_0243
# /content/JAAD/rgb-images/video_0243
#
#
# video_0244
# /content/JAAD/rgb-images/video_0244
#
#
# video_0244
# /content/JAAD/rgb-images/video_0244
#
#
# video_0245
# /content/JAAD/rgb-images/video_0245
#
#
# video_0245
# /content/JAAD/rgb-images/video_0245
#
#
# video_0246
# /content/JAAD/rgb-images/video_0246
#
#
# video_0246
# /content/JAAD/rgb-images/video_0246
#
#
# video_0247
# /content/JAAD/rgb-images/video_0247
#
#
# video_0247
# /content/JAAD/rgb-images/video_0247
#
#
# video_0248
# /content/JAAD/rgb-images/video_0248
#
#
# video_0248
# /content/JAAD/rgb-images/video_0248
#
#
# video_0249
# /content/JAAD/rgb-images/video_0249
#
#
# video_0249
# /content/JAAD/rgb-images/video_0249
#
#
# video_0250
# /content/JAAD/rgb-images/video_0250
#
#
# video_0250
# /content/JAAD/rgb-images/video_0250
#
#
# video_0251
# /content/JAAD/rgb-images/video_0251
#
#
# video_0251
# /content/JAAD/rgb-images/video_0251
#
#
# video_0252
# /content/JAAD/rgb-images/video_0252
#
#
# video_0252
# /content/JAAD/rgb-images/video_0252
#
#
# video_0253
# /content/JAAD/rgb-images/video_0253
#
#
# video_0253
# /content/JAAD/rgb-images/video_0253
#
#
# video_0254
# /content/JAAD/rgb-images/video_0254
#
#
# video_0254
# /content/JAAD/rgb-images/video_0254
#
#
# video_0255
# /content/JAAD/rgb-images/video_0255
#
#
# video_0255
# /content/JAAD/rgb-images/video_0255
#
#
# video_0256
# /content/JAAD/rgb-images/video_0256
#
#
# video_0256
# /content/JAAD/rgb-images/video_0256
#
#
# video_0257
# /content/JAAD/rgb-images/video_0257
#
#
# video_0257
# /content/JAAD/rgb-images/video_0257
#
#
# video_0258
# /content/JAAD/rgb-images/video_0258
#
#
# video_0258
# /content/JAAD/rgb-images/video_0258
#
#
# video_0259
# /content/JAAD/rgb-images/video_0259
#
#
# video_0259
# /content/JAAD/rgb-images/video_0259
#
#
# video_0260
# /content/JAAD/rgb-images/video_0260
#
#
# video_0260
# /content/JAAD/rgb-images/video_0260
#
#
# video_0261
# /content/JAAD/rgb-images/video_0261
#
#
# video_0261
# /content/JAAD/rgb-images/video_0261
#
#
# video_0262
# /content/JAAD/rgb-images/video_0262
#
#
# video_0262
# /content/JAAD/rgb-images/video_0262
#
#
# video_0263
# /content/JAAD/rgb-images/video_0263
#
#
# video_0263
# /content/JAAD/rgb-images/video_0263
#
#
# video_0264
# /content/JAAD/rgb-images/video_0264
#
#
# video_0264
# /content/JAAD/rgb-images/video_0264
#
#
# video_0265
# /content/JAAD/rgb-images/video_0265
#
#
# video_0265
# /content/JAAD/rgb-images/video_0265
#
#
# video_0266
# /content/JAAD/rgb-images/video_0266
#
#
# video_0266
# /content/JAAD/rgb-images/video_0266
#
#
# video_0267
# /content/JAAD/rgb-images/video_0267
#
#
# video_0267
# /content/JAAD/rgb-images/video_0267
#
#
# video_0268
# /content/JAAD/rgb-images/video_0268
#
#
# video_0268
# /content/JAAD/rgb-images/video_0268
#
#
# video_0269
# /content/JAAD/rgb-images/video_0269
#
#
# video_0269
# /content/JAAD/rgb-images/video_0269
#
#
# video_0270
# /content/JAAD/rgb-images/video_0270
#
#
# video_0270
# /content/JAAD/rgb-images/video_0270
#
#
# video_0271
# /content/JAAD/rgb-images/video_0271
#
#
# video_0271
# /content/JAAD/rgb-images/video_0271
#
#
# video_0272
# /content/JAAD/rgb-images/video_0272
#
#
# video_0272
# /content/JAAD/rgb-images/video_0272
#
#
# video_0273
# /content/JAAD/rgb-images/video_0273
#
#
# video_0273
# /content/JAAD/rgb-images/video_0273
#
#
# video_0274
# /content/JAAD/rgb-images/video_0274
#
#
# video_0274
# /content/JAAD/rgb-images/video_0274
#
#
# video_0275
# /content/JAAD/rgb-images/video_0275
#
#
# video_0275
# /content/JAAD/rgb-images/video_0275
#
#
# video_0276
# /content/JAAD/rgb-images/video_0276
#
#
# video_0276
# /content/JAAD/rgb-images/video_0276
#
#
# video_0277
# /content/JAAD/rgb-images/video_0277
#
#
# video_0277
# /content/JAAD/rgb-images/video_0277
#
#
# video_0278
# /content/JAAD/rgb-images/video_0278
#
#
# video_0278
# /content/JAAD/rgb-images/video_0278
#
#
# video_0279
# /content/JAAD/rgb-images/video_0279
#
#
# video_0279
# /content/JAAD/rgb-images/video_0279
#
#
# video_0280
# /content/JAAD/rgb-images/video_0280
#
#
# video_0280
# /content/JAAD/rgb-images/video_0280
#
#
# video_0281
# /content/JAAD/rgb-images/video_0281
#
#
# video_0281
# /content/JAAD/rgb-images/video_0281
#
#
# video_0282
# /content/JAAD/rgb-images/video_0282
#
#
# video_0282
# /content/JAAD/rgb-images/video_0282
#
#
# video_0283
# /content/JAAD/rgb-images/video_0283
#
#
# video_0283
# /content/JAAD/rgb-images/video_0283
#
#
# video_0284
# /content/JAAD/rgb-images/video_0284
#
#
# video_0284
# /content/JAAD/rgb-images/video_0284
#
#
# video_0285
# /content/JAAD/rgb-images/video_0285
#
#
# video_0285
# /content/JAAD/rgb-images/video_0285
#
#
# video_0286
# /content/JAAD/rgb-images/video_0286
#
#
# video_0286
# /content/JAAD/rgb-images/video_0286
#
#
# video_0287
# /content/JAAD/rgb-images/video_0287
#
#
# video_0287
# /content/JAAD/rgb-images/video_0287
#
#
# video_0288
# /content/JAAD/rgb-images/video_0288
#
#
# video_0288
# /content/JAAD/rgb-images/video_0288
#
#
# video_0289
# /content/JAAD/rgb-images/video_0289
#
#
# video_0289
# /content/JAAD/rgb-images/video_0289
#
#
# video_0290
# /content/JAAD/rgb-images/video_0290
#
#
# video_0290
# /content/JAAD/rgb-images/video_0290
#
#
# video_0291
# /content/JAAD/rgb-images/video_0291
#
#
# video_0291
# /content/JAAD/rgb-images/video_0291
#
#
# video_0292
# /content/JAAD/rgb-images/video_0292
#
#
# video_0292
# /content/JAAD/rgb-images/video_0292
#
#
# video_0293
# /content/JAAD/rgb-images/video_0293
#
#
# video_0293
# /content/JAAD/rgb-images/video_0293
#
#
# video_0294
# /content/JAAD/rgb-images/video_0294
#
#
# video_0294
# /content/JAAD/rgb-images/video_0294
#
#
# video_0295
# /content/JAAD/rgb-images/video_0295
#
#
# video_0295
# /content/JAAD/rgb-images/video_0295
#
#
# video_0296
# /content/JAAD/rgb-images/video_0296
#
#
# video_0296
# /content/JAAD/rgb-images/video_0296
#
#
# video_0297
# /content/JAAD/rgb-images/video_0297
#
#
# video_0297
# /content/JAAD/rgb-images/video_0297
#
#
# video_0298
# /content/JAAD/rgb-images/video_0298
#
#
# video_0298
# /content/JAAD/rgb-images/video_0298
#
#
# video_0299
# /content/JAAD/rgb-images/video_0299
#
#
# video_0299
# /content/JAAD/rgb-images/video_0299
#
#
# video_0300
# /content/JAAD/rgb-images/video_0300
#
#
# video_0300
# /content/JAAD/rgb-images/video_0300
#
#
# video_0301
# /content/JAAD/rgb-images/video_0301
#
#
# video_0301
# /content/JAAD/rgb-images/video_0301
#
#
# video_0302
# /content/JAAD/rgb-images/video_0302
#
#
# video_0302
# /content/JAAD/rgb-images/video_0302
#
#
# video_0303
# /content/JAAD/rgb-images/video_0303
#
#
# video_0303
# /content/JAAD/rgb-images/video_0303
#
#
# video_0304
# /content/JAAD/rgb-images/video_0304
#
#
# video_0304
# /content/JAAD/rgb-images/video_0304
#
#
# video_0305
# /content/JAAD/rgb-images/video_0305
#
#
# video_0305
# /content/JAAD/rgb-images/video_0305
#
#
# video_0306
# /content/JAAD/rgb-images/video_0306
#
#
# video_0306
# /content/JAAD/rgb-images/video_0306
#
#
# video_0307
# /content/JAAD/rgb-images/video_0307
#
#
# video_0307
# /content/JAAD/rgb-images/video_0307
#
#
# video_0308
# /content/JAAD/rgb-images/video_0308
#
#
# video_0308
# /content/JAAD/rgb-images/video_0308
#
#
# video_0309
# /content/JAAD/rgb-images/video_0309
#
#
# video_0309
# /content/JAAD/rgb-images/video_0309
#
#
# video_0310
# /content/JAAD/rgb-images/video_0310
#
#
# video_0310
# /content/JAAD/rgb-images/video_0310
#
#
# video_0311
# /content/JAAD/rgb-images/video_0311
#
#
# video_0311
# /content/JAAD/rgb-images/video_0311
#
#
# video_0312
# /content/JAAD/rgb-images/video_0312
#
#
# video_0312
# /content/JAAD/rgb-images/video_0312
#
#
# video_0313
# /content/JAAD/rgb-images/video_0313
#
#
# video_0313
# /content/JAAD/rgb-images/video_0313
#
#
# video_0314
# /content/JAAD/rgb-images/video_0314
#
#
# video_0314
# /content/JAAD/rgb-images/video_0314
#
#
# video_0315
# /content/JAAD/rgb-images/video_0315
#
#
# video_0315
# /content/JAAD/rgb-images/video_0315
#
#
# video_0316
# /content/JAAD/rgb-images/video_0316
#
#
# video_0316
# /content/JAAD/rgb-images/video_0316
#
#
# video_0317
# /content/JAAD/rgb-images/video_0317
#
#
# video_0317
# /content/JAAD/rgb-images/video_0317
#
#
# video_0318
# /content/JAAD/rgb-images/video_0318
#
#
# video_0318
# /content/JAAD/rgb-images/video_0318
#
#
# video_0319
# /content/JAAD/rgb-images/video_0319
#
#
# video_0319
# /content/JAAD/rgb-images/video_0319
#
#
# video_0320
# /content/JAAD/rgb-images/video_0320
#
#
# video_0320
# /content/JAAD/rgb-images/video_0320
#
#
# video_0321
# /content/JAAD/rgb-images/video_0321
#
#
# video_0321
# /content/JAAD/rgb-images/video_0321
#
#
# video_0322
# /content/JAAD/rgb-images/video_0322
#
#
# video_0322
# /content/JAAD/rgb-images/video_0322
#
#
# video_0323
# /content/JAAD/rgb-images/video_0323
#
#
# video_0323
# /content/JAAD/rgb-images/video_0323
#
#
# video_0324
# /content/JAAD/rgb-images/video_0324
#
#
# video_0324
# /content/JAAD/rgb-images/video_0324
#
#
# video_0325
# /content/JAAD/rgb-images/video_0325
#
#
# video_0325
# /content/JAAD/rgb-images/video_0325
#
#
# video_0326
# /content/JAAD/rgb-images/video_0326
#
#
# video_0326
# /content/JAAD/rgb-images/video_0326
#
#
# video_0327
# /content/JAAD/rgb-images/video_0327
#
#
# video_0327
# /content/JAAD/rgb-images/video_0327
#
#
# video_0328
# /content/JAAD/rgb-images/video_0328
#
#
# video_0328
# /content/JAAD/rgb-images/video_0328
#
#
# video_0329
# /content/JAAD/rgb-images/video_0329
#
#
# video_0329
# /content/JAAD/rgb-images/video_0329
#
#
# video_0330
# /content/JAAD/rgb-images/video_0330
#
#
# video_0330
# /content/JAAD/rgb-images/video_0330
#
#
# video_0331
# /content/JAAD/rgb-images/video_0331
#
#
# video_0331
# /content/JAAD/rgb-images/video_0331
#
#
# video_0332
# /content/JAAD/rgb-images/video_0332
#
#
# video_0332
# /content/JAAD/rgb-images/video_0332
#
#
# video_0333
# /content/JAAD/rgb-images/video_0333
#
#
# video_0333
# /content/JAAD/rgb-images/video_0333
#
#
# video_0334
# /content/JAAD/rgb-images/video_0334
#
#
# video_0334
# /content/JAAD/rgb-images/video_0334
#
#
# video_0335
# /content/JAAD/rgb-images/video_0335
#
#
# video_0335
# /content/JAAD/rgb-images/video_0335
#
#
# video_0336
# /content/JAAD/rgb-images/video_0336
#
#
# video_0336
# /content/JAAD/rgb-images/video_0336
#
#
# video_0337
# /content/JAAD/rgb-images/video_0337
#
#
# video_0337
# /content/JAAD/rgb-images/video_0337
#
#
# video_0338
# /content/JAAD/rgb-images/video_0338
#
#
# video_0338
# /content/JAAD/rgb-images/video_0338
#
#
# video_0339
# /content/JAAD/rgb-images/video_0339
#
#
# video_0339
# /content/JAAD/rgb-images/video_0339
#
#
# video_0340
# /content/JAAD/rgb-images/video_0340
#
#
# video_0340
# /content/JAAD/rgb-images/video_0340
#
#
# video_0341
# /content/JAAD/rgb-images/video_0341
#
#
# video_0341
# /content/JAAD/rgb-images/video_0341
#
#
# video_0342
# /content/JAAD/rgb-images/video_0342
#
#
# video_0342
# /content/JAAD/rgb-images/video_0342
#
#
# video_0343
# /content/JAAD/rgb-images/video_0343
#
#
# video_0343
# /content/JAAD/rgb-images/video_0343
#
#
# video_0344
# /content/JAAD/rgb-images/video_0344
#
#
# video_0344
# /content/JAAD/rgb-images/video_0344
#
#
# video_0345
# /content/JAAD/rgb-images/video_0345
#
#
# video_0345
# /content/JAAD/rgb-images/video_0345
#
#
# video_0346
# /content/JAAD/rgb-images/video_0346
#
#
# video_0346
# /content/JAAD/rgb-images/video_0346

# %% [markdown]
# # train list and test list prep

# %%
# import numpy as np
# num_videos = 346
# x = np.arange(1,num_videos+1)

# %%
# from sklearn.model_selection import train_test_split
# vid_train, vid_test = train_test_split(x, test_size = 0.2, random_state=42)
# print(len(vid_train)) # 276
# print(len(vid_test))  # 70

# %%
# train_vid_list = []
# test_vid_list = []
# vid_list = os.listdir('/content/JAAD/annotations_yowo')
# for vid in vid_list:
#   vid_num = int(vid[-4:])
#   if vid_num in vid_train:
#     train_vid_list.append(vid)
#   else:
#     test_vid_list.append(vid)
# def get_annotation_list(vid_list):
#   base_path = '/content/JAAD/annotations_yowo'
#   annotation_list = []
#   for vid in vid_list:
#     for frame in sorted(os.listdir(os.path.join(base_path, vid))): 
#       # annotation_list.append(os.path.join(base_path, vid, frame))
#       annotation_list.append(os.path.join(vid, frame))      
#   return annotation_list
# trainlist = get_annotation_list(train_vid_list)
# testlist = get_annotation_list(test_vid_list)
# print(len(trainlist))
# print(len(testlist))
# trainlist[:3]

# %%
# os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/data')
# with open('trainlist.txt', 'w') as f:
#     for item in trainlist:
#         f.write("%s\n" % item)
# with open('testlist.txt', 'w') as f:
#     for item in testlist:
#         f.write("%s\n" % item)

# %%
# !mv /content/JAAD/annotations_yowo /content/drive/MyDrive/NLP_and_CV_Projects/CV/data/annotations_yowo

# %% [markdown]
# # Import YOWO

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch.autograd import Variable

from cfg import *
from cfam import CFAMBlock
from backbones_2d import darknet
from backbones_3d import mobilenet, shufflenet, mobilenetv2, shufflenetv2, resnext, resnet

num_classes = 2 # 24 is the number of classes of ucf101 dataset, 
#if we set this differently, we need to specify to not import pretrained weights of the last layer

class YOWO(nn.Module): # model.py
    def __init__(self):
        super(YOWO, self).__init__()
        
        ##### 2D Backbone #####
        # if opt.backbone_2d == "darknet":
        self.backbone_2d = darknet.Darknet("cfg/yolo.cfg")
        num_ch_2d = 425 # Number of output channels for backbone_2d
        # load pretrained weights
        self.backbone_2d.load_weights("weights/yolo.weights")

        ##### 3D Backbone ##### # resnet18: lighter but no pre-trained
        # default = "resnext101":
        self.backbone_3d = resnext.resnext101()
        num_ch_3d = 2048 # Number of output channels for backbone_3d
        # load 3d pretrained weights
        self.backbone_3d = self.backbone_3d.cuda()
        self.backbone_3d = nn.DataParallel(self.backbone_3d, device_ids=None) # Because the pretrained backbone models are saved in Dataparalled mode
        pretrained_3d_backbone = torch.load('weights/resnext-101-kinetics.pth')
        backbone_3d_dict = self.backbone_3d.state_dict()
        pretrained_3d_backbone_dict = {k: v for k, v in pretrained_3d_backbone['state_dict'].items() if k in backbone_3d_dict} # 1. filter out unnecessary keys
        backbone_3d_dict.update(pretrained_3d_backbone_dict) # 2. overwrite entries in the existing state dict
        self.backbone_3d.load_state_dict(backbone_3d_dict) # 3. load the new state dict
        self.backbone_3d = self.backbone_3d.module # remove the dataparallel wrapper


        ##### Attention & Final Conv #####f
        self.cfam = CFAMBlock(num_ch_2d+num_ch_3d, 1024)
        self.conv_final = nn.Conv2d(1024, 5*(num_classes+4+1), kernel_size=1, bias=False) # 5: number of anchors, num_classes, 4: coordinates, 1: confidence score
        self.seen = 0



    def forward(self, input):
        x_3d = input # Input clip (None, num_channels, clip_duration, W, H) W and H must be divisible to 32 (480, 256?)
        x_2d = input[:, :, -1, :, :] # Last frame of the clip that is read

        x_2d = self.backbone_2d(x_2d)
        x_3d = self.backbone_3d(x_3d)
        x_3d = torch.squeeze(x_3d, dim=2)

        x = torch.cat((x_3d, x_2d), dim=1)
        x = self.cfam(x)

        out = self.conv_final(x)

        return out


def get_fine_tuning_parameters(model, freeze_backbone_2d = False, freeze_backbone_3d = False):
    ft_module_names = ['cfam', 'conv_final'] # Always fine tune 'cfam' and 'conv_final'
    if not freeze_backbone_2d:
        ft_module_names.append('backbone_2d') # Fine tune complete backbone_2d
    else:
        ft_module_names.append('backbone_2d.models.29') # Fine tune only layer 29 and 30
        ft_module_names.append('backbone_2d.models.30') # Fine tune only layer 29 and 30

    if not freeze_backbone_3d:
        ft_module_names.append('backbone_3d') # Fine tune complete backbone_3d
    else:
        ft_module_names.append('backbone_3d.layer4') # Fine tune only layer 4

    parameters = [] # trainable parameteres
    for k, v in model.named_parameters():
        for ft_module in ft_module_names:
            if ft_module in k:
                parameters.append({'params': v})
                break
            else:
                parameters.append({'params': v, 'lr': 0.0}) # freeze layers
    
    return parameters

# %%
# model       = YOWO()
# model       = model.cuda()
# model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
# model.seen  = 0
# # print(model)

# parameters = get_fine_tuning_parameters(model)#, opt)
# print(parameters)
# optimizer = optim.SGD(model.parameters(), lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)

# %%
# count = 0
# weights1 = []
# for v in model.parameters():
#   if count < 5:
#     weights1.append(v)
#   count += 1
# weights2 = []
# count = 0
# for k, v in model.named_parameters():
#   if count <5:
#     weights2.append(v)
#   count += 1
# print(weights1[0]==weights2[0])

# %%
# count = 0
# for k, v in model.named_parameters():
#   if count < 2:
#     print('k = ', k)
#     print('v = ', v)
#   count += 1

# %%
# model       = YOWO()
# model       = model.cuda()
# model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
# print(model)

# %%
# model_state = torch.load('./backup/yowo_ucf101-24_16f_best.pth') # load pre-trained model on ucf101 dataset

# %%
# model.load_state_dict(model_state['state_dict']) #

# %%
# from torchsummary import summary
# summary(model, (3, 16,480,256)) # channel x frames x W x H 480x256

# %% [markdown]
# # Setup and train function

# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/')

from __future__ import print_function
import sys
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torchvision import datasets, transforms

import dataset
import random
import math
import os
# from opts import parse_opts
from utils import *
from cfg import parse_cfg
from region_loss import RegionLoss

# from model import YOWO, get_fine_tuning_parameters

# # Training settings
# opt = parse_opts()
# # which dataset to use
# dataset_use   = opt.dataset

dataset_use = 'jaad'

# assert dataset_use == 'ucf101-24' or dataset_use == 'jhmdb-21', 'invalid dataset'
# # path for dataset of training and validation
# datacfg       = opt.data_cfg
# # path for cfg file
# cfgfile       = opt.cfg_file

# data_options  = read_data_cfg(datacfg)
# net_options   = parse_cfg(cfgfile)[0]

# obtain list for training and testing
basepath      = '/content/JAAD/'#data_options['base'] # /content/data/rgb-images
trainlist     = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/data/trainlist.txt' # /content/data/trainlist.txt
testlist      = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/data/testlist.txt'# /content/data/testlist.txt

# Demo
# basepath = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/data'

###
backupdir     = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup'
# number of training samples
nsamples      = file_lines(trainlist)
gpus          = '0' #data_options['gpus']  # e.g. 0   ,1,2,3
ngpus         = len(gpus.split(','))
num_workers   = 4  #?int(data_options['num_workers']) 0, 4, 10?

batch_size    = 4        #int(net_options['batch']) # 12 8 4
clip_duration = 16        #int(net_options['clip_duration']) # 16 frames
max_batches   = 200000    #int(net_options['max_batches']) # 100000
learning_rate = 0.01    #float(net_options['learning_rate']) # 0.0001 0.001
momentum      = 0.9       # float(net_options['momentum']) # 0.9
decay         = 0.0005    #float(net_options['decay']) # 0.0005
steps         = [10000,20000,30000,40000]#,50000,60000]   # [float(step) for step in net_options['steps'].split(',')] # [10000,20000,30000,40000] or [30000,40000,50000,60000]
scales        = [0.5,0.5,0.5,0.5]#,0.5,0.5]           #[float(scale) for scale in net_options['scales'].split(',')] # [0.5,0.5,0.5,0.5]

# loss parameters
# loss_options               = parse_cfg(cfgfile)[1]
region_loss                = RegionLoss()
# anchors                    = loss_options['anchors'].split(',')
region_loss.anchors        = [0.70458, 1.18803, 1.26654, 2.55121, 1.59382, 4.08321, 2.30548, 4.94180, 3.52332, 5.91979]
#[float(i) for i in anchors] #anchors = 0.70458, 1.18803, 1.26654, 2.55121, 1.59382, 4.08321, 2.30548, 4.94180, 3.52332, 5.91979
region_loss.num_classes    = 2   # int(loss_options['classes']) # 24
region_loss.num_anchors    = 5    #int(loss_options['num']) # 5
region_loss.anchor_step    = len(region_loss.anchors)//region_loss.num_anchors #
region_loss.object_scale   = 25. # float(loss_options['object_scale']) # 5 25(tune1_e4)=>16(tune2_e5) 5(nope) 10(nope) 16:tune4_e4=>10:e5  25
region_loss.noobject_scale = 1. # float(loss_options['noobject_scale']) # 1
region_loss.class_scale    = 1. # float(loss_options['class_scale']) # 1
region_loss.coord_scale    = 200. # float(loss_options['coord_scale']) # 1 10(tune1_e4)=>20(tune2_e5) 10(nope) 20(nope) 20:tune4_e4,e5     100
region_loss.batch          = batch_size #batch_size # 12



#Train parameters
max_epochs    = max_batches*batch_size//nsamples+1
use_cuda      = True 
seed          = int(time.time())
# seed          = 42
eps           = 1e-5
best_fscore   = 0   # initialize best fscore
begin_epoch = 1
end_epoch = 10


# Test parameters
nms_thresh    = 0.2 # non_maximum suppression threshold       0.4 0.5 0.3 0.2
iou_thresh    = 0.3 # >=iou_threshold => correctly identified 0.5 0.5 0.4 0.3
# proposals when confidence score >= 0.25

# # print('N_samples = ', nsamples)
# print('num of batches per epoch =', nsamples//batch_size+1)

# print('nms_thresh =', nms_thresh)
# print('iou_thresh =', iou_thresh)

if not os.path.exists(backupdir):
    os.mkdir(backupdir)
    
torch.manual_seed(seed)
if use_cuda:
    os.environ['CUDA_VISIBLE_DEVICES'] = gpus
    torch.cuda.manual_seed(seed)

# Create model
# model = YOWO(opt)
model       = YOWO()
model       = model.cuda()
model       = nn.DataParallel(model, device_ids=None) # in multi-gpu case
model.seen  = 0
# print(model)

# parameters = get_fine_tuning_parameters(model)#, opt)
# optimizer = optim.SGD(parameters, lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)
optimizer = optim.SGD(model.parameters(), lr=learning_rate/batch_size, momentum=momentum, dampening=0, weight_decay=decay*batch_size)

kwargs = {'num_workers': num_workers, 'pin_memory': True} if use_cuda else {}
################


# resume_path = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_vali_3_16f_checkpoint.pth'
resume_path = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_manual_tune5_coord100_ob25_e5_16f_checkpoint.pth'


#############
# Load resume path if necessary
# if opt.resume_path:
if os.path.exists(resume_path):
    print("===================================================================")
    print('loading checkpoint {}'.format(resume_path))
    checkpoint = torch.load(resume_path) # opt.resume_path
    # opt.begin_epoch = checkpoint['epoch'] + 1
    begin_epoch = checkpoint['epoch'] + 1
    best_fscore = checkpoint['fscore']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    model.seen = checkpoint['epoch'] * nsamples
    print("Loaded model fscore: ", checkpoint['fscore'])
    print("===================================================================")

region_loss.seen  = model.seen
processed_batches = model.seen//batch_size

init_width        = 480 # int(net_options['width']) # 224  480
init_height       = 256 # int(net_options['height']) # 224  270
init_epoch        = model.seen//nsamples 

##########################

def adjust_learning_rate(optimizer, batch):
    lr = learning_rate
    for i in range(len(steps)):
        scale = scales[i] if i < len(scales) else 1
        if batch >= steps[i]:
            lr = lr * scale
            if batch == steps[i]:
                break
        else:
            break
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr/batch_size
    return lr



def train(epoch):
    global processed_batches
    t0 = time.time()
    cur_model = model.module
    region_loss.l_x.reset()
    region_loss.l_y.reset()
    region_loss.l_w.reset()
    region_loss.l_h.reset()
    region_loss.l_conf.reset()
    region_loss.l_cls.reset()
    region_loss.l_total.reset()

    train_loader = torch.utils.data.DataLoader(
        dataset.listDataset(basepath, trainlist, dataset_use=dataset_use, shape=(init_width, init_height),
                       shuffle=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                       ]), 
                       train=True, 
                       seen=cur_model.seen,
                       batch_size=batch_size,
                       clip_duration=clip_duration,
                       num_workers=num_workers),
        batch_size=batch_size, shuffle=False, **kwargs)

    lr = adjust_learning_rate(optimizer, processed_batches)
    logging('training at epoch %d, lr %f' % (epoch, lr))

    model.train()

    for batch_idx, (data, target) in enumerate(train_loader):
        # print(data.size)
        # print(target.size)
        adjust_learning_rate(optimizer, processed_batches)
        processed_batches = processed_batches + 1

        if use_cuda:
            data = data.cuda()

        optimizer.zero_grad()
        output = model(data)
        region_loss.seen = region_loss.seen + data.data.size(0)
        loss = region_loss(output, target)
        loss.backward()
        optimizer.step()

        # save result every 500 batches
        if processed_batches % 500 == 0: # From time to time, reset averagemeters to see improvements
            region_loss.l_x.reset()
            region_loss.l_y.reset()
            region_loss.l_w.reset()
            region_loss.l_h.reset()
            region_loss.l_conf.reset()
            region_loss.l_cls.reset()
            region_loss.l_total.reset()

    t1 = time.time()
    logging('trained with %f samples/s' % (len(train_loader.dataset)/(t1-t0)))
    print('')
# Out:
# ===================================================================
# loading checkpoint /content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup/yowo_jaad_manual_tune5_coord100_ob25_e5_16f_checkpoint.pth
# Loaded model fscore:  0
# ===================================================================

# %%
print('epoch of checkpoint =',checkpoint['epoch'])
# Out:
# epoch of checkpoint = 5

# %% [markdown]
# # Test function

# %%
def test(epoch):
    def truths_length(truths):
        for i in range(50):
            if truths[i][1] == 0:
                return i

    test_loader = torch.utils.data.DataLoader(
    dataset.listDataset(basepath, testlist, dataset_use=dataset_use, shape=(init_width, init_height),
                   shuffle=False,
                   transform=transforms.Compose([
                       transforms.ToTensor()
                   ]), train=False),
    batch_size=batch_size, shuffle=False, **kwargs)

    num_classes = region_loss.num_classes
    anchors     = region_loss.anchors
    num_anchors = region_loss.num_anchors
    conf_thresh_valid = 0.005
    total       = 0.0
    proposals   = 0.0
    correct     = 0.0
    fscore = 0.0

    correct_classification = 0.0
    total_detected = 0.0

    nbatch      = file_lines(testlist) // batch_size

    logging('validation at epoch %d' % (epoch))
    model.eval()

    for batch_idx, (frame_idx, data, target) in enumerate(test_loader):
        if use_cuda:
            data = data.cuda()
        with torch.no_grad():
            output = model(data).data
            all_boxes = get_region_boxes(output, conf_thresh_valid, num_classes, anchors, num_anchors, 0, 1)
            # output (batch size, anchor*(4+1+num_classes), h, w) ; h, w: grid size
            for i in range(output.size(0)): # size(0): batch size
                boxes = all_boxes[i]
                boxes = nms(boxes, nms_thresh)
                if dataset_use == 'ucf101-24':
                    detection_path = os.path.join('ucf_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join('ucf_detections', 'detections_'+str(epoch))
                    if not os.path.exists('ucf_detections'):
                        os.mkdir('ucf_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                elif dataset_use == 'jaad': 
                    detection_path = os.path.join('jaad_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join('jaad_detections', 'detections_'+str(epoch))
                    if not os.path.exists('jaad_detections'):
                        os.mkdir('jaad_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                else:
                    detection_path = os.path.join(dataset_use+'_detections', 'detections_'+str(epoch), frame_idx[i])
                    current_dir = os.path.join(dataset_use+'_detections', 'detections_'+str(epoch))
                    if not os.path.exists(dataset_use+'_detections'):
                        os.mkdir(dataset_use+'_detections')
                    if not os.path.exists(current_dir):
                        os.mkdir(current_dir)
                
                # print all the boxes
                # boxes = n_boxes * [x_center, y_center, w, h, confidence score, prob of the activity, int of class predicted]
                
                # with open(detection_path, 'w+') as f_detect:
                #     for box in boxes:
                #         x1 = round(float(box[0]-box[2]/2.0) * 320.0)
                #         y1 = round(float(box[1]-box[3]/2.0) * 240.0)
                #         x2 = round(float(box[0]+box[2]/2.0) * 320.0)
                #         y2 = round(float(box[1]+box[3]/2.0) * 240.0)

                #         det_conf = float(box[4])  # detected confidence > 0.25 is detected
                #         for j in range((len(box)-5)//2):
                #             cls_conf = float(box[5+2*j].item()) # class confidence

                #             if type(box[6+2*j]) == torch.Tensor:
                #                 cls_id = int(box[6+2*j].item())
                #             else:
                #                 cls_id = int(box[6+2*j])
                #             prob = det_conf * cls_conf  # means = detected confidence * class confidence

                #             # f_detect.write(str(int(box[6])+1) + ' ' + str(prob) + ' ' + str(x1) + ' ' + str(y1) + ' ' + str(x2) + ' ' + str(y2) + '\n')
                #             f_detect.write(str(int(box[6])+1) + ' ' + str(det_conf) + ' ' + str(cls_conf) + ' ' + str(x1) + ' ' + str(y1) + ' ' + str(x2) + ' ' + str(y2) + '\n')
                
                truths = target[i].view(-1, 5)
                num_gts = truths_length(truths)
        
                total = total + num_gts  # total ground truths
                # After NMS
                for i in range(len(boxes)): # for all proposal boxes in that frame
                    if boxes[i][4] > 0.25: # det_confs: detection confidence score
                        proposals = proposals+1

                for i in range(num_gts):
                    box_gt = [truths[i][1], truths[i][2], truths[i][3], truths[i][4], 1.0, 1.0, truths[i][0]]
                    best_iou = 0
                    best_j = -1
                    for j in range(len(boxes)): # find the best box (highest iou)
                        iou = bbox_iou(box_gt, boxes[j], x1y1x2y2=False)
                        if iou > best_iou:
                            best_j = j
                            best_iou = iou

                    if best_iou > iou_thresh:
                        total_detected += 1
                        if int(boxes[best_j][6]) == box_gt[6]: # correctly classified
                            correct_classification += 1

                    if best_iou > iou_thresh and int(boxes[best_j][6]) == box_gt[6]: # correct localization AND classification
                        correct = correct+1

            precision = 1.0*correct/(proposals+eps) # how accurate is the prediction
            recall = 1.0*correct/(total+eps)  # correctly localized AND classify
            fscore = 2.0*precision*recall/(precision+recall+eps)
            logging("[%d/%d] precision: %f, recall: %f, fscore: %f" % (batch_idx, nbatch, precision, recall, fscore))

    classification_accuracy = 1.0 * correct_classification / (total_detected + eps)  # accuracy of the classification if detected
    localization_recall = 1.0 * total_detected / (total + eps) # correct localization

    print("Classification accuracy: %.3f" % classification_accuracy)
    print("Localization recall: %.3f" % localization_recall)

    return classification_accuracy, localization_recall, precision, recall, fscore

# %% [markdown]
# # Main: Train model without test

# %%
backupdir
# Out:
# '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup'

# %%
# begin_epoch = 10

# %%
begin_epoch
# Out:
# 6

# %%
namedataset = 'jaad'
evaluate = False

if evaluate == True:
    logging('evaluating ...')
    test(0)
else:
    # for epoch in range(opt.begin_epoch, opt.end_epoch + 1):
    # begin_epoch = 6
    # end_epoch = 25
    # for epoch in range(begin_epoch, end_epoch):
    for epoch in range(begin_epoch, begin_epoch+1):
        # Train the model for 1 epoch
        train(epoch)
        # save checkpoint epoch
        
        state = {
          'epoch': epoch,
          'state_dict': model.state_dict(),
          'optimizer': optimizer.state_dict(),
          'fscore': 0 ## fscores are saved in ./jaad_detections/
          }
        is_best = False
        # coord_scale = 20; object_scale = 25
        save_checkpoint(state, is_best, backupdir, namedataset+'_train_tune5_coord100_ob25_'+str(epoch), clip_duration) ###### coord50_ob25
      
        logging(' Weights are saved to backup directory: %s' % (backupdir))

        # Validate the model
        # classification_accuracy, localization_recall, precision, recall, fscore = test(epoch)

        # is_best = fscore > best_fscore
        # if is_best:
        #     print("New best fscore is achieved: ", fscore)
        #     print("Previous fscore was: ", best_fscore)
        #     best_fscore = fscore

        # Save the model to backup directory
    
        # state = {
        #     'epoch': epoch,
        #     'state_dict': model.state_dict(),
        #     'optimizer': optimizer.state_dict(),
        #     'fscore': fscore
        #     }
        # save_checkpoint(state, is_best=False, backupdir, namedataset+'_vali_'+str(epoch), clip_duration)
        # save_checkpoint(state, is_best, backupdir, namedataset+str(epoch), clip_duration) # save a checkpoint AND a best model
        # save_checkpoint(state, is_best, backupdir, opt.dataset, clip_duration)
        # save_checkpoint(state, is_best, backupdir, namedataset, clip_duration)
        
        # logging('Weights are saved to backup directory: %s' % (backupdir))
        
        # eval_result = {'class_acc': classification_accuracy,
        #               'loc_recall': localization_recall, 
        #               'precision': precision, 
        #               'recall': recall, 
        #               'fscore': fscore} 
        # fileout = 'jaad_eval_result_e' + str(epoch)
        # import json
        # with open(f'./jaad_detections/{fileout}.json', 'w') as fp:
        #     json.dump(eval_result, fp)
# Out:
# 2021-01-23 06:50:41 training at epoch 6, lr 0.000625
# 325114: nGT 6, recall 0, proposals 0, loss: x 33.36(33.36), y 8.63(8.63), w 32.68(32.68), h 35.89(35.89), conf 0.83(0.83), cls 0.72(0.72), total 112.11(112.11)
# 325118: nGT 10, recall 2, proposals 0, loss: x 35.78(34.57), y 17.80(13.22), w 91.16(61.92), h 116.74(76.31), conf 10.00(5.41), cls 1.84(1.28), total 273.30(192.71)
# 325122: nGT 3, recall 1, proposals 0, loss: x 20.33(29.82), y 2.21(9.55), w 30.65(51.49), h 9.12(53.92), conf 2.78(4.54), cls 0.67(1.08), total 65.76(150.39)
# 325126: nGT 6, recall 1, proposals 0, loss: x 32.87(30.59), y 3.57(8.05), w 17.25(42.93), h 7.45(42.30), conf 6.59(5.05), cls 0.81(1.01), total 68.54(129.93)
# 325130: nGT 3, recall 0, proposals 0, loss: x 11.49(26.77), y 13.40(9.12), w 121.61(58.67), h 26.89(39.22), conf 1.63(4.37), cls 0.55(0.92), total 175.57(139.06)
# 325134: nGT 5, recall 1, proposals 0, loss: x 34.35(28.03), y 19.14(10.79), w 121.32(69.11), h 93.86(48.32), conf 8.65(5.08), cls 0.47(0.84), total 277.80(162.18)
# 325138: nGT 4, recall 1, proposals 0, loss: x 22.13(27.19), y 1.07(9.40), w 5.11(59.97), h 29.07(45.57), conf 5.88(5.19), cls 0.66(0.82), total 63.91(148.14)
# 325142: nGT 4, recall 1, proposals 0, loss: x 7.96(24.78), y 25.95(11.47), w 14.74(54.31), h 13.93(41.62), conf 3.51(4.98), cls 0.79(0.81), total 66.89(137.99)
# 325146: nGT 6, recall 0, proposals 6, loss: x 23.51(24.64), y 19.34(12.35), w 145.21(64.41), h 108.53(49.05), conf 2.48(4.71), cls 0.97(0.83), total 300.03(155.99)
# 325150: nGT 11, recall 1, proposals 0, loss: x 35.03(25.68), y 35.06(14.62), w 208.91(78.86), h 38.56(48.00), conf 2.94(4.53), cls 1.56(0.90), total 322.07(172.60)
# 325154: nGT 5, recall 0, proposals 6, loss: x 32.55(26.30), y 1.79(13.45), w 84.88(79.41), h 28.57(46.24), conf 1.49(4.25), cls 0.56(0.87), total 149.83(170.53)
# 325158: nGT 3, recall 0, proposals 0, loss: x 10.73(25.01), y 44.60(16.05), w 17.82(74.28), h 15.34(43.66), conf 4.43(4.27), cls 0.92(0.88), total 93.83(164.14)
# 325162: nGT 7, recall 0, proposals 0, loss: x 26.37(25.11), y 34.06(17.43), w 88.52(75.37), h 99.88(47.99), conf 3.16(4.18), cls 1.00(0.88), total 252.99(170.97)
# 325166: nGT 3, recall 1, proposals 0, loss: x 4.12(23.61), y 4.55(16.51), w 39.85(72.84), h 63.34(49.08), conf 4.63(4.21), cls 0.30(0.84), total 116.78(167.10)
# 325170: nGT 3, recall 0, proposals 0, loss: x 13.00(22.90), y 6.53(15.85), w 37.04(70.45), h 7.17(46.29), conf 3.31(4.15), cls 0.53(0.82), total 67.57(160.47)
# 325174: nGT 3, recall 0, proposals 0, loss: x 11.25(22.18), y 0.76(14.90), w 5.82(66.41), h 9.49(43.99), conf 1.27(3.97), cls 0.37(0.79), total 28.96(152.25)
# 325178: nGT 7, recall 0, proposals 0, loss: x 43.89(23.45), y 13.96(14.85), w 193.24(73.87), h 137.25(49.48), conf 2.64(3.90), cls 1.05(0.81), total 392.03(166.35)
# 325182: nGT 2, recall 0, proposals 0, loss: x 1.67(22.24), y 20.91(15.18), w 39.90(71.98), h 8.42(47.19), conf 2.55(3.82), cls 0.35(0.78), total 73.79(161.21)
# 325186: nGT 4, recall 0, proposals 0, loss: x 16.62(21.95), y 16.42(15.25), w 73.36(72.06), h 34.28(46.51), conf 2.42(3.75), cls 0.61(0.77), total 143.70(160.29)
# 325190: nGT 3, recall 1, proposals 0, loss: x 9.71(21.34), y 9.35(14.95), w 31.79(70.04), h 3.97(44.39), conf 8.23(3.97), cls 0.48(0.76), total 63.52(155.45)
# 325194: nGT 9, recall 0, proposals 0, loss: x 48.29(22.62), y 28.00(15.58), w 237.30(78.01), h 53.03(44.80), conf 2.26(3.89), cls 1.12(0.78), total 370.00(165.67)
# 325198: nGT 10, recall 1, proposals 0, loss: x 25.56(22.75), y 65.71(17.85), w 140.57(80.85), h 105.67(47.57), conf 8.97(4.12), cls 1.44(0.81), total 347.93(173.95)
# 325202: nGT 3, recall 0, proposals 0, loss: x 8.19(22.12), y 10.93(17.55), w 1.44(77.40), h 1.67(45.57), conf 3.74(4.10), cls 0.35(0.79), total 26.32(167.53)
# 325206: nGT 8, recall 0, proposals 0, loss: x 36.16(22.70), y 50.61(18.93), w 235.08(83.97), h 43.66(45.49), conf 6.63(4.21), cls 1.12(0.80), total 373.26(176.10)
# 325210: nGT 4, recall 0, proposals 0, loss: x 20.51(22.62), y 33.19(19.50), w 113.98(85.17), h 65.10(46.27), conf 4.49(4.22), cls 0.73(0.80), total 238.00(178.58)
# 325214: nGT 8, recall 3, proposals 0, loss: x 37.76(23.20), y 36.39(20.15), w 51.07(83.86), h 84.94(47.76), conf 12.25(4.53), cls 1.09(0.81), total 223.50(180.31)
# 325218: nGT 10, recall 2, proposals 0, loss: x 35.96(23.67), y 53.44(21.38), w 102.80(84.56), h 48.48(47.79), conf 16.25(4.96), cls 1.62(0.84), total 258.54(183.21)
# 325222: nGT 4, recall 0, proposals 0, loss: x 3.02(22.93), y 15.04(21.16), w 8.96(81.86), h 17.32(46.70), conf 8.10(5.08), cls 0.28(0.82), total 52.72(178.55)
# 325226: nGT 14, recall 2, proposals 0, loss: x 52.97(23.97), y 53.03(22.26), w 51.58(80.81), h 19.97(45.78), conf 22.82(5.69), cls 1.91(0.86), total 202.27(179.36)
# 325230: nGT 6, recall 1, proposals 0, loss: x 28.96(24.14), y 18.15(22.12), w 46.56(79.67), h 38.25(45.53), conf 14.88(5.99), cls 0.95(0.86), total 147.75(178.31)
# 325234: nGT 4, recall 1, proposals 0, loss: x 21.30(24.04), y 35.76(22.56), w 18.83(77.71), h 19.73(44.70), conf 17.58(6.37), cls 0.66(0.85), total 113.86(176.23)
# 325238: nGT 5, recall 0, proposals 0, loss: x 16.99(23.82), y 5.37(22.02), w 5.44(75.45), h 18.35(43.87), conf 18.06(6.73), cls 0.56(0.84), total 64.77(172.75)
# 325242: nGT 5, recall 1, proposals 0, loss: x 16.04(23.59), y 21.16(22.00), w 49.90(74.68), h 9.73(42.84), conf 22.72(7.22), cls 0.73(0.84), total 120.28(171.16)
# 325246: nGT 1, recall 1, proposals 0, loss: x 0.19(22.90), y 1.30(21.39), w 0.90(72.51), h 0.13(41.58), conf 18.77(7.56), cls 0.15(0.82), total 21.44(166.75)
# 325250: nGT 7, recall 2, proposals 0, loss: x 10.42(22.54), y 8.26(21.01), w 100.30(73.30), h 35.68(41.41), conf 20.29(7.92), cls 1.00(0.83), total 175.95(167.02)
# 325254: nGT 4, recall 0, proposals 0, loss: x 6.64(22.10), y 27.37(21.19), w 18.28(71.77), h 12.32(40.60), conf 15.98(8.14), cls 0.65(0.82), total 81.24(164.63)
# 325258: nGT 3, recall 1, proposals 0, loss: x 18.65(22.01), y 5.67(20.77), w 19.67(70.36), h 34.09(40.43), conf 12.47(8.26), cls 0.43(0.81), total 90.98(162.64)
# 325262: nGT 5, recall 1, proposals 0, loss: x 25.18(22.09), y 17.96(20.70), w 26.28(69.20), h 26.11(40.05), conf 9.94(8.31), cls 0.67(0.81), total 106.14(161.16)
# 325266: nGT 4, recall 0, proposals 0, loss: x 10.25(21.79), y 5.11(20.30), w 66.41(69.13), h 3.91(39.12), conf 7.35(8.28), cls 0.51(0.80), total 93.55(159.42)
# 325270: nGT 6, recall 0, proposals 0, loss: x 28.47(21.96), y 10.89(20.06), w 88.85(69.63), h 25.92(38.79), conf 7.69(8.27), cls 1.05(0.81), total 162.86(159.51)
# 325274: nGT 6, recall 0, proposals 0, loss: x 19.09(21.89), y 24.53(20.17), w 45.79(69.04), h 25.68(38.47), conf 8.61(8.27), cls 0.75(0.80), total 124.45(158.65)
# 325278: nGT 4, recall 0, proposals 0, loss: x 11.44(21.64), y 10.87(19.95), w 36.46(68.27), h 9.72(37.79), conf 5.35(8.21), cls 0.64(0.80), total 74.50(156.65)
# 325282: nGT 7, recall 0, proposals 0, loss: x 29.68(21.82), y 34.42(20.28), w 49.92(67.84), h 71.30(38.57), conf 6.49(8.17), cls 1.19(0.81), total 193.00(157.50)
# 325286: nGT 10, recall 1, proposals 0, loss: x 45.87(22.37), y 58.09(21.14), w 82.35(68.17), h 49.52(38.82), conf 13.69(8.29), cls 1.21(0.82), total 250.73(159.61)
# 325290: nGT 8, recall 3, proposals 0, loss: x 8.93(22.07), y 32.08(21.39), w 24.58(67.20), h 34.57(38.72), conf 21.20(8.58), cls 0.97(0.82), total 122.32(158.79)
# 325294: nGT 8, recall 1, proposals 0, loss: x 29.86(22.24), y 32.25(21.62), w 25.04(66.29), h 12.46(38.15), conf 11.28(8.64), cls 1.15(0.83), total 112.04(157.77)
# 325298: nGT 4, recall 1, proposals 0, loss: x 6.11(21.90), y 8.75(21.35), w 44.68(65.83), h 20.80(37.78), conf 13.00(8.73), cls 0.74(0.83), total 94.07(156.41)
# 325302: nGT 8, recall 0, proposals 0, loss: x 12.32(21.70), y 7.38(21.06), w 17.55(64.82), h 3.85(37.08), conf 9.82(8.75), cls 0.29(0.82), total 51.22(154.22)
# 325306: nGT 4, recall 0, proposals 0, loss: x 25.21(21.77), y 20.85(21.05), w 62.29(64.77), h 10.60(36.54), conf 12.12(8.82), cls 0.56(0.81), total 131.62(153.76)
# 325310: nGT 9, recall 2, proposals 0, loss: x 19.10(21.72), y 12.42(20.88), w 35.72(64.19), h 26.01(36.33), conf 15.85(8.96), cls 0.80(0.81), total 109.89(152.88)
# 325314: nGT 5, recall 0, proposals 0, loss: x 13.44(21.55), y 23.97(20.94), w 33.39(63.58), h 36.64(36.33), conf 9.40(8.97), cls 0.79(0.81), total 117.62(152.19)
# 325318: nGT 9, recall 5, proposals 0, loss: x 22.92(21.58), y 36.98(21.25), w 60.90(63.53), h 9.51(35.82), conf 27.08(9.32), cls 1.53(0.82), total 158.93(152.32)
# 325322: nGT 3, recall 0, proposals 0, loss: x 14.34(21.44), y 7.99(21.00), w 17.86(62.67), h 4.47(35.22), conf 8.24(9.30), cls 0.49(0.82), total 53.39(150.46)
# 325326: nGT 5, recall 2, proposals 0, loss: x 18.88(21.40), y 23.17(21.04), w 27.87(62.03), h 39.10(35.30), conf 14.84(9.40), cls 0.87(0.82), total 124.73(149.98)
# 325330: nGT 7, recall 2, proposals 0, loss: x 4.33(21.09), y 27.64(21.16), w 46.70(61.75), h 32.64(35.25), conf 14.57(9.49), cls 1.10(0.82), total 126.98(149.56)
# 325334: nGT 8, recall 0, proposals 0, loss: x 37.37(21.38), y 23.58(21.20), w 44.92(61.45), h 12.99(34.85), conf 6.78(9.45), cls 0.91(0.82), total 126.56(149.15)
# 325338: nGT 9, recall 1, proposals 0, loss: x 11.66(21.21), y 17.32(21.14), w 94.02(62.02), h 81.39(35.67), conf 13.87(9.52), cls 1.09(0.83), total 219.35(150.38)
# 325342: nGT 5, recall 1, proposals 0, loss: x 16.30(21.12), y 31.10(21.31), w 50.09(61.81), h 60.92(36.10), conf 7.43(9.49), cls 0.76(0.83), total 166.61(150.66)
# 325346: nGT 12, recall 0, proposals 0, loss: x 18.99(21.09), y 40.48(21.63), w 268.47(65.32), h 23.67(35.89), conf 4.61(9.41), cls 1.13(0.83), total 357.34(154.16)
# 325350: nGT 4, recall 0, proposals 0, loss: x 25.56(21.16), y 10.08(21.44), w 35.91(64.83), h 0.12(35.30), conf 4.74(9.33), cls 0.70(0.83), total 77.10(152.88)
# 325354: nGT 8, recall 0, proposals 0, loss: x 11.82(21.01), y 27.13(21.53), w 35.22(64.34), h 94.61(36.27), conf 7.05(9.29), cls 1.15(0.84), total 176.97(153.28)
# 325358: nGT 5, recall 1, proposals 0, loss: x 11.77(20.86), y 12.86(21.39), w 52.66(64.15), h 21.00(36.02), conf 9.51(9.29), cls 0.75(0.83), total 108.56(152.55)
# 325362: nGT 5, recall 0, proposals 0, loss: x 14.87(20.76), y 12.52(21.25), w 18.71(63.43), h 106.31(37.14), conf 4.54(9.22), cls 0.85(0.84), total 157.81(152.64)
# 325366: nGT 8, recall 1, proposals 0, loss: x 23.65(20.81), y 56.68(21.81), w 31.38(62.93), h 44.52(37.25), conf 10.59(9.24), cls 1.41(0.84), total 168.22(152.88)
# 325622: nGT 4, recall 3, proposals 0, loss: x 11.68(19.68), y 31.77(20.87), w 61.73(57.58), h 0.96(35.82), conf 11.45(9.88), cls 0.41(0.79), total 118.01(144.62)
# 325626: nGT 5, recall 1, proposals 0, loss: x 30.24(19.76), y 0.93(20.72), w 61.49(57.61), h 45.84(35.90), conf 6.32(9.86), cls 0.81(0.79), total 145.63(144.63)
# 325630: nGT 9, recall 0, proposals 0, loss: x 29.29(19.83), y 43.86(20.90), w 64.21(57.67), h 92.57(36.33), conf 3.19(9.81), cls 1.05(0.79), total 234.17(145.32)
# 325634: nGT 4, recall 2, proposals 0, loss: x 13.87(19.79), y 12.41(20.83), w 18.69(57.37), h 4.57(36.09), conf 10.04(9.81), cls 0.63(0.79), total 60.21(144.67)
# 325638: nGT 5, recall 1, proposals 0, loss: x 38.54(19.93), y 23.90(20.85), w 42.41(57.25), h 22.19(35.98), conf 6.52(9.78), cls 0.75(0.79), total 134.31(144.59)
# 325642: nGT 10, recall 2, proposals 0, loss: x 40.27(20.08), y 35.99(20.97), w 26.08(57.02), h 15.60(35.83), conf 16.24(9.83), cls 1.57(0.79), total 135.75(144.52)
# 325646: nGT 5, recall 0, proposals 0, loss: x 21.24(20.09), y 14.87(20.92), w 5.21(56.63), h 58.99(36.00), conf 4.99(9.80), cls 0.66(0.79), total 105.95(144.24)
# 325650: nGT 6, recall 1, proposals 0, loss: x 17.09(20.07), y 23.08(20.94), w 22.63(56.38), h 15.01(35.85), conf 10.76(9.80), cls 0.90(0.79), total 89.47(143.83)
# 325654: nGT 3, recall 0, proposals 0, loss: x 17.49(20.05), y 9.26(20.85), w 2.60(55.99), h 3.42(35.61), conf 5.76(9.77), cls 0.51(0.79), total 39.05(143.06)
# 325658: nGT 7, recall 1, proposals 0, loss: x 20.10(20.05), y 18.57(20.84), w 125.50(56.49), h 86.46(35.98), conf 9.46(9.77), cls 0.74(0.79), total 260.84(143.92)
# 325662: nGT 5, recall 1, proposals 0, loss: x 26.74(20.10), y 35.68(20.94), w 192.11(57.48), h 80.24(36.30), conf 8.83(9.76), cls 0.64(0.79), total 344.24(145.37)
# 325666: nGT 3, recall 1, proposals 0, loss: x 15.85(20.07), y 21.48(20.95), w 3.92(57.09), h 9.40(36.11), conf 7.24(9.75), cls 0.58(0.79), total 58.46(144.75)
# 325670: nGT 3, recall 1, proposals 0, loss: x 17.83(20.05), y 8.90(20.86), w 30.61(56.90), h 29.62(36.06), conf 5.45(9.71), cls 0.44(0.78), total 92.86(144.37)
# 325674: nGT 8, recall 1, proposals 0, loss: x 17.84(20.04), y 27.39(20.91), w 74.84(57.03), h 43.10(36.11), conf 4.87(9.68), cls 1.15(0.79), total 169.19(144.55)
# 325678: nGT 7, recall 2, proposals 0, loss: x 22.76(20.05), y 54.69(21.15), w 17.30(56.75), h 57.17(36.26), conf 10.62(9.69), cls 1.06(0.79), total 163.59(144.68)
# 325682: nGT 5, recall 2, proposals 0, loss: x 7.42(19.97), y 14.90(21.10), w 34.42(56.59), h 74.66(36.53), conf 12.20(9.70), cls 0.58(0.79), total 144.19(144.68)
# 325998: nGT 8, recall 1, proposals 0, loss: x 33.57(19.51), y 15.14(20.64), w 14.11(53.58), h 7.68(34.17), conf 12.40(9.53), cls 0.79(0.78), total 83.68(138.22)
# 326002: nGT 3, recall 0, proposals 0, loss: x 21.77(19.52), y 19.39(20.64), w 13.94(53.40), h 3.28(34.03), conf 4.27(9.51), cls 0.29(0.78), total 62.96(137.88)
# 326006: nGT 3, recall 1, proposals 0, loss: x 3.68(3.68), y 13.76(13.76), w 24.27(24.27), h 41.08(41.08), conf 7.87(7.87), cls 0.46(0.46), total 91.11(91.11)
# 326010: nGT 6, recall 1, proposals 0, loss: x 38.41(21.05), y 38.42(26.09), w 12.27(18.27), h 26.10(33.59), conf 7.18(7.52), cls 0.78(0.62), total 123.16(107.14)
# 326014: nGT 7, recall 1, proposals 0, loss: x 34.19(25.43), y 23.80(25.33), w 51.44(29.32), h 20.80(29.32), conf 6.80(7.28), cls 0.89(0.71), total 137.91(117.39)
# 326018: nGT 3, recall 1, proposals 0, loss: x 9.07(21.34), y 21.40(24.34), w 9.80(24.44), h 73.21(40.29), conf 7.52(7.34), cls 0.65(0.70), total 121.64(118.46)
# 326022: nGT 2, recall 0, proposals 0, loss: x 16.09(20.29), y 11.38(21.75), w 7.70(21.09), h 1.27(32.49), conf 4.68(6.81), cls 0.36(0.63), total 41.49(103.06)
# 326026: nGT 8, recall 2, proposals 0, loss: x 23.54(20.83), y 39.13(24.65), w 31.71(22.86), h 39.86(33.72), conf 13.96(8.00), cls 1.20(0.72), total 149.39(110.78)
# 326030: nGT 7, recall 2, proposals 0, loss: x 24.10(21.30), y 59.71(29.66), w 33.17(24.34), h 4.48(29.54), conf 16.71(9.24), cls 0.98(0.76), total 139.15(114.84)
# 326034: nGT 2, recall 0, proposals 0, loss: x 4.94(19.25), y 9.17(27.10), w 32.47(25.35), h 38.66(30.68), conf 4.10(8.60), cls 0.34(0.71), total 89.67(111.69)
# 326038: nGT 6, recall 0, proposals 0, loss: x 25.25(19.92), y 20.30(26.34), w 215.52(46.48), h 204.64(50.01), conf 4.58(8.15), cls 0.93(0.73), total 471.21(151.64)
# 326042: nGT 7, recall 1, proposals 0, loss: x 31.97(21.12), y 33.82(27.09), w 43.99(46.23), h 34.15(48.42), conf 12.96(8.64), cls 0.99(0.76), total 157.89(152.26)
# 326046: nGT 4, recall 1, proposals 0, loss: x 8.10(19.94), y 6.99(25.26), w 13.34(43.24), h 9.31(44.87), conf 5.91(8.39), cls 0.46(0.73), total 44.11(142.43)
# 326050: nGT 5, recall 0, proposals 0, loss: x 18.64(19.83), y 17.10(24.58), w 80.55(46.35), h 86.80(48.36), conf 4.53(8.07), cls 0.68(0.73), total 208.29(147.92)
# 326054: nGT 1, recall 1, proposals 0, loss: x 0.13(18.32), y 1.44(22.80), w 1.60(42.91), h 0.12(44.65), conf 5.58(7.87), cls 0.19(0.68), total 9.06(137.24)
# 326058: nGT 3, recall 0, proposals 0, loss: x 5.29(17.39), y 8.79(21.80), w 14.40(40.87), h 4.94(41.82), conf 5.95(7.74), cls 0.34(0.66), total 39.71(130.27)
# 326062: nGT 6, recall 3, proposals 0, loss: x 12.30(17.05), y 11.35(21.10), w 39.85(40.80), h 12.11(39.83), conf 13.43(8.12), cls 0.62(0.66), total 89.64(127.56)
# 326066: nGT 2, recall 0, proposals 0, loss: x 17.65(17.08), y 5.03(20.10), w 15.25(39.21), h 9.97(37.97), conf 5.37(7.94), cls 0.29(0.63), total 53.56(122.94)
# 326070: nGT 4, recall 0, proposals 0, loss: x 17.80(17.13), y 5.41(19.23), w 25.10(38.38), h 45.95(38.44), conf 5.16(7.78), cls 0.48(0.63), total 99.90(121.58)
# 326074: nGT 3, recall 1, proposals 0, loss: x 10.67(16.77), y 3.24(18.35), w 12.60(36.94), h 7.33(36.71), conf 7.03(7.74), cls 0.31(0.61), total 41.18(117.12)
# 326078: nGT 6, recall 2, proposals 0, loss: x 16.73(16.77), y 23.31(18.61), w 3.47(35.18), h 9.43(35.27), conf 11.08(7.92), cls 0.56(0.61), total 64.58(114.35)
# 326082: nGT 8, recall 0, proposals 0, loss: x 35.58(17.71), y 17.95(18.57), w 226.67(44.76), h 66.41(36.83), conf 6.52(7.85), cls 1.04(0.63), total 354.15(126.34)
# 326086: nGT 4, recall 2, proposals 0, loss: x 18.01(17.72), y 27.90(19.02), w 20.74(43.61), h 9.18(35.51), conf 10.72(7.98), cls 0.59(0.63), total 87.14(124.47)
# 326090: nGT 6, recall 3, proposals 0, loss: x 19.22(17.79), y 4.94(18.38), w 17.68(42.43), h 4.47(34.10), conf 14.69(8.29), cls 0.54(0.62), total 61.53(121.61)
# 326094: nGT 6, recall 0, proposals 0, loss: x 16.82(17.75), y 12.19(18.11), w 95.62(44.75), h 86.43(36.38), conf 5.75(8.18), cls 0.65(0.62), total 217.45(125.78)
# 326098: nGT 6, recall 2, proposals 0, loss: x 11.56(17.49), y 35.48(18.83), w 80.52(46.24), h 89.55(38.59), conf 11.90(8.33), cls 0.73(0.63), total 229.74(130.11)
# 326102: nGT 13, recall 7, proposals 0, loss: x 35.89(18.23), y 42.02(19.76), w 192.81(52.10), h 46.03(38.89), conf 29.08(9.16), cls 1.42(0.66), total 347.25(138.80)
# 326106: nGT 5, recall 0, proposals 0, loss: x 34.03(18.83), y 28.28(20.09), w 53.40(52.15), h 45.04(39.13), conf 4.58(8.99), cls 0.78(0.66), total 166.11(139.85)
# 326110: nGT 7, recall 1, proposals 0, loss: x 21.88(18.95), y 28.02(20.38), w 102.83(54.03), h 6.83(37.93), conf 9.22(8.99), cls 0.97(0.67), total 169.75(140.96)
# 326114: nGT 4, recall 1, proposals 0, loss: x 18.86(18.94), y 16.14(20.23), w 74.99(54.78), h 136.86(41.46), conf 7.39(8.94), cls 0.63(0.67), total 254.88(145.02)
# 326118: nGT 8, recall 3, proposals 0, loss: x 59.05(20.33), y 30.72(20.59), w 21.42(53.63), h 27.00(40.97), conf 11.19(9.01), cls 1.13(0.69), total 150.52(145.21)
# 326122: nGT 7, recall 0, proposals 0, loss: x 27.03(20.55), y 39.94(21.24), w 28.25(52.78), h 23.20(40.37), conf 10.97(9.08), cls 1.06(0.70), total 130.44(144.72)
# 326126: nGT 6, recall 1, proposals 0, loss: x 29.04(20.82), y 39.37(21.82), w 24.68(51.87), h 34.23(40.17), conf 11.94(9.17), cls 1.12(0.71), total 140.37(144.58)
# 326130: nGT 2, recall 1, proposals 0, loss: x 9.55(20.47), y 21.54(21.81), w 35.14(51.35), h 5.53(39.09), conf 7.99(9.14), cls 0.24(0.70), total 79.98(142.56)
# 326134: nGT 10, recall 4, proposals 0, loss: x 32.97(20.85), y 18.48(21.71), w 103.53(52.93), h 4.74(38.05), conf 18.93(9.43), cls 1.42(0.72), total 180.06(143.70)
# 326138: nGT 9, recall 0, proposals 0, loss: x 20.59(20.84), y 14.47(21.50), w 104.89(54.46), h 56.81(38.60), conf 8.67(9.41), cls 0.83(0.72), total 206.25(145.54)
# 326142: nGT 5, recall 2, proposals 0, loss: x 23.33(20.91), y 30.72(21.76), w 28.39(53.72), h 35.01(38.50), conf 12.60(9.50), cls 0.74(0.73), total 130.79(145.12)
# 326146: nGT 6, recall 3, proposals 0, loss: x 8.39(20.57), y 32.85(22.07), w 64.22(54.01), h 29.30(38.24), conf 14.64(9.64), cls 0.46(0.72), total 149.86(145.25)
# 326150: nGT 8, recall 0, proposals 0, loss: x 45.88(21.25), y 32.82(22.36), w 46.49(53.80), h 76.67(39.28), conf 2.78(9.46), cls 1.54(0.74), total 206.19(146.90)
# 326154: nGT 7, recall 2, proposals 0, loss: x 9.95(20.95), y 64.49(23.47), w 66.24(54.13), h 129.75(41.66), conf 9.42(9.46), cls 1.03(0.75), total 280.87(150.42)
# 326158: nGT 4, recall 0, proposals 0, loss: x 9.01(20.65), y 6.69(23.04), w 5.40(52.88), h 103.20(43.24), conf 3.92(9.32), cls 0.70(0.75), total 128.92(149.87)
# 326162: nGT 6, recall 1, proposals 0, loss: x 29.26(20.86), y 42.44(23.52), w 104.91(54.18), h 101.90(44.71), conf 8.24(9.29), cls 0.99(0.75), total 287.74(153.32)
# 326166: nGT 4, recall 2, proposals 0, loss: x 12.90(20.67), y 7.49(23.13), w 77.62(54.75), h 24.38(44.21), conf 8.16(9.26), cls 0.42(0.74), total 130.97(152.77)
# 326170: nGT 8, recall 1, proposals 0, loss: x 49.67(21.36), y 57.61(23.95), w 51.32(54.67), h 68.08(44.78), conf 4.51(9.15), cls 1.28(0.76), total 232.47(154.67)
# 326174: nGT 4, recall 0, proposals 0, loss: x 23.62(21.41), y 13.96(23.72), w 84.00(55.35), h 25.81(44.34), conf 6.87(9.09), cls 0.45(0.75), total 154.70(154.67)
# 326178: nGT 7, recall 2, proposals 0, loss: x 13.87(21.24), y 26.32(23.78), w 141.38(57.31), h 24.29(43.88), conf 10.10(9.12), cls 1.13(0.76), total 217.09(156.09)
# 326182: nGT 6, recall 0, proposals 0, loss: x 28.72(21.41), y 22.61(23.75), w 229.86(61.14), h 16.42(43.27), conf 1.43(8.95), cls 0.86(0.76), total 299.90(159.28)
# 326186: nGT 3, recall 0, proposals 0, loss: x 15.43(21.28), y 18.06(23.63), w 221.22(64.62), h 32.00(43.03), conf 1.13(8.78), cls 0.55(0.76), total 288.40(162.09)
# 326250: nGT 5, recall 1, proposals 0, loss: x 11.28(21.29), y 4.83(22.37), w 28.30(76.66), h 0.81(40.41), conf 13.36(10.52), cls 0.66(0.76), total 59.24(172.02)
# 326254: nGT 2, recall 0, proposals 0, loss: x 15.88(21.21), y 11.65(22.20), w 15.29(75.69), h 9.39(39.91), conf 1.89(10.39), cls 0.28(0.76), total 54.38(170.15)
# 326258: nGT 5, recall 1, proposals 0, loss: x 18.77(21.17), y 23.33(22.22), w 72.13(75.63), h 25.83(39.69), conf 8.10(10.35), cls 0.88(0.76), total 149.04(169.82)
# 326262: nGT 6, recall 1, proposals 0, loss: x 15.67(21.08), y 15.23(22.11), w 117.78(76.28), h 157.52(41.51), conf 4.59(10.26), cls 0.62(0.76), total 311.41(172.00)
# 326266: nGT 10, recall 0, proposals 0, loss: x 37.70(21.33), y 19.86(22.08), w 312.61(79.86), h 13.25(41.08), conf 2.97(10.15), cls 0.95(0.76), total 387.34(175.26)
# 326270: nGT 5, recall 0, proposals 0, loss: x 12.42(21.20), y 10.24(21.90), w 5.24(78.75), h 1.65(40.49), conf 7.13(10.11), cls 0.53(0.76), total 37.20(173.20)
# 326274: nGT 3, recall 0, proposals 0, loss: x 7.66(21.00), y 3.46(21.63), w 15.17(77.81), h 14.35(40.11), conf 4.01(10.02), cls 0.52(0.75), total 45.18(171.32)
# 326278: nGT 5, recall 3, proposals 0, loss: x 14.96(20.91), y 8.33(21.44), w 18.91(76.96), h 47.47(40.21), conf 20.47(10.17), cls 0.78(0.75), total 110.91(170.44)
# 326282: nGT 6, recall 1, proposals 0, loss: x 21.20(20.92), y 14.31(21.33), w 79.59(77.00), h 30.57(40.07), conf 12.60(10.20), cls 0.81(0.75), total 159.08(170.28)
# 326286: nGT 7, recall 2, proposals 0, loss: x 10.87(20.78), y 12.67(21.21), w 106.96(77.42), h 86.89(40.73), conf 20.05(10.34), cls 0.86(0.76), total 238.30(171.24)
# 326290: nGT 4, recall 3, proposals 0, loss: x 14.63(20.69), y 18.84(21.18), w 2.03(76.37), h 18.16(40.42), conf 22.33(10.51), cls 0.65(0.75), total 76.64(169.92)
# 326294: nGT 2, recall 2, proposals 0, loss: x 0.33(20.41), y 2.56(20.92), w 11.26(75.48), h 2.15(39.90), conf 16.65(10.59), cls 0.31(0.75), total 33.26(168.05)
# 326298: nGT 5, recall 0, proposals 0, loss: x 39.89(20.68), y 17.14(20.87), w 74.50(75.47), h 101.11(40.72), conf 11.67(10.61), cls 0.87(0.75), total 245.18(169.09)
# 326302: nGT 4, recall 0, proposals 0, loss: x 30.82(20.81), y 18.67(20.84), w 49.46(75.12), h 3.04(40.22), conf 12.63(10.63), cls 0.58(0.75), total 115.20(168.37)
# 326306: nGT 4, recall 0, proposals 0, loss: x 27.29(20.90), y 23.98(20.89), w 162.51(76.27), h 3.93(39.74), conf 8.29(10.60), cls 0.68(0.75), total 226.68(169.14)
# 326310: nGT 3, recall 1, proposals 0, loss: x 13.00(20.79), y 9.71(20.74), w 69.12(76.18), h 17.65(39.46), conf 9.02(10.58), cls 0.47(0.74), total 118.98(168.49)
# 326314: nGT 2, recall 1, proposals 0, loss: x 9.61(20.65), y 7.05(20.56), w 4.09(75.25), h 1.06(38.96), conf 10.01(10.57), cls 0.36(0.74), total 32.18(166.74)
# 326318: nGT 3, recall 0, proposals 0, loss: x 25.47(20.71), y 12.70(20.47), w 16.36(74.51), h 37.93(38.95), conf 4.69(10.50), cls 0.43(0.73), total 97.58(165.87)
# 326322: nGT 5, recall 0, proposals 0, loss: x 33.18(20.87), y 18.70(20.44), w 203.17(76.11), h 107.43(39.81), conf 5.80(10.44), cls 0.89(0.74), total 369.17(168.41)
# 326326: nGT 5, recall 1, proposals 0, loss: x 24.01(20.91), y 20.29(20.44), w 15.58(75.37), h 12.17(39.47), conf 9.78(10.43), cls 0.82(0.74), total 82.64(167.35)
# 326330: nGT 1, recall 0, proposals 0, loss: x 2.89(20.69), y 0.64(20.20), w 6.18(74.52), h 18.32(39.21), conf 1.92(10.33), cls 0.17(0.73), total 30.12(165.68)
# 326334: nGT 8, recall 1, proposals 0, loss: x 61.21(21.17), y 27.74(20.29), w 53.53(74.27), h 114.65(40.12), conf 10.26(10.33), cls 1.22(0.74), total 268.61(166.92)
# 326338: nGT 2, recall 0, proposals 0, loss: x 2.90(20.96), y 1.13(20.06), w 5.97(73.46), h 13.48(39.80), conf 1.64(10.22), cls 0.17(0.73), total 25.28(165.23)
# 326342: nGT 6, recall 1, proposals 0, loss: x 28.47(21.05), y 29.04(20.17), w 20.39(72.83), h 41.28(39.82), conf 6.47(10.18), cls 0.79(0.73), total 126.43(164.77)
# 326346: nGT 11, recall 4, proposals 0, loss: x 24.01(21.08), y 28.86(20.27), w 38.69(72.44), h 26.01(39.66), conf 19.41(10.29), cls 1.00(0.73), total 137.97(164.46)
# 326350: nGT 6, recall 1, proposals 0, loss: x 20.38(21.07), y 34.29(20.43), w 33.24(71.99), h 47.45(39.75), conf 5.74(10.24), cls 0.73(0.73), total 141.83(164.20)
# 326354: nGT 7, recall 5, proposals 0, loss: x 8.49(20.93), y 34.70(20.59), w 21.25(71.41), h 6.41(39.37), conf 13.65(10.27), cls 0.64(0.73), total 85.13(163.30)
# 326358: nGT 6, recall 2, proposals 0, loss: x 12.08(20.83), y 20.56(20.59), w 92.02(71.64), h 24.19(39.20), conf 12.40(10.30), cls 0.71(0.73), total 161.97(163.29)
# 326362: nGT 3, recall 0, proposals 0, loss: x 6.87(20.67), y 18.78(20.57), w 13.22(70.99), h 7.42(38.84), conf 2.58(10.21), cls 0.51(0.73), total 49.38(162.02)
# 326366: nGT 3, recall 0, proposals 0, loss: x 11.39(20.57), y 20.41(20.57), w 34.97(70.60), h 20.49(38.64), conf 4.30(10.15), cls 0.53(0.73), total 92.10(161.25)
# 326370: nGT 7, recall 0, proposals 0, loss: x 44.36(20.83), y 16.86(20.53), w 33.69(70.19), h 27.97(38.53), conf 7.13(10.11), cls 1.06(0.73), total 131.07(160.93)
# 326374: nGT 8, recall 2, proposals 0, loss: x 14.40(20.76), y 23.71(20.56), w 43.89(69.91), h 11.36(38.23), conf 13.44(10.15), cls 1.01(0.73), total 107.80(160.36)
# 326378: nGT 6, recall 2, proposals 0, loss: x 29.56(20.86), y 20.58(20.56), w 11.51(69.29), h 5.19(37.88), conf 12.25(10.17), cls 0.92(0.74), total 80.00(159.50)
# 326382: nGT 7, recall 1, proposals 0, loss: x 19.03(20.84), y 16.67(20.52), w 165.00(70.30), h 72.20(38.24), conf 8.03(10.15), cls 0.83(0.74), total 281.76(160.79)
# 326386: nGT 5, recall 1, proposals 0, loss: x 25.83(20.89), y 19.16(20.51), w 21.26(69.79), h 33.47(38.19), conf 10.25(10.15), cls 0.87(0.74), total 110.85(160.27)
# 326390: nGT 2, recall 0, proposals 0, loss: x 10.15(20.78), y 10.37(20.40), w 92.47(70.02), h 4.84(37.85), conf 4.26(10.09), cls 0.31(0.73), total 122.40(159.88)
# 326394: nGT 2, recall 0, proposals 0, loss: x 10.29(20.67), y 13.83(20.34), w 55.72(69.87), h 8.61(37.55), conf 4.52(10.03), cls 0.47(0.73), total 93.43(159.20)
# 326398: nGT 5, recall 2, proposals 0, loss: x 12.90(20.59), y 9.78(20.23), w 18.88(69.36), h 4.59(37.22), conf 15.39(10.09), cls 0.83(0.73), total 62.37(158.22)
# 326402: nGT 4, recall 2, proposals 0, loss: x 10.90(20.50), y 19.07(20.22), w 30.32(68.97), h 24.30(37.09), conf 10.90(10.10), cls 0.80(0.73), total 96.29(157.60)
# 326406: nGT 8, recall 3, proposals 0, loss: x 27.86(20.57), y 49.79(20.51), w 36.51(68.65), h 9.61(36.82), conf 24.27(10.24), cls 1.47(0.74), total 149.51(157.52)
# 326410: nGT 5, recall 0, proposals 0, loss: x 17.19(20.53), y 22.07(20.53), w 54.59(68.51), h 30.01(36.75), conf 6.33(10.20), cls 0.84(0.74), total 131.03(157.26)
# 326414: nGT 2, recall 1, proposals 0, loss: x 6.75(20.40), y 3.82(20.36), w 12.75(67.97), h 7.01(36.46), conf 7.17(10.17), cls 0.30(0.74), total 37.80(156.10)
# 326418: nGT 7, recall 0, proposals 0, loss: x 22.53(20.42), y 7.46(20.24), w 24.22(67.55), h 35.96(36.46), conf 4.39(10.11), cls 0.87(0.74), total 95.43(155.52)
# 326422: nGT 10, recall 1, proposals 0, loss: x 18.33(20.40), y 16.03(20.20), w 34.75(67.24), h 42.03(36.51), conf 6.37(10.08), cls 1.12(0.74), total 118.63(155.17)
# 326426: nGT 6, recall 1, proposals 0, loss: x 24.10(20.44), y 23.06(20.23), w 14.62(66.74), h 7.01(36.23), conf 5.40(10.03), cls 0.59(0.74), total 74.79(154.41)
# 326430: nGT 2, recall 0, proposals 0, loss: x 16.48(20.40), y 12.99(20.16), w 51.82(66.60), h 8.38(35.97), conf 2.30(9.96), cls 0.34(0.74), total 92.31(153.83)
# 326434: nGT 4, recall 0, proposals 0, loss: x 20.28(20.40), y 20.90(20.17), w 24.18(66.21), h 17.02(35.80), conf 5.83(9.92), cls 0.67(0.74), total 88.88(153.23)
# 326502: nGT 9, recall 1, proposals 0, loss: x 17.86(20.24), y 24.59(20.12), w 153.92(67.30), h 57.18(36.77), conf 11.40(9.77), cls 0.83(0.74), total 265.78(154.94)
# 326506: nGT 2, recall 0, proposals 0, loss: x 3.87(20.11), y 1.65(19.97), w 8.45(66.83), h 2.24(36.50), conf 6.32(9.74), cls 0.41(0.74), total 22.94(153.89)
# 326510: nGT 4, recall 3, proposals 0, loss: x 15.50(20.07), y 1.16(19.83), w 22.68(66.48), h 7.28(36.27), conf 15.00(9.78), cls 0.66(0.74), total 62.28(153.17)
# 326514: nGT 3, recall 0, proposals 0, loss: x 18.24(20.06), y 17.40(19.81), w 190.89(67.45), h 26.75(36.19), conf 5.99(9.75), cls 0.53(0.74), total 259.80(154.00)
# 326518: nGT 4, recall 2, proposals 0, loss: x 11.28(19.99), y 14.38(19.76), w 5.82(66.98), h 2.00(35.93), conf 14.09(9.79), cls 0.55(0.74), total 48.13(153.18)
# 326522: nGT 9, recall 0, proposals 0, loss: x 27.69(20.05), y 27.00(19.82), w 92.95(67.18), h 53.08(36.06), conf 8.58(9.78), cls 1.23(0.74), total 210.53(153.62)
# 326526: nGT 6, recall 0, proposals 0, loss: x 39.28(20.20), y 14.46(19.78), w 26.03(66.86), h 51.95(36.18), conf 3.49(9.73), cls 0.89(0.74), total 136.10(153.49)
# 326530: nGT 7, recall 0, proposals 0, loss: x 41.94(20.36), y 23.70(19.81), w 46.59(66.71), h 42.80(36.23), conf 4.48(9.69), cls 1.18(0.74), total 160.68(153.54)
# 326534: nGT 5, recall 2, proposals 0, loss: x 23.14(20.38), y 14.21(19.77), w 71.36(66.74), h 9.71(36.03), conf 14.50(9.73), cls 0.76(0.74), total 133.68(153.39)
# 326538: nGT 5, recall 0, proposals 0, loss: x 4.12(20.26), y 17.77(19.75), w 26.96(66.45), h 8.30(35.83), conf 6.43(9.70), cls 0.72(0.74), total 64.31(152.73)
# 326542: nGT 5, recall 1, proposals 0, loss: x 26.22(20.31), y 31.44(19.84), w 46.74(66.30), h 51.24(35.94), conf 6.28(9.68), cls 1.11(0.75), total 163.03(152.81)
# 326546: nGT 5, recall 0, proposals 0, loss: x 25.10(20.34), y 15.45(19.81), w 206.38(67.33), h 75.48(36.23), conf 6.07(9.65), cls 0.72(0.75), total 329.20(154.10)
# 326550: nGT 3, recall 1, proposals 0, loss: x 1.92(20.21), y 7.79(19.72), w 29.35(67.05), h 18.07(36.10), conf 6.91(9.63), cls 0.52(0.74), total 64.55(153.45)
# 326554: nGT 4, recall 1, proposals 0, loss: x 1.84(20.07), y 0.94(19.58), w 6.71(66.61), h 2.82(35.86), conf 6.61(9.61), cls 0.30(0.74), total 19.22(152.48)
# 326558: nGT 9, recall 1, proposals 0, loss: x 21.51(20.08), y 12.94(19.53), w 19.69(66.28), h 23.72(35.77), conf 6.96(9.59), cls 0.72(0.74), total 85.54(152.00)
# 326562: nGT 8, recall 1, proposals 0, loss: x 22.29(20.10), y 31.41(19.62), w 9.81(65.87), h 5.11(35.55), conf 11.95(9.61), cls 1.10(0.74), total 81.67(151.49)
# 326566: nGT 5, recall 1, proposals 0, loss: x 23.39(20.12), y 12.71(19.57), w 40.92(65.70), h 46.98(35.63), conf 8.26(9.60), cls 0.77(0.74), total 133.04(151.36)
# 326570: nGT 5, recall 1, proposals 0, loss: x 23.95(20.15), y 14.05(19.53), w 3.28(65.26), h 24.82(35.56), conf 7.42(9.58), cls 0.65(0.74), total 74.16(150.82)
# 326574: nGT 4, recall 1, proposals 0, loss: x 11.94(20.09), y 4.89(19.43), w 13.62(64.90), h 48.33(35.64), conf 7.40(9.57), cls 0.46(0.74), total 86.65(150.37)
# 326578: nGT 5, recall 0, proposals 0, loss: x 21.43(20.10), y 11.86(19.38), w 111.75(65.22), h 193.32(36.74), conf 4.63(9.53), cls 0.82(0.74), total 343.81(151.71)
# 326582: nGT 2, recall 1, proposals 0, loss: x 12.62(20.05), y 5.30(19.28), w 29.11(64.97), h 23.28(36.65), conf 5.54(9.50), cls 0.28(0.74), total 76.14(151.19)
# 326586: nGT 4, recall 1, proposals 0, loss: x 17.05(20.03), y 4.33(19.18), w 34.91(64.77), h 8.17(36.45), conf 5.59(9.48), cls 0.39(0.74), total 70.44(150.64)
# 326590: nGT 4, recall 2, proposals 0, loss: x 5.71(19.93), y 16.56(19.16), w 40.16(64.60), h 31.18(36.42), conf 12.27(9.50), cls 0.79(0.74), total 106.67(150.34)
# 326594: nGT 6, recall 2, proposals 0, loss: x 23.84(19.96), y 14.48(19.13), w 13.53(64.25), h 15.20(36.27), conf 12.37(9.52), cls 1.11(0.74), total 80.52(149.87)
# 326598: nGT 7, recall 1, proposals 0, loss: x 26.82(20.00), y 26.52(19.18), w 102.98(64.51), h 107.06(36.75), conf 6.01(9.49), cls 1.14(0.74), total 270.52(150.68)
# 326602: nGT 4, recall 2, proposals 0, loss: x 2.66(19.89), y 9.05(19.11), w 21.33(64.23), h 26.58(36.68), conf 10.29(9.50), cls 0.67(0.74), total 70.58(150.14)
# 326606: nGT 4, recall 0, proposals 0, loss: x 23.13(19.91), y 3.18(19.00), w 45.02(64.10), h 80.60(36.97), conf 1.66(9.45), cls 0.77(0.74), total 154.37(150.17)
# 326610: nGT 3, recall 0, proposals 0, loss: x 10.12(19.85), y 4.12(18.91), w 8.08(63.73), h 2.59(36.74), conf 3.50(9.41), cls 0.42(0.74), total 28.82(149.37)
# 326614: nGT 2, recall 0, proposals 0, loss: x 14.71(19.81), y 2.11(18.80), w 0.81(63.32), h 2.38(36.52), conf 2.99(9.36), cls 0.22(0.74), total 23.22(148.55)
# 326618: nGT 0, recall 0, proposals 0, loss: x 0.00(19.68), y 0.00(18.67), w 0.00(62.91), h 0.00(36.28), conf 1.24(9.31), cls 0.00(0.73), total 1.24(147.59)
# 326622: nGT 9, recall 3, proposals 0, loss: x 21.91(19.70), y 42.17(18.83), w 54.43(62.85), h 13.90(36.14), conf 15.93(9.35), cls 0.97(0.73), total 149.33(147.60)
# 326626: nGT 5, recall 1, proposals 0, loss: x 14.91(19.67), y 5.88(18.74), w 18.80(62.57), h 3.57(35.93), conf 5.79(9.33), cls 0.41(0.73), total 49.35(146.97)

# %%
# 348
### Save checkpoint
epoch = begin_epoch-1
state = {
  'epoch': epoch,
  'state_dict': model.state_dict(),
  'optimizer': optimizer.state_dict(),# aa
  'fscore': 0 ##
  }
is_best = False
save_checkpoint(state, is_best, backupdir, namedataset+'_manual_tune5_coord100_ob25_e'+str(epoch), clip_duration)
# save_checkpoint(state, is_best, backupdir, namedataset+'_manual_tune_1_'+str(epoch), clip_duration)
# manual 1: coord_scale = class_scale = 0.1, result: l_cls = 0.1, l_
logging('Weights are saved to backup directory: %s' % (backupdir))
# Out:
# 2021-01-23 06:44:02 Weights are saved to backup directory: /content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/backup

# %% [markdown]
# # Test tuning

# %%
epoch = checkpoint['epoch']
epoch
# Out:
# 4

# %%
namedataset = 'jaad'
evaluate = True
# if opt.evaluate:
if evaluate == True:
    logging('evaluating ...')
    # classification_accuracy, localization_recall, precision, recall, fscore = test(0) # 0 means evaluation, >0 means test at that epoch
# Validate the model
    classification_accuracy, localization_recall, precision, recall, fscore = test(epoch)

    # is_best = fscore > best_fscore
    # if is_best:
    #     print("New best fscore is achieved: ", fscore)
    #     print("Previous fscore was: ", best_fscore)
    #     best_fscore = fscore



    # Save the model to backup directory
    state = {
        'epoch': epoch,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'fscore': fscore
        }
    is_best = False
    save_checkpoint(state, is_best, backupdir, namedataset+'_vali_auto_1_'+str(epoch), clip_duration)
    # save_checkpoint(state, is_best, backupdir, opt.dataset, clip_duration)
    # save_checkpoint(state, is_best, backupdir, namedataset, clip_duration)
    
    logging('Weights are saved to backup directory: %s' % (backupdir))
    # Save the evaluation result
    eval_result = {'class_acc': classification_accuracy,
                  'loc_recall': localization_recall, 
                  'precision': precision, 
                  'recall': recall, 
                  'fscore': fscore} 
    fileout = 'jaad_eval_result_auto_e' + str(epoch)
    import json
    with open(f'./jaad_detections/{fileout}.json', 'w') as fp:
        json.dump(eval_result, fp)
# Out:
# 2021-01-19 17:00:40 evaluating ...
# 2021-01-19 17:00:41 validation at epoch 4
# /content/drive/MyDrive/NLP_and_CV_Projects/CV/Model/YOWO/utils.py:280: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   cls_confs = torch.nn.Softmax()(Variable(output[5:5+num_classes].transpose(0,1))).data #softmax_class
# 2021-01-19 17:00:47 [0/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:49 [1/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:51 [2/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:52 [3/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:54 [4/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:56 [5/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:57 [6/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:00:59 [7/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:00 [8/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:02 [9/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:04 [10/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:05 [11/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:07 [12/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:09 [13/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:11 [14/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:13 [15/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:16 [16/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:18 [17/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:21 [18/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:24 [19/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:26 [20/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:29 [21/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:31 [22/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:33 [23/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:35 [24/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:37 [25/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:39 [26/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:41 [27/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:43 [28/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:45 [29/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:47 [30/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:49 [31/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:51 [32/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:53 [33/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:55 [34/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:56 [35/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:58 [36/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:01:59 [37/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:01 [38/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:02 [39/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:04 [40/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:05 [41/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:07 [42/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:09 [43/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:10 [44/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:13 [45/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:15 [46/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:16 [47/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:19 [48/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:21 [49/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:23 [50/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:26 [51/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:28 [52/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:30 [53/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:32 [54/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:35 [55/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:37 [56/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
# 2021-01-19 17:02:39 [57/2126] precision: 0.000000, recall: 0.000000, fscore: 0.000000
