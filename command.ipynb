# %%
import os
os.chdir('/content/drive/MyDrive/NLP_and_CV_Projects/CV/Tuyen/YOWO/')

# %%
import torch

# %%
3Dmodel = '/content/drive/MyDrive/NLP_and_CV_Projects/CV/Tuyen/YOWO/backup/yowo_ucf101-24_16f_best.pth'

# %%
# !python video_mAP.py --dataset ucf101-24 \
	 				--data_cfg cfg/ucf24.data \
	 				--cfg_file cfg/ucf24.cfg \
	 				--n_classes 10 \
	 				--backbone_3d resnext101 \
	 				--backbone_2d darknet \
	 				--resume_path /content/drive/MyDrive/NLP_and_CV_Projects/CV/Tuyen/YOWO/backup/yowo_ucf101-24_16f_best.pth \
# Out:
# DataParallel(
#   (module): YOWO(
#     (backbone_2d): Darknet(
#       (models): ModuleList(
#         (0): Sequential(
#           (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (leaky1): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): Sequential(
#           (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (leaky2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (4): Sequential(
# ...

# %%
pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/111/NLP_and_CV_Projects/CV/Tuyen/YOWO'
